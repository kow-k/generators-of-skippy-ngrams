# %% [markdown]
# # Generator of (inclusive) (extended) (skippy) n-grams out of words or sentences
#
# developed by Kow Kuroda (kow.kuroda@gmail.com)
#
# Limitations
# - Cython-enhancement is effective only on non-Apple Silicons with Python 3.10, 3.11 and 3.12.
#
# Creation
# - 2025/08/19
#
# Modifications
# - None

# %% [markdown]
# # Set up data

# %%
analyze_words = True # if False, analyze sentential/phrasal objects

# %%
import pathlib
if analyze_words:
    data_dir = 'data/words'
    files = list(pathlib.Path(data_dir).glob('buddhist-listed2.txt'))
else:
    data_dir = 'data/phrases'
    files = list(pathlib.Path(data_dir).glob('austen-j-sample100.txt'))
##
print(files)

##
file = files[0]
source_name = file.stem
print(f"source_name: {source_name}")
# Out:
# [PosixPath('data/words/buddhist-listed2.txt')]
# source_name: buddhist-listed2

# %%
## get data
docs = file.read_text(encoding = 'utf-8').splitlines()

## lowercase
docs = [ doc.lower() for doc in docs if len(doc) > 0 ]
print(docs[:10])
# Out:
# ['阿羅漢', '辟支仏', '転法輪', '十二因縁', '五蘊盛苦', '三法印', '四念処', '四神足', '五根五力', '七覚支']

# %% [markdown]
# # Set up Cython

# %%
#conda update -n base -c defaults conda -y

# %%
## Cython の導入 (必要に応じて)
#!conda uninstall cython -y # seems necessary in certain situations
#!conda install cython -y
## Try the following if the above fails
#!pip install cython --upgrade --force-reinstall
#!conda update -n base -c defaults conda -y

# %%
#!pip show cython

# %%
## Cython を使うかどうか
use_Cython = True

# %%
## run the follwing only once before you use Cython
if use_Cython:
    # !rm -rf build dist *.c *.so
    # !python setup.py clean build_ext --inplace
# Out:
# Compiling gen_ngrams_cy.py because it changed.
# [1/1] Cythonizing gen_ngrams_cy.py
# /Users/kowk/opt/anaconda3/lib/python3.11/site-packages/Cython/Compiler/Main.py:381: FutureWarning: Cython directive 'language_level' not set, using '3str' for now (Py3). This has changed from earlier releases! File: /Users/kowk/Dropbox/GitHub/skippy-ngrams-generators/gen_ngrams_cy.py
#   tree = Parsing.p_module(s, pxd, full_module_name)
# running clean
# running build_ext
# building 'gen_ngrams_cy' extension
# creating build
# creating build/temp.macosx-10.15-x86_64-cpython-311
# clang -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/kowk/opt/anaconda3/include -fPIC -O2 -isystem /Users/kowk/opt/anaconda3/include -I/usr/local/include -I/usr/local/opt/llvm/include -I/Users/kowk/opt/anaconda3/include/python3.11 -c gen_ngrams_cy.c -o build/temp.macosx-10.15-x86_64-cpython-311/gen_ngrams_cy.o
# creating build/lib.macosx-10.15-x86_64-cpython-311
# clang -bundle -undefined dynamic_lookup -Wl,-rpath,/Users/kowk/opt/anaconda3/lib -L/Users/kowk/opt/anaconda3/lib -Wl,-rpath,/Users/kowk/opt/anaconda3/lib -L/Users/kowk/opt/anaconda3/lib -L/Library/Developer/CommandLineTools/SDKs/MacOSX.sdk/usr/lib -L/usr/local/lib -L/usr/local/opt/llvm/lib -I/usr/local/include -I/usr/local/opt/llvm/include build/temp.macosx-10.15-x86_64-cpython-311/gen_ngrams_cy.o -o build/lib.macosx-10.15-x86_64-cpython-311/gen_ngrams_cy.cpython-311-darwin.so
# ld: warning: dylib (/usr/local/opt/llvm/lib/libunwind.dylib) was built for newer macOS version (11.0) than being linked (10.15)
# ld: warning: dylib (/usr/local/opt/llvm/lib/libunwind.dylib) was built for newer macOS version (11.0) than being linked (10.15)
# copying build/lib.macosx-10.15-x86_64-cpython-311/gen_ngrams_cy.cpython-311-darwin.so ->

# %%
if use_Cython:
    try:
        # %reload_ext Cython
    except ImportError:
        # %load_ext Cython
    ## The following works with 3.10 on M1, but not with 3.11, 3.12 on Apple Silicons
    import gen_ngrams_cy as gen_ngrams
else:
    import gen_ngrams

# %% [markdown]
# # Generation of (extended) (skippy) n-grams

# %%
## parameters
if analyze_words:
    segmenter: str = r""
    sep_local: str = ""
else:
    segmenter: str = r" "
    sep_local: str = " "

# %%
## flags
check: bool = False
generated_as_string: bool = True
generated_as_list: bool = not(generated_as_string)

# %%
## saving results
save_results: bool = False
save_dir: str = "saves"

# %%
#!conda install pandas -y

# %%
max_n_for_ngram: int = 5

# %%
import pandas as pd
columns0 = ['doc']
columns1 = [ f"{i}g" for i in range(1, max_n_for_ngram + 1)]
columns2 = [ f"sk{i}g" for i in range(1, max_n_for_ngram + 1)]
columns3 = [ f"xsk{i}g" for i in range(1, max_n_for_ngram + 1)]

used_columns = columns0 + columns1 + columns2 + columns3
df = pd.DataFrame(columns = used_columns)

# %%
## generate regular n-grams
import re
for i, doc in enumerate(docs):
    ## update df for word
    df.loc[i,'doc'] = doc
    ##
    print(f"Processing word {i}: {doc} [use_Cython: {use_Cython}]")
    word_segs = [ x for x in re.split(segmenter, doc) if len(x) > 0 ]
    if len(word_segs) > 1:
        for j in range(1, max_n_for_ngram + 1):
            print(f"generating {j}-grams ...")
            ngrams = gen_ngrams.gen_ngrams(word_segs, j, sep = sep_local, as_list = generated_as_list, check = False)
            if check:
                print(ngrams)
            ## update df
            df.loc[i, f'{j}g'] = ngrams
# Out:
# Processing word 0: 阿羅漢 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 1: 辟支仏 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 2: 転法輪 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 3: 十二因縁 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 4: 五蘊盛苦 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 5: 三法印 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 6: 四念処 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 7: 四神足 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 8: 五根五力 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 9: 七覚支 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 10: 三十七道品 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 11: 十善戒 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 12: 六神通 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 13: 四無量心 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 14: 慈悲喜捨 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 15: 八風不動 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 16: 不退転 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 17: 阿耨多羅三藐三菩提 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 18: 一切智 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 19: 無生法忍 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 20: 止観双修 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 21: 四禅定 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 22: 九次第定 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 23: 滅尽定 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 24: 無想定 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 25: 観呼吸 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 26: 観身不浄 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 27: 数息観 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 28: 白骨観 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 29: 不浄観 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 30: 慈心観 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 31: 因縁観 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 32: 念死観 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 33: 随念三宝 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 34: 経行禅 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 35: 立禅法 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 36: 食禅法 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 37: 作務禅 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 38: 公案禅 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 39: 只管打坐 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 40: 阿含経 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 41: 大般涅槃経 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 42: 大日経 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 43: 金剛頂経 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 44: 理趣経 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 45: 観音経 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 46: 地蔵経 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 47: 薬師経 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 48: 無量寿経 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 49: 観無量寿経 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 50: 倶舎論 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 51: 成実論 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 52: 大智度論 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 53: 中論頌 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 54: 唯識論 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 55: 起信論 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 56: 摩訶止観 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 57: 法界次第 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 58: 禅源諸詮集 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 59: 景徳伝灯録 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 60: 小乗仏教 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 61: 大乗仏教 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 62: 金剛乗 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 63: 秘密仏教 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 64: 南都六宗 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 65: 三論宗 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 66: 成実宗 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 67: 俱舎宗 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 68: 法相宗 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 69: 律宗派 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 70: 時宗派 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 71: 融通念仏宗 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 72: 一遍上人 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 73: 親鸞聖人 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 74: 法然上人 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 75: 道元禅師 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 76: 栄西禅師 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 77: 空海大師 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 78: 最澄大師 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 79: 鑑真和上 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 80: 開眼供養 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 81: 入仏供養 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 82: 落慶法要 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 83: 授戒会 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 84: 結縁灌頂 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 85: 伝法灌頂 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 86: 護摩供養 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 87: 千体仏供養 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 88: 水子供養 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 89: 先祖供養 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 90: 施餓鬼会 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 91: 大施食会 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 92: 盆踊り [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 93: 精霊流し [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 94: 迎え火 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 95: 送り火 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 96: 棚経参り [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 97: お数珠 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 98: 線香供養 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 99: 献花供養 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 100: 五重塔 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 101: 三重塔 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 102: 多宝塔 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 103: 仏舎利塔 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 104: 観音堂 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 105: 薬師堂 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 106: 阿弥陀堂 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 107: 大雄宝殿 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 108: 法堂建築 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 109: 禅堂建築 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 110: 客殿建築 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 111: 庫裏建築 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 112: 山門建築 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 113: 鐘楼建築 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 114: 経蔵建築 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 115: 宝蔵建築 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 116: 石庭造園 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 117: 枯山水 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 118: 借景技法 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 119: 禅庭設計 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 120: 千手観音 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 121: 十一面観音 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 122: 馬頭観音 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 123: 如意輪観音 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 124: 准胝観音 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 125: 不空羂索観音 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 126: 聖観音菩薩 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 127: 勢至菩薩 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 128: 文殊菩薩 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 129: 普賢菩薩 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 130: 弥勒菩薩 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 131: 薬王菩薩 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 132: 薬上菩薩 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 133: 虚空蔵菩薩 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 134: 大勢至菩薩 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 135: 金剛界曼荼羅 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 136: 胎蔵界曼荼羅 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 137: 両部曼荼羅 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 138: 八葉蓮華 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 139: 宝相華文様 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 140: 出家得度 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 141: 在家信者 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 142: 優婆塞 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 143: 優婆夷 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 144: 沙弥僧 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 145: 沙弥尼 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 146: 比丘僧 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 147: 比丘尼 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 148: 阿闍梨 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 149: 三蔵法師 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 150: 律師職位 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 151: 禅師職位 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 152: 大僧正 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 153: 僧正職位 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 154: 権僧正 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 155: 少僧都 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 156: 権少僧都 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 157: 法印大和尚 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 158: 伝燈大阿闍梨 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 159: 権大僧都 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 160: 三論教学 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 161: 法相教学 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 162: 華厳教学 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 163: 天台教学 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 164: 真言教学 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 165: 浄土教学 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 166: 禅宗教学 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 167: 日蓮教学 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 168: 唯識思想 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 169: 如来蔵思想 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 170: 本覚思想 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 171: 末法思想 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 172: 易行道 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 173: 難行道 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 174: 聖道門 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 175: 浄土門 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 176: 権教方便 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 177: 実教真実 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 178: 五時八教 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 179: 化法四教 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 180: 降誕会法要 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 181: 成道会法要 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 182: 涅槃会法要 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 183: 春彼岸法要 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 184: 秋彼岸法要 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 185: 盂蘭盆会 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 186: 十夜法要 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 187: 修正会法要 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 188: 節分会法要 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 189: 灌仏会法要 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 190: 花祭り行事 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 191: 除夜の鐘 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 192: 初詣参拝 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 193: 初護摩法要 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 194: 開山忌法要 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 195: 両祖忌法要 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 196: 宗祖忌法要 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 197: 御会式法要 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 198: 報恩講法要 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 199: 追悼法要式 [use_Cython: True]
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...

# %%
df
# Out:
#        doc               1g                2g               3g            4g  \
# 0      阿羅漢        [阿, 羅, 漢]          [阿羅, 羅漢]            [阿羅漢]         [阿羅漢]
# 1      辟支仏        [辟, 支, 仏]          [辟支, 支仏]            [辟支仏]         [辟支仏]
# 2      転法輪        [転, 法, 輪]          [転法, 法輪]            [転法輪]         [転法輪]
# 3     十二因縁     [十, 二, 因, 縁]      [十二, 二因, 因縁]       [十二因, 二因縁]        [十二因縁]
# 4     五蘊盛苦     [五, 蘊, 盛, 苦]      [五蘊, 蘊盛, 盛苦]       [五蘊盛, 蘊盛苦]        [五蘊盛苦]
# ..     ...              ...               ...              ...           ...
# 195  両祖忌法要  [両, 祖, 忌, 法, 要]  [両祖, 祖忌, 忌法, 法要]  [両祖忌, 祖忌法, 忌法要]  [両祖忌法, 祖忌法要]
# 196  宗祖忌法要  [宗, 祖, 忌, 法, 要]  [宗祖, 祖忌, 忌法, 法要]  [宗祖忌, 祖忌法, 忌法要]  [宗祖忌法, 祖忌法要]
# 197  御会式法要  [御, 会, 式, 法, 要]  [御会, 会式, 式法, 法要]  [御会式, 会式法, 式法要]  [御会式法, 会式法要]
# 198  報恩講法要  [報, 恩, 講, 法, 要]  [報恩, 恩講, 講法, 法要]  [報恩講, 恩講法, 講法要]  [報恩講法, 恩講法要]
# 199  追悼法要式  [追, 悼, 法, 要, 式]  [追悼, 悼法, 法要, 要式]  [追悼法, 悼法要, 法要式]  [追悼法要, 悼法要式]
#
#           5g sk1g sk2g sk3g sk4g sk5g xsk1g xsk2g xsk3g xsk4g xsk5g
# 0      [阿羅漢]  NaN  NaN  NaN  NaN  NaN   NaN   NaN   NaN   NaN   NaN
# 1      [辟支仏]  NaN  NaN  NaN  NaN  NaN   NaN   NaN   NaN   NaN   NaN
# 2      [転法輪]  NaN  NaN  NaN  NaN  NaN   NaN   NaN   NaN   NaN   NaN
# 3     [十二因縁]  NaN  NaN  NaN  NaN  NaN   NaN   NaN   NaN   NaN   NaN
# 4     [五蘊盛苦]  NaN  NaN  NaN  NaN  NaN   NaN   NaN   NaN   NaN   NaN
# ..       ...  ...  ...  ...  ...  ...   ...   ...   ...   ...   ...
# 195  [両祖忌法要]  NaN  NaN  NaN  NaN  NaN   NaN   NaN   NaN   NaN   NaN
# 196  [宗祖忌法要]  NaN  NaN  NaN  NaN  NaN   NaN   NaN   NaN   NaN   NaN
# 197  [御会式法要]  NaN  NaN  NaN  NaN  NaN   NaN   NaN   NaN   NaN   NaN
# 198  [報恩講法要]  NaN  NaN  NaN  NaN  NaN   NaN   NaN   NaN   NaN   NaN
# 199  [追悼法要式]  NaN  NaN  NaN  NaN  NaN   NaN   NaN   NaN   NaN   NaN
#
# [200 rows x 16 columns]

# %%
## generate skippy n-grams
import re
for i, doc in enumerate(docs):
    print(f"Processing word {i}: {doc} [use_Cython: {use_Cython}]")
    word_segs = [ seg for seg in re.split(segmenter, doc) if len(seg) > 0 ]
    if len(word_segs) > 1:
        for j in range(1, max_n_for_ngram + 1):
            print(f"generating skippy {j}-grams ...")
            ngrams = gen_ngrams.gen_skippy_ngrams(word_segs, j, sep = sep_local, as_list = generated_as_list, check = False)
            if check:
                print(ngrams)
            ## update df
            df.loc[i, f'sk{j}g'] = ngrams
# Out:
# Processing word 0: 阿羅漢 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 1: 辟支仏 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 2: 転法輪 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 3: 十二因縁 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 4: 五蘊盛苦 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 5: 三法印 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 6: 四念処 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 7: 四神足 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 8: 五根五力 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 9: 七覚支 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 10: 三十七道品 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 11: 十善戒 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 12: 六神通 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 13: 四無量心 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 14: 慈悲喜捨 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 15: 八風不動 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 16: 不退転 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 17: 阿耨多羅三藐三菩提 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 18: 一切智 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 19: 無生法忍 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 20: 止観双修 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 21: 四禅定 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 22: 九次第定 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 23: 滅尽定 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 24: 無想定 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 25: 観呼吸 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 26: 観身不浄 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 27: 数息観 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 28: 白骨観 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 29: 不浄観 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 30: 慈心観 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 31: 因縁観 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 32: 念死観 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 33: 随念三宝 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 34: 経行禅 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 35: 立禅法 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 36: 食禅法 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 37: 作務禅 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 38: 公案禅 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 39: 只管打坐 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 40: 阿含経 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 41: 大般涅槃経 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 42: 大日経 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 43: 金剛頂経 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 44: 理趣経 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 45: 観音経 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 46: 地蔵経 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 47: 薬師経 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 48: 無量寿経 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 49: 観無量寿経 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 50: 倶舎論 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 51: 成実論 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 52: 大智度論 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 53: 中論頌 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 54: 唯識論 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 55: 起信論 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 56: 摩訶止観 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 57: 法界次第 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 58: 禅源諸詮集 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 59: 景徳伝灯録 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 60: 小乗仏教 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 61: 大乗仏教 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 62: 金剛乗 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 63: 秘密仏教 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 64: 南都六宗 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 65: 三論宗 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 66: 成実宗 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 67: 俱舎宗 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 68: 法相宗 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 69: 律宗派 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 70: 時宗派 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 71: 融通念仏宗 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 72: 一遍上人 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 73: 親鸞聖人 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 74: 法然上人 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 75: 道元禅師 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 76: 栄西禅師 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 77: 空海大師 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 78: 最澄大師 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 79: 鑑真和上 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 80: 開眼供養 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 81: 入仏供養 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 82: 落慶法要 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 83: 授戒会 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 84: 結縁灌頂 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 85: 伝法灌頂 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 86: 護摩供養 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 87: 千体仏供養 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 88: 水子供養 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 89: 先祖供養 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 90: 施餓鬼会 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 91: 大施食会 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 92: 盆踊り [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 93: 精霊流し [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 94: 迎え火 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 95: 送り火 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 96: 棚経参り [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 97: お数珠 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 98: 線香供養 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 99: 献花供養 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 100: 五重塔 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 101: 三重塔 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 102: 多宝塔 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 103: 仏舎利塔 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 104: 観音堂 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 105: 薬師堂 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 106: 阿弥陀堂 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 107: 大雄宝殿 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 108: 法堂建築 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 109: 禅堂建築 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 110: 客殿建築 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 111: 庫裏建築 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 112: 山門建築 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 113: 鐘楼建築 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 114: 経蔵建築 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 115: 宝蔵建築 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 116: 石庭造園 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 117: 枯山水 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 118: 借景技法 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 119: 禅庭設計 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 120: 千手観音 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 121: 十一面観音 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 122: 馬頭観音 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 123: 如意輪観音 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 124: 准胝観音 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 125: 不空羂索観音 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 126: 聖観音菩薩 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 127: 勢至菩薩 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 128: 文殊菩薩 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 129: 普賢菩薩 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 130: 弥勒菩薩 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 131: 薬王菩薩 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 132: 薬上菩薩 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 133: 虚空蔵菩薩 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 134: 大勢至菩薩 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 135: 金剛界曼荼羅 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 136: 胎蔵界曼荼羅 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 137: 両部曼荼羅 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 138: 八葉蓮華 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 139: 宝相華文様 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 140: 出家得度 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 141: 在家信者 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 142: 優婆塞 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 143: 優婆夷 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 144: 沙弥僧 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 145: 沙弥尼 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 146: 比丘僧 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 147: 比丘尼 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 148: 阿闍梨 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 149: 三蔵法師 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 150: 律師職位 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 151: 禅師職位 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 152: 大僧正 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 153: 僧正職位 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 154: 権僧正 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 155: 少僧都 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 156: 権少僧都 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 157: 法印大和尚 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 158: 伝燈大阿闍梨 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 159: 権大僧都 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 160: 三論教学 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 161: 法相教学 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 162: 華厳教学 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 163: 天台教学 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 164: 真言教学 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 165: 浄土教学 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 166: 禅宗教学 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 167: 日蓮教学 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 168: 唯識思想 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 169: 如来蔵思想 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 170: 本覚思想 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 171: 末法思想 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 172: 易行道 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 173: 難行道 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 174: 聖道門 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 175: 浄土門 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 176: 権教方便 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 177: 実教真実 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 178: 五時八教 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 179: 化法四教 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 180: 降誕会法要 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 181: 成道会法要 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 182: 涅槃会法要 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 183: 春彼岸法要 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 184: 秋彼岸法要 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 185: 盂蘭盆会 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 186: 十夜法要 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 187: 修正会法要 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 188: 節分会法要 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 189: 灌仏会法要 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 190: 花祭り行事 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 191: 除夜の鐘 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 192: 初詣参拝 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 193: 初護摩法要 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 194: 開山忌法要 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 195: 両祖忌法要 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 196: 宗祖忌法要 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 197: 御会式法要 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 198: 報恩講法要 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 199: 追悼法要式 [use_Cython: True]
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...

# %%
df
# Out:
#        doc               1g                2g               3g            4g  \
# 0      阿羅漢        [阿, 羅, 漢]          [阿羅, 羅漢]            [阿羅漢]         [阿羅漢]
# 1      辟支仏        [辟, 支, 仏]          [辟支, 支仏]            [辟支仏]         [辟支仏]
# 2      転法輪        [転, 法, 輪]          [転法, 法輪]            [転法輪]         [転法輪]
# 3     十二因縁     [十, 二, 因, 縁]      [十二, 二因, 因縁]       [十二因, 二因縁]        [十二因縁]
# 4     五蘊盛苦     [五, 蘊, 盛, 苦]      [五蘊, 蘊盛, 盛苦]       [五蘊盛, 蘊盛苦]        [五蘊盛苦]
# ..     ...              ...               ...              ...           ...
# 195  両祖忌法要  [両, 祖, 忌, 法, 要]  [両祖, 祖忌, 忌法, 法要]  [両祖忌, 祖忌法, 忌法要]  [両祖忌法, 祖忌法要]
# 196  宗祖忌法要  [宗, 祖, 忌, 法, 要]  [宗祖, 祖忌, 忌法, 法要]  [宗祖忌, 祖忌法, 忌法要]  [宗祖忌法, 祖忌法要]
# 197  御会式法要  [御, 会, 式, 法, 要]  [御会, 会式, 式法, 法要]  [御会式, 会式法, 式法要]  [御会式法, 会式法要]
# 198  報恩講法要  [報, 恩, 講, 法, 要]  [報恩, 恩講, 講法, 法要]  [報恩講, 恩講法, 講法要]  [報恩講法, 恩講法要]
# 199  追悼法要式  [追, 悼, 法, 要, 式]  [追悼, 悼法, 法要, 要式]  [追悼法, 悼法要, 法要式]  [追悼法要, 悼法要式]
#
#           5g             sk1g                                            sk2g  \
# 0      [阿羅漢]        [阿, 羅, 漢]                                   [阿羅, 阿…漢, 羅漢]
# 1      [辟支仏]        [辟, 支, 仏]                                   [辟支, 辟…仏, 支仏]
# 2      [転法輪]        [転, 法, 輪]                                   [転法, 転…輪, 法輪]
# 3     [十二因縁]     [十, 二, 因, 縁]                     [十二, 十…因, 十…縁, 二因, 二…縁, 因縁]
# 4     [五蘊盛苦]     [五, 蘊, 盛, 苦]                     [五蘊, 五…盛, 五…苦, 蘊盛, 蘊…苦, 盛苦]
# ..       ...              ...                                             ...
# 195  [両祖忌法要]  [両, 祖, 忌, 法, 要]  [両祖, 両…忌, 両…法, 両…要, 祖忌, 祖…法, 祖…要, 忌法, 忌…要, 法要]
# 196  [宗祖忌法要]  [宗, 祖, 忌, 法, 要]  [宗祖, 宗…忌, 宗…法, 宗…要, 祖忌, 祖…法, 祖…要, 忌法, 忌…要, 法要]
# 197  [御会式法要]  [御, 会, 式, 法, 要]  [御会, 御…式, 御…法, 御…要, 会式, 会…法, 会…要, 式法, 式…要, 法要]
# 198  [報恩講法要]  [報, 恩, 講, 法, 要]  [報恩, 報…講, 報…法, 報…要, 恩講, 恩…法, 恩…要, 講法, 講…要, 法要]
# 199  [追悼法要式]  [追, 悼, 法, 要, 式]  [追悼, 追…法, 追…要, 追…式, 悼法, 悼…要, 悼…式, 法要, 法…式, 要式]
#
#                                                   sk3g  \
# 0                                                [阿羅漢]
# 1                                                [辟支仏]
# 2                                                [転法輪]
# 3                               [十二因, 十二…縁, 十…因縁, 二因縁]
# 4                               [五蘊盛, 五蘊…苦, 五…盛苦, 蘊盛苦]
# ..                                                 ...
# 195  [両祖忌, 両祖…法, 両祖…要, 両…忌法, 両…忌…要, 両…法要, 祖忌法, 祖忌…要...
# 196  [宗祖忌, 宗祖…法, 宗祖…要, 宗…忌法, 宗…忌…要, 宗…法要, 祖忌法, 祖忌…要...
# 197  [御会式, 御会…法, 御会…要, 御…式法, 御…式…要, 御…法要, 会式法, 会式…要...
# 198  [報恩講, 報恩…法, 報恩…要, 報…講法, 報…講…要, 報…法要, 恩講法, 恩講…要...
# 199  [追悼法, 追悼…要, 追悼…式, 追…法要, 追…法…式, 追…要式, 悼法要, 悼法…式...
#
#                                   sk4g     sk5g xsk1g xsk2g xsk3g xsk4g xsk5g
# 0                                [阿羅漢]    [阿羅漢]   NaN   NaN   NaN   NaN   NaN
# 1                                [辟支仏]    [辟支仏]   NaN   NaN   NaN   NaN   NaN
# 2                                [転法輪]    [転法輪]   NaN   NaN   NaN   NaN   NaN
# 3                               [十二因縁]   [十二因縁]   NaN   NaN   NaN   NaN   NaN
# 4                               [五蘊盛苦]   [五蘊盛苦]   NaN   NaN   NaN   NaN   NaN
# ..                                 ...      ...   ...   ...   ...   ...   ...
# 195  [両祖忌法, 両祖忌…要, 両祖…法要, 両…忌法要, 祖忌法要]  [両祖忌法要]   NaN   NaN   NaN   NaN   NaN
# 196  [宗祖忌法, 宗祖忌…要, 宗祖…法要, 宗…忌法要, 祖忌法要]  [宗祖忌法要]   NaN   NaN   NaN   NaN   NaN
# 197  [御会式法, 御会式…要, 御会…法要, 御…式法要, 会式法要]  [御会式法要]   NaN   NaN   NaN   NaN   NaN
# 198  [報恩講法, 報恩講…要, 報恩…法要, 報…講法要, 恩講法要]  [報恩講法要]   NaN   NaN   NaN   NaN   NaN
# 199  [追悼法要, 追悼法…式, 追悼…要式, 追…法要式, 悼法要式]  [追悼法要式]   NaN   NaN   NaN   NaN   NaN
#
# [200 rows x 16 columns]

# %%
## generate extended skippy n-grams
import re
for i, doc in enumerate(docs):
    print(f"Processing word {i}: {doc} [use_Cython: {use_Cython}]")
    word_segs = [ seg for seg in re.split(segmenter, doc) if len(seg) > 0 ]
    if len(word_segs) > 1:
        for j in range(1, max_n_for_ngram + 1):
            print(f"generating extended skippy {j}-grams ...")
            ngrams = gen_ngrams.gen_extended_skippy_ngrams(word_segs, j, sep = sep_local, as_list = generated_as_list, check = False)
            if check:
                print(ngrams)
            ## update df
            df.loc[i, f'xsk{j}g'] = ngrams
# Out:
# Processing word 0: 阿羅漢 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 1: 辟支仏 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 2: 転法輪 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 3: 十二因縁 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 4: 五蘊盛苦 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 5: 三法印 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 6: 四念処 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 7: 四神足 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 8: 五根五力 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 9: 七覚支 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 10: 三十七道品 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 11: 十善戒 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 12: 六神通 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 13: 四無量心 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 14: 慈悲喜捨 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 15: 八風不動 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 16: 不退転 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 17: 阿耨多羅三藐三菩提 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 18: 一切智 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 19: 無生法忍 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 20: 止観双修 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 21: 四禅定 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 22: 九次第定 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 23: 滅尽定 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 24: 無想定 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 25: 観呼吸 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 26: 観身不浄 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 27: 数息観 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 28: 白骨観 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 29: 不浄観 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 30: 慈心観 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 31: 因縁観 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 32: 念死観 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 33: 随念三宝 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 34: 経行禅 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 35: 立禅法 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 36: 食禅法 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 37: 作務禅 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 38: 公案禅 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 39: 只管打坐 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 40: 阿含経 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 41: 大般涅槃経 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 42: 大日経 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 43: 金剛頂経 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 44: 理趣経 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 45: 観音経 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 46: 地蔵経 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 47: 薬師経 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 48: 無量寿経 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 49: 観無量寿経 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 50: 倶舎論 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 51: 成実論 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 52: 大智度論 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 53: 中論頌 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 54: 唯識論 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 55: 起信論 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 56: 摩訶止観 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 57: 法界次第 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 58: 禅源諸詮集 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 59: 景徳伝灯録 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 60: 小乗仏教 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 61: 大乗仏教 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 62: 金剛乗 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 63: 秘密仏教 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 64: 南都六宗 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 65: 三論宗 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 66: 成実宗 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 67: 俱舎宗 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 68: 法相宗 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 69: 律宗派 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 70: 時宗派 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 71: 融通念仏宗 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 72: 一遍上人 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 73: 親鸞聖人 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 74: 法然上人 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 75: 道元禅師 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 76: 栄西禅師 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 77: 空海大師 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 78: 最澄大師 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 79: 鑑真和上 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 80: 開眼供養 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 81: 入仏供養 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 82: 落慶法要 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 83: 授戒会 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 84: 結縁灌頂 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 85: 伝法灌頂 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 86: 護摩供養 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 87: 千体仏供養 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 88: 水子供養 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 89: 先祖供養 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 90: 施餓鬼会 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 91: 大施食会 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 92: 盆踊り [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 93: 精霊流し [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 94: 迎え火 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 95: 送り火 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 96: 棚経参り [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 97: お数珠 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 98: 線香供養 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 99: 献花供養 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 100: 五重塔 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 101: 三重塔 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 102: 多宝塔 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 103: 仏舎利塔 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 104: 観音堂 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 105: 薬師堂 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 106: 阿弥陀堂 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 107: 大雄宝殿 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 108: 法堂建築 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 109: 禅堂建築 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 110: 客殿建築 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 111: 庫裏建築 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 112: 山門建築 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 113: 鐘楼建築 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 114: 経蔵建築 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 115: 宝蔵建築 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 116: 石庭造園 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 117: 枯山水 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 118: 借景技法 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 119: 禅庭設計 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 120: 千手観音 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 121: 十一面観音 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 122: 馬頭観音 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 123: 如意輪観音 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 124: 准胝観音 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 125: 不空羂索観音 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 126: 聖観音菩薩 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 127: 勢至菩薩 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 128: 文殊菩薩 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 129: 普賢菩薩 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 130: 弥勒菩薩 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 131: 薬王菩薩 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 132: 薬上菩薩 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 133: 虚空蔵菩薩 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 134: 大勢至菩薩 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 135: 金剛界曼荼羅 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 136: 胎蔵界曼荼羅 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 137: 両部曼荼羅 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 138: 八葉蓮華 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 139: 宝相華文様 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 140: 出家得度 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 141: 在家信者 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 142: 優婆塞 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 143: 優婆夷 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 144: 沙弥僧 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 145: 沙弥尼 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 146: 比丘僧 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 147: 比丘尼 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 148: 阿闍梨 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 149: 三蔵法師 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 150: 律師職位 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 151: 禅師職位 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 152: 大僧正 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 153: 僧正職位 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 154: 権僧正 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 155: 少僧都 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 156: 権少僧都 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 157: 法印大和尚 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 158: 伝燈大阿闍梨 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 159: 権大僧都 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 160: 三論教学 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 161: 法相教学 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 162: 華厳教学 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 163: 天台教学 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 164: 真言教学 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 165: 浄土教学 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 166: 禅宗教学 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 167: 日蓮教学 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 168: 唯識思想 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 169: 如来蔵思想 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 170: 本覚思想 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 171: 末法思想 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 172: 易行道 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 173: 難行道 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 174: 聖道門 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 175: 浄土門 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 176: 権教方便 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 177: 実教真実 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 178: 五時八教 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 179: 化法四教 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 180: 降誕会法要 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 181: 成道会法要 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 182: 涅槃会法要 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 183: 春彼岸法要 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 184: 秋彼岸法要 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 185: 盂蘭盆会 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 186: 十夜法要 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 187: 修正会法要 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 188: 節分会法要 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 189: 灌仏会法要 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 190: 花祭り行事 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 191: 除夜の鐘 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 192: 初詣参拝 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 193: 初護摩法要 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 194: 開山忌法要 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 195: 両祖忌法要 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 196: 宗祖忌法要 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 197: 御会式法要 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 198: 報恩講法要 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 199: 追悼法要式 [use_Cython: True]
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...

# %%
## result
df
# Out:
#        doc               1g                2g               3g            4g  \
# 0      阿羅漢        [阿, 羅, 漢]          [阿羅, 羅漢]            [阿羅漢]         [阿羅漢]
# 1      辟支仏        [辟, 支, 仏]          [辟支, 支仏]            [辟支仏]         [辟支仏]
# 2      転法輪        [転, 法, 輪]          [転法, 法輪]            [転法輪]         [転法輪]
# 3     十二因縁     [十, 二, 因, 縁]      [十二, 二因, 因縁]       [十二因, 二因縁]        [十二因縁]
# 4     五蘊盛苦     [五, 蘊, 盛, 苦]      [五蘊, 蘊盛, 盛苦]       [五蘊盛, 蘊盛苦]        [五蘊盛苦]
# ..     ...              ...               ...              ...           ...
# 195  両祖忌法要  [両, 祖, 忌, 法, 要]  [両祖, 祖忌, 忌法, 法要]  [両祖忌, 祖忌法, 忌法要]  [両祖忌法, 祖忌法要]
# 196  宗祖忌法要  [宗, 祖, 忌, 法, 要]  [宗祖, 祖忌, 忌法, 法要]  [宗祖忌, 祖忌法, 忌法要]  [宗祖忌法, 祖忌法要]
# 197  御会式法要  [御, 会, 式, 法, 要]  [御会, 会式, 式法, 法要]  [御会式, 会式法, 式法要]  [御会式法, 会式法要]
# 198  報恩講法要  [報, 恩, 講, 法, 要]  [報恩, 恩講, 講法, 法要]  [報恩講, 恩講法, 講法要]  [報恩講法, 恩講法要]
# 199  追悼法要式  [追, 悼, 法, 要, 式]  [追悼, 悼法, 法要, 要式]  [追悼法, 悼法要, 法要式]  [追悼法要, 悼法要式]
#
#           5g             sk1g                                            sk2g  \
# 0      [阿羅漢]        [阿, 羅, 漢]                                   [阿羅, 阿…漢, 羅漢]
# 1      [辟支仏]        [辟, 支, 仏]                                   [辟支, 辟…仏, 支仏]
# 2      [転法輪]        [転, 法, 輪]                                   [転法, 転…輪, 法輪]
# 3     [十二因縁]     [十, 二, 因, 縁]                     [十二, 十…因, 十…縁, 二因, 二…縁, 因縁]
# 4     [五蘊盛苦]     [五, 蘊, 盛, 苦]                     [五蘊, 五…盛, 五…苦, 蘊盛, 蘊…苦, 盛苦]
# ..       ...              ...                                             ...
# 195  [両祖忌法要]  [両, 祖, 忌, 法, 要]  [両祖, 両…忌, 両…法, 両…要, 祖忌, 祖…法, 祖…要, 忌法, 忌…要, 法要]
# 196  [宗祖忌法要]  [宗, 祖, 忌, 法, 要]  [宗祖, 宗…忌, 宗…法, 宗…要, 祖忌, 祖…法, 祖…要, 忌法, 忌…要, 法要]
# 197  [御会式法要]  [御, 会, 式, 法, 要]  [御会, 御…式, 御…法, 御…要, 会式, 会…法, 会…要, 式法, 式…要, 法要]
# 198  [報恩講法要]  [報, 恩, 講, 法, 要]  [報恩, 報…講, 報…法, 報…要, 恩講, 恩…法, 恩…要, 講法, 講…要, 法要]
# 199  [追悼法要式]  [追, 悼, 法, 要, 式]  [追悼, 追…法, 追…要, 追…式, 悼法, 悼…要, 悼…式, 法要, 法…式, 要式]
#
#                                                   sk3g  \
# 0                                                [阿羅漢]
# 1                                                [辟支仏]
# 2                                                [転法輪]
# 3                               [十二因, 十二…縁, 十…因縁, 二因縁]
# 4                               [五蘊盛, 五蘊…苦, 五…盛苦, 蘊盛苦]
# ..                                                 ...
# 195  [両祖忌, 両祖…法, 両祖…要, 両…忌法, 両…忌…要, 両…法要, 祖忌法, 祖忌…要...
# 196  [宗祖忌, 宗祖…法, 宗祖…要, 宗…忌法, 宗…忌…要, 宗…法要, 祖忌法, 祖忌…要...
# 197  [御会式, 御会…法, 御会…要, 御…式法, 御…式…要, 御…法要, 会式法, 会式…要...
# 198  [報恩講, 報恩…法, 報恩…要, 報…講法, 報…講…要, 報…法要, 恩講法, 恩講…要...
# 199  [追悼法, 追悼…要, 追悼…式, 追…法要, 追…法…式, 追…要式, 悼法要, 悼法…式...
#
#                                   sk4g     sk5g                xsk1g  \
# 0                                [阿羅漢]    [阿羅漢]          [阿…, 羅…, 漢]
# 1                                [辟支仏]    [辟支仏]          [辟…, 支…, 仏]
# 2                                [転法輪]    [転法輪]          [転…, 法…, 輪]
# 3                               [十二因縁]   [十二因縁]      [十…, 二…, 因…, 縁]
# 4                               [五蘊盛苦]   [五蘊盛苦]      [五…, 蘊…, 盛…, 苦]
# ..                                 ...      ...                  ...
# 195  [両祖忌法, 両祖忌…要, 両祖…法要, 両…忌法要, 祖忌法要]  [両祖忌法要]  [両…, 祖…, 忌…, 法…, 要]
# 196  [宗祖忌法, 宗祖忌…要, 宗祖…法要, 宗…忌法要, 祖忌法要]  [宗祖忌法要]  [宗…, 祖…, 忌…, 法…, 要]
# 197  [御会式法, 御会式…要, 御会…法要, 御…式法要, 会式法要]  [御会式法要]  [御…, 会…, 式…, 法…, 要]
# 198  [報恩講法, 報恩講…要, 報恩…法要, 報…講法要, 恩講法要]  [報恩講法要]  [報…, 恩…, 講…, 法…, 要]
# 199  [追悼法要, 追悼法…式, 追悼…要式, 追…法要式, 悼法要式]  [追悼法要式]  [追…, 悼…, 法…, 要…, 式]
#
#                                                  xsk2g  \
# 0                                       [阿羅…, 阿…漢, 羅漢]
# 1                                       [辟支…, 辟…仏, 支仏]
# 2                                       [転法…, 転…輪, 法輪]
# 3                       [十二…, 十…因…, 十…縁, 二因…, 二…縁, 因縁]
# 4                       [五蘊…, 五…盛…, 五…苦, 蘊盛…, 蘊…苦, 盛苦]
# ..                                                 ...
# 195  [両祖…, 両…忌…, 両…法…, 両…要, 祖忌…, 祖…法…, 祖…要, 忌法…, 忌…...
# 196  [宗祖…, 宗…忌…, 宗…法…, 宗…要, 祖忌…, 祖…法…, 祖…要, 忌法…, 忌…...
# 197  [御会…, 御…式…, 御…法…, 御…要, 会式…, 会…法…, 会…要, 式法…, 式…...
# 198  [報恩…, 報…講…, 報…法…, 報…要, 恩講…, 恩…法…, 恩…要, 講法…, 講…...
# 199  [追悼…, 追…法…, 追…要…, 追…式, 悼法…, 悼…要…, 悼…式, 法要…, 法…...
#
#                                                  xsk3g  \
# 0                                                [阿羅漢]
# 1                                                [辟支仏]
# 2                                                [転法輪]
# 3                           [十…二因…, 十…二…縁, 十…因縁, 二…因縁]
# 4                           [五…蘊盛…, 五…蘊…苦, 五…盛苦, 蘊…盛苦]
# ..                                                 ...
# 195  [両…祖忌…, 両…祖…法…, 両…祖…要, 両…忌法…, 両…忌…要, 両…法要, 祖…忌...
# 196  [宗…祖忌…, 宗…祖…法…, 宗…祖…要, 宗…忌法…, 宗…忌…要, 宗…法要, 祖…忌...
# 197  [御…会式…, 御…会…法…, 御…会…要, 御…式法…, 御…式…要, 御…法要, 会…式...
# 198  [報…恩講…, 報…恩…法…, 報…恩…要, 報…講法…, 報…講…要, 報…法要, 恩…講...
# 199  [追…悼法…, 追…悼…要…, 追…悼…式, 追…法要…, 追…法…式, 追…要式, 悼…法...
#
#                                           xsk4g    xsk5g
# 0                                         [阿羅漢]    [阿羅漢]
# 1                                         [辟支仏]    [辟支仏]
# 2                                         [転法輪]    [転法輪]
# 3                                        [十二因縁]   [十二因縁]
# 4                                        [五蘊盛苦]   [五蘊盛苦]
# ..                                          ...      ...
# 195  [両…祖…忌法…, 両…祖…忌…要, 両…祖…法要, 両…忌…法要, 祖…忌…法要]  [両祖忌法要]
# 196  [宗…祖…忌法…, 宗…祖…忌…要, 宗…祖…法要, 宗…忌…法要, 祖…忌…法要]  [宗祖忌法要]
# 197  [御…会…式法…, 御…会…式…要, 御…会…法要, 御…式…法要, 会…式…法要]  [御会式法要]
# 198  [報…恩…講法…, 報…恩…講…要, 報…恩…法要, 報…講…法要, 恩…講…法要]  [報恩講法要]
# 199  [追…悼…法要…, 追…悼…法…式, 追…悼…要式, 追…法…要式, 悼…法…要式]  [追悼法要式]
#
# [200 rows x 16 columns]

# %%
if save_results:
    file_name = f"{save_dir}/{source_name}-simple-reg-sk-xsk-df.csv"
    df.to_csv(file_name, header = True)

# %% [markdown]
# # Creating inclusive versions

# %%
## create inclusive extended skippy ngrams
import pandas as pd
inclusive_xsk_df = pd.DataFrame()
check = False
for i in range(2, max_n_for_ngram + 1):
    source_col, target_col = f"xsk{i-1}g", f"xsk{i}g"
    if i == 2:
        S = df[source_col]
    else:
        S = inclusive_xsk_df[source_col]
    T = df[target_col]
    ##
    U = []
    for s, t in zip(S, T):
        try:
            r = [ x for x in s if x not in t ]
            if check:
                print(f"r: {sorted(r)}")
            ##
            if len(r) > 0:
                try:
                    u = t + r
                except TypeError:
                    pass
            else:
                u = t
            if check:
                print(f"u: {sorted(u)}")    
        except TypeError:
            pass
        ##
        U.append(u)
    ##
    inclusive_xsk_df.loc[:,target_col] = U
##
inclusive_xsk_df

##
if save_results:
    file_name = f"{save_dir}/{source_name}-inclusive-xsk-df.csv"
    df.to_csv(file_name, header = True, index = False)

# %%
## create inclusive skippy ngrams
import pandas as pd
inclusive_sk_df = pd.DataFrame()
check = False
for i in range(2, max_n_for_ngram + 1):
    source_col, target_col = f"sk{i-1}g", f"sk{i}g"
    if i == 2:
        S = df[source_col]
    else:
        S = inclusive_sk_df[source_col]
    T = df[target_col]
    ##
    U = []
    for s, t in zip(S, T):
        try:
            r = [ x for x in s if x not in t ]
            if check:
                print(f"r: {sorted(r)}")
            ##
            if len(r) > 0:
                try:
                    u = t + r
                except TypeError:
                    pass
            else:
                u = t
            if check:
                print(f"u: {sorted(u)}")    
        except TypeError:
            pass
        ##
        U.append(u)
    ##
    inclusive_sk_df.loc[:,target_col] = U
##
inclusive_sk_df

##
if save_results:
    file_name = f"{save_dir}/{source_name}-inclusive-sk-df.csv"
    df.to_csv(file_name, header = True, index = False)

# %%
## create inclusive regular ngrams
import pandas as pd
inclusive_df = pd.DataFrame()
check = False
for i in range(2, max_n_for_ngram + 1):
    source_col, target_col = f"{i-1}g", f"{i}g"
    U = []
    if i == 2:
        S = df[source_col]
    else:
        S = inclusive_df[source_col]
    T = df[target_col]
    for s, t in zip(S, T):
        try:
            r = [ x for x in s if x not in t ]
            if check:
                print(f"r: {sorted(r)}")
            ##
            if len(r) > 0:
                try:
                    u = t + r
                except TypeError:
                    pass
            else:
                u = t
            if check:
                print(f"u: {sorted(u)}")    
        except TypeError:
            pass
        ##
        U.append(u)
    ##
    inclusive_df.loc[:,target_col] = U
##
inclusive_df

##
if save_results:
    file_name = f"{save_dir}/{source_name}-inclusive-reg-df.csv"
    df.to_csv(file_name, header = True, index = False)

# %% [markdown]
# # end of file
