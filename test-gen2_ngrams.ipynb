# %% [markdown]
# # Generator of (extended) (skippy) n-grams out of words or sentences
#
# developed by Kow Kuroda (kow.kuroda@gmail.com)
#
# This Jupyter notebook demonstrates how to use gen2_ngrams.py (or gen2_ngrams_cy.pyx) developed to enhance the usability of its predecessor "gen_ngrams.py".
#
# There are two main differences from its predecessor. First, gen_skippy_ngrams(..) generates extended skippy n-grams with "extended = True" option. Second, gen_skippy_ngrams(..) cann generate inclusive n-grams, thereby dispensing with incremental generation of n-grams from 1-grams.
#
# Limitations
# - Availablity of Cython-enhancement is limited. Apple Silicons like M1 and M2 (M3 is not tested yet) do not accept it, though it is available under Python 3.10 on M1.
#
# Creation
# - 2025/08/19
#
# Modifications
# - 2025/08/21 minor changes;
# - 2025/08/22 i) minor changes; Cython-enhancement was implemented;

# %% [markdown]
# # Set up Cython

# %%
#conda update -n base -c defaults conda -y

# %%
## Cython の導入 (必要に応じて)
#!conda uninstall cython -y # seems necessary in certain situations
#!conda install cython -y
## Try the following if the above fails
#!pip install cython --upgrade --force-reinstall
#!conda update -n base -c defaults conda -y

# %%
#!pip show cython

# %%
## Cython を使うかどうか
use_Cython = False

# %%
## Cython extension の(再)構築が必要な場合は True に
build_Cython_extension = True
if build_Cython_extension:
    # !python setup.py clean build_ext --inplace
# Out:
# Traceback (most recent call last):
#   File "/Users/kowk/Dropbox/GitHub/generator-of-skippy-ngrams/setup.py", line 4, in <module>
#     setup(ext_modules=cythonize('gen2_ngrams_cy.pyx'))
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Volumes/K/opt/anaconda3/envs/py3.11/lib/python3.11/site-packages/Cython/Build/Dependencies.py", line 978, in cythonize
#     module_list, module_metadata = create_extension_list(
#                                    ^^^^^^^^^^^^^^^^^^^^^^
#   File "/Volumes/K/opt/anaconda3/envs/py3.11/lib/python3.11/site-packages/Cython/Build/Dependencies.py", line 809, in create_extension_list
#     for file in nonempty(sorted(extended_iglob(filepattern)), "'%s' doesn't match any files" % filepattern):
#   File "/Volumes/K/opt/anaconda3/envs/py3.11/lib/python3.11/site-packages/Cython/Build/Dependencies.py", line 80, in nonempty
#     raise ValueError(error_msg)
# ValueError: 'gen2_ngrams_cy.pyx' doesn't match any files

# %%
## Cython 版の読込み
## will not run on Apple Silicons like M1, M2
#if use_Cython:
#    try:
#        %reload_ext Cython
#    except ImportError:
#        %load_ext Cython
#    import gen2_ngrams_cy as gen_ngrams
#else:
#    import gen2_ngrams as gen_ngrams
import gen2_ngrams as gen_ngrams

# %% [markdown]
# # Set up data

# %%
analyze_words = True # if False, analyze sentential/phrasal objects

## parameters for analysis
if analyze_words:
    segmenter: str = r""
    sep_local: str = ""
else:
    segmenter: str = r" "
    sep_local: str = " "

# %%
import pathlib
if analyze_words:
    data_dir = 'data/words'
    files = list(pathlib.Path(data_dir).glob('buddhist-listed2.txt'))
else:
    data_dir = 'data/phrases'
    files = list(pathlib.Path(data_dir).glob('austen-j-sample100.txt'))
##
print(files)

##
file = files[0]
source_name = file.stem
print(f"source_name: {source_name}")
# Out:
# [PosixPath('data/words/buddhist-listed2.txt')]
# source_name: buddhist-listed2

# %%
## get data
docs = file.read_text(encoding = 'utf-8').splitlines()

## lowercase
docs = [ doc.lower() for doc in docs if len(doc) > 0 ]
print(docs[:10])
# Out:
# ['阿羅漢', '辟支仏', '転法輪', '十二因縁', '五蘊盛苦', '三法印', '四念処', '四神足', '五根五力', '七覚支']

# %% [markdown]
# # Generation of (extended) (skippy) n-grams

# %%
## flags
check: bool = False

## saving results
save_results: bool = False
save_dir: str = "saves"

# %%
## n の最大値
max_n_for_ngram: int = 4

## max_gap_size
max_gap_size = 3

## n-gram
ngram_is_inclusive = True
#skippy_means_extended = True

## n-gram を文字列として生成するか否か
generated_as_string: bool = True
generated_as_list: bool = not(generated_as_string)

# %%
#!conda install pandas -y

# %%
import pandas as pd
columns0 = ['doc']
columns1 = [ f"{i}g" for i in range(1, max_n_for_ngram + 1)]
columns2 = [ f"sk{i}g" for i in range(1, max_n_for_ngram + 1)]
columns3 = [ f"xsk{i}g" for i in range(1, max_n_for_ngram + 1)]

used_columns = columns0 + columns1 + columns2 + columns3
df = pd.DataFrame(columns = used_columns)

# %% [markdown]
# ## Extended skippy

# %%
## generate extended skippy n-grams
import re, unicodedata
for i, doc in enumerate(docs):
    ## update df for word
    df.loc[i,'doc'] = doc
    
    print(f"Processing word {i} [use_Cython: {use_Cython}]: {doc}")
    ## Unicode normalization is necessay to proper handling of accents in languages like Irish and Welsh
    word_segs = [ seg for seg in re.split(segmenter, unicodedata.normalize('NFC', doc)) if len(seg) > 0 ]
    for j in range(1, max_n_for_ngram + 1):
        print(f"generating extended skippy {j}-grams ...")
        ngrams = gen_ngrams.gen_skippy_ngrams(word_segs, j, extended = True, inclusive = ngram_is_inclusive, max_gap_size = max_gap_size, sep = sep_local, as_list = generated_as_list, check = False)
        if check:
            print(ngrams)
        ## update df
        df.loc[i, f'xsk{j}g'] = ngrams
# Out:
# Processing word 0 [use_Cython: False]: 阿羅漢
# generating extended skippy 1-grams ...
# #subsegs_full: [['阿', '羅', '漢']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['阿', '羅', '漢']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['阿', '羅', '漢']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['阿', '羅', '漢']]
# Processing word 1 [use_Cython: False]: 辟支仏
# generating extended skippy 1-grams ...
# #subsegs_full: [['辟', '支', '仏']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['辟', '支', '仏']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['辟', '支', '仏']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['辟', '支', '仏']]
# Processing word 2 [use_Cython: False]: 転法輪
# generating extended skippy 1-grams ...
# #subsegs_full: [['転', '法', '輪']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['転', '法', '輪']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['転', '法', '輪']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['転', '法', '輪']]
# Processing word 3 [use_Cython: False]: 十二因縁
# generating extended skippy 1-grams ...
# #subsegs_full: [['十', '二', '因', '縁']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['十', '二', '因', '縁']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['十', '二', '因', '縁']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['十', '二', '因', '縁']]
# Processing word 4 [use_Cython: False]: 五蘊盛苦
# generating extended skippy 1-grams ...
# #subsegs_full: [['五', '蘊', '盛', '苦']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['五', '蘊', '盛', '苦']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['五', '蘊', '盛', '苦']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['五', '蘊', '盛', '苦']]
# Processing word 5 [use_Cython: False]: 三法印
# generating extended skippy 1-grams ...
# #subsegs_full: [['三', '法', '印']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['三', '法', '印']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['三', '法', '印']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['三', '法', '印']]
# Processing word 6 [use_Cython: False]: 四念処
# generating extended skippy 1-grams ...
# #subsegs_full: [['四', '念', '処']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['四', '念', '処']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['四', '念', '処']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['四', '念', '処']]
# Processing word 7 [use_Cython: False]: 四神足
# generating extended skippy 1-grams ...
# #subsegs_full: [['四', '神', '足']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['四', '神', '足']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['四', '神', '足']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['四', '神', '足']]
# Processing word 8 [use_Cython: False]: 五根五力
# generating extended skippy 1-grams ...
# #subsegs_full: [['五', '根', '五', '力']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['五', '根', '五', '力']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['五', '根', '五', '力']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['五', '根', '五', '力']]
# Processing word 9 [use_Cython: False]: 七覚支
# generating extended skippy 1-grams ...
# #subsegs_full: [['七', '覚', '支']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['七', '覚', '支']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['七', '覚', '支']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['七', '覚', '支']]
# Processing word 10 [use_Cython: False]: 三十七道品
# generating extended skippy 1-grams ...
# #subsegs_full: [['三', '十', '七', '道', '品']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['三', '十', '七', '道', '品']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['三', '十', '七', '道', '品']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['三', '十', '七', '道', '品']]
# Processing word 11 [use_Cython: False]: 十善戒
# generating extended skippy 1-grams ...
# #subsegs_full: [['十', '善', '戒']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['十', '善', '戒']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['十', '善', '戒']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['十', '善', '戒']]
# Processing word 12 [use_Cython: False]: 六神通
# generating extended skippy 1-grams ...
# #subsegs_full: [['六', '神', '通']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['六', '神', '通']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['六', '神', '通']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['六', '神', '通']]
# Processing word 13 [use_Cython: False]: 四無量心
# generating extended skippy 1-grams ...
# #subsegs_full: [['四', '無', '量', '心']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['四', '無', '量', '心']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['四', '無', '量', '心']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['四', '無', '量', '心']]
# Processing word 14 [use_Cython: False]: 慈悲喜捨
# generating extended skippy 1-grams ...
# #subsegs_full: [['慈', '悲', '喜', '捨']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['慈', '悲', '喜', '捨']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['慈', '悲', '喜', '捨']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['慈', '悲', '喜', '捨']]
# Processing word 15 [use_Cython: False]: 八風不動
# generating extended skippy 1-grams ...
# #subsegs_full: [['八', '風', '不', '動']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['八', '風', '不', '動']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['八', '風', '不', '動']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['八', '風', '不', '動']]
# Processing word 16 [use_Cython: False]: 不退転
# generating extended skippy 1-grams ...
# #subsegs_full: [['不', '退', '転']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['不', '退', '転']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['不', '退', '転']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['不', '退', '転']]
# Processing word 17 [use_Cython: False]: 阿耨多羅三藐三菩提
# generating extended skippy 1-grams ...
# #subsegs_full: [['阿', '耨', '多', '羅', '三', '藐', '三', '菩', '提']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['阿', '耨', '多', '羅', '三', '藐', '三', '菩', '提']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['阿', '耨', '多', '羅', '三', '藐', '三', '菩', '提']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['阿', '耨', '多', '羅', '三', '藐', '三', '菩', '提']]
# Processing word 18 [use_Cython: False]: 一切智
# generating extended skippy 1-grams ...
# #subsegs_full: [['一', '切', '智']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['一', '切', '智']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['一', '切', '智']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['一', '切', '智']]
# Processing word 19 [use_Cython: False]: 無生法忍
# generating extended skippy 1-grams ...
# #subsegs_full: [['無', '生', '法', '忍']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['無', '生', '法', '忍']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['無', '生', '法', '忍']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['無', '生', '法', '忍']]
# Processing word 20 [use_Cython: False]: 止観双修
# generating extended skippy 1-grams ...
# #subsegs_full: [['止', '観', '双', '修']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['止', '観', '双', '修']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['止', '観', '双', '修']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['止', '観', '双', '修']]
# Processing word 21 [use_Cython: False]: 四禅定
# generating extended skippy 1-grams ...
# #subsegs_full: [['四', '禅', '定']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['四', '禅', '定']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['四', '禅', '定']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['四', '禅', '定']]
# Processing word 22 [use_Cython: False]: 九次第定
# generating extended skippy 1-grams ...
# #subsegs_full: [['九', '次', '第', '定']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['九', '次', '第', '定']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['九', '次', '第', '定']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['九', '次', '第', '定']]
# Processing word 23 [use_Cython: False]: 滅尽定
# generating extended skippy 1-grams ...
# #subsegs_full: [['滅', '尽', '定']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['滅', '尽', '定']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['滅', '尽', '定']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['滅', '尽', '定']]
# Processing word 24 [use_Cython: False]: 無想定
# generating extended skippy 1-grams ...
# #subsegs_full: [['無', '想', '定']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['無', '想', '定']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['無', '想', '定']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['無', '想', '定']]
# Processing word 25 [use_Cython: False]: 観呼吸
# generating extended skippy 1-grams ...
# #subsegs_full: [['観', '呼', '吸']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['観', '呼', '吸']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['観', '呼', '吸']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['観', '呼', '吸']]
# Processing word 26 [use_Cython: False]: 観身不浄
# generating extended skippy 1-grams ...
# #subsegs_full: [['観', '身', '不', '浄']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['観', '身', '不', '浄']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['観', '身', '不', '浄']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['観', '身', '不', '浄']]
# Processing word 27 [use_Cython: False]: 数息観
# generating extended skippy 1-grams ...
# #subsegs_full: [['数', '息', '観']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['数', '息', '観']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['数', '息', '観']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['数', '息', '観']]
# Processing word 28 [use_Cython: False]: 白骨観
# generating extended skippy 1-grams ...
# #subsegs_full: [['白', '骨', '観']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['白', '骨', '観']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['白', '骨', '観']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['白', '骨', '観']]
# Processing word 29 [use_Cython: False]: 不浄観
# generating extended skippy 1-grams ...
# #subsegs_full: [['不', '浄', '観']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['不', '浄', '観']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['不', '浄', '観']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['不', '浄', '観']]
# Processing word 30 [use_Cython: False]: 慈心観
# generating extended skippy 1-grams ...
# #subsegs_full: [['慈', '心', '観']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['慈', '心', '観']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['慈', '心', '観']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['慈', '心', '観']]
# Processing word 31 [use_Cython: False]: 因縁観
# generating extended skippy 1-grams ...
# #subsegs_full: [['因', '縁', '観']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['因', '縁', '観']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['因', '縁', '観']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['因', '縁', '観']]
# Processing word 32 [use_Cython: False]: 念死観
# generating extended skippy 1-grams ...
# #subsegs_full: [['念', '死', '観']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['念', '死', '観']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['念', '死', '観']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['念', '死', '観']]
# Processing word 33 [use_Cython: False]: 随念三宝
# generating extended skippy 1-grams ...
# #subsegs_full: [['随', '念', '三', '宝']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['随', '念', '三', '宝']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['随', '念', '三', '宝']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['随', '念', '三', '宝']]
# Processing word 34 [use_Cython: False]: 経行禅
# generating extended skippy 1-grams ...
# #subsegs_full: [['経', '行', '禅']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['経', '行', '禅']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['経', '行', '禅']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['経', '行', '禅']]
# Processing word 35 [use_Cython: False]: 立禅法
# generating extended skippy 1-grams ...
# #subsegs_full: [['立', '禅', '法']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['立', '禅', '法']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['立', '禅', '法']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['立', '禅', '法']]
# Processing word 36 [use_Cython: False]: 食禅法
# generating extended skippy 1-grams ...
# #subsegs_full: [['食', '禅', '法']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['食', '禅', '法']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['食', '禅', '法']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['食', '禅', '法']]
# Processing word 37 [use_Cython: False]: 作務禅
# generating extended skippy 1-grams ...
# #subsegs_full: [['作', '務', '禅']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['作', '務', '禅']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['作', '務', '禅']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['作', '務', '禅']]
# Processing word 38 [use_Cython: False]: 公案禅
# generating extended skippy 1-grams ...
# #subsegs_full: [['公', '案', '禅']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['公', '案', '禅']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['公', '案', '禅']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['公', '案', '禅']]
# Processing word 39 [use_Cython: False]: 只管打坐
# generating extended skippy 1-grams ...
# #subsegs_full: [['只', '管', '打', '坐']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['只', '管', '打', '坐']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['只', '管', '打', '坐']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['只', '管', '打', '坐']]
# Processing word 40 [use_Cython: False]: 阿含経
# generating extended skippy 1-grams ...
# #subsegs_full: [['阿', '含', '経']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['阿', '含', '経']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['阿', '含', '経']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['阿', '含', '経']]
# Processing word 41 [use_Cython: False]: 大般涅槃経
# generating extended skippy 1-grams ...
# #subsegs_full: [['大', '般', '涅', '槃', '経']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['大', '般', '涅', '槃', '経']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['大', '般', '涅', '槃', '経']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['大', '般', '涅', '槃', '経']]
# Processing word 42 [use_Cython: False]: 大日経
# generating extended skippy 1-grams ...
# #subsegs_full: [['大', '日', '経']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['大', '日', '経']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['大', '日', '経']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['大', '日', '経']]
# Processing word 43 [use_Cython: False]: 金剛頂経
# generating extended skippy 1-grams ...
# #subsegs_full: [['金', '剛', '頂', '経']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['金', '剛', '頂', '経']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['金', '剛', '頂', '経']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['金', '剛', '頂', '経']]
# Processing word 44 [use_Cython: False]: 理趣経
# generating extended skippy 1-grams ...
# #subsegs_full: [['理', '趣', '経']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['理', '趣', '経']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['理', '趣', '経']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['理', '趣', '経']]
# Processing word 45 [use_Cython: False]: 観音経
# generating extended skippy 1-grams ...
# #subsegs_full: [['観', '音', '経']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['観', '音', '経']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['観', '音', '経']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['観', '音', '経']]
# Processing word 46 [use_Cython: False]: 地蔵経
# generating extended skippy 1-grams ...
# #subsegs_full: [['地', '蔵', '経']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['地', '蔵', '経']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['地', '蔵', '経']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['地', '蔵', '経']]
# Processing word 47 [use_Cython: False]: 薬師経
# generating extended skippy 1-grams ...
# #subsegs_full: [['薬', '師', '経']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['薬', '師', '経']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['薬', '師', '経']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['薬', '師', '経']]
# Processing word 48 [use_Cython: False]: 無量寿経
# generating extended skippy 1-grams ...
# #subsegs_full: [['無', '量', '寿', '経']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['無', '量', '寿', '経']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['無', '量', '寿', '経']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['無', '量', '寿', '経']]
# Processing word 49 [use_Cython: False]: 観無量寿経
# generating extended skippy 1-grams ...
# #subsegs_full: [['観', '無', '量', '寿', '経']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['観', '無', '量', '寿', '経']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['観', '無', '量', '寿', '経']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['観', '無', '量', '寿', '経']]
# Processing word 50 [use_Cython: False]: 倶舎論
# generating extended skippy 1-grams ...
# #subsegs_full: [['倶', '舎', '論']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['倶', '舎', '論']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['倶', '舎', '論']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['倶', '舎', '論']]
# Processing word 51 [use_Cython: False]: 成実論
# generating extended skippy 1-grams ...
# #subsegs_full: [['成', '実', '論']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['成', '実', '論']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['成', '実', '論']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['成', '実', '論']]
# Processing word 52 [use_Cython: False]: 大智度論
# generating extended skippy 1-grams ...
# #subsegs_full: [['大', '智', '度', '論']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['大', '智', '度', '論']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['大', '智', '度', '論']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['大', '智', '度', '論']]
# Processing word 53 [use_Cython: False]: 中論頌
# generating extended skippy 1-grams ...
# #subsegs_full: [['中', '論', '頌']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['中', '論', '頌']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['中', '論', '頌']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['中', '論', '頌']]
# Processing word 54 [use_Cython: False]: 唯識論
# generating extended skippy 1-grams ...
# #subsegs_full: [['唯', '識', '論']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['唯', '識', '論']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['唯', '識', '論']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['唯', '識', '論']]
# Processing word 55 [use_Cython: False]: 起信論
# generating extended skippy 1-grams ...
# #subsegs_full: [['起', '信', '論']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['起', '信', '論']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['起', '信', '論']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['起', '信', '論']]
# Processing word 56 [use_Cython: False]: 摩訶止観
# generating extended skippy 1-grams ...
# #subsegs_full: [['摩', '訶', '止', '観']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['摩', '訶', '止', '観']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['摩', '訶', '止', '観']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['摩', '訶', '止', '観']]
# Processing word 57 [use_Cython: False]: 法界次第
# generating extended skippy 1-grams ...
# #subsegs_full: [['法', '界', '次', '第']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['法', '界', '次', '第']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['法', '界', '次', '第']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['法', '界', '次', '第']]
# Processing word 58 [use_Cython: False]: 禅源諸詮集
# generating extended skippy 1-grams ...
# #subsegs_full: [['禅', '源', '諸', '詮', '集']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['禅', '源', '諸', '詮', '集']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['禅', '源', '諸', '詮', '集']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['禅', '源', '諸', '詮', '集']]
# Processing word 59 [use_Cython: False]: 景徳伝灯録
# generating extended skippy 1-grams ...
# #subsegs_full: [['景', '徳', '伝', '灯', '録']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['景', '徳', '伝', '灯', '録']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['景', '徳', '伝', '灯', '録']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['景', '徳', '伝', '灯', '録']]
# Processing word 60 [use_Cython: False]: 小乗仏教
# generating extended skippy 1-grams ...
# #subsegs_full: [['小', '乗', '仏', '教']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['小', '乗', '仏', '教']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['小', '乗', '仏', '教']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['小', '乗', '仏', '教']]
# Processing word 61 [use_Cython: False]: 大乗仏教
# generating extended skippy 1-grams ...
# #subsegs_full: [['大', '乗', '仏', '教']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['大', '乗', '仏', '教']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['大', '乗', '仏', '教']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['大', '乗', '仏', '教']]
# Processing word 62 [use_Cython: False]: 金剛乗
# generating extended skippy 1-grams ...
# #subsegs_full: [['金', '剛', '乗']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['金', '剛', '乗']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['金', '剛', '乗']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['金', '剛', '乗']]
# Processing word 63 [use_Cython: False]: 秘密仏教
# generating extended skippy 1-grams ...
# #subsegs_full: [['秘', '密', '仏', '教']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['秘', '密', '仏', '教']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['秘', '密', '仏', '教']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['秘', '密', '仏', '教']]
# Processing word 64 [use_Cython: False]: 南都六宗
# generating extended skippy 1-grams ...
# #subsegs_full: [['南', '都', '六', '宗']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['南', '都', '六', '宗']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['南', '都', '六', '宗']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['南', '都', '六', '宗']]
# Processing word 65 [use_Cython: False]: 三論宗
# generating extended skippy 1-grams ...
# #subsegs_full: [['三', '論', '宗']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['三', '論', '宗']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['三', '論', '宗']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['三', '論', '宗']]
# Processing word 66 [use_Cython: False]: 成実宗
# generating extended skippy 1-grams ...
# #subsegs_full: [['成', '実', '宗']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['成', '実', '宗']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['成', '実', '宗']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['成', '実', '宗']]
# Processing word 67 [use_Cython: False]: 俱舎宗
# generating extended skippy 1-grams ...
# #subsegs_full: [['俱', '舎', '宗']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['俱', '舎', '宗']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['俱', '舎', '宗']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['俱', '舎', '宗']]
# Processing word 68 [use_Cython: False]: 法相宗
# generating extended skippy 1-grams ...
# #subsegs_full: [['法', '相', '宗']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['法', '相', '宗']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['法', '相', '宗']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['法', '相', '宗']]
# Processing word 69 [use_Cython: False]: 律宗派
# generating extended skippy 1-grams ...
# #subsegs_full: [['律', '宗', '派']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['律', '宗', '派']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['律', '宗', '派']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['律', '宗', '派']]
# Processing word 70 [use_Cython: False]: 時宗派
# generating extended skippy 1-grams ...
# #subsegs_full: [['時', '宗', '派']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['時', '宗', '派']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['時', '宗', '派']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['時', '宗', '派']]
# Processing word 71 [use_Cython: False]: 融通念仏宗
# generating extended skippy 1-grams ...
# #subsegs_full: [['融', '通', '念', '仏', '宗']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['融', '通', '念', '仏', '宗']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['融', '通', '念', '仏', '宗']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['融', '通', '念', '仏', '宗']]
# Processing word 72 [use_Cython: False]: 一遍上人
# generating extended skippy 1-grams ...
# #subsegs_full: [['一', '遍', '上', '人']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['一', '遍', '上', '人']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['一', '遍', '上', '人']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['一', '遍', '上', '人']]
# Processing word 73 [use_Cython: False]: 親鸞聖人
# generating extended skippy 1-grams ...
# #subsegs_full: [['親', '鸞', '聖', '人']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['親', '鸞', '聖', '人']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['親', '鸞', '聖', '人']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['親', '鸞', '聖', '人']]
# Processing word 74 [use_Cython: False]: 法然上人
# generating extended skippy 1-grams ...
# #subsegs_full: [['法', '然', '上', '人']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['法', '然', '上', '人']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['法', '然', '上', '人']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['法', '然', '上', '人']]
# Processing word 75 [use_Cython: False]: 道元禅師
# generating extended skippy 1-grams ...
# #subsegs_full: [['道', '元', '禅', '師']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['道', '元', '禅', '師']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['道', '元', '禅', '師']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['道', '元', '禅', '師']]
# Processing word 76 [use_Cython: False]: 栄西禅師
# generating extended skippy 1-grams ...
# #subsegs_full: [['栄', '西', '禅', '師']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['栄', '西', '禅', '師']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['栄', '西', '禅', '師']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['栄', '西', '禅', '師']]
# Processing word 77 [use_Cython: False]: 空海大師
# generating extended skippy 1-grams ...
# #subsegs_full: [['空', '海', '大', '師']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['空', '海', '大', '師']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['空', '海', '大', '師']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['空', '海', '大', '師']]
# Processing word 78 [use_Cython: False]: 最澄大師
# generating extended skippy 1-grams ...
# #subsegs_full: [['最', '澄', '大', '師']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['最', '澄', '大', '師']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['最', '澄', '大', '師']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['最', '澄', '大', '師']]
# Processing word 79 [use_Cython: False]: 鑑真和上
# generating extended skippy 1-grams ...
# #subsegs_full: [['鑑', '真', '和', '上']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['鑑', '真', '和', '上']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['鑑', '真', '和', '上']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['鑑', '真', '和', '上']]
# Processing word 80 [use_Cython: False]: 開眼供養
# generating extended skippy 1-grams ...
# #subsegs_full: [['開', '眼', '供', '養']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['開', '眼', '供', '養']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['開', '眼', '供', '養']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['開', '眼', '供', '養']]
# Processing word 81 [use_Cython: False]: 入仏供養
# generating extended skippy 1-grams ...
# #subsegs_full: [['入', '仏', '供', '養']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['入', '仏', '供', '養']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['入', '仏', '供', '養']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['入', '仏', '供', '養']]
# Processing word 82 [use_Cython: False]: 落慶法要
# generating extended skippy 1-grams ...
# #subsegs_full: [['落', '慶', '法', '要']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['落', '慶', '法', '要']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['落', '慶', '法', '要']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['落', '慶', '法', '要']]
# Processing word 83 [use_Cython: False]: 授戒会
# generating extended skippy 1-grams ...
# #subsegs_full: [['授', '戒', '会']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['授', '戒', '会']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['授', '戒', '会']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['授', '戒', '会']]
# Processing word 84 [use_Cython: False]: 結縁灌頂
# generating extended skippy 1-grams ...
# #subsegs_full: [['結', '縁', '灌', '頂']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['結', '縁', '灌', '頂']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['結', '縁', '灌', '頂']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['結', '縁', '灌', '頂']]
# Processing word 85 [use_Cython: False]: 伝法灌頂
# generating extended skippy 1-grams ...
# #subsegs_full: [['伝', '法', '灌', '頂']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['伝', '法', '灌', '頂']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['伝', '法', '灌', '頂']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['伝', '法', '灌', '頂']]
# Processing word 86 [use_Cython: False]: 護摩供養
# generating extended skippy 1-grams ...
# #subsegs_full: [['護', '摩', '供', '養']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['護', '摩', '供', '養']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['護', '摩', '供', '養']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['護', '摩', '供', '養']]
# Processing word 87 [use_Cython: False]: 千体仏供養
# generating extended skippy 1-grams ...
# #subsegs_full: [['千', '体', '仏', '供', '養']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['千', '体', '仏', '供', '養']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['千', '体', '仏', '供', '養']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['千', '体', '仏', '供', '養']]
# Processing word 88 [use_Cython: False]: 水子供養
# generating extended skippy 1-grams ...
# #subsegs_full: [['水', '子', '供', '養']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['水', '子', '供', '養']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['水', '子', '供', '養']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['水', '子', '供', '養']]
# Processing word 89 [use_Cython: False]: 先祖供養
# generating extended skippy 1-grams ...
# #subsegs_full: [['先', '祖', '供', '養']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['先', '祖', '供', '養']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['先', '祖', '供', '養']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['先', '祖', '供', '養']]
# Processing word 90 [use_Cython: False]: 施餓鬼会
# generating extended skippy 1-grams ...
# #subsegs_full: [['施', '餓', '鬼', '会']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['施', '餓', '鬼', '会']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['施', '餓', '鬼', '会']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['施', '餓', '鬼', '会']]
# Processing word 91 [use_Cython: False]: 大施食会
# generating extended skippy 1-grams ...
# #subsegs_full: [['大', '施', '食', '会']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['大', '施', '食', '会']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['大', '施', '食', '会']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['大', '施', '食', '会']]
# Processing word 92 [use_Cython: False]: 盆踊り
# generating extended skippy 1-grams ...
# #subsegs_full: [['盆', '踊', 'り']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['盆', '踊', 'り']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['盆', '踊', 'り']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['盆', '踊', 'り']]
# Processing word 93 [use_Cython: False]: 精霊流し
# generating extended skippy 1-grams ...
# #subsegs_full: [['精', '霊', '流', 'し']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['精', '霊', '流', 'し']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['精', '霊', '流', 'し']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['精', '霊', '流', 'し']]
# Processing word 94 [use_Cython: False]: 迎え火
# generating extended skippy 1-grams ...
# #subsegs_full: [['迎', 'え', '火']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['迎', 'え', '火']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['迎', 'え', '火']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['迎', 'え', '火']]
# Processing word 95 [use_Cython: False]: 送り火
# generating extended skippy 1-grams ...
# #subsegs_full: [['送', 'り', '火']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['送', 'り', '火']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['送', 'り', '火']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['送', 'り', '火']]
# Processing word 96 [use_Cython: False]: 棚経参り
# generating extended skippy 1-grams ...
# #subsegs_full: [['棚', '経', '参', 'り']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['棚', '経', '参', 'り']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['棚', '経', '参', 'り']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['棚', '経', '参', 'り']]
# Processing word 97 [use_Cython: False]: お数珠
# generating extended skippy 1-grams ...
# #subsegs_full: [['お', '数', '珠']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['お', '数', '珠']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['お', '数', '珠']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['お', '数', '珠']]
# Processing word 98 [use_Cython: False]: 線香供養
# generating extended skippy 1-grams ...
# #subsegs_full: [['線', '香', '供', '養']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['線', '香', '供', '養']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['線', '香', '供', '養']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['線', '香', '供', '養']]
# Processing word 99 [use_Cython: False]: 献花供養
# generating extended skippy 1-grams ...
# #subsegs_full: [['献', '花', '供', '養']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['献', '花', '供', '養']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['献', '花', '供', '養']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['献', '花', '供', '養']]
# Processing word 100 [use_Cython: False]: 五重塔
# generating extended skippy 1-grams ...
# #subsegs_full: [['五', '重', '塔']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['五', '重', '塔']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['五', '重', '塔']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['五', '重', '塔']]
# Processing word 101 [use_Cython: False]: 三重塔
# generating extended skippy 1-grams ...
# #subsegs_full: [['三', '重', '塔']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['三', '重', '塔']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['三', '重', '塔']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['三', '重', '塔']]
# Processing word 102 [use_Cython: False]: 多宝塔
# generating extended skippy 1-grams ...
# #subsegs_full: [['多', '宝', '塔']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['多', '宝', '塔']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['多', '宝', '塔']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['多', '宝', '塔']]
# Processing word 103 [use_Cython: False]: 仏舎利塔
# generating extended skippy 1-grams ...
# #subsegs_full: [['仏', '舎', '利', '塔']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['仏', '舎', '利', '塔']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['仏', '舎', '利', '塔']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['仏', '舎', '利', '塔']]
# Processing word 104 [use_Cython: False]: 観音堂
# generating extended skippy 1-grams ...
# #subsegs_full: [['観', '音', '堂']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['観', '音', '堂']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['観', '音', '堂']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['観', '音', '堂']]
# Processing word 105 [use_Cython: False]: 薬師堂
# generating extended skippy 1-grams ...
# #subsegs_full: [['薬', '師', '堂']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['薬', '師', '堂']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['薬', '師', '堂']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['薬', '師', '堂']]
# Processing word 106 [use_Cython: False]: 阿弥陀堂
# generating extended skippy 1-grams ...
# #subsegs_full: [['阿', '弥', '陀', '堂']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['阿', '弥', '陀', '堂']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['阿', '弥', '陀', '堂']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['阿', '弥', '陀', '堂']]
# Processing word 107 [use_Cython: False]: 大雄宝殿
# generating extended skippy 1-grams ...
# #subsegs_full: [['大', '雄', '宝', '殿']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['大', '雄', '宝', '殿']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['大', '雄', '宝', '殿']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['大', '雄', '宝', '殿']]
# Processing word 108 [use_Cython: False]: 法堂建築
# generating extended skippy 1-grams ...
# #subsegs_full: [['法', '堂', '建', '築']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['法', '堂', '建', '築']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['法', '堂', '建', '築']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['法', '堂', '建', '築']]
# Processing word 109 [use_Cython: False]: 禅堂建築
# generating extended skippy 1-grams ...
# #subsegs_full: [['禅', '堂', '建', '築']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['禅', '堂', '建', '築']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['禅', '堂', '建', '築']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['禅', '堂', '建', '築']]
# Processing word 110 [use_Cython: False]: 客殿建築
# generating extended skippy 1-grams ...
# #subsegs_full: [['客', '殿', '建', '築']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['客', '殿', '建', '築']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['客', '殿', '建', '築']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['客', '殿', '建', '築']]
# Processing word 111 [use_Cython: False]: 庫裏建築
# generating extended skippy 1-grams ...
# #subsegs_full: [['庫', '裏', '建', '築']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['庫', '裏', '建', '築']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['庫', '裏', '建', '築']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['庫', '裏', '建', '築']]
# Processing word 112 [use_Cython: False]: 山門建築
# generating extended skippy 1-grams ...
# #subsegs_full: [['山', '門', '建', '築']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['山', '門', '建', '築']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['山', '門', '建', '築']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['山', '門', '建', '築']]
# Processing word 113 [use_Cython: False]: 鐘楼建築
# generating extended skippy 1-grams ...
# #subsegs_full: [['鐘', '楼', '建', '築']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['鐘', '楼', '建', '築']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['鐘', '楼', '建', '築']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['鐘', '楼', '建', '築']]
# Processing word 114 [use_Cython: False]: 経蔵建築
# generating extended skippy 1-grams ...
# #subsegs_full: [['経', '蔵', '建', '築']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['経', '蔵', '建', '築']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['経', '蔵', '建', '築']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['経', '蔵', '建', '築']]
# Processing word 115 [use_Cython: False]: 宝蔵建築
# generating extended skippy 1-grams ...
# #subsegs_full: [['宝', '蔵', '建', '築']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['宝', '蔵', '建', '築']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['宝', '蔵', '建', '築']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['宝', '蔵', '建', '築']]
# Processing word 116 [use_Cython: False]: 石庭造園
# generating extended skippy 1-grams ...
# #subsegs_full: [['石', '庭', '造', '園']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['石', '庭', '造', '園']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['石', '庭', '造', '園']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['石', '庭', '造', '園']]
# Processing word 117 [use_Cython: False]: 枯山水
# generating extended skippy 1-grams ...
# #subsegs_full: [['枯', '山', '水']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['枯', '山', '水']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['枯', '山', '水']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['枯', '山', '水']]
# Processing word 118 [use_Cython: False]: 借景技法
# generating extended skippy 1-grams ...
# #subsegs_full: [['借', '景', '技', '法']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['借', '景', '技', '法']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['借', '景', '技', '法']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['借', '景', '技', '法']]
# Processing word 119 [use_Cython: False]: 禅庭設計
# generating extended skippy 1-grams ...
# #subsegs_full: [['禅', '庭', '設', '計']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['禅', '庭', '設', '計']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['禅', '庭', '設', '計']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['禅', '庭', '設', '計']]
# Processing word 120 [use_Cython: False]: 千手観音
# generating extended skippy 1-grams ...
# #subsegs_full: [['千', '手', '観', '音']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['千', '手', '観', '音']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['千', '手', '観', '音']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['千', '手', '観', '音']]
# Processing word 121 [use_Cython: False]: 十一面観音
# generating extended skippy 1-grams ...
# #subsegs_full: [['十', '一', '面', '観', '音']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['十', '一', '面', '観', '音']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['十', '一', '面', '観', '音']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['十', '一', '面', '観', '音']]
# Processing word 122 [use_Cython: False]: 馬頭観音
# generating extended skippy 1-grams ...
# #subsegs_full: [['馬', '頭', '観', '音']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['馬', '頭', '観', '音']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['馬', '頭', '観', '音']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['馬', '頭', '観', '音']]
# Processing word 123 [use_Cython: False]: 如意輪観音
# generating extended skippy 1-grams ...
# #subsegs_full: [['如', '意', '輪', '観', '音']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['如', '意', '輪', '観', '音']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['如', '意', '輪', '観', '音']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['如', '意', '輪', '観', '音']]
# Processing word 124 [use_Cython: False]: 准胝観音
# generating extended skippy 1-grams ...
# #subsegs_full: [['准', '胝', '観', '音']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['准', '胝', '観', '音']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['准', '胝', '観', '音']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['准', '胝', '観', '音']]
# Processing word 125 [use_Cython: False]: 不空羂索観音
# generating extended skippy 1-grams ...
# #subsegs_full: [['不', '空', '羂', '索', '観', '音']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['不', '空', '羂', '索', '観', '音']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['不', '空', '羂', '索', '観', '音']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['不', '空', '羂', '索', '観', '音']]
# Processing word 126 [use_Cython: False]: 聖観音菩薩
# generating extended skippy 1-grams ...
# #subsegs_full: [['聖', '観', '音', '菩', '薩']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['聖', '観', '音', '菩', '薩']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['聖', '観', '音', '菩', '薩']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['聖', '観', '音', '菩', '薩']]
# Processing word 127 [use_Cython: False]: 勢至菩薩
# generating extended skippy 1-grams ...
# #subsegs_full: [['勢', '至', '菩', '薩']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['勢', '至', '菩', '薩']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['勢', '至', '菩', '薩']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['勢', '至', '菩', '薩']]
# Processing word 128 [use_Cython: False]: 文殊菩薩
# generating extended skippy 1-grams ...
# #subsegs_full: [['文', '殊', '菩', '薩']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['文', '殊', '菩', '薩']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['文', '殊', '菩', '薩']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['文', '殊', '菩', '薩']]
# Processing word 129 [use_Cython: False]: 普賢菩薩
# generating extended skippy 1-grams ...
# #subsegs_full: [['普', '賢', '菩', '薩']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['普', '賢', '菩', '薩']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['普', '賢', '菩', '薩']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['普', '賢', '菩', '薩']]
# Processing word 130 [use_Cython: False]: 弥勒菩薩
# generating extended skippy 1-grams ...
# #subsegs_full: [['弥', '勒', '菩', '薩']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['弥', '勒', '菩', '薩']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['弥', '勒', '菩', '薩']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['弥', '勒', '菩', '薩']]
# Processing word 131 [use_Cython: False]: 薬王菩薩
# generating extended skippy 1-grams ...
# #subsegs_full: [['薬', '王', '菩', '薩']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['薬', '王', '菩', '薩']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['薬', '王', '菩', '薩']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['薬', '王', '菩', '薩']]
# Processing word 132 [use_Cython: False]: 薬上菩薩
# generating extended skippy 1-grams ...
# #subsegs_full: [['薬', '上', '菩', '薩']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['薬', '上', '菩', '薩']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['薬', '上', '菩', '薩']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['薬', '上', '菩', '薩']]
# Processing word 133 [use_Cython: False]: 虚空蔵菩薩
# generating extended skippy 1-grams ...
# #subsegs_full: [['虚', '空', '蔵', '菩', '薩']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['虚', '空', '蔵', '菩', '薩']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['虚', '空', '蔵', '菩', '薩']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['虚', '空', '蔵', '菩', '薩']]
# Processing word 134 [use_Cython: False]: 大勢至菩薩
# generating extended skippy 1-grams ...
# #subsegs_full: [['大', '勢', '至', '菩', '薩']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['大', '勢', '至', '菩', '薩']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['大', '勢', '至', '菩', '薩']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['大', '勢', '至', '菩', '薩']]
# Processing word 135 [use_Cython: False]: 金剛界曼荼羅
# generating extended skippy 1-grams ...
# #subsegs_full: [['金', '剛', '界', '曼', '荼', '羅']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['金', '剛', '界', '曼', '荼', '羅']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['金', '剛', '界', '曼', '荼', '羅']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['金', '剛', '界', '曼', '荼', '羅']]
# Processing word 136 [use_Cython: False]: 胎蔵界曼荼羅
# generating extended skippy 1-grams ...
# #subsegs_full: [['胎', '蔵', '界', '曼', '荼', '羅']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['胎', '蔵', '界', '曼', '荼', '羅']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['胎', '蔵', '界', '曼', '荼', '羅']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['胎', '蔵', '界', '曼', '荼', '羅']]
# Processing word 137 [use_Cython: False]: 両部曼荼羅
# generating extended skippy 1-grams ...
# #subsegs_full: [['両', '部', '曼', '荼', '羅']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['両', '部', '曼', '荼', '羅']]
# generating extended skippy 3-grams ...
# ...
# generating extended skippy 4-grams ...
# #subsegs_full: [['少', '僧', '都']]
# Processing word 156 [use_Cython: False]: 権少僧都
# generating extended skippy 1-grams ...
# #subsegs_full: [['権', '少', '僧', '都']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['権', '少', '僧', '都']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['権', '少', '僧', '都']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['権', '少', '僧', '都']]
# Processing word 157 [use_Cython: False]: 法印大和尚
# generating extended skippy 1-grams ...
# #subsegs_full: [['法', '印', '大', '和', '尚']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['法', '印', '大', '和', '尚']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['法', '印', '大', '和', '尚']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['法', '印', '大', '和', '尚']]
# Processing word 158 [use_Cython: False]: 伝燈大阿闍梨
# generating extended skippy 1-grams ...
# #subsegs_full: [['伝', '燈', '大', '阿', '闍', '梨']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['伝', '燈', '大', '阿', '闍', '梨']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['伝', '燈', '大', '阿', '闍', '梨']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['伝', '燈', '大', '阿', '闍', '梨']]
# Processing word 159 [use_Cython: False]: 権大僧都
# generating extended skippy 1-grams ...
# #subsegs_full: [['権', '大', '僧', '都']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['権', '大', '僧', '都']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['権', '大', '僧', '都']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['権', '大', '僧', '都']]
# Processing word 160 [use_Cython: False]: 三論教学
# generating extended skippy 1-grams ...
# #subsegs_full: [['三', '論', '教', '学']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['三', '論', '教', '学']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['三', '論', '教', '学']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['三', '論', '教', '学']]
# Processing word 161 [use_Cython: False]: 法相教学
# generating extended skippy 1-grams ...
# #subsegs_full: [['法', '相', '教', '学']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['法', '相', '教', '学']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['法', '相', '教', '学']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['法', '相', '教', '学']]
# Processing word 162 [use_Cython: False]: 華厳教学
# generating extended skippy 1-grams ...
# #subsegs_full: [['華', '厳', '教', '学']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['華', '厳', '教', '学']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['華', '厳', '教', '学']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['華', '厳', '教', '学']]
# Processing word 163 [use_Cython: False]: 天台教学
# generating extended skippy 1-grams ...
# #subsegs_full: [['天', '台', '教', '学']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['天', '台', '教', '学']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['天', '台', '教', '学']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['天', '台', '教', '学']]
# Processing word 164 [use_Cython: False]: 真言教学
# generating extended skippy 1-grams ...
# #subsegs_full: [['真', '言', '教', '学']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['真', '言', '教', '学']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['真', '言', '教', '学']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['真', '言', '教', '学']]
# Processing word 165 [use_Cython: False]: 浄土教学
# generating extended skippy 1-grams ...
# #subsegs_full: [['浄', '土', '教', '学']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['浄', '土', '教', '学']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['浄', '土', '教', '学']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['浄', '土', '教', '学']]
# Processing word 166 [use_Cython: False]: 禅宗教学
# generating extended skippy 1-grams ...
# #subsegs_full: [['禅', '宗', '教', '学']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['禅', '宗', '教', '学']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['禅', '宗', '教', '学']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['禅', '宗', '教', '学']]
# Processing word 167 [use_Cython: False]: 日蓮教学
# generating extended skippy 1-grams ...
# #subsegs_full: [['日', '蓮', '教', '学']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['日', '蓮', '教', '学']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['日', '蓮', '教', '学']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['日', '蓮', '教', '学']]
# Processing word 168 [use_Cython: False]: 唯識思想
# generating extended skippy 1-grams ...
# #subsegs_full: [['唯', '識', '思', '想']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['唯', '識', '思', '想']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['唯', '識', '思', '想']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['唯', '識', '思', '想']]
# Processing word 169 [use_Cython: False]: 如来蔵思想
# generating extended skippy 1-grams ...
# #subsegs_full: [['如', '来', '蔵', '思', '想']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['如', '来', '蔵', '思', '想']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['如', '来', '蔵', '思', '想']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['如', '来', '蔵', '思', '想']]
# Processing word 170 [use_Cython: False]: 本覚思想
# generating extended skippy 1-grams ...
# #subsegs_full: [['本', '覚', '思', '想']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['本', '覚', '思', '想']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['本', '覚', '思', '想']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['本', '覚', '思', '想']]
# Processing word 171 [use_Cython: False]: 末法思想
# generating extended skippy 1-grams ...
# #subsegs_full: [['末', '法', '思', '想']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['末', '法', '思', '想']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['末', '法', '思', '想']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['末', '法', '思', '想']]
# Processing word 172 [use_Cython: False]: 易行道
# generating extended skippy 1-grams ...
# #subsegs_full: [['易', '行', '道']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['易', '行', '道']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['易', '行', '道']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['易', '行', '道']]
# Processing word 173 [use_Cython: False]: 難行道
# generating extended skippy 1-grams ...
# #subsegs_full: [['難', '行', '道']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['難', '行', '道']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['難', '行', '道']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['難', '行', '道']]
# Processing word 174 [use_Cython: False]: 聖道門
# generating extended skippy 1-grams ...
# #subsegs_full: [['聖', '道', '門']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['聖', '道', '門']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['聖', '道', '門']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['聖', '道', '門']]
# Processing word 175 [use_Cython: False]: 浄土門
# generating extended skippy 1-grams ...
# #subsegs_full: [['浄', '土', '門']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['浄', '土', '門']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['浄', '土', '門']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['浄', '土', '門']]
# Processing word 176 [use_Cython: False]: 権教方便
# generating extended skippy 1-grams ...
# #subsegs_full: [['権', '教', '方', '便']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['権', '教', '方', '便']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['権', '教', '方', '便']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['権', '教', '方', '便']]
# Processing word 177 [use_Cython: False]: 実教真実
# generating extended skippy 1-grams ...
# #subsegs_full: [['実', '教', '真', '実']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['実', '教', '真', '実']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['実', '教', '真', '実']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['実', '教', '真', '実']]
# Processing word 178 [use_Cython: False]: 五時八教
# generating extended skippy 1-grams ...
# #subsegs_full: [['五', '時', '八', '教']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['五', '時', '八', '教']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['五', '時', '八', '教']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['五', '時', '八', '教']]
# Processing word 179 [use_Cython: False]: 化法四教
# generating extended skippy 1-grams ...
# #subsegs_full: [['化', '法', '四', '教']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['化', '法', '四', '教']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['化', '法', '四', '教']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['化', '法', '四', '教']]
# Processing word 180 [use_Cython: False]: 降誕会法要
# generating extended skippy 1-grams ...
# #subsegs_full: [['降', '誕', '会', '法', '要']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['降', '誕', '会', '法', '要']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['降', '誕', '会', '法', '要']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['降', '誕', '会', '法', '要']]
# Processing word 181 [use_Cython: False]: 成道会法要
# generating extended skippy 1-grams ...
# #subsegs_full: [['成', '道', '会', '法', '要']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['成', '道', '会', '法', '要']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['成', '道', '会', '法', '要']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['成', '道', '会', '法', '要']]
# Processing word 182 [use_Cython: False]: 涅槃会法要
# generating extended skippy 1-grams ...
# #subsegs_full: [['涅', '槃', '会', '法', '要']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['涅', '槃', '会', '法', '要']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['涅', '槃', '会', '法', '要']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['涅', '槃', '会', '法', '要']]
# Processing word 183 [use_Cython: False]: 春彼岸法要
# generating extended skippy 1-grams ...
# #subsegs_full: [['春', '彼', '岸', '法', '要']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['春', '彼', '岸', '法', '要']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['春', '彼', '岸', '法', '要']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['春', '彼', '岸', '法', '要']]
# Processing word 184 [use_Cython: False]: 秋彼岸法要
# generating extended skippy 1-grams ...
# #subsegs_full: [['秋', '彼', '岸', '法', '要']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['秋', '彼', '岸', '法', '要']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['秋', '彼', '岸', '法', '要']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['秋', '彼', '岸', '法', '要']]
# Processing word 185 [use_Cython: False]: 盂蘭盆会
# generating extended skippy 1-grams ...
# #subsegs_full: [['盂', '蘭', '盆', '会']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['盂', '蘭', '盆', '会']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['盂', '蘭', '盆', '会']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['盂', '蘭', '盆', '会']]
# Processing word 186 [use_Cython: False]: 十夜法要
# generating extended skippy 1-grams ...
# #subsegs_full: [['十', '夜', '法', '要']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['十', '夜', '法', '要']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['十', '夜', '法', '要']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['十', '夜', '法', '要']]
# Processing word 187 [use_Cython: False]: 修正会法要
# generating extended skippy 1-grams ...
# #subsegs_full: [['修', '正', '会', '法', '要']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['修', '正', '会', '法', '要']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['修', '正', '会', '法', '要']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['修', '正', '会', '法', '要']]
# Processing word 188 [use_Cython: False]: 節分会法要
# generating extended skippy 1-grams ...
# #subsegs_full: [['節', '分', '会', '法', '要']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['節', '分', '会', '法', '要']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['節', '分', '会', '法', '要']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['節', '分', '会', '法', '要']]
# Processing word 189 [use_Cython: False]: 灌仏会法要
# generating extended skippy 1-grams ...
# #subsegs_full: [['灌', '仏', '会', '法', '要']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['灌', '仏', '会', '法', '要']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['灌', '仏', '会', '法', '要']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['灌', '仏', '会', '法', '要']]
# Processing word 190 [use_Cython: False]: 花祭り行事
# generating extended skippy 1-grams ...
# #subsegs_full: [['花', '祭', 'り', '行', '事']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['花', '祭', 'り', '行', '事']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['花', '祭', 'り', '行', '事']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['花', '祭', 'り', '行', '事']]
# Processing word 191 [use_Cython: False]: 除夜の鐘
# generating extended skippy 1-grams ...
# #subsegs_full: [['除', '夜', 'の', '鐘']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['除', '夜', 'の', '鐘']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['除', '夜', 'の', '鐘']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['除', '夜', 'の', '鐘']]
# Processing word 192 [use_Cython: False]: 初詣参拝
# generating extended skippy 1-grams ...
# #subsegs_full: [['初', '詣', '参', '拝']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['初', '詣', '参', '拝']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['初', '詣', '参', '拝']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['初', '詣', '参', '拝']]
# Processing word 193 [use_Cython: False]: 初護摩法要
# generating extended skippy 1-grams ...
# #subsegs_full: [['初', '護', '摩', '法', '要']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['初', '護', '摩', '法', '要']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['初', '護', '摩', '法', '要']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['初', '護', '摩', '法', '要']]
# Processing word 194 [use_Cython: False]: 開山忌法要
# generating extended skippy 1-grams ...
# #subsegs_full: [['開', '山', '忌', '法', '要']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['開', '山', '忌', '法', '要']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['開', '山', '忌', '法', '要']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['開', '山', '忌', '法', '要']]
# Processing word 195 [use_Cython: False]: 両祖忌法要
# generating extended skippy 1-grams ...
# #subsegs_full: [['両', '祖', '忌', '法', '要']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['両', '祖', '忌', '法', '要']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['両', '祖', '忌', '法', '要']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['両', '祖', '忌', '法', '要']]
# Processing word 196 [use_Cython: False]: 宗祖忌法要
# generating extended skippy 1-grams ...
# #subsegs_full: [['宗', '祖', '忌', '法', '要']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['宗', '祖', '忌', '法', '要']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['宗', '祖', '忌', '法', '要']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['宗', '祖', '忌', '法', '要']]
# Processing word 197 [use_Cython: False]: 御会式法要
# generating extended skippy 1-grams ...
# #subsegs_full: [['御', '会', '式', '法', '要']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['御', '会', '式', '法', '要']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['御', '会', '式', '法', '要']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['御', '会', '式', '法', '要']]
# Processing word 198 [use_Cython: False]: 報恩講法要
# generating extended skippy 1-grams ...
# #subsegs_full: [['報', '恩', '講', '法', '要']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['報', '恩', '講', '法', '要']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['報', '恩', '講', '法', '要']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['報', '恩', '講', '法', '要']]
# Processing word 199 [use_Cython: False]: 追悼法要式
# generating extended skippy 1-grams ...
# #subsegs_full: [['追', '悼', '法', '要', '式']]
# generating extended skippy 2-grams ...
# #subsegs_full: [['追', '悼', '法', '要', '式']]
# generating extended skippy 3-grams ...
# #subsegs_full: [['追', '悼', '法', '要', '式']]
# generating extended skippy 4-grams ...
# #subsegs_full: [['追', '悼', '法', '要', '式']]

# %%
df[columns0 + columns3]
# Out:
#        doc                    xsk1g  \
# 0      阿羅漢            [阿…, …羅…, …漢]
# 1      辟支仏            [辟…, …支…, …仏]
# 2      転法輪            [転…, …法…, …輪]
# 3     十二因縁       [十…, …二…, …因…, …縁]
# 4     五蘊盛苦       [五…, …蘊…, …盛…, …苦]
# ..     ...                      ...
# 195  両祖忌法要  [両…, …祖…, …忌…, …法…, …要]
# 196  宗祖忌法要  [宗…, …祖…, …忌…, …法…, …要]
# 197  御会式法要  [御…, …会…, …式…, …法…, …要]
# 198  報恩講法要  [報…, …恩…, …講…, …法…, …要]
# 199  追悼法要式  [追…, …悼…, …法…, …要…, …式]
#
#                                                  xsk2g  \
# 0                         [阿羅…, 阿…漢, 阿…, …羅漢, …羅…, …漢]
# 1                         [辟支…, 辟…仏, 辟…, …支仏, …支…, …仏]
# 2                         [転法…, 転…輪, 転…, …法輪, …法…, …輪]
# 3    [十二…, 十…因…, 十…縁, 十…, …二因…, …二…縁, …二…, …因縁, …因…...
# 4    [五蘊…, 五…盛…, 五…苦, 五…, …蘊盛…, …蘊…苦, …蘊…, …盛苦, …盛…...
# ..                                                 ...
# 195  [両祖…, 両…忌…, 両…法…, 両…要, 両…, …祖忌…, …祖…法…, …祖…要, ...
# 196  [宗祖…, 宗…忌…, 宗…法…, 宗…要, 宗…, …祖忌…, …祖…法…, …祖…要, ...
# 197  [御会…, 御…式…, 御…法…, 御…要, 御…, …会式…, …会…法…, …会…要, ...
# 198  [報恩…, 報…講…, 報…法…, 報…要, 報…, …恩講…, …恩…法…, …恩…要, ...
# 199  [追悼…, 追…法…, 追…要…, 追…式, 追…, …悼法…, …悼…要…, …悼…式, ...
#
#                                                  xsk3g  \
# 0                    [阿羅…, 阿…漢, 阿…, …羅漢, …羅…, …漢, 阿羅漢]
# 1                    [辟支…, 辟…仏, 辟…, …支仏, …支…, …仏, 辟支仏]
# 2                    [転法…, 転…輪, 転…, …法輪, …法…, …輪, 転法輪]
# 3    [十二因…, 十二…縁, 十二…, 十…因縁, 十…因…, 十…縁, 十…, …二因縁, …...
# 4    [五蘊盛…, 五蘊…苦, 五蘊…, 五…盛苦, 五…盛…, 五…苦, 五…, …蘊盛苦, …...
# ..                                                 ...
# 195  [両祖忌…, 両祖…法…, 両祖…要, 両祖…, 両…忌法…, 両…忌…要, 両…忌…, 両...
# 196  [宗祖忌…, 宗祖…法…, 宗祖…要, 宗祖…, 宗…忌法…, 宗…忌…要, 宗…忌…, 宗...
# 197  [御会式…, 御会…法…, 御会…要, 御会…, 御…式法…, 御…式…要, 御…式…, 御...
# 198  [報恩講…, 報恩…法…, 報恩…要, 報恩…, 報…講法…, 報…講…要, 報…講…, 報...
# 199  [追悼法…, 追悼…要…, 追悼…式, 追悼…, 追…法要…, 追…法…式, 追…法…, 追...
#
#                                                  xsk4g
# 0                    [阿羅…, 阿…漢, 阿…, …羅漢, …羅…, …漢, 阿羅漢]
# 1                    [辟支…, 辟…仏, 辟…, …支仏, …支…, …仏, 辟支仏]
# 2                    [転法…, 転…輪, 転…, …法輪, …法…, …輪, 転法輪]
# 3    [十二因…, 十二…縁, 十二…, 十…因縁, 十…因…, 十…縁, 十…, …二因縁, …...
# 4    [五蘊盛…, 五蘊…苦, 五蘊…, 五…盛苦, 五…盛…, 五…苦, 五…, …蘊盛苦, …...
# ..                                                 ...
# 195  [両祖忌法…, 両祖忌…要, 両祖忌…, 両祖…法要, 両祖…法…, 両祖…要, 両祖…, ...
# 196  [宗祖忌法…, 宗祖忌…要, 宗祖忌…, 宗祖…法要, 宗祖…法…, 宗祖…要, 宗祖…, ...
# 197  [御会式法…, 御会式…要, 御会式…, 御会…法要, 御会…法…, 御会…要, 御会…, ...
# 198  [報恩講法…, 報恩講…要, 報恩講…, 報恩…法要, 報恩…法…, 報恩…要, 報恩…, ...
# 199  [追悼法要…, 追悼法…式, 追悼法…, 追悼…要式, 追悼…要…, 追悼…式, 追悼…, ...
#
# [200 rows x 5 columns]

# %% [markdown]
# ## Skippy

# %%
## generate regular skippy n-grams
import re
for i, doc in enumerate(docs):
    print(f"Processing word {i} [use_Cython: {use_Cython}]: {doc}")
    word_segs = [ seg for seg in re.split(segmenter, doc) if len(seg) > 0 ]
    for j in range(1, max_n_for_ngram + 1):
        print(f"generating skippy {j}-grams ...")
        ngrams = gen_ngrams.gen_skippy_ngrams(word_segs, j, extended = False, inclusive = ngram_is_inclusive, max_gap_size = max_gap_size, sep = sep_local, as_list = generated_as_list, check = False)
        if check:
            print(ngrams)
        ## update df
        df.loc[i, f'sk{j}g'] = ngrams
# Out:
# Processing word 0 [use_Cython: False]: 阿羅漢
# generating skippy 1-grams ...
# #subsegs_full: [['阿', '羅', '漢']]
# generating skippy 2-grams ...
# #subsegs_full: [['阿', '羅', '漢']]
# generating skippy 3-grams ...
# #subsegs_full: [['阿', '羅', '漢']]
# generating skippy 4-grams ...
# #subsegs_full: [['阿', '羅', '漢']]
# Processing word 1 [use_Cython: False]: 辟支仏
# generating skippy 1-grams ...
# #subsegs_full: [['辟', '支', '仏']]
# generating skippy 2-grams ...
# #subsegs_full: [['辟', '支', '仏']]
# generating skippy 3-grams ...
# #subsegs_full: [['辟', '支', '仏']]
# generating skippy 4-grams ...
# #subsegs_full: [['辟', '支', '仏']]
# Processing word 2 [use_Cython: False]: 転法輪
# generating skippy 1-grams ...
# #subsegs_full: [['転', '法', '輪']]
# generating skippy 2-grams ...
# #subsegs_full: [['転', '法', '輪']]
# generating skippy 3-grams ...
# #subsegs_full: [['転', '法', '輪']]
# generating skippy 4-grams ...
# #subsegs_full: [['転', '法', '輪']]
# Processing word 3 [use_Cython: False]: 十二因縁
# generating skippy 1-grams ...
# #subsegs_full: [['十', '二', '因', '縁']]
# generating skippy 2-grams ...
# #subsegs_full: [['十', '二', '因', '縁']]
# generating skippy 3-grams ...
# #subsegs_full: [['十', '二', '因', '縁']]
# generating skippy 4-grams ...
# #subsegs_full: [['十', '二', '因', '縁']]
# Processing word 4 [use_Cython: False]: 五蘊盛苦
# generating skippy 1-grams ...
# #subsegs_full: [['五', '蘊', '盛', '苦']]
# generating skippy 2-grams ...
# #subsegs_full: [['五', '蘊', '盛', '苦']]
# generating skippy 3-grams ...
# #subsegs_full: [['五', '蘊', '盛', '苦']]
# generating skippy 4-grams ...
# #subsegs_full: [['五', '蘊', '盛', '苦']]
# Processing word 5 [use_Cython: False]: 三法印
# generating skippy 1-grams ...
# #subsegs_full: [['三', '法', '印']]
# generating skippy 2-grams ...
# #subsegs_full: [['三', '法', '印']]
# generating skippy 3-grams ...
# #subsegs_full: [['三', '法', '印']]
# generating skippy 4-grams ...
# #subsegs_full: [['三', '法', '印']]
# Processing word 6 [use_Cython: False]: 四念処
# generating skippy 1-grams ...
# #subsegs_full: [['四', '念', '処']]
# generating skippy 2-grams ...
# #subsegs_full: [['四', '念', '処']]
# generating skippy 3-grams ...
# #subsegs_full: [['四', '念', '処']]
# generating skippy 4-grams ...
# #subsegs_full: [['四', '念', '処']]
# Processing word 7 [use_Cython: False]: 四神足
# generating skippy 1-grams ...
# #subsegs_full: [['四', '神', '足']]
# generating skippy 2-grams ...
# #subsegs_full: [['四', '神', '足']]
# generating skippy 3-grams ...
# #subsegs_full: [['四', '神', '足']]
# generating skippy 4-grams ...
# #subsegs_full: [['四', '神', '足']]
# Processing word 8 [use_Cython: False]: 五根五力
# generating skippy 1-grams ...
# #subsegs_full: [['五', '根', '五', '力']]
# generating skippy 2-grams ...
# #subsegs_full: [['五', '根', '五', '力']]
# generating skippy 3-grams ...
# #subsegs_full: [['五', '根', '五', '力']]
# generating skippy 4-grams ...
# #subsegs_full: [['五', '根', '五', '力']]
# Processing word 9 [use_Cython: False]: 七覚支
# generating skippy 1-grams ...
# #subsegs_full: [['七', '覚', '支']]
# generating skippy 2-grams ...
# #subsegs_full: [['七', '覚', '支']]
# generating skippy 3-grams ...
# #subsegs_full: [['七', '覚', '支']]
# generating skippy 4-grams ...
# #subsegs_full: [['七', '覚', '支']]
# Processing word 10 [use_Cython: False]: 三十七道品
# generating skippy 1-grams ...
# #subsegs_full: [['三', '十', '七', '道', '品']]
# generating skippy 2-grams ...
# #subsegs_full: [['三', '十', '七', '道', '品']]
# generating skippy 3-grams ...
# #subsegs_full: [['三', '十', '七', '道', '品']]
# generating skippy 4-grams ...
# #subsegs_full: [['三', '十', '七', '道', '品']]
# Processing word 11 [use_Cython: False]: 十善戒
# generating skippy 1-grams ...
# #subsegs_full: [['十', '善', '戒']]
# generating skippy 2-grams ...
# #subsegs_full: [['十', '善', '戒']]
# generating skippy 3-grams ...
# #subsegs_full: [['十', '善', '戒']]
# generating skippy 4-grams ...
# #subsegs_full: [['十', '善', '戒']]
# Processing word 12 [use_Cython: False]: 六神通
# generating skippy 1-grams ...
# #subsegs_full: [['六', '神', '通']]
# generating skippy 2-grams ...
# #subsegs_full: [['六', '神', '通']]
# generating skippy 3-grams ...
# #subsegs_full: [['六', '神', '通']]
# generating skippy 4-grams ...
# #subsegs_full: [['六', '神', '通']]
# Processing word 13 [use_Cython: False]: 四無量心
# generating skippy 1-grams ...
# #subsegs_full: [['四', '無', '量', '心']]
# generating skippy 2-grams ...
# #subsegs_full: [['四', '無', '量', '心']]
# generating skippy 3-grams ...
# #subsegs_full: [['四', '無', '量', '心']]
# generating skippy 4-grams ...
# #subsegs_full: [['四', '無', '量', '心']]
# Processing word 14 [use_Cython: False]: 慈悲喜捨
# generating skippy 1-grams ...
# #subsegs_full: [['慈', '悲', '喜', '捨']]
# generating skippy 2-grams ...
# #subsegs_full: [['慈', '悲', '喜', '捨']]
# generating skippy 3-grams ...
# #subsegs_full: [['慈', '悲', '喜', '捨']]
# generating skippy 4-grams ...
# #subsegs_full: [['慈', '悲', '喜', '捨']]
# Processing word 15 [use_Cython: False]: 八風不動
# generating skippy 1-grams ...
# #subsegs_full: [['八', '風', '不', '動']]
# generating skippy 2-grams ...
# #subsegs_full: [['八', '風', '不', '動']]
# generating skippy 3-grams ...
# #subsegs_full: [['八', '風', '不', '動']]
# generating skippy 4-grams ...
# #subsegs_full: [['八', '風', '不', '動']]
# Processing word 16 [use_Cython: False]: 不退転
# generating skippy 1-grams ...
# #subsegs_full: [['不', '退', '転']]
# generating skippy 2-grams ...
# #subsegs_full: [['不', '退', '転']]
# generating skippy 3-grams ...
# #subsegs_full: [['不', '退', '転']]
# generating skippy 4-grams ...
# #subsegs_full: [['不', '退', '転']]
# Processing word 17 [use_Cython: False]: 阿耨多羅三藐三菩提
# generating skippy 1-grams ...
# #subsegs_full: [['阿', '耨', '多', '羅', '三', '藐', '三', '菩', '提']]
# generating skippy 2-grams ...
# #subsegs_full: [['阿', '耨', '多', '羅', '三', '藐', '三', '菩', '提']]
# generating skippy 3-grams ...
# #subsegs_full: [['阿', '耨', '多', '羅', '三', '藐', '三', '菩', '提']]
# generating skippy 4-grams ...
# #subsegs_full: [['阿', '耨', '多', '羅', '三', '藐', '三', '菩', '提']]
# Processing word 18 [use_Cython: False]: 一切智
# generating skippy 1-grams ...
# #subsegs_full: [['一', '切', '智']]
# generating skippy 2-grams ...
# #subsegs_full: [['一', '切', '智']]
# generating skippy 3-grams ...
# #subsegs_full: [['一', '切', '智']]
# generating skippy 4-grams ...
# #subsegs_full: [['一', '切', '智']]
# Processing word 19 [use_Cython: False]: 無生法忍
# generating skippy 1-grams ...
# #subsegs_full: [['無', '生', '法', '忍']]
# generating skippy 2-grams ...
# #subsegs_full: [['無', '生', '法', '忍']]
# generating skippy 3-grams ...
# #subsegs_full: [['無', '生', '法', '忍']]
# generating skippy 4-grams ...
# #subsegs_full: [['無', '生', '法', '忍']]
# Processing word 20 [use_Cython: False]: 止観双修
# generating skippy 1-grams ...
# #subsegs_full: [['止', '観', '双', '修']]
# generating skippy 2-grams ...
# #subsegs_full: [['止', '観', '双', '修']]
# generating skippy 3-grams ...
# #subsegs_full: [['止', '観', '双', '修']]
# generating skippy 4-grams ...
# #subsegs_full: [['止', '観', '双', '修']]
# Processing word 21 [use_Cython: False]: 四禅定
# generating skippy 1-grams ...
# #subsegs_full: [['四', '禅', '定']]
# generating skippy 2-grams ...
# #subsegs_full: [['四', '禅', '定']]
# generating skippy 3-grams ...
# #subsegs_full: [['四', '禅', '定']]
# generating skippy 4-grams ...
# #subsegs_full: [['四', '禅', '定']]
# Processing word 22 [use_Cython: False]: 九次第定
# generating skippy 1-grams ...
# #subsegs_full: [['九', '次', '第', '定']]
# generating skippy 2-grams ...
# #subsegs_full: [['九', '次', '第', '定']]
# generating skippy 3-grams ...
# #subsegs_full: [['九', '次', '第', '定']]
# generating skippy 4-grams ...
# #subsegs_full: [['九', '次', '第', '定']]
# Processing word 23 [use_Cython: False]: 滅尽定
# generating skippy 1-grams ...
# #subsegs_full: [['滅', '尽', '定']]
# generating skippy 2-grams ...
# #subsegs_full: [['滅', '尽', '定']]
# generating skippy 3-grams ...
# #subsegs_full: [['滅', '尽', '定']]
# generating skippy 4-grams ...
# #subsegs_full: [['滅', '尽', '定']]
# Processing word 24 [use_Cython: False]: 無想定
# generating skippy 1-grams ...
# #subsegs_full: [['無', '想', '定']]
# generating skippy 2-grams ...
# #subsegs_full: [['無', '想', '定']]
# generating skippy 3-grams ...
# #subsegs_full: [['無', '想', '定']]
# generating skippy 4-grams ...
# #subsegs_full: [['無', '想', '定']]
# Processing word 25 [use_Cython: False]: 観呼吸
# generating skippy 1-grams ...
# #subsegs_full: [['観', '呼', '吸']]
# generating skippy 2-grams ...
# #subsegs_full: [['観', '呼', '吸']]
# generating skippy 3-grams ...
# #subsegs_full: [['観', '呼', '吸']]
# generating skippy 4-grams ...
# #subsegs_full: [['観', '呼', '吸']]
# Processing word 26 [use_Cython: False]: 観身不浄
# generating skippy 1-grams ...
# #subsegs_full: [['観', '身', '不', '浄']]
# generating skippy 2-grams ...
# #subsegs_full: [['観', '身', '不', '浄']]
# generating skippy 3-grams ...
# #subsegs_full: [['観', '身', '不', '浄']]
# generating skippy 4-grams ...
# #subsegs_full: [['観', '身', '不', '浄']]
# Processing word 27 [use_Cython: False]: 数息観
# generating skippy 1-grams ...
# #subsegs_full: [['数', '息', '観']]
# generating skippy 2-grams ...
# #subsegs_full: [['数', '息', '観']]
# generating skippy 3-grams ...
# #subsegs_full: [['数', '息', '観']]
# generating skippy 4-grams ...
# #subsegs_full: [['数', '息', '観']]
# Processing word 28 [use_Cython: False]: 白骨観
# generating skippy 1-grams ...
# #subsegs_full: [['白', '骨', '観']]
# generating skippy 2-grams ...
# #subsegs_full: [['白', '骨', '観']]
# generating skippy 3-grams ...
# #subsegs_full: [['白', '骨', '観']]
# generating skippy 4-grams ...
# #subsegs_full: [['白', '骨', '観']]
# Processing word 29 [use_Cython: False]: 不浄観
# generating skippy 1-grams ...
# #subsegs_full: [['不', '浄', '観']]
# generating skippy 2-grams ...
# #subsegs_full: [['不', '浄', '観']]
# generating skippy 3-grams ...
# #subsegs_full: [['不', '浄', '観']]
# generating skippy 4-grams ...
# #subsegs_full: [['不', '浄', '観']]
# Processing word 30 [use_Cython: False]: 慈心観
# generating skippy 1-grams ...
# #subsegs_full: [['慈', '心', '観']]
# generating skippy 2-grams ...
# #subsegs_full: [['慈', '心', '観']]
# generating skippy 3-grams ...
# #subsegs_full: [['慈', '心', '観']]
# generating skippy 4-grams ...
# #subsegs_full: [['慈', '心', '観']]
# Processing word 31 [use_Cython: False]: 因縁観
# generating skippy 1-grams ...
# #subsegs_full: [['因', '縁', '観']]
# generating skippy 2-grams ...
# #subsegs_full: [['因', '縁', '観']]
# generating skippy 3-grams ...
# #subsegs_full: [['因', '縁', '観']]
# generating skippy 4-grams ...
# #subsegs_full: [['因', '縁', '観']]
# Processing word 32 [use_Cython: False]: 念死観
# generating skippy 1-grams ...
# #subsegs_full: [['念', '死', '観']]
# generating skippy 2-grams ...
# #subsegs_full: [['念', '死', '観']]
# generating skippy 3-grams ...
# #subsegs_full: [['念', '死', '観']]
# generating skippy 4-grams ...
# #subsegs_full: [['念', '死', '観']]
# Processing word 33 [use_Cython: False]: 随念三宝
# generating skippy 1-grams ...
# #subsegs_full: [['随', '念', '三', '宝']]
# generating skippy 2-grams ...
# #subsegs_full: [['随', '念', '三', '宝']]
# generating skippy 3-grams ...
# #subsegs_full: [['随', '念', '三', '宝']]
# generating skippy 4-grams ...
# #subsegs_full: [['随', '念', '三', '宝']]
# Processing word 34 [use_Cython: False]: 経行禅
# generating skippy 1-grams ...
# #subsegs_full: [['経', '行', '禅']]
# generating skippy 2-grams ...
# #subsegs_full: [['経', '行', '禅']]
# generating skippy 3-grams ...
# #subsegs_full: [['経', '行', '禅']]
# generating skippy 4-grams ...
# #subsegs_full: [['経', '行', '禅']]
# Processing word 35 [use_Cython: False]: 立禅法
# generating skippy 1-grams ...
# #subsegs_full: [['立', '禅', '法']]
# generating skippy 2-grams ...
# #subsegs_full: [['立', '禅', '法']]
# generating skippy 3-grams ...
# #subsegs_full: [['立', '禅', '法']]
# generating skippy 4-grams ...
# #subsegs_full: [['立', '禅', '法']]
# Processing word 36 [use_Cython: False]: 食禅法
# generating skippy 1-grams ...
# #subsegs_full: [['食', '禅', '法']]
# generating skippy 2-grams ...
# #subsegs_full: [['食', '禅', '法']]
# generating skippy 3-grams ...
# #subsegs_full: [['食', '禅', '法']]
# generating skippy 4-grams ...
# #subsegs_full: [['食', '禅', '法']]
# Processing word 37 [use_Cython: False]: 作務禅
# generating skippy 1-grams ...
# #subsegs_full: [['作', '務', '禅']]
# generating skippy 2-grams ...
# #subsegs_full: [['作', '務', '禅']]
# generating skippy 3-grams ...
# #subsegs_full: [['作', '務', '禅']]
# generating skippy 4-grams ...
# #subsegs_full: [['作', '務', '禅']]
# Processing word 38 [use_Cython: False]: 公案禅
# generating skippy 1-grams ...
# #subsegs_full: [['公', '案', '禅']]
# generating skippy 2-grams ...
# #subsegs_full: [['公', '案', '禅']]
# generating skippy 3-grams ...
# #subsegs_full: [['公', '案', '禅']]
# generating skippy 4-grams ...
# #subsegs_full: [['公', '案', '禅']]
# Processing word 39 [use_Cython: False]: 只管打坐
# generating skippy 1-grams ...
# #subsegs_full: [['只', '管', '打', '坐']]
# generating skippy 2-grams ...
# #subsegs_full: [['只', '管', '打', '坐']]
# generating skippy 3-grams ...
# #subsegs_full: [['只', '管', '打', '坐']]
# generating skippy 4-grams ...
# #subsegs_full: [['只', '管', '打', '坐']]
# Processing word 40 [use_Cython: False]: 阿含経
# generating skippy 1-grams ...
# #subsegs_full: [['阿', '含', '経']]
# generating skippy 2-grams ...
# #subsegs_full: [['阿', '含', '経']]
# generating skippy 3-grams ...
# #subsegs_full: [['阿', '含', '経']]
# generating skippy 4-grams ...
# #subsegs_full: [['阿', '含', '経']]
# Processing word 41 [use_Cython: False]: 大般涅槃経
# generating skippy 1-grams ...
# #subsegs_full: [['大', '般', '涅', '槃', '経']]
# generating skippy 2-grams ...
# #subsegs_full: [['大', '般', '涅', '槃', '経']]
# generating skippy 3-grams ...
# #subsegs_full: [['大', '般', '涅', '槃', '経']]
# generating skippy 4-grams ...
# #subsegs_full: [['大', '般', '涅', '槃', '経']]
# Processing word 42 [use_Cython: False]: 大日経
# generating skippy 1-grams ...
# #subsegs_full: [['大', '日', '経']]
# generating skippy 2-grams ...
# #subsegs_full: [['大', '日', '経']]
# generating skippy 3-grams ...
# #subsegs_full: [['大', '日', '経']]
# generating skippy 4-grams ...
# #subsegs_full: [['大', '日', '経']]
# Processing word 43 [use_Cython: False]: 金剛頂経
# generating skippy 1-grams ...
# #subsegs_full: [['金', '剛', '頂', '経']]
# generating skippy 2-grams ...
# #subsegs_full: [['金', '剛', '頂', '経']]
# generating skippy 3-grams ...
# #subsegs_full: [['金', '剛', '頂', '経']]
# generating skippy 4-grams ...
# #subsegs_full: [['金', '剛', '頂', '経']]
# Processing word 44 [use_Cython: False]: 理趣経
# generating skippy 1-grams ...
# #subsegs_full: [['理', '趣', '経']]
# generating skippy 2-grams ...
# #subsegs_full: [['理', '趣', '経']]
# generating skippy 3-grams ...
# #subsegs_full: [['理', '趣', '経']]
# generating skippy 4-grams ...
# #subsegs_full: [['理', '趣', '経']]
# Processing word 45 [use_Cython: False]: 観音経
# generating skippy 1-grams ...
# #subsegs_full: [['観', '音', '経']]
# generating skippy 2-grams ...
# #subsegs_full: [['観', '音', '経']]
# generating skippy 3-grams ...
# #subsegs_full: [['観', '音', '経']]
# generating skippy 4-grams ...
# #subsegs_full: [['観', '音', '経']]
# Processing word 46 [use_Cython: False]: 地蔵経
# generating skippy 1-grams ...
# #subsegs_full: [['地', '蔵', '経']]
# generating skippy 2-grams ...
# #subsegs_full: [['地', '蔵', '経']]
# generating skippy 3-grams ...
# #subsegs_full: [['地', '蔵', '経']]
# generating skippy 4-grams ...
# #subsegs_full: [['地', '蔵', '経']]
# Processing word 47 [use_Cython: False]: 薬師経
# generating skippy 1-grams ...
# #subsegs_full: [['薬', '師', '経']]
# generating skippy 2-grams ...
# #subsegs_full: [['薬', '師', '経']]
# generating skippy 3-grams ...
# #subsegs_full: [['薬', '師', '経']]
# generating skippy 4-grams ...
# #subsegs_full: [['薬', '師', '経']]
# Processing word 48 [use_Cython: False]: 無量寿経
# generating skippy 1-grams ...
# #subsegs_full: [['無', '量', '寿', '経']]
# generating skippy 2-grams ...
# #subsegs_full: [['無', '量', '寿', '経']]
# generating skippy 3-grams ...
# #subsegs_full: [['無', '量', '寿', '経']]
# generating skippy 4-grams ...
# #subsegs_full: [['無', '量', '寿', '経']]
# Processing word 49 [use_Cython: False]: 観無量寿経
# generating skippy 1-grams ...
# #subsegs_full: [['観', '無', '量', '寿', '経']]
# generating skippy 2-grams ...
# #subsegs_full: [['観', '無', '量', '寿', '経']]
# generating skippy 3-grams ...
# #subsegs_full: [['観', '無', '量', '寿', '経']]
# generating skippy 4-grams ...
# #subsegs_full: [['観', '無', '量', '寿', '経']]
# Processing word 50 [use_Cython: False]: 倶舎論
# generating skippy 1-grams ...
# #subsegs_full: [['倶', '舎', '論']]
# generating skippy 2-grams ...
# #subsegs_full: [['倶', '舎', '論']]
# generating skippy 3-grams ...
# #subsegs_full: [['倶', '舎', '論']]
# generating skippy 4-grams ...
# #subsegs_full: [['倶', '舎', '論']]
# Processing word 51 [use_Cython: False]: 成実論
# generating skippy 1-grams ...
# #subsegs_full: [['成', '実', '論']]
# generating skippy 2-grams ...
# #subsegs_full: [['成', '実', '論']]
# generating skippy 3-grams ...
# #subsegs_full: [['成', '実', '論']]
# generating skippy 4-grams ...
# #subsegs_full: [['成', '実', '論']]
# Processing word 52 [use_Cython: False]: 大智度論
# generating skippy 1-grams ...
# #subsegs_full: [['大', '智', '度', '論']]
# generating skippy 2-grams ...
# #subsegs_full: [['大', '智', '度', '論']]
# generating skippy 3-grams ...
# #subsegs_full: [['大', '智', '度', '論']]
# generating skippy 4-grams ...
# #subsegs_full: [['大', '智', '度', '論']]
# Processing word 53 [use_Cython: False]: 中論頌
# generating skippy 1-grams ...
# #subsegs_full: [['中', '論', '頌']]
# generating skippy 2-grams ...
# #subsegs_full: [['中', '論', '頌']]
# generating skippy 3-grams ...
# #subsegs_full: [['中', '論', '頌']]
# generating skippy 4-grams ...
# #subsegs_full: [['中', '論', '頌']]
# Processing word 54 [use_Cython: False]: 唯識論
# generating skippy 1-grams ...
# #subsegs_full: [['唯', '識', '論']]
# generating skippy 2-grams ...
# #subsegs_full: [['唯', '識', '論']]
# generating skippy 3-grams ...
# #subsegs_full: [['唯', '識', '論']]
# generating skippy 4-grams ...
# #subsegs_full: [['唯', '識', '論']]
# Processing word 55 [use_Cython: False]: 起信論
# generating skippy 1-grams ...
# #subsegs_full: [['起', '信', '論']]
# generating skippy 2-grams ...
# #subsegs_full: [['起', '信', '論']]
# generating skippy 3-grams ...
# #subsegs_full: [['起', '信', '論']]
# generating skippy 4-grams ...
# #subsegs_full: [['起', '信', '論']]
# Processing word 56 [use_Cython: False]: 摩訶止観
# generating skippy 1-grams ...
# #subsegs_full: [['摩', '訶', '止', '観']]
# generating skippy 2-grams ...
# #subsegs_full: [['摩', '訶', '止', '観']]
# generating skippy 3-grams ...
# #subsegs_full: [['摩', '訶', '止', '観']]
# generating skippy 4-grams ...
# #subsegs_full: [['摩', '訶', '止', '観']]
# Processing word 57 [use_Cython: False]: 法界次第
# generating skippy 1-grams ...
# #subsegs_full: [['法', '界', '次', '第']]
# generating skippy 2-grams ...
# #subsegs_full: [['法', '界', '次', '第']]
# generating skippy 3-grams ...
# #subsegs_full: [['法', '界', '次', '第']]
# generating skippy 4-grams ...
# #subsegs_full: [['法', '界', '次', '第']]
# Processing word 58 [use_Cython: False]: 禅源諸詮集
# generating skippy 1-grams ...
# #subsegs_full: [['禅', '源', '諸', '詮', '集']]
# generating skippy 2-grams ...
# #subsegs_full: [['禅', '源', '諸', '詮', '集']]
# generating skippy 3-grams ...
# #subsegs_full: [['禅', '源', '諸', '詮', '集']]
# generating skippy 4-grams ...
# #subsegs_full: [['禅', '源', '諸', '詮', '集']]
# Processing word 59 [use_Cython: False]: 景徳伝灯録
# generating skippy 1-grams ...
# #subsegs_full: [['景', '徳', '伝', '灯', '録']]
# generating skippy 2-grams ...
# #subsegs_full: [['景', '徳', '伝', '灯', '録']]
# generating skippy 3-grams ...
# #subsegs_full: [['景', '徳', '伝', '灯', '録']]
# generating skippy 4-grams ...
# #subsegs_full: [['景', '徳', '伝', '灯', '録']]
# Processing word 60 [use_Cython: False]: 小乗仏教
# generating skippy 1-grams ...
# #subsegs_full: [['小', '乗', '仏', '教']]
# generating skippy 2-grams ...
# #subsegs_full: [['小', '乗', '仏', '教']]
# generating skippy 3-grams ...
# #subsegs_full: [['小', '乗', '仏', '教']]
# generating skippy 4-grams ...
# #subsegs_full: [['小', '乗', '仏', '教']]
# Processing word 61 [use_Cython: False]: 大乗仏教
# generating skippy 1-grams ...
# #subsegs_full: [['大', '乗', '仏', '教']]
# generating skippy 2-grams ...
# #subsegs_full: [['大', '乗', '仏', '教']]
# generating skippy 3-grams ...
# #subsegs_full: [['大', '乗', '仏', '教']]
# generating skippy 4-grams ...
# #subsegs_full: [['大', '乗', '仏', '教']]
# Processing word 62 [use_Cython: False]: 金剛乗
# generating skippy 1-grams ...
# #subsegs_full: [['金', '剛', '乗']]
# generating skippy 2-grams ...
# #subsegs_full: [['金', '剛', '乗']]
# generating skippy 3-grams ...
# #subsegs_full: [['金', '剛', '乗']]
# generating skippy 4-grams ...
# #subsegs_full: [['金', '剛', '乗']]
# Processing word 63 [use_Cython: False]: 秘密仏教
# generating skippy 1-grams ...
# #subsegs_full: [['秘', '密', '仏', '教']]
# generating skippy 2-grams ...
# #subsegs_full: [['秘', '密', '仏', '教']]
# generating skippy 3-grams ...
# #subsegs_full: [['秘', '密', '仏', '教']]
# generating skippy 4-grams ...
# #subsegs_full: [['秘', '密', '仏', '教']]
# Processing word 64 [use_Cython: False]: 南都六宗
# generating skippy 1-grams ...
# #subsegs_full: [['南', '都', '六', '宗']]
# generating skippy 2-grams ...
# #subsegs_full: [['南', '都', '六', '宗']]
# generating skippy 3-grams ...
# #subsegs_full: [['南', '都', '六', '宗']]
# generating skippy 4-grams ...
# #subsegs_full: [['南', '都', '六', '宗']]
# Processing word 65 [use_Cython: False]: 三論宗
# generating skippy 1-grams ...
# #subsegs_full: [['三', '論', '宗']]
# generating skippy 2-grams ...
# #subsegs_full: [['三', '論', '宗']]
# generating skippy 3-grams ...
# #subsegs_full: [['三', '論', '宗']]
# generating skippy 4-grams ...
# #subsegs_full: [['三', '論', '宗']]
# Processing word 66 [use_Cython: False]: 成実宗
# generating skippy 1-grams ...
# #subsegs_full: [['成', '実', '宗']]
# generating skippy 2-grams ...
# #subsegs_full: [['成', '実', '宗']]
# generating skippy 3-grams ...
# #subsegs_full: [['成', '実', '宗']]
# generating skippy 4-grams ...
# #subsegs_full: [['成', '実', '宗']]
# Processing word 67 [use_Cython: False]: 俱舎宗
# generating skippy 1-grams ...
# #subsegs_full: [['俱', '舎', '宗']]
# generating skippy 2-grams ...
# #subsegs_full: [['俱', '舎', '宗']]
# generating skippy 3-grams ...
# #subsegs_full: [['俱', '舎', '宗']]
# generating skippy 4-grams ...
# #subsegs_full: [['俱', '舎', '宗']]
# Processing word 68 [use_Cython: False]: 法相宗
# generating skippy 1-grams ...
# #subsegs_full: [['法', '相', '宗']]
# generating skippy 2-grams ...
# #subsegs_full: [['法', '相', '宗']]
# generating skippy 3-grams ...
# #subsegs_full: [['法', '相', '宗']]
# generating skippy 4-grams ...
# #subsegs_full: [['法', '相', '宗']]
# Processing word 69 [use_Cython: False]: 律宗派
# generating skippy 1-grams ...
# #subsegs_full: [['律', '宗', '派']]
# generating skippy 2-grams ...
# #subsegs_full: [['律', '宗', '派']]
# generating skippy 3-grams ...
# #subsegs_full: [['律', '宗', '派']]
# generating skippy 4-grams ...
# #subsegs_full: [['律', '宗', '派']]
# Processing word 70 [use_Cython: False]: 時宗派
# generating skippy 1-grams ...
# #subsegs_full: [['時', '宗', '派']]
# generating skippy 2-grams ...
# #subsegs_full: [['時', '宗', '派']]
# generating skippy 3-grams ...
# #subsegs_full: [['時', '宗', '派']]
# generating skippy 4-grams ...
# #subsegs_full: [['時', '宗', '派']]
# Processing word 71 [use_Cython: False]: 融通念仏宗
# generating skippy 1-grams ...
# #subsegs_full: [['融', '通', '念', '仏', '宗']]
# generating skippy 2-grams ...
# #subsegs_full: [['融', '通', '念', '仏', '宗']]
# generating skippy 3-grams ...
# #subsegs_full: [['融', '通', '念', '仏', '宗']]
# generating skippy 4-grams ...
# #subsegs_full: [['融', '通', '念', '仏', '宗']]
# Processing word 72 [use_Cython: False]: 一遍上人
# generating skippy 1-grams ...
# #subsegs_full: [['一', '遍', '上', '人']]
# generating skippy 2-grams ...
# #subsegs_full: [['一', '遍', '上', '人']]
# generating skippy 3-grams ...
# #subsegs_full: [['一', '遍', '上', '人']]
# generating skippy 4-grams ...
# #subsegs_full: [['一', '遍', '上', '人']]
# Processing word 73 [use_Cython: False]: 親鸞聖人
# generating skippy 1-grams ...
# #subsegs_full: [['親', '鸞', '聖', '人']]
# generating skippy 2-grams ...
# #subsegs_full: [['親', '鸞', '聖', '人']]
# generating skippy 3-grams ...
# #subsegs_full: [['親', '鸞', '聖', '人']]
# generating skippy 4-grams ...
# #subsegs_full: [['親', '鸞', '聖', '人']]
# Processing word 74 [use_Cython: False]: 法然上人
# generating skippy 1-grams ...
# #subsegs_full: [['法', '然', '上', '人']]
# generating skippy 2-grams ...
# #subsegs_full: [['法', '然', '上', '人']]
# generating skippy 3-grams ...
# #subsegs_full: [['法', '然', '上', '人']]
# generating skippy 4-grams ...
# #subsegs_full: [['法', '然', '上', '人']]
# Processing word 75 [use_Cython: False]: 道元禅師
# generating skippy 1-grams ...
# #subsegs_full: [['道', '元', '禅', '師']]
# generating skippy 2-grams ...
# #subsegs_full: [['道', '元', '禅', '師']]
# generating skippy 3-grams ...
# #subsegs_full: [['道', '元', '禅', '師']]
# generating skippy 4-grams ...
# #subsegs_full: [['道', '元', '禅', '師']]
# Processing word 76 [use_Cython: False]: 栄西禅師
# generating skippy 1-grams ...
# #subsegs_full: [['栄', '西', '禅', '師']]
# generating skippy 2-grams ...
# #subsegs_full: [['栄', '西', '禅', '師']]
# generating skippy 3-grams ...
# #subsegs_full: [['栄', '西', '禅', '師']]
# generating skippy 4-grams ...
# #subsegs_full: [['栄', '西', '禅', '師']]
# Processing word 77 [use_Cython: False]: 空海大師
# generating skippy 1-grams ...
# #subsegs_full: [['空', '海', '大', '師']]
# generating skippy 2-grams ...
# #subsegs_full: [['空', '海', '大', '師']]
# generating skippy 3-grams ...
# #subsegs_full: [['空', '海', '大', '師']]
# generating skippy 4-grams ...
# #subsegs_full: [['空', '海', '大', '師']]
# Processing word 78 [use_Cython: False]: 最澄大師
# generating skippy 1-grams ...
# #subsegs_full: [['最', '澄', '大', '師']]
# generating skippy 2-grams ...
# #subsegs_full: [['最', '澄', '大', '師']]
# generating skippy 3-grams ...
# #subsegs_full: [['最', '澄', '大', '師']]
# generating skippy 4-grams ...
# #subsegs_full: [['最', '澄', '大', '師']]
# Processing word 79 [use_Cython: False]: 鑑真和上
# generating skippy 1-grams ...
# #subsegs_full: [['鑑', '真', '和', '上']]
# generating skippy 2-grams ...
# #subsegs_full: [['鑑', '真', '和', '上']]
# generating skippy 3-grams ...
# #subsegs_full: [['鑑', '真', '和', '上']]
# generating skippy 4-grams ...
# #subsegs_full: [['鑑', '真', '和', '上']]
# Processing word 80 [use_Cython: False]: 開眼供養
# generating skippy 1-grams ...
# #subsegs_full: [['開', '眼', '供', '養']]
# generating skippy 2-grams ...
# #subsegs_full: [['開', '眼', '供', '養']]
# generating skippy 3-grams ...
# #subsegs_full: [['開', '眼', '供', '養']]
# generating skippy 4-grams ...
# #subsegs_full: [['開', '眼', '供', '養']]
# Processing word 81 [use_Cython: False]: 入仏供養
# generating skippy 1-grams ...
# #subsegs_full: [['入', '仏', '供', '養']]
# generating skippy 2-grams ...
# #subsegs_full: [['入', '仏', '供', '養']]
# generating skippy 3-grams ...
# #subsegs_full: [['入', '仏', '供', '養']]
# generating skippy 4-grams ...
# #subsegs_full: [['入', '仏', '供', '養']]
# Processing word 82 [use_Cython: False]: 落慶法要
# generating skippy 1-grams ...
# #subsegs_full: [['落', '慶', '法', '要']]
# generating skippy 2-grams ...
# #subsegs_full: [['落', '慶', '法', '要']]
# generating skippy 3-grams ...
# #subsegs_full: [['落', '慶', '法', '要']]
# generating skippy 4-grams ...
# #subsegs_full: [['落', '慶', '法', '要']]
# Processing word 83 [use_Cython: False]: 授戒会
# generating skippy 1-grams ...
# #subsegs_full: [['授', '戒', '会']]
# generating skippy 2-grams ...
# #subsegs_full: [['授', '戒', '会']]
# generating skippy 3-grams ...
# #subsegs_full: [['授', '戒', '会']]
# generating skippy 4-grams ...
# #subsegs_full: [['授', '戒', '会']]
# Processing word 84 [use_Cython: False]: 結縁灌頂
# generating skippy 1-grams ...
# #subsegs_full: [['結', '縁', '灌', '頂']]
# generating skippy 2-grams ...
# #subsegs_full: [['結', '縁', '灌', '頂']]
# generating skippy 3-grams ...
# #subsegs_full: [['結', '縁', '灌', '頂']]
# generating skippy 4-grams ...
# #subsegs_full: [['結', '縁', '灌', '頂']]
# Processing word 85 [use_Cython: False]: 伝法灌頂
# generating skippy 1-grams ...
# #subsegs_full: [['伝', '法', '灌', '頂']]
# generating skippy 2-grams ...
# #subsegs_full: [['伝', '法', '灌', '頂']]
# generating skippy 3-grams ...
# #subsegs_full: [['伝', '法', '灌', '頂']]
# generating skippy 4-grams ...
# #subsegs_full: [['伝', '法', '灌', '頂']]
# Processing word 86 [use_Cython: False]: 護摩供養
# generating skippy 1-grams ...
# #subsegs_full: [['護', '摩', '供', '養']]
# generating skippy 2-grams ...
# #subsegs_full: [['護', '摩', '供', '養']]
# generating skippy 3-grams ...
# #subsegs_full: [['護', '摩', '供', '養']]
# generating skippy 4-grams ...
# #subsegs_full: [['護', '摩', '供', '養']]
# Processing word 87 [use_Cython: False]: 千体仏供養
# generating skippy 1-grams ...
# #subsegs_full: [['千', '体', '仏', '供', '養']]
# generating skippy 2-grams ...
# #subsegs_full: [['千', '体', '仏', '供', '養']]
# generating skippy 3-grams ...
# #subsegs_full: [['千', '体', '仏', '供', '養']]
# generating skippy 4-grams ...
# #subsegs_full: [['千', '体', '仏', '供', '養']]
# Processing word 88 [use_Cython: False]: 水子供養
# generating skippy 1-grams ...
# #subsegs_full: [['水', '子', '供', '養']]
# generating skippy 2-grams ...
# #subsegs_full: [['水', '子', '供', '養']]
# generating skippy 3-grams ...
# #subsegs_full: [['水', '子', '供', '養']]
# generating skippy 4-grams ...
# #subsegs_full: [['水', '子', '供', '養']]
# Processing word 89 [use_Cython: False]: 先祖供養
# generating skippy 1-grams ...
# #subsegs_full: [['先', '祖', '供', '養']]
# generating skippy 2-grams ...
# #subsegs_full: [['先', '祖', '供', '養']]
# generating skippy 3-grams ...
# #subsegs_full: [['先', '祖', '供', '養']]
# generating skippy 4-grams ...
# #subsegs_full: [['先', '祖', '供', '養']]
# Processing word 90 [use_Cython: False]: 施餓鬼会
# generating skippy 1-grams ...
# #subsegs_full: [['施', '餓', '鬼', '会']]
# generating skippy 2-grams ...
# #subsegs_full: [['施', '餓', '鬼', '会']]
# generating skippy 3-grams ...
# #subsegs_full: [['施', '餓', '鬼', '会']]
# generating skippy 4-grams ...
# #subsegs_full: [['施', '餓', '鬼', '会']]
# Processing word 91 [use_Cython: False]: 大施食会
# generating skippy 1-grams ...
# #subsegs_full: [['大', '施', '食', '会']]
# generating skippy 2-grams ...
# #subsegs_full: [['大', '施', '食', '会']]
# generating skippy 3-grams ...
# #subsegs_full: [['大', '施', '食', '会']]
# generating skippy 4-grams ...
# #subsegs_full: [['大', '施', '食', '会']]
# Processing word 92 [use_Cython: False]: 盆踊り
# generating skippy 1-grams ...
# #subsegs_full: [['盆', '踊', 'り']]
# generating skippy 2-grams ...
# #subsegs_full: [['盆', '踊', 'り']]
# generating skippy 3-grams ...
# #subsegs_full: [['盆', '踊', 'り']]
# generating skippy 4-grams ...
# #subsegs_full: [['盆', '踊', 'り']]
# Processing word 93 [use_Cython: False]: 精霊流し
# generating skippy 1-grams ...
# #subsegs_full: [['精', '霊', '流', 'し']]
# generating skippy 2-grams ...
# #subsegs_full: [['精', '霊', '流', 'し']]
# generating skippy 3-grams ...
# #subsegs_full: [['精', '霊', '流', 'し']]
# generating skippy 4-grams ...
# #subsegs_full: [['精', '霊', '流', 'し']]
# Processing word 94 [use_Cython: False]: 迎え火
# generating skippy 1-grams ...
# #subsegs_full: [['迎', 'え', '火']]
# generating skippy 2-grams ...
# #subsegs_full: [['迎', 'え', '火']]
# generating skippy 3-grams ...
# #subsegs_full: [['迎', 'え', '火']]
# generating skippy 4-grams ...
# #subsegs_full: [['迎', 'え', '火']]
# Processing word 95 [use_Cython: False]: 送り火
# generating skippy 1-grams ...
# #subsegs_full: [['送', 'り', '火']]
# generating skippy 2-grams ...
# #subsegs_full: [['送', 'り', '火']]
# generating skippy 3-grams ...
# #subsegs_full: [['送', 'り', '火']]
# generating skippy 4-grams ...
# #subsegs_full: [['送', 'り', '火']]
# Processing word 96 [use_Cython: False]: 棚経参り
# generating skippy 1-grams ...
# #subsegs_full: [['棚', '経', '参', 'り']]
# generating skippy 2-grams ...
# #subsegs_full: [['棚', '経', '参', 'り']]
# generating skippy 3-grams ...
# #subsegs_full: [['棚', '経', '参', 'り']]
# generating skippy 4-grams ...
# #subsegs_full: [['棚', '経', '参', 'り']]
# Processing word 97 [use_Cython: False]: お数珠
# generating skippy 1-grams ...
# #subsegs_full: [['お', '数', '珠']]
# generating skippy 2-grams ...
# #subsegs_full: [['お', '数', '珠']]
# generating skippy 3-grams ...
# #subsegs_full: [['お', '数', '珠']]
# generating skippy 4-grams ...
# #subsegs_full: [['お', '数', '珠']]
# Processing word 98 [use_Cython: False]: 線香供養
# generating skippy 1-grams ...
# #subsegs_full: [['線', '香', '供', '養']]
# generating skippy 2-grams ...
# #subsegs_full: [['線', '香', '供', '養']]
# generating skippy 3-grams ...
# #subsegs_full: [['線', '香', '供', '養']]
# generating skippy 4-grams ...
# #subsegs_full: [['線', '香', '供', '養']]
# Processing word 99 [use_Cython: False]: 献花供養
# generating skippy 1-grams ...
# #subsegs_full: [['献', '花', '供', '養']]
# generating skippy 2-grams ...
# #subsegs_full: [['献', '花', '供', '養']]
# generating skippy 3-grams ...
# #subsegs_full: [['献', '花', '供', '養']]
# generating skippy 4-grams ...
# #subsegs_full: [['献', '花', '供', '養']]
# Processing word 100 [use_Cython: False]: 五重塔
# generating skippy 1-grams ...
# #subsegs_full: [['五', '重', '塔']]
# generating skippy 2-grams ...
# #subsegs_full: [['五', '重', '塔']]
# generating skippy 3-grams ...
# #subsegs_full: [['五', '重', '塔']]
# generating skippy 4-grams ...
# #subsegs_full: [['五', '重', '塔']]
# Processing word 101 [use_Cython: False]: 三重塔
# generating skippy 1-grams ...
# #subsegs_full: [['三', '重', '塔']]
# generating skippy 2-grams ...
# #subsegs_full: [['三', '重', '塔']]
# generating skippy 3-grams ...
# #subsegs_full: [['三', '重', '塔']]
# generating skippy 4-grams ...
# #subsegs_full: [['三', '重', '塔']]
# Processing word 102 [use_Cython: False]: 多宝塔
# generating skippy 1-grams ...
# #subsegs_full: [['多', '宝', '塔']]
# generating skippy 2-grams ...
# #subsegs_full: [['多', '宝', '塔']]
# generating skippy 3-grams ...
# #subsegs_full: [['多', '宝', '塔']]
# generating skippy 4-grams ...
# #subsegs_full: [['多', '宝', '塔']]
# Processing word 103 [use_Cython: False]: 仏舎利塔
# generating skippy 1-grams ...
# #subsegs_full: [['仏', '舎', '利', '塔']]
# generating skippy 2-grams ...
# #subsegs_full: [['仏', '舎', '利', '塔']]
# generating skippy 3-grams ...
# #subsegs_full: [['仏', '舎', '利', '塔']]
# generating skippy 4-grams ...
# #subsegs_full: [['仏', '舎', '利', '塔']]
# Processing word 104 [use_Cython: False]: 観音堂
# generating skippy 1-grams ...
# #subsegs_full: [['観', '音', '堂']]
# generating skippy 2-grams ...
# #subsegs_full: [['観', '音', '堂']]
# generating skippy 3-grams ...
# #subsegs_full: [['観', '音', '堂']]
# generating skippy 4-grams ...
# #subsegs_full: [['観', '音', '堂']]
# Processing word 105 [use_Cython: False]: 薬師堂
# generating skippy 1-grams ...
# #subsegs_full: [['薬', '師', '堂']]
# generating skippy 2-grams ...
# #subsegs_full: [['薬', '師', '堂']]
# generating skippy 3-grams ...
# #subsegs_full: [['薬', '師', '堂']]
# generating skippy 4-grams ...
# #subsegs_full: [['薬', '師', '堂']]
# Processing word 106 [use_Cython: False]: 阿弥陀堂
# generating skippy 1-grams ...
# #subsegs_full: [['阿', '弥', '陀', '堂']]
# generating skippy 2-grams ...
# #subsegs_full: [['阿', '弥', '陀', '堂']]
# generating skippy 3-grams ...
# #subsegs_full: [['阿', '弥', '陀', '堂']]
# generating skippy 4-grams ...
# #subsegs_full: [['阿', '弥', '陀', '堂']]
# Processing word 107 [use_Cython: False]: 大雄宝殿
# generating skippy 1-grams ...
# #subsegs_full: [['大', '雄', '宝', '殿']]
# generating skippy 2-grams ...
# #subsegs_full: [['大', '雄', '宝', '殿']]
# generating skippy 3-grams ...
# #subsegs_full: [['大', '雄', '宝', '殿']]
# generating skippy 4-grams ...
# #subsegs_full: [['大', '雄', '宝', '殿']]
# Processing word 108 [use_Cython: False]: 法堂建築
# generating skippy 1-grams ...
# #subsegs_full: [['法', '堂', '建', '築']]
# generating skippy 2-grams ...
# #subsegs_full: [['法', '堂', '建', '築']]
# generating skippy 3-grams ...
# #subsegs_full: [['法', '堂', '建', '築']]
# generating skippy 4-grams ...
# #subsegs_full: [['法', '堂', '建', '築']]
# Processing word 109 [use_Cython: False]: 禅堂建築
# generating skippy 1-grams ...
# #subsegs_full: [['禅', '堂', '建', '築']]
# generating skippy 2-grams ...
# #subsegs_full: [['禅', '堂', '建', '築']]
# generating skippy 3-grams ...
# #subsegs_full: [['禅', '堂', '建', '築']]
# generating skippy 4-grams ...
# #subsegs_full: [['禅', '堂', '建', '築']]
# Processing word 110 [use_Cython: False]: 客殿建築
# generating skippy 1-grams ...
# #subsegs_full: [['客', '殿', '建', '築']]
# generating skippy 2-grams ...
# #subsegs_full: [['客', '殿', '建', '築']]
# generating skippy 3-grams ...
# #subsegs_full: [['客', '殿', '建', '築']]
# generating skippy 4-grams ...
# #subsegs_full: [['客', '殿', '建', '築']]
# Processing word 111 [use_Cython: False]: 庫裏建築
# generating skippy 1-grams ...
# #subsegs_full: [['庫', '裏', '建', '築']]
# generating skippy 2-grams ...
# #subsegs_full: [['庫', '裏', '建', '築']]
# generating skippy 3-grams ...
# #subsegs_full: [['庫', '裏', '建', '築']]
# generating skippy 4-grams ...
# #subsegs_full: [['庫', '裏', '建', '築']]
# Processing word 112 [use_Cython: False]: 山門建築
# generating skippy 1-grams ...
# #subsegs_full: [['山', '門', '建', '築']]
# generating skippy 2-grams ...
# #subsegs_full: [['山', '門', '建', '築']]
# generating skippy 3-grams ...
# #subsegs_full: [['山', '門', '建', '築']]
# generating skippy 4-grams ...
# #subsegs_full: [['山', '門', '建', '築']]
# Processing word 113 [use_Cython: False]: 鐘楼建築
# generating skippy 1-grams ...
# #subsegs_full: [['鐘', '楼', '建', '築']]
# generating skippy 2-grams ...
# #subsegs_full: [['鐘', '楼', '建', '築']]
# generating skippy 3-grams ...
# #subsegs_full: [['鐘', '楼', '建', '築']]
# generating skippy 4-grams ...
# #subsegs_full: [['鐘', '楼', '建', '築']]
# Processing word 114 [use_Cython: False]: 経蔵建築
# generating skippy 1-grams ...
# #subsegs_full: [['経', '蔵', '建', '築']]
# generating skippy 2-grams ...
# #subsegs_full: [['経', '蔵', '建', '築']]
# generating skippy 3-grams ...
# #subsegs_full: [['経', '蔵', '建', '築']]
# generating skippy 4-grams ...
# #subsegs_full: [['経', '蔵', '建', '築']]
# Processing word 115 [use_Cython: False]: 宝蔵建築
# generating skippy 1-grams ...
# #subsegs_full: [['宝', '蔵', '建', '築']]
# generating skippy 2-grams ...
# #subsegs_full: [['宝', '蔵', '建', '築']]
# generating skippy 3-grams ...
# #subsegs_full: [['宝', '蔵', '建', '築']]
# generating skippy 4-grams ...
# #subsegs_full: [['宝', '蔵', '建', '築']]
# Processing word 116 [use_Cython: False]: 石庭造園
# generating skippy 1-grams ...
# #subsegs_full: [['石', '庭', '造', '園']]
# generating skippy 2-grams ...
# #subsegs_full: [['石', '庭', '造', '園']]
# generating skippy 3-grams ...
# #subsegs_full: [['石', '庭', '造', '園']]
# generating skippy 4-grams ...
# #subsegs_full: [['石', '庭', '造', '園']]
# Processing word 117 [use_Cython: False]: 枯山水
# generating skippy 1-grams ...
# #subsegs_full: [['枯', '山', '水']]
# generating skippy 2-grams ...
# #subsegs_full: [['枯', '山', '水']]
# generating skippy 3-grams ...
# #subsegs_full: [['枯', '山', '水']]
# generating skippy 4-grams ...
# #subsegs_full: [['枯', '山', '水']]
# Processing word 118 [use_Cython: False]: 借景技法
# generating skippy 1-grams ...
# #subsegs_full: [['借', '景', '技', '法']]
# generating skippy 2-grams ...
# #subsegs_full: [['借', '景', '技', '法']]
# generating skippy 3-grams ...
# #subsegs_full: [['借', '景', '技', '法']]
# generating skippy 4-grams ...
# #subsegs_full: [['借', '景', '技', '法']]
# Processing word 119 [use_Cython: False]: 禅庭設計
# generating skippy 1-grams ...
# #subsegs_full: [['禅', '庭', '設', '計']]
# generating skippy 2-grams ...
# #subsegs_full: [['禅', '庭', '設', '計']]
# generating skippy 3-grams ...
# #subsegs_full: [['禅', '庭', '設', '計']]
# generating skippy 4-grams ...
# #subsegs_full: [['禅', '庭', '設', '計']]
# Processing word 120 [use_Cython: False]: 千手観音
# generating skippy 1-grams ...
# #subsegs_full: [['千', '手', '観', '音']]
# generating skippy 2-grams ...
# #subsegs_full: [['千', '手', '観', '音']]
# generating skippy 3-grams ...
# #subsegs_full: [['千', '手', '観', '音']]
# generating skippy 4-grams ...
# #subsegs_full: [['千', '手', '観', '音']]
# Processing word 121 [use_Cython: False]: 十一面観音
# generating skippy 1-grams ...
# #subsegs_full: [['十', '一', '面', '観', '音']]
# generating skippy 2-grams ...
# #subsegs_full: [['十', '一', '面', '観', '音']]
# generating skippy 3-grams ...
# #subsegs_full: [['十', '一', '面', '観', '音']]
# generating skippy 4-grams ...
# #subsegs_full: [['十', '一', '面', '観', '音']]
# Processing word 122 [use_Cython: False]: 馬頭観音
# generating skippy 1-grams ...
# #subsegs_full: [['馬', '頭', '観', '音']]
# generating skippy 2-grams ...
# #subsegs_full: [['馬', '頭', '観', '音']]
# generating skippy 3-grams ...
# #subsegs_full: [['馬', '頭', '観', '音']]
# generating skippy 4-grams ...
# #subsegs_full: [['馬', '頭', '観', '音']]
# Processing word 123 [use_Cython: False]: 如意輪観音
# generating skippy 1-grams ...
# #subsegs_full: [['如', '意', '輪', '観', '音']]
# generating skippy 2-grams ...
# #subsegs_full: [['如', '意', '輪', '観', '音']]
# generating skippy 3-grams ...
# #subsegs_full: [['如', '意', '輪', '観', '音']]
# generating skippy 4-grams ...
# #subsegs_full: [['如', '意', '輪', '観', '音']]
# Processing word 124 [use_Cython: False]: 准胝観音
# generating skippy 1-grams ...
# #subsegs_full: [['准', '胝', '観', '音']]
# generating skippy 2-grams ...
# #subsegs_full: [['准', '胝', '観', '音']]
# generating skippy 3-grams ...
# #subsegs_full: [['准', '胝', '観', '音']]
# generating skippy 4-grams ...
# #subsegs_full: [['准', '胝', '観', '音']]
# Processing word 125 [use_Cython: False]: 不空羂索観音
# generating skippy 1-grams ...
# #subsegs_full: [['不', '空', '羂', '索', '観', '音']]
# generating skippy 2-grams ...
# #subsegs_full: [['不', '空', '羂', '索', '観', '音']]
# generating skippy 3-grams ...
# #subsegs_full: [['不', '空', '羂', '索', '観', '音']]
# generating skippy 4-grams ...
# #subsegs_full: [['不', '空', '羂', '索', '観', '音']]
# Processing word 126 [use_Cython: False]: 聖観音菩薩
# generating skippy 1-grams ...
# #subsegs_full: [['聖', '観', '音', '菩', '薩']]
# generating skippy 2-grams ...
# #subsegs_full: [['聖', '観', '音', '菩', '薩']]
# generating skippy 3-grams ...
# #subsegs_full: [['聖', '観', '音', '菩', '薩']]
# generating skippy 4-grams ...
# #subsegs_full: [['聖', '観', '音', '菩', '薩']]
# Processing word 127 [use_Cython: False]: 勢至菩薩
# generating skippy 1-grams ...
# #subsegs_full: [['勢', '至', '菩', '薩']]
# generating skippy 2-grams ...
# #subsegs_full: [['勢', '至', '菩', '薩']]
# generating skippy 3-grams ...
# #subsegs_full: [['勢', '至', '菩', '薩']]
# generating skippy 4-grams ...
# #subsegs_full: [['勢', '至', '菩', '薩']]
# Processing word 128 [use_Cython: False]: 文殊菩薩
# generating skippy 1-grams ...
# #subsegs_full: [['文', '殊', '菩', '薩']]
# generating skippy 2-grams ...
# #subsegs_full: [['文', '殊', '菩', '薩']]
# generating skippy 3-grams ...
# #subsegs_full: [['文', '殊', '菩', '薩']]
# generating skippy 4-grams ...
# #subsegs_full: [['文', '殊', '菩', '薩']]
# Processing word 129 [use_Cython: False]: 普賢菩薩
# generating skippy 1-grams ...
# #subsegs_full: [['普', '賢', '菩', '薩']]
# generating skippy 2-grams ...
# #subsegs_full: [['普', '賢', '菩', '薩']]
# generating skippy 3-grams ...
# #subsegs_full: [['普', '賢', '菩', '薩']]
# generating skippy 4-grams ...
# #subsegs_full: [['普', '賢', '菩', '薩']]
# Processing word 130 [use_Cython: False]: 弥勒菩薩
# generating skippy 1-grams ...
# #subsegs_full: [['弥', '勒', '菩', '薩']]
# generating skippy 2-grams ...
# #subsegs_full: [['弥', '勒', '菩', '薩']]
# generating skippy 3-grams ...
# #subsegs_full: [['弥', '勒', '菩', '薩']]
# generating skippy 4-grams ...
# #subsegs_full: [['弥', '勒', '菩', '薩']]
# Processing word 131 [use_Cython: False]: 薬王菩薩
# generating skippy 1-grams ...
# #subsegs_full: [['薬', '王', '菩', '薩']]
# generating skippy 2-grams ...
# #subsegs_full: [['薬', '王', '菩', '薩']]
# generating skippy 3-grams ...
# #subsegs_full: [['薬', '王', '菩', '薩']]
# generating skippy 4-grams ...
# #subsegs_full: [['薬', '王', '菩', '薩']]
# Processing word 132 [use_Cython: False]: 薬上菩薩
# generating skippy 1-grams ...
# #subsegs_full: [['薬', '上', '菩', '薩']]
# generating skippy 2-grams ...
# #subsegs_full: [['薬', '上', '菩', '薩']]
# generating skippy 3-grams ...
# #subsegs_full: [['薬', '上', '菩', '薩']]
# generating skippy 4-grams ...
# #subsegs_full: [['薬', '上', '菩', '薩']]
# Processing word 133 [use_Cython: False]: 虚空蔵菩薩
# generating skippy 1-grams ...
# #subsegs_full: [['虚', '空', '蔵', '菩', '薩']]
# generating skippy 2-grams ...
# #subsegs_full: [['虚', '空', '蔵', '菩', '薩']]
# generating skippy 3-grams ...
# #subsegs_full: [['虚', '空', '蔵', '菩', '薩']]
# generating skippy 4-grams ...
# #subsegs_full: [['虚', '空', '蔵', '菩', '薩']]
# Processing word 134 [use_Cython: False]: 大勢至菩薩
# generating skippy 1-grams ...
# #subsegs_full: [['大', '勢', '至', '菩', '薩']]
# generating skippy 2-grams ...
# #subsegs_full: [['大', '勢', '至', '菩', '薩']]
# generating skippy 3-grams ...
# #subsegs_full: [['大', '勢', '至', '菩', '薩']]
# generating skippy 4-grams ...
# #subsegs_full: [['大', '勢', '至', '菩', '薩']]
# Processing word 135 [use_Cython: False]: 金剛界曼荼羅
# generating skippy 1-grams ...
# #subsegs_full: [['金', '剛', '界', '曼', '荼', '羅']]
# generating skippy 2-grams ...
# #subsegs_full: [['金', '剛', '界', '曼', '荼', '羅']]
# generating skippy 3-grams ...
# #subsegs_full: [['金', '剛', '界', '曼', '荼', '羅']]
# generating skippy 4-grams ...
# #subsegs_full: [['金', '剛', '界', '曼', '荼', '羅']]
# Processing word 136 [use_Cython: False]: 胎蔵界曼荼羅
# generating skippy 1-grams ...
# #subsegs_full: [['胎', '蔵', '界', '曼', '荼', '羅']]
# generating skippy 2-grams ...
# #subsegs_full: [['胎', '蔵', '界', '曼', '荼', '羅']]
# generating skippy 3-grams ...
# #subsegs_full: [['胎', '蔵', '界', '曼', '荼', '羅']]
# generating skippy 4-grams ...
# #subsegs_full: [['胎', '蔵', '界', '曼', '荼', '羅']]
# Processing word 137 [use_Cython: False]: 両部曼荼羅
# generating skippy 1-grams ...
# #subsegs_full: [['両', '部', '曼', '荼', '羅']]
# generating skippy 2-grams ...
# #subsegs_full: [['両', '部', '曼', '荼', '羅']]
# generating skippy 3-grams ...
# #subsegs_full: [['両', '部', '曼', '荼', '羅']]
# generating skippy 4-grams ...
# #subsegs_full: [['両', '部', '曼', '荼', '羅']]
# Processing word 138 [use_Cython: False]: 八葉蓮華
# generating skippy 1-grams ...
# #subsegs_full: [['八', '葉', '蓮', '華']]
# generating skippy 2-grams ...
# #subsegs_full: [['八', '葉', '蓮', '華']]
# generating skippy 3-grams ...
# #subsegs_full: [['八', '葉', '蓮', '華']]
# generating skippy 4-grams ...
# #subsegs_full: [['八', '葉', '蓮', '華']]
# Processing word 139 [use_Cython: False]: 宝相華文様
# generating skippy 1-grams ...
# #subsegs_full: [['宝', '相', '華', '文', '様']]
# generating skippy 2-grams ...
# #subsegs_full: [['宝', '相', '華', '文', '様']]
# generating skippy 3-grams ...
# #subsegs_full: [['宝', '相', '華', '文', '様']]
# generating skippy 4-grams ...
# #subsegs_full: [['宝', '相', '華', '文', '様']]
# Processing word 140 [use_Cython: False]: 出家得度
# generating skippy 1-grams ...
# #subsegs_full: [['出', '家', '得', '度']]
# generating skippy 2-grams ...
# #subsegs_full: [['出', '家', '得', '度']]
# generating skippy 3-grams ...
# #subsegs_full: [['出', '家', '得', '度']]
# generating skippy 4-grams ...
# #subsegs_full: [['出', '家', '得', '度']]
# Processing word 141 [use_Cython: False]: 在家信者
# generating skippy 1-grams ...
# #subsegs_full: [['在', '家', '信', '者']]
# generating skippy 2-grams ...
# #subsegs_full: [['在', '家', '信', '者']]
# generating skippy 3-grams ...
# #subsegs_full: [['在', '家', '信', '者']]
# generating skippy 4-grams ...
# #subsegs_full: [['在', '家', '信', '者']]
# Processing word 142 [use_Cython: False]: 優婆塞
# generating skippy 1-grams ...
# #subsegs_full: [['優', '婆', '塞']]
# generating skippy 2-grams ...
# #subsegs_full: [['優', '婆', '塞']]
# generating skippy 3-grams ...
# #subsegs_full: [['優', '婆', '塞']]
# generating skippy 4-grams ...
# #subsegs_full: [['優', '婆', '塞']]
# Processing word 143 [use_Cython: False]: 優婆夷
# generating skippy 1-grams ...
# #subsegs_full: [['優', '婆', '夷']]
# generating skippy 2-grams ...
# #subsegs_full: [['優', '婆', '夷']]
# generating skippy 3-grams ...
# #subsegs_full: [['優', '婆', '夷']]
# generating skippy 4-grams ...
# #subsegs_full: [['優', '婆', '夷']]
# Processing word 144 [use_Cython: False]: 沙弥僧
# generating skippy 1-grams ...
# #subsegs_full: [['沙', '弥', '僧']]
# generating skippy 2-grams ...
# #subsegs_full: [['沙', '弥', '僧']]
# generating skippy 3-grams ...
# #subsegs_full: [['沙', '弥', '僧']]
# generating skippy 4-grams ...
# #subsegs_full: [['沙', '弥', '僧']]
# Processing word 145 [use_Cython: False]: 沙弥尼
# generating skippy 1-grams ...
# #subsegs_full: [['沙', '弥', '尼']]
# generating skippy 2-grams ...
# #subsegs_full: [['沙', '弥', '尼']]
# generating skippy 3-grams ...
# #subsegs_full: [['沙', '弥', '尼']]
# generating skippy 4-grams ...
# #subsegs_full: [['沙', '弥', '尼']]
# Processing word 146 [use_Cython: False]: 比丘僧
# generating skippy 1-grams ...
# #subsegs_full: [['比', '丘', '僧']]
# generating skippy 2-grams ...
# #subsegs_full: [['比', '丘', '僧']]
# generating skippy 3-grams ...
# #subsegs_full: [['比', '丘', '僧']]
# generating skippy 4-grams ...
# #subsegs_full: [['比', '丘', '僧']]
# Processing word 147 [use_Cython: False]: 比丘尼
# generating skippy 1-grams ...
# #subsegs_full: [['比', '丘', '尼']]
# generating skippy 2-grams ...
# #subsegs_full: [['比', '丘', '尼']]
# generating skippy 3-grams ...
# #subsegs_full: [['比', '丘', '尼']]
# generating skippy 4-grams ...
# #subsegs_full: [['比', '丘', '尼']]
# Processing word 148 [use_Cython: False]: 阿闍梨
# generating skippy 1-grams ...
# #subsegs_full: [['阿', '闍', '梨']]
# generating skippy 2-grams ...
# #subsegs_full: [['阿', '闍', '梨']]
# generating skippy 3-grams ...
# #subsegs_full: [['阿', '闍', '梨']]
# generating skippy 4-grams ...
# #subsegs_full: [['阿', '闍', '梨']]
# Processing word 149 [use_Cython: False]: 三蔵法師
# generating skippy 1-grams ...
# #subsegs_full: [['三', '蔵', '法', '師']]
# generating skippy 2-grams ...
# #subsegs_full: [['三', '蔵', '法', '師']]
# generating skippy 3-grams ...
# #subsegs_full: [['三', '蔵', '法', '師']]
# generating skippy 4-grams ...
# #subsegs_full: [['三', '蔵', '法', '師']]
# Processing word 150 [use_Cython: False]: 律師職位
# generating skippy 1-grams ...
# #subsegs_full: [['律', '師', '職', '位']]
# generating skippy 2-grams ...
# #subsegs_full: [['律', '師', '職', '位']]
# generating skippy 3-grams ...
# #subsegs_full: [['律', '師', '職', '位']]
# generating skippy 4-grams ...
# #subsegs_full: [['律', '師', '職', '位']]
# Processing word 151 [use_Cython: False]: 禅師職位
# generating skippy 1-grams ...
# #subsegs_full: [['禅', '師', '職', '位']]
# generating skippy 2-grams ...
# #subsegs_full: [['禅', '師', '職', '位']]
# generating skippy 3-grams ...
# #subsegs_full: [['禅', '師', '職', '位']]
# generating skippy 4-grams ...
# #subsegs_full: [['禅', '師', '職', '位']]
# Processing word 152 [use_Cython: False]: 大僧正
# generating skippy 1-grams ...
# #subsegs_full: [['大', '僧', '正']]
# generating skippy 2-grams ...
# #subsegs_full: [['大', '僧', '正']]
# generating skippy 3-grams ...
# #subsegs_full: [['大', '僧', '正']]
# generating skippy 4-grams ...
# #subsegs_full: [['大', '僧', '正']]
# Processing word 153 [use_Cython: False]: 僧正職位
# generating skippy 1-grams ...
# #subsegs_full: [['僧', '正', '職', '位']]
# generating skippy 2-grams ...
# #subsegs_full: [['僧', '正', '職', '位']]
# generating skippy 3-grams ...
# #subsegs_full: [['僧', '正', '職', '位']]
# generating skippy 4-grams ...
# #subsegs_full: [['僧', '正', '職', '位']]
# Processing word 154 [use_Cython: False]: 権僧正
# generating skippy 1-grams ...
# #subsegs_full: [['権', '僧', '正']]
# generating skippy 2-grams ...
# #subsegs_full: [['権', '僧', '正']]
# generating skippy 3-grams ...
# #subsegs_full: [['権', '僧', '正']]
# generating skippy 4-grams ...
# #subsegs_full: [['権', '僧', '正']]
# Processing word 155 [use_Cython: False]: 少僧都
# generating skippy 1-grams ...
# #subsegs_full: [['少', '僧', '都']]
# generating skippy 2-grams ...
# #subsegs_full: [['少', '僧', '都']]
# generating skippy 3-grams ...
# #subsegs_full: [['少', '僧', '都']]
# generating skippy 4-grams ...
# #subsegs_full: [['少', '僧', '都']]
# Processing word 156 [use_Cython: False]: 権少僧都
# generating skippy 1-grams ...
# #subsegs_full: [['権', '少', '僧', '都']]
# generating skippy 2-grams ...
# #subsegs_full: [['権', '少', '僧', '都']]
# generating skippy 3-grams ...
# #subsegs_full: [['権', '少', '僧', '都']]
# generating skippy 4-grams ...
# #subsegs_full: [['権', '少', '僧', '都']]
# Processing word 157 [use_Cython: False]: 法印大和尚
# generating skippy 1-grams ...
# #subsegs_full: [['法', '印', '大', '和', '尚']]
# generating skippy 2-grams ...
# #subsegs_full: [['法', '印', '大', '和', '尚']]
# generating skippy 3-grams ...
# #subsegs_full: [['法', '印', '大', '和', '尚']]
# generating skippy 4-grams ...
# #subsegs_full: [['法', '印', '大', '和', '尚']]
# Processing word 158 [use_Cython: False]: 伝燈大阿闍梨
# generating skippy 1-grams ...
# #subsegs_full: [['伝', '燈', '大', '阿', '闍', '梨']]
# generating skippy 2-grams ...
# #subsegs_full: [['伝', '燈', '大', '阿', '闍', '梨']]
# generating skippy 3-grams ...
# #subsegs_full: [['伝', '燈', '大', '阿', '闍', '梨']]
# generating skippy 4-grams ...
# #subsegs_full: [['伝', '燈', '大', '阿', '闍', '梨']]
# Processing word 159 [use_Cython: False]: 権大僧都
# generating skippy 1-grams ...
# #subsegs_full: [['権', '大', '僧', '都']]
# generating skippy 2-grams ...
# #subsegs_full: [['権', '大', '僧', '都']]
# generating skippy 3-grams ...
# #subsegs_full: [['権', '大', '僧', '都']]
# generating skippy 4-grams ...
# #subsegs_full: [['権', '大', '僧', '都']]
# Processing word 160 [use_Cython: False]: 三論教学
# generating skippy 1-grams ...
# #subsegs_full: [['三', '論', '教', '学']]
# generating skippy 2-grams ...
# #subsegs_full: [['三', '論', '教', '学']]
# generating skippy 3-grams ...
# #subsegs_full: [['三', '論', '教', '学']]
# generating skippy 4-grams ...
# #subsegs_full: [['三', '論', '教', '学']]
# Processing word 161 [use_Cython: False]: 法相教学
# generating skippy 1-grams ...
# #subsegs_full: [['法', '相', '教', '学']]
# generating skippy 2-grams ...
# #subsegs_full: [['法', '相', '教', '学']]
# generating skippy 3-grams ...
# #subsegs_full: [['法', '相', '教', '学']]
# generating skippy 4-grams ...
# #subsegs_full: [['法', '相', '教', '学']]
# Processing word 162 [use_Cython: False]: 華厳教学
# generating skippy 1-grams ...
# #subsegs_full: [['華', '厳', '教', '学']]
# generating skippy 2-grams ...
# #subsegs_full: [['華', '厳', '教', '学']]
# generating skippy 3-grams ...
# #subsegs_full: [['華', '厳', '教', '学']]
# generating skippy 4-grams ...
# #subsegs_full: [['華', '厳', '教', '学']]
# Processing word 163 [use_Cython: False]: 天台教学
# generating skippy 1-grams ...
# #subsegs_full: [['天', '台', '教', '学']]
# generating skippy 2-grams ...
# #subsegs_full: [['天', '台', '教', '学']]
# generating skippy 3-grams ...
# #subsegs_full: [['天', '台', '教', '学']]
# generating skippy 4-grams ...
# #subsegs_full: [['天', '台', '教', '学']]
# Processing word 164 [use_Cython: False]: 真言教学
# generating skippy 1-grams ...
# #subsegs_full: [['真', '言', '教', '学']]
# generating skippy 2-grams ...
# #subsegs_full: [['真', '言', '教', '学']]
# generating skippy 3-grams ...
# #subsegs_full: [['真', '言', '教', '学']]
# generating skippy 4-grams ...
# #subsegs_full: [['真', '言', '教', '学']]
# Processing word 165 [use_Cython: False]: 浄土教学
# generating skippy 1-grams ...
# #subsegs_full: [['浄', '土', '教', '学']]
# generating skippy 2-grams ...
# #subsegs_full: [['浄', '土', '教', '学']]
# generating skippy 3-grams ...
# #subsegs_full: [['浄', '土', '教', '学']]
# generating skippy 4-grams ...
# #subsegs_full: [['浄', '土', '教', '学']]
# Processing word 166 [use_Cython: False]: 禅宗教学
# generating skippy 1-grams ...
# #subsegs_full: [['禅', '宗', '教', '学']]
# generating skippy 2-grams ...
# #subsegs_full: [['禅', '宗', '教', '学']]
# generating skippy 3-grams ...
# #subsegs_full: [['禅', '宗', '教', '学']]
# generating skippy 4-grams ...
# #subsegs_full: [['禅', '宗', '教', '学']]
# Processing word 167 [use_Cython: False]: 日蓮教学
# generating skippy 1-grams ...
# #subsegs_full: [['日', '蓮', '教', '学']]
# generating skippy 2-grams ...
# #subsegs_full: [['日', '蓮', '教', '学']]
# generating skippy 3-grams ...
# #subsegs_full: [['日', '蓮', '教', '学']]
# generating skippy 4-grams ...
# #subsegs_full: [['日', '蓮', '教', '学']]
# Processing word 168 [use_Cython: False]: 唯識思想
# generating skippy 1-grams ...
# #subsegs_full: [['唯', '識', '思', '想']]
# generating skippy 2-grams ...
# #subsegs_full: [['唯', '識', '思', '想']]
# generating skippy 3-grams ...
# #subsegs_full: [['唯', '識', '思', '想']]
# generating skippy 4-grams ...
# #subsegs_full: [['唯', '識', '思', '想']]
# Processing word 169 [use_Cython: False]: 如来蔵思想
# generating skippy 1-grams ...
# #subsegs_full: [['如', '来', '蔵', '思', '想']]
# generating skippy 2-grams ...
# #subsegs_full: [['如', '来', '蔵', '思', '想']]
# generating skippy 3-grams ...
# #subsegs_full: [['如', '来', '蔵', '思', '想']]
# generating skippy 4-grams ...
# #subsegs_full: [['如', '来', '蔵', '思', '想']]
# Processing word 170 [use_Cython: False]: 本覚思想
# generating skippy 1-grams ...
# #subsegs_full: [['本', '覚', '思', '想']]
# generating skippy 2-grams ...
# #subsegs_full: [['本', '覚', '思', '想']]
# generating skippy 3-grams ...
# #subsegs_full: [['本', '覚', '思', '想']]
# generating skippy 4-grams ...
# #subsegs_full: [['本', '覚', '思', '想']]
# Processing word 171 [use_Cython: False]: 末法思想
# generating skippy 1-grams ...
# #subsegs_full: [['末', '法', '思', '想']]
# generating skippy 2-grams ...
# #subsegs_full: [['末', '法', '思', '想']]
# generating skippy 3-grams ...
# #subsegs_full: [['末', '法', '思', '想']]
# generating skippy 4-grams ...
# #subsegs_full: [['末', '法', '思', '想']]
# Processing word 172 [use_Cython: False]: 易行道
# generating skippy 1-grams ...
# #subsegs_full: [['易', '行', '道']]
# generating skippy 2-grams ...
# #subsegs_full: [['易', '行', '道']]
# generating skippy 3-grams ...
# #subsegs_full: [['易', '行', '道']]
# generating skippy 4-grams ...
# #subsegs_full: [['易', '行', '道']]
# Processing word 173 [use_Cython: False]: 難行道
# generating skippy 1-grams ...
# #subsegs_full: [['難', '行', '道']]
# generating skippy 2-grams ...
# #subsegs_full: [['難', '行', '道']]
# generating skippy 3-grams ...
# #subsegs_full: [['難', '行', '道']]
# generating skippy 4-grams ...
# #subsegs_full: [['難', '行', '道']]
# Processing word 174 [use_Cython: False]: 聖道門
# generating skippy 1-grams ...
# #subsegs_full: [['聖', '道', '門']]
# generating skippy 2-grams ...
# #subsegs_full: [['聖', '道', '門']]
# generating skippy 3-grams ...
# #subsegs_full: [['聖', '道', '門']]
# generating skippy 4-grams ...
# #subsegs_full: [['聖', '道', '門']]
# Processing word 175 [use_Cython: False]: 浄土門
# generating skippy 1-grams ...
# #subsegs_full: [['浄', '土', '門']]
# generating skippy 2-grams ...
# #subsegs_full: [['浄', '土', '門']]
# generating skippy 3-grams ...
# #subsegs_full: [['浄', '土', '門']]
# generating skippy 4-grams ...
# #subsegs_full: [['浄', '土', '門']]
# Processing word 176 [use_Cython: False]: 権教方便
# generating skippy 1-grams ...
# #subsegs_full: [['権', '教', '方', '便']]
# generating skippy 2-grams ...
# #subsegs_full: [['権', '教', '方', '便']]
# generating skippy 3-grams ...
# #subsegs_full: [['権', '教', '方', '便']]
# generating skippy 4-grams ...
# #subsegs_full: [['権', '教', '方', '便']]
# Processing word 177 [use_Cython: False]: 実教真実
# generating skippy 1-grams ...
# #subsegs_full: [['実', '教', '真', '実']]
# generating skippy 2-grams ...
# #subsegs_full: [['実', '教', '真', '実']]
# generating skippy 3-grams ...
# #subsegs_full: [['実', '教', '真', '実']]
# generating skippy 4-grams ...
# #subsegs_full: [['実', '教', '真', '実']]
# Processing word 178 [use_Cython: False]: 五時八教
# generating skippy 1-grams ...
# #subsegs_full: [['五', '時', '八', '教']]
# generating skippy 2-grams ...
# #subsegs_full: [['五', '時', '八', '教']]
# generating skippy 3-grams ...
# #subsegs_full: [['五', '時', '八', '教']]
# generating skippy 4-grams ...
# #subsegs_full: [['五', '時', '八', '教']]
# Processing word 179 [use_Cython: False]: 化法四教
# generating skippy 1-grams ...
# #subsegs_full: [['化', '法', '四', '教']]
# generating skippy 2-grams ...
# #subsegs_full: [['化', '法', '四', '教']]
# generating skippy 3-grams ...
# #subsegs_full: [['化', '法', '四', '教']]
# generating skippy 4-grams ...
# #subsegs_full: [['化', '法', '四', '教']]
# Processing word 180 [use_Cython: False]: 降誕会法要
# generating skippy 1-grams ...
# #subsegs_full: [['降', '誕', '会', '法', '要']]
# generating skippy 2-grams ...
# #subsegs_full: [['降', '誕', '会', '法', '要']]
# generating skippy 3-grams ...
# #subsegs_full: [['降', '誕', '会', '法', '要']]
# generating skippy 4-grams ...
# #subsegs_full: [['降', '誕', '会', '法', '要']]
# Processing word 181 [use_Cython: False]: 成道会法要
# generating skippy 1-grams ...
# #subsegs_full: [['成', '道', '会', '法', '要']]
# generating skippy 2-grams ...
# #subsegs_full: [['成', '道', '会', '法', '要']]
# generating skippy 3-grams ...
# #subsegs_full: [['成', '道', '会', '法', '要']]
# generating skippy 4-grams ...
# #subsegs_full: [['成', '道', '会', '法', '要']]
# Processing word 182 [use_Cython: False]: 涅槃会法要
# generating skippy 1-grams ...
# #subsegs_full: [['涅', '槃', '会', '法', '要']]
# generating skippy 2-grams ...
# #subsegs_full: [['涅', '槃', '会', '法', '要']]
# generating skippy 3-grams ...
# #subsegs_full: [['涅', '槃', '会', '法', '要']]
# generating skippy 4-grams ...
# #subsegs_full: [['涅', '槃', '会', '法', '要']]
# Processing word 183 [use_Cython: False]: 春彼岸法要
# generating skippy 1-grams ...
# #subsegs_full: [['春', '彼', '岸', '法', '要']]
# generating skippy 2-grams ...
# #subsegs_full: [['春', '彼', '岸', '法', '要']]
# generating skippy 3-grams ...
# #subsegs_full: [['春', '彼', '岸', '法', '要']]
# generating skippy 4-grams ...
# #subsegs_full: [['春', '彼', '岸', '法', '要']]
# Processing word 184 [use_Cython: False]: 秋彼岸法要
# generating skippy 1-grams ...
# #subsegs_full: [['秋', '彼', '岸', '法', '要']]
# generating skippy 2-grams ...
# #subsegs_full: [['秋', '彼', '岸', '法', '要']]
# generating skippy 3-grams ...
# #subsegs_full: [['秋', '彼', '岸', '法', '要']]
# generating skippy 4-grams ...
# #subsegs_full: [['秋', '彼', '岸', '法', '要']]
# Processing word 185 [use_Cython: False]: 盂蘭盆会
# generating skippy 1-grams ...
# #subsegs_full: [['盂', '蘭', '盆', '会']]
# generating skippy 2-grams ...
# #subsegs_full: [['盂', '蘭', '盆', '会']]
# generating skippy 3-grams ...
# #subsegs_full: [['盂', '蘭', '盆', '会']]
# generating skippy 4-grams ...
# #subsegs_full: [['盂', '蘭', '盆', '会']]
# Processing word 186 [use_Cython: False]: 十夜法要
# generating skippy 1-grams ...
# #subsegs_full: [['十', '夜', '法', '要']]
# generating skippy 2-grams ...
# #subsegs_full: [['十', '夜', '法', '要']]
# generating skippy 3-grams ...
# #subsegs_full: [['十', '夜', '法', '要']]
# generating skippy 4-grams ...
# #subsegs_full: [['十', '夜', '法', '要']]
# Processing word 187 [use_Cython: False]: 修正会法要
# generating skippy 1-grams ...
# #subsegs_full: [['修', '正', '会', '法', '要']]
# generating skippy 2-grams ...
# #subsegs_full: [['修', '正', '会', '法', '要']]
# generating skippy 3-grams ...
# #subsegs_full: [['修', '正', '会', '法', '要']]
# generating skippy 4-grams ...
# #subsegs_full: [['修', '正', '会', '法', '要']]
# Processing word 188 [use_Cython: False]: 節分会法要
# generating skippy 1-grams ...
# #subsegs_full: [['節', '分', '会', '法', '要']]
# generating skippy 2-grams ...
# #subsegs_full: [['節', '分', '会', '法', '要']]
# generating skippy 3-grams ...
# #subsegs_full: [['節', '分', '会', '法', '要']]
# generating skippy 4-grams ...
# #subsegs_full: [['節', '分', '会', '法', '要']]
# Processing word 189 [use_Cython: False]: 灌仏会法要
# generating skippy 1-grams ...
# #subsegs_full: [['灌', '仏', '会', '法', '要']]
# generating skippy 2-grams ...
# #subsegs_full: [['灌', '仏', '会', '法', '要']]
# generating skippy 3-grams ...
# #subsegs_full: [['灌', '仏', '会', '法', '要']]
# generating skippy 4-grams ...
# #subsegs_full: [['灌', '仏', '会', '法', '要']]
# Processing word 190 [use_Cython: False]: 花祭り行事
# generating skippy 1-grams ...
# #subsegs_full: [['花', '祭', 'り', '行', '事']]
# generating skippy 2-grams ...
# #subsegs_full: [['花', '祭', 'り', '行', '事']]
# generating skippy 3-grams ...
# #subsegs_full: [['花', '祭', 'り', '行', '事']]
# generating skippy 4-grams ...
# #subsegs_full: [['花', '祭', 'り', '行', '事']]
# Processing word 191 [use_Cython: False]: 除夜の鐘
# generating skippy 1-grams ...
# #subsegs_full: [['除', '夜', 'の', '鐘']]
# generating skippy 2-grams ...
# #subsegs_full: [['除', '夜', 'の', '鐘']]
# generating skippy 3-grams ...
# #subsegs_full: [['除', '夜', 'の', '鐘']]
# generating skippy 4-grams ...
# #subsegs_full: [['除', '夜', 'の', '鐘']]
# Processing word 192 [use_Cython: False]: 初詣参拝
# generating skippy 1-grams ...
# #subsegs_full: [['初', '詣', '参', '拝']]
# generating skippy 2-grams ...
# #subsegs_full: [['初', '詣', '参', '拝']]
# generating skippy 3-grams ...
# #subsegs_full: [['初', '詣', '参', '拝']]
# generating skippy 4-grams ...
# #subsegs_full: [['初', '詣', '参', '拝']]
# Processing word 193 [use_Cython: False]: 初護摩法要
# generating skippy 1-grams ...
# #subsegs_full: [['初', '護', '摩', '法', '要']]
# generating skippy 2-grams ...
# #subsegs_full: [['初', '護', '摩', '法', '要']]
# generating skippy 3-grams ...
# #subsegs_full: [['初', '護', '摩', '法', '要']]
# generating skippy 4-grams ...
# #subsegs_full: [['初', '護', '摩', '法', '要']]
# Processing word 194 [use_Cython: False]: 開山忌法要
# generating skippy 1-grams ...
# #subsegs_full: [['開', '山', '忌', '法', '要']]
# generating skippy 2-grams ...
# #subsegs_full: [['開', '山', '忌', '法', '要']]
# generating skippy 3-grams ...
# #subsegs_full: [['開', '山', '忌', '法', '要']]
# generating skippy 4-grams ...
# #subsegs_full: [['開', '山', '忌', '法', '要']]
# Processing word 195 [use_Cython: False]: 両祖忌法要
# generating skippy 1-grams ...
# #subsegs_full: [['両', '祖', '忌', '法', '要']]
# generating skippy 2-grams ...
# #subsegs_full: [['両', '祖', '忌', '法', '要']]
# generating skippy 3-grams ...
# #subsegs_full: [['両', '祖', '忌', '法', '要']]
# generating skippy 4-grams ...
# #subsegs_full: [['両', '祖', '忌', '法', '要']]
# Processing word 196 [use_Cython: False]: 宗祖忌法要
# generating skippy 1-grams ...
# #subsegs_full: [['宗', '祖', '忌', '法', '要']]
# generating skippy 2-grams ...
# #subsegs_full: [['宗', '祖', '忌', '法', '要']]
# generating skippy 3-grams ...
# #subsegs_full: [['宗', '祖', '忌', '法', '要']]
# generating skippy 4-grams ...
# #subsegs_full: [['宗', '祖', '忌', '法', '要']]
# Processing word 197 [use_Cython: False]: 御会式法要
# generating skippy 1-grams ...
# #subsegs_full: [['御', '会', '式', '法', '要']]
# generating skippy 2-grams ...
# #subsegs_full: [['御', '会', '式', '法', '要']]
# generating skippy 3-grams ...
# #subsegs_full: [['御', '会', '式', '法', '要']]
# generating skippy 4-grams ...
# #subsegs_full: [['御', '会', '式', '法', '要']]
# Processing word 198 [use_Cython: False]: 報恩講法要
# generating skippy 1-grams ...
# #subsegs_full: [['報', '恩', '講', '法', '要']]
# generating skippy 2-grams ...
# #subsegs_full: [['報', '恩', '講', '法', '要']]
# generating skippy 3-grams ...
# #subsegs_full: [['報', '恩', '講', '法', '要']]
# generating skippy 4-grams ...
# #subsegs_full: [['報', '恩', '講', '法', '要']]
# Processing word 199 [use_Cython: False]: 追悼法要式
# generating skippy 1-grams ...
# #subsegs_full: [['追', '悼', '法', '要', '式']]
# generating skippy 2-grams ...
# #subsegs_full: [['追', '悼', '法', '要', '式']]
# generating skippy 3-grams ...
# #subsegs_full: [['追', '悼', '法', '要', '式']]
# generating skippy 4-grams ...
# #subsegs_full: [['追', '悼', '法', '要', '式']]

# %%
df[columns0 + columns2]
# Out:
#        doc             sk1g  \
# 0      阿羅漢        [阿, 羅, 漢]
# 1      辟支仏        [辟, 支, 仏]
# 2      転法輪        [転, 法, 輪]
# 3     十二因縁     [十, 二, 因, 縁]
# 4     五蘊盛苦     [五, 蘊, 盛, 苦]
# ..     ...              ...
# 195  両祖忌法要  [両, 祖, 忌, 法, 要]
# 196  宗祖忌法要  [宗, 祖, 忌, 法, 要]
# 197  御会式法要  [御, 会, 式, 法, 要]
# 198  報恩講法要  [報, 恩, 講, 法, 要]
# 199  追悼法要式  [追, 悼, 法, 要, 式]
#
#                                                   sk2g  \
# 0                               [阿羅, 阿…漢, 阿, 羅漢, 羅, 漢]
# 1                               [辟支, 辟…仏, 辟, 支仏, 支, 仏]
# 2                               [転法, 転…輪, 転, 法輪, 法, 輪]
# 3              [十二, 十…因, 十…縁, 十, 二因, 二…縁, 二, 因縁, 因, 縁]
# 4              [五蘊, 五…盛, 五…苦, 五, 蘊盛, 蘊…苦, 蘊, 盛苦, 盛, 苦]
# ..                                                 ...
# 195  [両祖, 両…忌, 両…法, 両…要, 両, 祖忌, 祖…法, 祖…要, 祖, 忌法, 忌…...
# 196  [宗祖, 宗…忌, 宗…法, 宗…要, 宗, 祖忌, 祖…法, 祖…要, 祖, 忌法, 忌…...
# 197  [御会, 御…式, 御…法, 御…要, 御, 会式, 会…法, 会…要, 会, 式法, 式…...
# 198  [報恩, 報…講, 報…法, 報…要, 報, 恩講, 恩…法, 恩…要, 恩, 講法, 講…...
# 199  [追悼, 追…法, 追…要, 追…式, 追, 悼法, 悼…要, 悼…式, 悼, 法要, 法…...
#
#                                                   sk3g  \
# 0                          [阿羅, 阿…漢, 阿, 羅漢, 羅, 漢, 阿羅漢]
# 1                          [辟支, 辟…仏, 辟, 支仏, 支, 仏, 辟支仏]
# 2                          [転法, 転…輪, 転, 法輪, 法, 輪, 転法輪]
# 3    [十二因, 十二…縁, 十二, 十…因縁, 十…因, 十…縁, 十, 二因縁, 二因, 二…...
# 4    [五蘊盛, 五蘊…苦, 五蘊, 五…盛苦, 五…盛, 五…苦, 五, 蘊盛苦, 蘊盛, 蘊…...
# ..                                                 ...
# 195  [両祖忌, 両祖…法, 両祖…要, 両祖, 両…忌法, 両…忌…要, 両…忌, 両…法要, ...
# 196  [宗祖忌, 宗祖…法, 宗祖…要, 宗祖, 宗…忌法, 宗…忌…要, 宗…忌, 宗…法要, ...
# 197  [御会式, 御会…法, 御会…要, 御会, 御…式法, 御…式…要, 御…式, 御…法要, ...
# 198  [報恩講, 報恩…法, 報恩…要, 報恩, 報…講法, 報…講…要, 報…講, 報…法要, ...
# 199  [追悼法, 追悼…要, 追悼…式, 追悼, 追…法要, 追…法…式, 追…法, 追…要式, ...
#
#                                                   sk4g
# 0                          [阿羅, 阿…漢, 阿, 羅漢, 羅, 漢, 阿羅漢]
# 1                          [辟支, 辟…仏, 辟, 支仏, 支, 仏, 辟支仏]
# 2                          [転法, 転…輪, 転, 法輪, 法, 輪, 転法輪]
# 3    [十二因, 十二…縁, 十二, 十…因縁, 十…因, 十…縁, 十, 二因縁, 二因, 二…...
# 4    [五蘊盛, 五蘊…苦, 五蘊, 五…盛苦, 五…盛, 五…苦, 五, 蘊盛苦, 蘊盛, 蘊…...
# ..                                                 ...
# 195  [両祖忌法, 両祖忌…要, 両祖忌, 両祖…法要, 両祖…法, 両祖…要, 両祖, 両…忌法...
# 196  [宗祖忌法, 宗祖忌…要, 宗祖忌, 宗祖…法要, 宗祖…法, 宗祖…要, 宗祖, 宗…忌法...
# 197  [御会式法, 御会式…要, 御会式, 御会…法要, 御会…法, 御会…要, 御会, 御…式法...
# 198  [報恩講法, 報恩講…要, 報恩講, 報恩…法要, 報恩…法, 報恩…要, 報恩, 報…講法...
# 199  [追悼法要, 追悼法…式, 追悼法, 追悼…要式, 追悼…要, 追悼…式, 追悼, 追…法要...
#
# [200 rows x 5 columns]

# %% [markdown]
# ## Normal

# %%
## generate non-skippy n-grams
import re
for i, doc in enumerate(docs):
    ## update df for word
    df.loc[i,'doc'] = doc
    ##
    print(f"Processing word {i} [use_Cython: {use_Cython}]: {doc}")
    word_segs = [ x for x in re.split(segmenter, doc) if len(x) > 0 ]
    for j in range(1, max_n_for_ngram + 1):
        print(f"generating {j}-grams ...")
        ngrams = gen_ngrams.gen_ngrams(word_segs, j, inclusive = ngram_is_inclusive, sep = sep_local, as_list = generated_as_list, check = False)
        if check:
            print(ngrams)
        ## update df
        df.loc[i, f'{j}g'] = ngrams
# Out:
# Processing word 0 [use_Cython: False]: 阿羅漢
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 1 [use_Cython: False]: 辟支仏
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 2 [use_Cython: False]: 転法輪
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 3 [use_Cython: False]: 十二因縁
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 4 [use_Cython: False]: 五蘊盛苦
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 5 [use_Cython: False]: 三法印
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 6 [use_Cython: False]: 四念処
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 7 [use_Cython: False]: 四神足
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 8 [use_Cython: False]: 五根五力
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 9 [use_Cython: False]: 七覚支
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 10 [use_Cython: False]: 三十七道品
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 11 [use_Cython: False]: 十善戒
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 12 [use_Cython: False]: 六神通
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 13 [use_Cython: False]: 四無量心
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 14 [use_Cython: False]: 慈悲喜捨
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 15 [use_Cython: False]: 八風不動
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 16 [use_Cython: False]: 不退転
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 17 [use_Cython: False]: 阿耨多羅三藐三菩提
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 18 [use_Cython: False]: 一切智
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 19 [use_Cython: False]: 無生法忍
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 20 [use_Cython: False]: 止観双修
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 21 [use_Cython: False]: 四禅定
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 22 [use_Cython: False]: 九次第定
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 23 [use_Cython: False]: 滅尽定
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 24 [use_Cython: False]: 無想定
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 25 [use_Cython: False]: 観呼吸
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 26 [use_Cython: False]: 観身不浄
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 27 [use_Cython: False]: 数息観
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 28 [use_Cython: False]: 白骨観
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 29 [use_Cython: False]: 不浄観
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 30 [use_Cython: False]: 慈心観
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 31 [use_Cython: False]: 因縁観
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 32 [use_Cython: False]: 念死観
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 33 [use_Cython: False]: 随念三宝
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 34 [use_Cython: False]: 経行禅
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 35 [use_Cython: False]: 立禅法
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 36 [use_Cython: False]: 食禅法
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 37 [use_Cython: False]: 作務禅
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 38 [use_Cython: False]: 公案禅
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 39 [use_Cython: False]: 只管打坐
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 40 [use_Cython: False]: 阿含経
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 41 [use_Cython: False]: 大般涅槃経
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 42 [use_Cython: False]: 大日経
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 43 [use_Cython: False]: 金剛頂経
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 44 [use_Cython: False]: 理趣経
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 45 [use_Cython: False]: 観音経
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 46 [use_Cython: False]: 地蔵経
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 47 [use_Cython: False]: 薬師経
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 48 [use_Cython: False]: 無量寿経
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 49 [use_Cython: False]: 観無量寿経
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 50 [use_Cython: False]: 倶舎論
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 51 [use_Cython: False]: 成実論
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 52 [use_Cython: False]: 大智度論
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 53 [use_Cython: False]: 中論頌
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 54 [use_Cython: False]: 唯識論
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 55 [use_Cython: False]: 起信論
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 56 [use_Cython: False]: 摩訶止観
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 57 [use_Cython: False]: 法界次第
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 58 [use_Cython: False]: 禅源諸詮集
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 59 [use_Cython: False]: 景徳伝灯録
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 60 [use_Cython: False]: 小乗仏教
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 61 [use_Cython: False]: 大乗仏教
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 62 [use_Cython: False]: 金剛乗
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 63 [use_Cython: False]: 秘密仏教
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 64 [use_Cython: False]: 南都六宗
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 65 [use_Cython: False]: 三論宗
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 66 [use_Cython: False]: 成実宗
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 67 [use_Cython: False]: 俱舎宗
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 68 [use_Cython: False]: 法相宗
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 69 [use_Cython: False]: 律宗派
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 70 [use_Cython: False]: 時宗派
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 71 [use_Cython: False]: 融通念仏宗
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 72 [use_Cython: False]: 一遍上人
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 73 [use_Cython: False]: 親鸞聖人
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 74 [use_Cython: False]: 法然上人
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 75 [use_Cython: False]: 道元禅師
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 76 [use_Cython: False]: 栄西禅師
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 77 [use_Cython: False]: 空海大師
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 78 [use_Cython: False]: 最澄大師
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 79 [use_Cython: False]: 鑑真和上
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 80 [use_Cython: False]: 開眼供養
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 81 [use_Cython: False]: 入仏供養
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 82 [use_Cython: False]: 落慶法要
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 83 [use_Cython: False]: 授戒会
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 84 [use_Cython: False]: 結縁灌頂
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 85 [use_Cython: False]: 伝法灌頂
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 86 [use_Cython: False]: 護摩供養
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 87 [use_Cython: False]: 千体仏供養
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 88 [use_Cython: False]: 水子供養
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 89 [use_Cython: False]: 先祖供養
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 90 [use_Cython: False]: 施餓鬼会
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 91 [use_Cython: False]: 大施食会
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 92 [use_Cython: False]: 盆踊り
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 93 [use_Cython: False]: 精霊流し
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 94 [use_Cython: False]: 迎え火
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 95 [use_Cython: False]: 送り火
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 96 [use_Cython: False]: 棚経参り
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 97 [use_Cython: False]: お数珠
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 98 [use_Cython: False]: 線香供養
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 99 [use_Cython: False]: 献花供養
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 100 [use_Cython: False]: 五重塔
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 101 [use_Cython: False]: 三重塔
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 102 [use_Cython: False]: 多宝塔
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 103 [use_Cython: False]: 仏舎利塔
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 104 [use_Cython: False]: 観音堂
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 105 [use_Cython: False]: 薬師堂
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 106 [use_Cython: False]: 阿弥陀堂
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 107 [use_Cython: False]: 大雄宝殿
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 108 [use_Cython: False]: 法堂建築
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 109 [use_Cython: False]: 禅堂建築
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 110 [use_Cython: False]: 客殿建築
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 111 [use_Cython: False]: 庫裏建築
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 112 [use_Cython: False]: 山門建築
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 113 [use_Cython: False]: 鐘楼建築
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 114 [use_Cython: False]: 経蔵建築
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 115 [use_Cython: False]: 宝蔵建築
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 116 [use_Cython: False]: 石庭造園
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 117 [use_Cython: False]: 枯山水
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 118 [use_Cython: False]: 借景技法
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 119 [use_Cython: False]: 禅庭設計
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 120 [use_Cython: False]: 千手観音
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 121 [use_Cython: False]: 十一面観音
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 122 [use_Cython: False]: 馬頭観音
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 123 [use_Cython: False]: 如意輪観音
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 124 [use_Cython: False]: 准胝観音
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 125 [use_Cython: False]: 不空羂索観音
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 126 [use_Cython: False]: 聖観音菩薩
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 127 [use_Cython: False]: 勢至菩薩
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 128 [use_Cython: False]: 文殊菩薩
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 129 [use_Cython: False]: 普賢菩薩
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 130 [use_Cython: False]: 弥勒菩薩
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 131 [use_Cython: False]: 薬王菩薩
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 132 [use_Cython: False]: 薬上菩薩
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 133 [use_Cython: False]: 虚空蔵菩薩
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 134 [use_Cython: False]: 大勢至菩薩
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 135 [use_Cython: False]: 金剛界曼荼羅
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 136 [use_Cython: False]: 胎蔵界曼荼羅
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 137 [use_Cython: False]: 両部曼荼羅
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 138 [use_Cython: False]: 八葉蓮華
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 139 [use_Cython: False]: 宝相華文様
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 140 [use_Cython: False]: 出家得度
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 141 [use_Cython: False]: 在家信者
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 142 [use_Cython: False]: 優婆塞
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 143 [use_Cython: False]: 優婆夷
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 144 [use_Cython: False]: 沙弥僧
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 145 [use_Cython: False]: 沙弥尼
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 146 [use_Cython: False]: 比丘僧
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 147 [use_Cython: False]: 比丘尼
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 148 [use_Cython: False]: 阿闍梨
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 149 [use_Cython: False]: 三蔵法師
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 150 [use_Cython: False]: 律師職位
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 151 [use_Cython: False]: 禅師職位
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 152 [use_Cython: False]: 大僧正
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 153 [use_Cython: False]: 僧正職位
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 154 [use_Cython: False]: 権僧正
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 155 [use_Cython: False]: 少僧都
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 156 [use_Cython: False]: 権少僧都
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 157 [use_Cython: False]: 法印大和尚
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 158 [use_Cython: False]: 伝燈大阿闍梨
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 159 [use_Cython: False]: 権大僧都
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 160 [use_Cython: False]: 三論教学
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 161 [use_Cython: False]: 法相教学
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 162 [use_Cython: False]: 華厳教学
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 163 [use_Cython: False]: 天台教学
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 164 [use_Cython: False]: 真言教学
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 165 [use_Cython: False]: 浄土教学
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 166 [use_Cython: False]: 禅宗教学
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 167 [use_Cython: False]: 日蓮教学
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 168 [use_Cython: False]: 唯識思想
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 169 [use_Cython: False]: 如来蔵思想
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 170 [use_Cython: False]: 本覚思想
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 171 [use_Cython: False]: 末法思想
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 172 [use_Cython: False]: 易行道
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 173 [use_Cython: False]: 難行道
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 174 [use_Cython: False]: 聖道門
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 175 [use_Cython: False]: 浄土門
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 176 [use_Cython: False]: 権教方便
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 177 [use_Cython: False]: 実教真実
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 178 [use_Cython: False]: 五時八教
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 179 [use_Cython: False]: 化法四教
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 180 [use_Cython: False]: 降誕会法要
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 181 [use_Cython: False]: 成道会法要
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 182 [use_Cython: False]: 涅槃会法要
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 183 [use_Cython: False]: 春彼岸法要
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 184 [use_Cython: False]: 秋彼岸法要
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 185 [use_Cython: False]: 盂蘭盆会
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 186 [use_Cython: False]: 十夜法要
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 187 [use_Cython: False]: 修正会法要
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 188 [use_Cython: False]: 節分会法要
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 189 [use_Cython: False]: 灌仏会法要
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 190 [use_Cython: False]: 花祭り行事
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 191 [use_Cython: False]: 除夜の鐘
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 192 [use_Cython: False]: 初詣参拝
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 193 [use_Cython: False]: 初護摩法要
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 194 [use_Cython: False]: 開山忌法要
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 195 [use_Cython: False]: 両祖忌法要
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 196 [use_Cython: False]: 宗祖忌法要
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 197 [use_Cython: False]: 御会式法要
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 198 [use_Cython: False]: 報恩講法要
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 199 [use_Cython: False]: 追悼法要式
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...

# %%
df[columns1]
# Out:
#                   1g                               2g  \
# 0          [阿, 羅, 漢]                [阿, 羅, 漢, 阿羅, 羅漢]
# 1          [辟, 支, 仏]                [辟, 支, 仏, 辟支, 支仏]
# 2          [転, 法, 輪]                [転, 法, 輪, 転法, 法輪]
# 3       [十, 二, 因, 縁]         [十, 二, 因, 縁, 十二, 二因, 因縁]
# 4       [五, 蘊, 盛, 苦]         [五, 蘊, 盛, 苦, 五蘊, 蘊盛, 盛苦]
# ..               ...                              ...
# 195  [両, 祖, 忌, 法, 要]  [両, 祖, 忌, 法, 要, 両祖, 祖忌, 忌法, 法要]
# 196  [宗, 祖, 忌, 法, 要]  [宗, 祖, 忌, 法, 要, 宗祖, 祖忌, 忌法, 法要]
# 197  [御, 会, 式, 法, 要]  [御, 会, 式, 法, 要, 御会, 会式, 式法, 法要]
# 198  [報, 恩, 講, 法, 要]  [報, 恩, 講, 法, 要, 報恩, 恩講, 講法, 法要]
# 199  [追, 悼, 法, 要, 式]  [追, 悼, 法, 要, 式, 追悼, 悼法, 法要, 要式]
#
#                                                  3g  \
# 0                                             [阿羅漢]
# 1                                             [辟支仏]
# 2                                             [転法輪]
# 3                [十, 二, 因, 縁, 十二, 二因, 因縁, 十二因, 二因縁]
# 4                [五, 蘊, 盛, 苦, 五蘊, 蘊盛, 盛苦, 五蘊盛, 蘊盛苦]
# ..                                              ...
# 195  [両, 祖, 忌, 法, 要, 両祖, 祖忌, 忌法, 法要, 両祖忌, 祖忌法, 忌法要]
# 196  [宗, 祖, 忌, 法, 要, 宗祖, 祖忌, 忌法, 法要, 宗祖忌, 祖忌法, 忌法要]
# 197  [御, 会, 式, 法, 要, 御会, 会式, 式法, 法要, 御会式, 会式法, 式法要]
# 198  [報, 恩, 講, 法, 要, 報恩, 恩講, 講法, 法要, 報恩講, 恩講法, 講法要]
# 199  [追, 悼, 法, 要, 式, 追悼, 悼法, 法要, 要式, 追悼法, 悼法要, 法要式]
#
#                                                     4g
# 0                                                [阿羅漢]
# 1                                                [辟支仏]
# 2                                                [転法輪]
# 3                                               [十二因縁]
# 4                                               [五蘊盛苦]
# ..                                                 ...
# 195  [両, 祖, 忌, 法, 要, 両祖, 祖忌, 忌法, 法要, 両祖忌, 祖忌法, 忌法要,...
# 196  [宗, 祖, 忌, 法, 要, 宗祖, 祖忌, 忌法, 法要, 宗祖忌, 祖忌法, 忌法要,...
# 197  [御, 会, 式, 法, 要, 御会, 会式, 式法, 法要, 御会式, 会式法, 式法要,...
# 198  [報, 恩, 講, 法, 要, 報恩, 恩講, 講法, 法要, 報恩講, 恩講法, 講法要,...
# 199  [追, 悼, 法, 要, 式, 追悼, 悼法, 法要, 要式, 追悼法, 悼法要, 法要式,...
#
# [200 rows x 4 columns]

# %% [markdown]
# ## Check differences

# %%
for i, row in df.iterrows():
    doc = row['doc']
    print("--------------")
    print(f"doc: {doc}")
    
    ## compare xsk, sk and norm
    for j in range(1, max_n_for_ngram + 1):
        print(" -------------")
        print(f"{j}g")
        norm_var = f"{j}g"
        sk_var = f"sk{j}g"
        xsk_var = f"xsk{j}g"
        norm  = list(df.loc[i,norm_var])
        print(f"norm: {norm}")
        sk  = list(df.loc[i,sk_var])
        print(f"sk: {sk}")
        xsk = list(df.loc[i,xsk_var])
        print(f"xsk: {xsk}")
        
        ## Commonalities
        C1 = [ x for x in norm if x in sk and x in xsk ]
        print(f"C1 x in norm, sk, and xsk: {C1}")
        ##
        C2 = [ x for x in norm if x in sk and not x in xsk ]
        print(f"C2 x in norm and sk, not in xsk: {C2}")
        ##
        C3 = [ x for x in norm if x in xsk and not x in sk ]
        print(f"C3 x in norm and xsk, not in sk: {C3}")
        ##
        C4 = [ x for x in sk if x in xsk and not x in norm ]
        print(f"C4 x in sk and xsk, not in norm: {C4}")
        
        ## Differences
        D1 = [ x for x in sk if not x in xsk ]
        print(f"D1 x in sk, not in xsk: {D1}")

        D2 = [ x for x in xsk if not x in sk ]
        print(f"D2 x in xsk, not in sk: {D2}")
# Out:
# --------------
# doc: 阿羅漢
#  -------------
# 1g
# norm: ['阿', '羅', '漢']
# sk: ['阿', '羅', '漢']
# xsk: ['阿…', '…羅…', '…漢']
# C1 x in norm, sk, and xsk: []
# C2 x in norm and sk, not in xsk: ['阿', '羅', '漢']
# C3 x in norm and xsk, not in sk: []
# C4 x in sk and xsk, not in norm: []
# D1 x in sk, not in xsk: ['阿', '羅', '漢']
# D2 x in xsk, not in sk: ['阿…', '…羅…', '…漢']
#  -------------
# 2g
# norm: ['阿', '羅', '漢', '阿羅', '羅漢']
# sk: ['阿羅', '阿…漢', '阿', '羅漢', '羅', '漢']
# xsk: ['阿羅…', '阿…漢', '阿…', '…羅漢', '…羅…', '…漢']
# C1 x in norm, sk, and xsk: []
# C2 x in norm and sk, not in xsk: ['阿', '羅', '漢', '阿羅', '羅漢']
# C3 x in norm and xsk, not in sk: []
# C4 x in sk and xsk, not in norm: ['阿…漢']
# D1 x in sk, not in xsk: ['阿羅', '阿', '羅漢', '羅', '漢']
# D2 x in xsk, not in sk: ['阿羅…', '阿…', '…羅漢', '…羅…', '…漢']
#  -------------
# 3g
# norm: ['阿羅漢']
# sk: ['阿羅', '阿…漢', '阿', '羅漢', '羅', '漢', '阿羅漢']
# xsk: ['阿羅…', '阿…漢', '阿…', '…羅漢', '…羅…', '…漢', '阿羅漢']
# C1 x in norm, sk, and xsk: ['阿羅漢']
# C2 x in norm and sk, not in xsk: []
# C3 x in norm and xsk, not in sk: []
# C4 x in sk and xsk, not in norm: ['阿…漢']
# D1 x in sk, not in xsk: ['阿羅', '阿', '羅漢', '羅', '漢']
# D2 x in xsk, not in sk: ['阿羅…', '阿…', '…羅漢', '…羅…', '…漢']
#  -------------
# 4g
# norm: ['阿羅漢']
# sk: ['阿羅', '阿…漢', '阿', '羅漢', '羅', '漢', '阿羅漢']
# xsk: ['阿羅…', '阿…漢', '阿…', '…羅漢', '…羅…', '…漢', '阿羅漢']
# C1 x in norm, sk, and xsk: ['阿羅漢']
# C2 x in norm and sk, not in xsk: []
# C3 x in norm and xsk, not in sk: []
# C4 x in sk and xsk, not in norm: ['阿…漢']
# D1 x in sk, not in xsk: ['阿羅', '阿', '羅漢', '羅', '漢']
# D2 x in xsk, not in sk: ['阿羅…', '阿…', '…羅漢', '…羅…', '…漢']
# --------------
# doc: 辟支仏
#  -------------
# 1g
# norm: ['辟', '支', '仏']
# sk: ['辟', '支', '仏']
# xsk: ['辟…', '…支…', '…仏']
# C1 x in norm, sk, and xsk: []
# C2 x in norm and sk, not in xsk: ['辟', '支', '仏']
# C3 x in norm and xsk, not in sk: []
# C4 x in sk and xsk, not in norm: []
# D1 x in sk, not in xsk: ['辟', '支', '仏']
# D2 x in xsk, not in sk: ['辟…', '…支…', '…仏']
#  -------------
# 2g
# norm: ['辟', '支', '仏', '辟支', '支仏']
# sk: ['辟支', '辟…仏', '辟', '支仏', '支', '仏']
# xsk: ['辟支…', '辟…仏', '辟…', '…支仏', '…支…', '…仏']
# C1 x in norm, sk, and xsk: []
# C2 x in norm and sk, not in xsk: ['辟', '支', '仏', '辟支', '支仏']
# C3 x in norm and xsk, not in sk: []
# C4 x in sk and xsk, not in norm: ['辟…仏']
# D1 x in sk, not in xsk: ['辟支', '辟', '支仏', '支', '仏']
# D2 x in xsk, not in sk: ['辟支…', '辟…', '…支仏', '…支…', '…仏']
#  -------------
# 3g
# norm: ['辟支仏']
# sk: ['辟支', '辟…仏', '辟', '支仏', '支', '仏', '辟支仏']
# xsk: ['辟支…', '辟…仏', '辟…', '…支仏', '…支…', '…仏', '辟支仏']
# C1 x in norm, sk, and xsk: ['辟支仏']
# C2 x in norm and sk, not in xsk: []
# C3 x in norm and xsk, not in sk: []
# C4 x in sk and xsk, not in norm: ['辟…仏']
# D1 x in sk, not in xsk: ['辟支', '辟', '支仏', '支', '仏']
# D2 x in xsk, not in sk: ['辟支…', '辟…', '…支仏', '…支…', '…仏']
#  -------------
# 4g
# norm: ['辟支仏']
# sk: ['辟支', '辟…仏', '辟', '支仏', '支', '仏', '辟支仏']
# xsk: ['辟支…', '辟…仏', '辟…', '…支仏', '…支…', '…仏', '辟支仏']
# C1 x in norm, sk, and xsk: ['辟支仏']
# C2 x in norm and sk, not in xsk: []
# C3 x in norm and xsk, not in sk: []
# C4 x in sk and xsk, not in norm: ['辟…仏']
# D1 x in sk, not in xsk: ['辟支', '辟', '支仏', '支', '仏']
# D2 x in xsk, not in sk: ['辟支…', '辟…', '…支仏', '…支…', '…仏']
# --------------
# doc: 転法輪
#  -------------
# 1g
# norm: ['転', '法', '輪']
# sk: ['転', '法', '輪']
# xsk: ['転…', '…法…', '…輪']
# C1 x in norm, sk, and xsk: []
# C2 x in norm and sk, not in xsk: ['転', '法', '輪']
# C3 x in norm and xsk, not in sk: []
# C4 x in sk and xsk, not in norm: []
# D1 x in sk, not in xsk: ['転', '法', '輪']
# D2 x in xsk, not in sk: ['転…', '…法…', '…輪']
#  -------------
# 2g
# norm: ['転', '法', '輪', '転法', '法輪']
# sk: ['転法', '転…輪', '転', '法輪', '法', '輪']
# xsk: ['転法…', '転…輪', '転…', '…法輪', '…法…', '…輪']
# C1 x in norm, sk, and xsk: []
# C2 x in norm and sk, not in xsk: ['転', '法', '輪', '転法', '法輪']
# C3 x in norm and xsk, not in sk: []
# C4 x in sk and xsk, not in norm: ['転…輪']
# D1 x in sk, not in xsk: ['転法', '転', '法輪', '法', '輪']
# D2 x in xsk, not in sk: ['転法…', '転…', '…法輪', '…法…', '…輪']
#  -------------
# 3g
# norm: ['転法輪']
# sk: ['転法', '転…輪', '転', '法輪', '法', '輪', '転法輪']
# xsk: ['転法…', '転…輪', '転…', '…法輪', '…法…', '…輪', '転法輪']
# C1 x in norm, sk, and xsk: ['転法輪']
# C2 x in norm and sk, not in xsk: []
# C3 x in norm and xsk, not in sk: []
# C4 x in sk and xsk, not in norm: ['転…輪']
# D1 x in sk, not in xsk: ['転法', '転', '法輪', '法', '輪']
# D2 x in xsk, not in sk: ['転法…', '転…', '…法輪', '…法…', '…輪']
#  -------------
# 4g
# norm: ['転法輪']
# sk: ['転法', '転…輪', '転', '法輪', '法', '輪', '転法輪']
# xsk: ['転法…', '転…輪', '転…', '…法輪', '…法…', '…輪', '転法輪']
# C1 x in norm, sk, and xsk: ['転法輪']
# C2 x in norm and sk, not in xsk: []
# C3 x in norm and xsk, not in sk: []
# C4 x in sk and xsk, not in norm: ['転…輪']
# D1 x in sk, not in xsk: ['転法', '転', '法輪', '法', '輪']
# D2 x in xsk, not in sk: ['転法…', '転…', '…法輪', '…法…', '…輪']
# --------------
# doc: 十二因縁
#  -------------
# 1g
# norm: ['十', '二', '因', '縁']
# sk: ['十', '二', '因', '縁']
# xsk: ['十…', '…二…', '…因…', '…縁']
# C1 x in norm, sk, and xsk: []
# C2 x in norm and sk, not in xsk: ['十', '二', '因', '縁']
# C3 x in norm and xsk, not in sk: []
# C4 x in sk and xsk, not in norm: []
# D1 x in sk, not in xsk: ['十', '二', '因', '縁']
# D2 x in xsk, not in sk: ['十…', '…二…', '…因…', '…縁']
#  -------------
# 2g
# norm: ['十', '二', '因', '縁', '十二', '二因', '因縁']
# sk: ['十二', '十…因', '十…縁', '十', '二因', '二…縁', '二', '因縁', '因', '縁']
# xsk: ['十二…', '十…因…', '十…縁', '十…', '…二因…', '…二…縁', '…二…', '…因縁', '…因…', '…縁']
# C1 x in norm, sk, and xsk: []
# C2 x in norm and sk, not in xsk: ['十', '二', '因', '縁', '十二', '二因', '因縁']
# C3 x in norm and xsk, not in sk: []
# C4 x in sk and xsk, not in norm: ['十…縁']
# D1 x in sk, not in xsk: ['十二', '十…因', '十', '二因', '二…縁', '二', '因縁', '因', '縁']
# D2 x in xsk, not in sk: ['十二…', '十…因…', '十…', '…二因…', '…二…縁', '…二…', '…因縁', '…因…', '…縁']
#  -------------
# 3g
# norm: ['十', '二', '因', '縁', '十二', '二因', '因縁', '十二因', '二因縁']
# sk: ['十二因', '十二…縁', '十二', '十…因縁', '十…因', '十…縁', '十', '二因縁', '二因', '二…縁', '二', '因縁', '因', '縁']
# xsk: ['十二因…', '十二…縁', '十二…', '十…因縁', '十…因…', '十…縁', '十…', '…二因縁', '…二因…', '…二…縁', '…二…', '…因縁', '…因…', '…縁']
# C1 x in norm, sk, and xsk: []
# C2 x in norm and sk, not in xsk: ['十', '二', '因', '縁', '十二', '二因', '因縁', '十二因', '二因縁']
# C3 x in norm and xsk, not in sk: []
# C4 x in sk and xsk, not in norm: ['十二…縁', '十…因縁', '十…縁']
# D1 x in sk, not in xsk: ['十二因', '十二', '十…因', '十', '二因縁', '二因', '二…縁', '二', '因縁', '因', '縁']
# D2 x in xsk, not in sk: ['十二因…', '十二…', '十…因…', '十…', '…二因縁', '…二因…', '…二…縁', '…二…', '…因縁', '…因…', '…縁']
#  -------------
# 4g
# norm: ['十二因縁']
# sk: ['十二因', '十二…縁', '十二', '十…因縁', '十…因', '十…縁', '十', '二因縁', '二因', '二…縁', '二', '因縁', '因', '縁', '十二因縁']
# xsk: ['十二因…', '十二…縁', '十二…', '十…因縁', '十…因…', '十…縁', '十…', '…二因縁', '…二因…', '…二…縁', '…二…', '…因縁', '…因…', '…縁', '十二因縁']
# C1 x in norm, sk, and xsk: ['十二因縁']
# C2 x in norm and sk, not in xsk: []
# C3 x in norm and xsk, not in sk: []
# C4 x in sk and xsk, not in norm: ['十二…縁', '十…因縁', '十…縁']
# D1 x in sk, not in xsk: ['十二因', '十二', '十…因', '十', '二因縁', '二因', '二…縁', '二', '因縁', '因', '縁']
# D2 x in xsk, not in sk: ['十二因…', '十二…', '十…因…', '十…', '…二因縁', '…二因…', '…二…縁', '…二…', '…因縁', '…因…', '…縁']
# --------------
# doc: 五蘊盛苦
#  -------------
# 1g
# norm: ['五', '蘊', '盛', '苦']
# sk: ['五', '蘊', '盛', '苦']
# xsk: ['五…', '…蘊…', '…盛…', '…苦']
# C1 x in norm, sk, and xsk: []
# C2 x in norm and sk, not in xsk: ['五', '蘊', '盛', '苦']
# C3 x in norm and xsk, not in sk: []
# C4 x in sk and xsk, not in norm: []
# D1 x in sk, not in xsk: ['五', '蘊', '盛', '苦']
# D2 x in xsk, not in sk: ['五…', '…蘊…', '…盛…', '…苦']
#  -------------
# 2g
# norm: ['五', '蘊', '盛', '苦', '五蘊', '蘊盛', '盛苦']
# sk: ['五蘊', '五…盛', '五…苦', '五', '蘊盛', '蘊…苦', '蘊', '盛苦', '盛', '苦']
# xsk: ['五蘊…', '五…盛…', '五…苦', '五…', '…蘊盛…', '…蘊…苦', '…蘊…', '…盛苦', '…盛…', '…苦']
# C1 x in norm, sk, and xsk: []
# C2 x in norm and sk, not in xsk: ['五', '蘊', '盛', '苦', '五蘊', '蘊盛', '盛苦']
# C3 x in norm and xsk, not in sk: []
# C4 x in sk and xsk, not in norm: ['五…苦']
# D1 x in sk, not in xsk: ['五蘊', '五…盛', '五', '蘊盛', '蘊…苦', '蘊', '盛苦', '盛', '苦']
# D2 x in xsk, not in sk: ['五蘊…', '五…盛…', '五…', '…蘊盛…', '…蘊…苦', '…蘊…', '…盛苦', '…盛…', '…苦']
#  -------------
# 3g
# norm: ['五', '蘊', '盛', '苦', '五蘊', '蘊盛', '盛苦', '五蘊盛', '蘊盛苦']
# sk: ['五蘊盛', '五蘊…苦', '五蘊', '五…盛苦', '五…盛', '五…苦', '五', '蘊盛苦', '蘊盛', '蘊…苦', '蘊', '盛苦', '盛', '苦']
# xsk: ['五蘊盛…', '五蘊…苦', '五蘊…', '五…盛苦', '五…盛…', '五…苦', '五…', '…蘊盛苦', '…蘊盛…', '…蘊…苦', '…蘊…', '…盛苦', '…盛…', '…苦']
# C1 x in norm, sk, and xsk: []
# C2 x in norm and sk, not in xsk: ['五', '蘊', '盛', '苦', '五蘊', '蘊盛', '盛苦', '五蘊盛', '蘊盛苦']
# C3 x in norm and xsk, not in sk: []
# C4 x in sk and xsk, not in norm: ['五蘊…苦', '五…盛苦', '五…苦']
# D1 x in sk, not in xsk: ['五蘊盛', '五蘊', '五…盛', '五', '蘊盛苦', '蘊盛', '蘊…苦', '蘊', '盛苦', '盛', '苦']
# D2 x in xsk, not in sk: ['五蘊盛…', '五蘊…', '五…盛…', '五…', '…蘊盛苦', '…蘊盛…', '…蘊…苦', '…蘊…', '…盛苦', '…盛…', '…苦']
#  -------------
# 4g
# norm: ['五蘊盛苦']
# sk: ['五蘊盛', '五蘊…苦', '五蘊', '五…盛苦', '五…盛', '五…苦', '五', '蘊盛苦', '蘊盛', '蘊…苦', '蘊', '盛苦', '盛', '苦', '五蘊盛苦']
# xsk: ['五蘊盛…', '五蘊…苦', '五蘊…', '五…盛苦', '五…盛…', '五…苦', '五…', '…蘊盛苦', '…蘊盛…', '…蘊…苦', '…蘊…', '…盛苦', '…盛…', '…苦', '五蘊盛苦']
# C1 x in norm, sk, and xsk: ['五蘊盛苦']
# C2 x in norm and sk, not in xsk: []
# C3 x in norm and xsk, not in sk: []
# C4 x in sk and xsk, not in norm: ['五蘊…苦', '五…盛苦', '五…苦']
# D1 x in sk, not in xsk: ['五蘊盛', '五蘊', '五…盛', '五', '蘊盛苦', '蘊盛', '蘊…苦', '蘊', '盛苦', '盛', '苦']
# D2 x in xsk, not in sk: ['五蘊盛…', '五蘊…', '五…盛…', '五…', '…蘊盛苦', '…蘊盛…', '…蘊…苦', '…蘊…', '…盛苦', '…盛…', '…苦']
# --------------
# doc: 三法印
#  -------------
# 1g
# norm: ['三', '法', '印']
# sk: ['三', '法', '印']
# xsk: ['三…', '…法…', '…印']
# C1 x in norm, sk, and xsk: []
# C2 x in norm and sk, not in xsk: ['三', '法', '印']
# C3 x in norm and xsk, not in sk: []
# C4 x in sk and xsk, not in norm: []
# D1 x in sk, not in xsk: ['三', '法', '印']
# D2 x in xsk, not in sk: ['三…', '…法…', '…印']
#  -------------
# 2g
# norm: ['三', '法', '印', '三法', '法印']
# sk: ['三法', '三…印', '三', '法印', '法', '印']
# xsk: ['三法…', '三…印', '三…', '…法印', '…法…', '…印']
# C1 x in norm, sk, and xsk: []
# C2 x in norm and sk, not in xsk: ['三', '法', '印', '三法', '法印']
# C3 x in norm and xsk, not in sk: []
# C4 x in sk and xsk, not in norm: ['三…印']
# D1 x in sk, not in xsk: ['三法', '三', '法印', '法', '印']
# D2 x in xsk, not in sk: ['三法…', '三…', '…法印', '…法…', '…印']
#  -------------
# 3g
# norm: ['三法印']
# sk: ['三法', '三…印', '三', '法印', '法', '印', '三法印']
# xsk: ['三法…', '三…印', '三…', '…法印', '…法…', '…印', '三法印']
# C1 x in norm, sk, and xsk: ['三法印']
# C2 x in norm and sk, not in xsk: []
# C3 x in norm and xsk, not in sk: []
# C4 x in sk and xsk, not in norm: ['三…印']
# D1 x in sk, not in xsk: ['三法', '三', '法印', '法', '印']
# D2 x in xsk, not in sk: ['三法…', '三…', '…法印', '…法…', '…印']
#  -------------
# 4g
# norm: ['三法印']
# sk: ['三法', '三…印', '三', '法印', '法', '印', '三法印']
# xsk: ['三法…', '三…印', '三…', '…法印', '…法…', '…印', '三法印']
# C1 x in norm, sk, and xsk: ['三法印']
# C2 x in norm and sk, not in xsk: []
# C3 x in norm and xsk, not in sk: []
# C4 x in sk and xsk, not in norm: ['三…印']
# D1 x in sk, not in xsk: ['三法', '三', '法印', '法', '印']
# D2 x in xsk, not in sk: ['三法…', '三…', '…法印', '…法…', '…印']
# --------------
# doc: 四念処
#  -------------
# 1g
# norm: ['四', '念', '処']
# sk: ['四', '念', '処']
# xsk: ['四…', '…念…', '…処']
# C1 x in norm, sk, and xsk: []
# C2 x in norm and sk, not in xsk: ['四', '念', '処']
# C3 x in norm and xsk, not in sk: []
# C4 x in sk and xsk, not in norm: []
# D1 x in sk, not in xsk: ['四', '念', '処']
# D2 x in xsk, not in sk: ['四…', '…念…', '…処']
#  -------------
# 2g
# norm: ['四', '念', '処', '四念', '念処']
# sk: ['四念', '四…処', '四', '念処', '念', '処']
# xsk: ['四念…', '四…処', '四…', '…念処', '…念…', '…処']
# C1 x in norm, sk, and xsk: []
# C2 x in norm and sk, not in xsk: ['四', '念', '処', '四念', '念処']
# C3 x in norm and xsk, not in sk: []
# C4 x in sk and xsk, not in norm: ['四…処']
# D1 x in sk, not in xsk: ['四念', '四', '念処', '念', '処']
# D2 x in xsk, not in sk: ['四念…', '四…', '…念処', '…念…', '…処']
#  -------------
# 3g
# norm: ['四念処']
# sk: ['四念', '四…処', '四', '念処', '念', '処', '四念処']
# xsk: ['四念…', '四…処', '四…', '…念処', '…念…', '…処', '四念処']
# C1 x in norm, sk, and xsk: ['四念処']
# C2 x in norm and sk, not in xsk: []
# C3 x in norm and xsk, not in sk: []
# C4 x in sk and xsk, not in norm: ['四…処']
# D1 x in sk, not in xsk: ['四念', '四', '念処', '念', '処']
# D2 x in xsk, not in sk: ['四念…', '四…', '…念処', '…念…', '…処']
#  -------------
# 4g
# norm: ['四念処']
# sk: ['四念', '四…処', '四', '念処', '念', '処', '四念処']
# xsk: ['四念…', '四…処', '四…', '…念処', '…念…', '…処', '四念処']
# C1 x in norm, sk, and xsk: ['四念処']
# C2 x in norm and sk, not in xsk: []
# C3 x in norm and xsk, not in sk: []
# C4 x in sk and xsk, not in norm: ['四…処']
# D1 x in sk, not in xsk: ['四念', '四', '念処', '念', '処']
# D2 x in xsk, not in sk: ['四念…', '四…', '…念処', '…念…', '…処']
# --------------
# doc: 四神足
#  -------------
# 1g
# norm: ['四', '神', '足']
# sk: ['四', '神', '足']
# xsk: ['四…', '…神…', '…足']
# C1 x in norm, sk, and xsk: []
# C2 x in norm and sk, not in xsk: ['四', '神', '足']
# C3 x in norm and xsk, not in sk: []
# C4 x in sk and xsk, not in norm: []
# D1 x in sk, not in xsk: ['四', '神', '足']
# D2 x in xsk, not in sk: ['四…', '…神…', '…足']
#  -------------
# 2g
# norm: ['四', '神', '足', '四神', '神足']
# sk: ['四神', '四…足', '四', '神足', '神', '足']
# xsk: ['四神…', '四…足', '四…', '…神足', '…神…', '…足']
# C1 x in norm, sk, and xsk: []
# C2 x in norm and sk, not in xsk: ['四', '神', '足', '四神', '神足']
# C3 x in norm and xsk, not in sk: []
# C4 x in sk and xsk, not in norm: ['四…足']
# D1 x in sk, not in xsk: ['四神', '四', '神足', '神', '足']
# D2 x in xsk, not in sk: ['四神…', '四…', '…神足', '…神…', '…足']
#  -------------
# 3g
# norm: ['四神足']
# sk: ['四神', '四…足', '四', '神足', '神', '足', '四神足']
# xsk: ['四神…', '四…足', '四…', '…神足', '…神…', '…足', '四神足']
# C1 x in norm, sk, and xsk: ['四神足']
# C2 x in norm and sk, not in xsk: []
# C3 x in norm and xsk, not in sk: []
# C4 x in sk and xsk, not in norm: ['四…足']
# D1 x in sk, not in xsk: ['四神', '四', '神足', '神', '足']
# D2 x in xsk, not in sk: ['四神…', '四…', '…神足', '…神…', '…足']
#  -------------
# 4g
# norm: ['四神足']
# sk: ['四神', '四…足', '四', '神足', '神', '足', '四神足']
# xsk: ['四神…', '四…足', '四…', '…神足', '…神…', '…足', '四神足']
# C1 x in norm, sk, and xsk: ['四神足']
# C2 x in norm and sk, not in xsk: []
# C3 x in norm and xsk, not in sk: []
# C4 x in sk and xsk, not in norm: ['四…足']
# D1 x in sk, not in xsk: ['四神', '四', '神足', '神', '足']
# D2 x in xsk, not in sk: ['四神…', '四…', '…神足', '…神…', '…足']
# --------------
# doc: 五根五力
#  -------------
# 1g
# norm: ['五', '根', '五', '力']
# sk: ['五', '根', '五', '力']
# xsk: ['五…', '…根…', '…五…', '…力']
# C1 x in norm, sk, and xsk: []
# C2 x in norm and sk, not in xsk: ['五', '根', '五', '力']
# C3 x in norm and xsk, not in sk: []
# C4 x in sk and xsk, not in norm: []
# D1 x in sk, not in xsk: ['五', '根', '五', '力']
# D2 x in xsk, not in sk: ['五…', '…根…', '…五…', '…力']
#  -------------
# 2g
# norm: ['五', '根', '五', '力', '五根', '根五', '五力']
# sk: ['五根', '五…五', '五…力', '五', '根五', '根…力', '根', '五力', '五', '力']
# xsk: ['五根…', '五…五…', '五…力', '五…', '…根五…', '…根…力', '…根…', '…五力', '…五…', '…力']
# C1 x in norm, sk, and xsk: []
# C2 x in norm and sk, not in xsk: ['五', '根', '五', '力', '五根', '根五', '五力']
# C3 x in norm and xsk, not in sk: []
# C4 x in sk and xsk, not in norm: ['五…力']
# D1 x in sk, not in xsk: ['五根', '五…五', '五', '根五', '根…力', '根', '五力', '五', '力']
# D2 x in xsk, not in sk: ['五根…', '五…五…', '五…', '…根五…', '…根…力', '…根…', '…五力', '…五…', '…力']
#  -------------
# 3g
# norm: ['五', '根', '五', '力', '五根', '根五', '五力', '五根五', '根五力']
# sk: ['五根五', '五根…力', '五根', '五…五力', '五…五', '五…力', '五', '根五力', '根五', '根…力', '根', '五力', '五', '力']
# xsk: ['五根五…', '五根…力', '五根…', '五…五力', '五…五…', '五…力', '五…', '…根五力', '…根五…', '…根…力', '…根…', '…五力', '…五…', '…力']
# C1 x in norm, sk, and xsk: []
# C2 x in norm and sk, not in xsk: ['五', '根', '五', '力', '五根', '根五', '五力', '五根五', '根五力']
# C3 x in norm and xsk, not in sk: []
# C4 x in sk and xsk, not in norm: ['五根…力', '五…五力', '五…力']
# D1 x in sk, not in xsk: ['五根五', '五根', '五…五', '五', '根五力', '根五', '根…力', '根', '五力', '五', '力']
# D2 x in xsk, not in sk: ['五根五…', '五根…', '五…五…', '五…', '…根五力', '…根五…', '…根…力', '…根…', '…五力', '…五…', '…力']
#  -------------
# 4g
# norm: ['五根五力']
# sk: ['五根五', '五根…力', '五根', '五…五力', '五…五', '五…力', '五', '根五力', '根五', '根…力', '根', '五力', '五', '力', '五根五力']
# xsk: ['五根五…', '五根…力', '五根…', '五…五力', '五…五…', '五…力', '五…', '…根五力', '…根五…', '…根…力', '…根…', '…五力', '…五…', '…力', '五根五力']
# C1 x in norm, sk, and xsk: ['五根五力']
# C2 x in norm and sk, not in xsk: []
# C3 x in norm and xsk, not in sk: []
# C4 x in sk and xsk, not in norm: ['五根…力', '五…五力', '五…力']
# D1 x in sk, not in xsk: ['五根五', '五根', '五…五', '五', '根五力', '根五', '根…力', '根', '五力', '五', '力']
# D2 x in xsk, not in sk: ['五根五…', '五根…', '五…五…', '五…', '…根五力', '…根五…', '…根…力', '…根…', '…五力', '…五…', '…力']
# --------------
# doc: 七覚支
#  -------------
# 1g
# norm: ['七', '覚', '支']
# sk: ['七', '覚', '支']
# xsk: ['七…', '…覚…', '…支']
# C1 x in norm, sk, and xsk: []
# C2 x in norm and sk, not in xsk: ['七', '覚', '支']
# C3 x in norm and xsk, not in sk: []
# C4 x in sk and xsk, not in norm: []
# D1 x in sk, not in xsk: ['七', '覚', '支']
# D2 x in xsk, not in sk: ['七…', '…覚…', '…支']
#  -------------
# 2g
# norm: ['七', '覚', '支', '七覚', '覚支']
# sk: ['七覚', '七…支', '七', '覚支', '覚', '支']
# xsk: ['七覚…', '七…支', '七…', '…覚支', '…覚…', '…支']
# C1 x in norm, sk, and xsk: []
# C2 x in norm and sk, not in xsk: ['七', '覚', '支', '七覚', '覚支']
# C3 x in norm and xsk, not in sk: []
# C4 x in sk and xsk, not in norm: ['七…支']
# D1 x in sk, not in xsk: ['七覚', '七', '覚支', '覚', '支']
# D2 x in xsk, not in sk: ['七覚…', '七…', '…覚支', '…覚…', '…支']
#  -------------
# 3g
# norm: ['七覚支']
# sk: ['七覚', '七…支', '七', '覚支', '覚', '支', '七覚支']
# xsk: ['七覚…', '七…支', '七…', '…覚支', '…覚…', '…支', '七覚支']
# C1 x in norm, sk, and xsk: ['七覚支']
# C2 x in norm and sk, not in xsk: []
# C3 x in norm and xsk, not in sk: []
# C4 x in sk and xsk, not in norm: ['七…支']
# D1 x in sk, not in xsk: ['七覚', '七', '覚支', '覚', '支']
# D2 x in xsk, not in sk: ['七覚…', '七…', '…覚支', '…覚…', '…支']
#  -------------
# 4g
# norm: ['七覚支']
# sk: ['七覚', '七…支', '七', '覚支', '覚', '支', '七覚支']
# xsk: ['七覚…', '七…支', '七…', '…覚支', '…覚…', '…支', '七覚支']
# C1 x in norm, sk, and xsk: ['七覚支']
# C2 x in norm and sk, not in xsk: []
# C3 x in norm and xsk, not in sk: []
# C4 x in sk and xsk, not in norm: ['七…支']
# D1 x in sk, not in xsk: ['七覚', '七', '覚支', '覚', '支']
# D2 x in xsk, not in sk: ['七覚…', '七…', '…覚支', '…覚…', '…支']
# --------------
# doc: 三十七道品
#  -------------
# 1g
# norm: ['三', '十', '七', '道', '品']
# sk: ['三', '十', '七', '道', '品']
# xsk: ['三…', '…十…', '…七…', '…道…', '…品']
# C1 x in norm, sk, and xsk: []
# C2 x in norm and sk, not in xsk: ['三', '十', '七', '道', '品']
# C3 x in norm and xsk, not in sk: []
# C4 x in sk and xsk, not in norm: []
# D1 x in sk, not in xsk: ['三', '十', '七', '道', '品']
# D2 x in xsk, not in sk: ['三…', '…十…', '…七…', '…道…', '…品']
#  -------------
# 2g
# norm: ['三', '十', '七', '道', '品', '三十', '十七', '七道', '道品']
# sk: ['三十', '三…七', '三…道', '三…品', '三', '十七', '十…道', '十…品', '十', '七道', '七…品', '七', '道品', '道', '品']
# xsk: ['三十…', '三…七…', '三…道…', '三…品', '三…', '…十七…', '…十…道…', '…十…品', '…十…', '…七道…', '…七…品', '…七…', '…道品', '…道…', '…品']
# C1 x in norm, sk, and xsk: []
# C2 x in norm and sk, not in xsk: ['三', '十', '七', '道', '品', '三十', '十七', '七道', '道品']
# C3 x in norm and xsk, not in sk: []
# C4 x in sk and xsk, not in norm: ['三…品']
# D1 x in sk, not in xsk: ['三十', '三…七', '三…道', '三', '十七', '十…道', '十…品', '十', '七道', '七…品', '七', '道品', '道', '品']
# D2 x in xsk, not in sk: ['三十…', '三…七…', '三…道…', '三…', '…十七…', '…十…道…', '…十…品', '…十…', '…七道…', '…七…品', '…七…', '…道品', '…道…', '…品']
#  -------------
# 3g
# norm: ['三', '十', '七', '道', '品', '三十', '十七', '七道', '道品', '三十七', '十七道', '七道品']
# sk: ['三十七', '三十…道', '三十…品', '三十', '三…七道', '三…七…品', '三…七', '三…道品', '三…道', '三…品', '三', '十七道', '十七…品', '十七', '十…道品', '十…道', '十…品', '十', '七道品', '七道', '七…品', '七', '道品', '道', '品']
# xsk: ['三十七…', '三十…道…', '三十…品', '三十…', '三…七道…', '三…七…品', '三…七…', '三…道品', '三…道…', '三…品', '三…', '…十七道…', '…十七…品', '…十七…', '…十…道品', '…十…道…', '…十…品', '…十…', '…七道品', '…七道…', '…七…品', '…七…', '…道品', '…道…', '…品']
# C1 x in norm, sk, and xsk: []
# C2 x in norm and sk, not in xsk: ['三', '十', '七', '道', '品', '三十', '十七', '七道', '道品', '三十七', '十七道', '七道品']
# C3 x in norm and xsk, not in sk: []
# C4 x in sk and xsk, not in norm: ['三十…品', '三…七…品', '三…道品', '三…品']
# D1 x in sk, not in xsk: ['三十七', '三十…道', '三十', '三…七道', '三…七', '三…道', '三', '十七道', '十七…品', '十七', '十…道品', '十…道', '十…品', '十', '七道品', '七道', '七…品', '七', '道品', '道', '品']
# D2 x in xsk, not in sk: ['三十七…', '三十…道…', '三十…', '三…七道…', '三…七…', '三…道…', '三…', '…十七道…', '…十七…品', '…十七…', '…十…道品', '…十…道…', '…十…品', '…十…', '…七道品', '…七道…', '…七…品', '…七…', '…道品', '…道…', '…品']
#  -------------
# 4g
# norm: ['三', '十', '七', '道', '品', '三十', '十七', '七道', '道品', '三十七', '十七道', '七道品', '三十七道', '十七道品']
# sk: ['三十七道', '三十七…品', '三十七', '三十…道品', '三十…道', '三十…品', '三十', '三…七道品', '三…七道', '三…七…品', '三…七', '三…道品', '三…道', '三…品', '三', '十七道品', '十七道', '十七…品', '十七', '十…道品', '十…道', '十…品', '十', '七道品', '七道', '七…品', '七', '道品', '道', '品']
# xsk: ['三十七道…', '三十七…品', '三十七…', '三十…道品', '三十…道…', '三十…品', '三十…', '三…七道品', '三…七道…', '三…七…品', '三…七…', '三…道品', '三…道…', '三…品', '三…', '…十七道品', '…十七道…', '…十七…品', '…十七…', '…十…道品', '…十…道…', '…十…品', '…十…', '…七道品', '…七道…', '…七…品', '…七…', '…道品', '…道…', '…品']
# C1 x in norm, sk, and xsk: []
# C2 x in norm and sk, not in xsk: ['三', '十', '七', '道', '品', '三十', '十七', '七道', '道品', '三十七', '十七道', '七道品', '三十七道', '十七道品']
# C3 x in norm and xsk, not in sk: []
# C4 x in sk and xsk, not in norm: ['三十七…品', '三十…道品', '三十…品', '三…七道品', '三…七…品', '三…道品', '三…品']
# D1 x in sk, not in xsk: ['三十七道', '三十七', '三十…道', '三十', '三…七道', '三…七', '三…道', '三', '十七道品', '十七道', '十七…品', '十七', '十…道品', '十…道', '十…品', '十', '七道品', '七道', '七…品', '七', '道品', '道', '品']
# D2 x in xsk, not in sk: ['三十七道…', '三十七…', '三十…道…', '三十…', '三…七道…', '三…七…', '三…道…', '三…', '…十七道品', '…十七道…', '…十七…品', '…十七…', '…十…道品', '…十…道…', '…十…品', '…十…', '…七道品', '…七道…', '…七…品', '…七…', '…道品', '…道…', '…品']
# --------------
# doc: 十善戒
#  -------------
# 1g
# norm: ['十', '善', '戒']
# sk: ['十', '善', '戒']
# xsk: ['十…', '…善…', '…戒']
# C1 x in norm, sk, and xsk: []
# C2 x in norm and sk, not in xsk: ['十', '善', '戒']
# C3 x in norm and xsk, not in sk: []
# C4 x in sk and xsk, not in norm: []
# D1 x in sk, not in xsk: ['十', '善', '戒']
# D2 x in xsk, not in sk: ['十…', '…善…', '…戒']
#  -------------
# 2g
# norm: ['十', '善', '戒', '十善', '善戒']
# sk: ['十善', '十…戒', '十', '善戒', '善', '戒']
# xsk: ['十善…', '十…戒', '十…', '…善戒', '…善…', '…戒']
# C1 x in norm, sk, and xsk: []
# C2 x in norm and sk, not in xsk: ['十', '善', '戒', '十善', '善戒']
# C3 x in norm and xsk, not in sk: []
# C4 x in sk and xsk, not in norm: ['十…戒']
# D1 x in sk, not in xsk: ['十善', '十', '善戒', '善', '戒']
# D2 x in xsk, not in sk: ['十善…', '十…', '…善戒', '…善…', '…戒']
#  -------------
# 3g
# norm: ['十善戒']
# sk: ['十善', '十…戒', '十', '善戒', '善', '戒', '十善戒']
# xsk: ['十善…', '十…戒', '十…', '…善戒', '…善…', '…戒', '十善戒']
# C1 x in norm, sk, and xsk: ['十善戒']
# C2 x in norm and sk, not in xsk: []
# C3 x in norm and xsk, not in sk: []
# C4 x in sk and xsk, not in norm: ['十…戒']
# D1 x in sk, not in xsk: ['十善', '十', '善戒', '善', '戒']
# D2 x in xsk, not in sk: ['十善…', '十…', '…善戒', '…善…', '…戒']
#  -------------
# 4g
# norm: ['十善戒']
# sk: ['十善', '十…戒', '十', '善戒', '善', '戒', '十善戒']
# xsk: ['十善…', '十…戒', '十…', '…善戒', '…善…', '…戒', '十善戒']
# C1 x in norm, sk, and xsk: ['十善戒']
# C2 x in norm and sk, not in xsk: []
# C3 x in norm and xsk, not in sk: []
# C4 x in sk and xsk, not in norm: ['十…戒']
# D1 x in sk, not in xsk: ['十善', '十', '善戒', '善', '戒']
# D2 x in xsk, not in sk: ['十善…', '十…', '…善戒', '…善…', '…戒']
# --------------
# doc: 六神通
#  -------------
# 1g
# norm: ['六', '神', '通']
# sk: ['六', '神', '通']
# xsk: ['六…', '…神…', '…通']
# C1 x in norm, sk, and xsk: []
# C2 x in norm and sk, not in xsk: ['六', '神', '通']
# C3 x in norm and xsk, not in sk: []
# C4 x in sk and xsk, not in norm: []
# D1 x in sk, not in xsk: ['六', '神', '通']
# D2 x in xsk, not in sk: ['六…', '…神…', '…通']
#  -------------
# 2g
# norm: ['六', '神', '通', '六神', '神通']
# sk: ['六神', '六…通', '六', '神通', '神', '通']
# xsk: ['六神…', '六…通', '六…', '…神通', '…神…', '…通']
# C1 x in norm, sk, and xsk: []
# C2 x in norm and sk, not in xsk: ['六', '神', '通', '六神', '神通']
# C3 x in norm and xsk, not in sk: []
# C4 x in sk and xsk, not in norm: ['六…通']
# D1 x in sk, not in xsk: ['六神', '六', '神通', '神', '通']
# D2 x in xsk, not in sk: ['六神…', '六…', '…神通', '…神…', '…通']
#  -------------
# 3g
# norm: ['六神通']
# sk: ['六神', '六…通', '六', '神通', '神', '通', '六神通']
# xsk: ['六神…', '六…通', '六…', '…神通', '…神…', '…通', '六神通']
# C1 x in norm, sk, and xsk: ['六神通']
# C2 x in norm and sk, not in xsk: []
# C3 x in norm and xsk, not in sk: []
# C4 x in sk and xsk, not in norm: ['六…通']
# D1 x in sk, not in xsk: ['六神', '六', '神通', '神', '通']
# D2 x in xsk, not in sk: ['六神…', '六…', '…神通', '…神…', '…通']
#  -------------
# 4g
# norm: ['六神通']
# sk: ['六神', '六…通', '六', '神通', '神', '通', '六神通']
# xsk: ['六神…', '六…通', '六…', '…神通', '…神…', '…通', '六神通']
# C1 x in norm, sk, and xsk: ['六神通']
# C2 x in norm and sk, not in xsk: []
# C3 x in norm and xsk, not in sk: []
# C4 x in sk and xsk, not in norm: ['六…通']
# D1 x in sk, not in xsk: ['六神', '六', '神通', '神', '通']
# D2 x in xsk, not in sk: ['六神…', '六…', '…神通', '…神…', '…通']
# --------------
# doc: 四無量心
#  -------------
# 1g
# norm: ['四', '無', '量', '心']
# sk: ['四', '無', '量', '心']
# xsk: ['四…', '…無…', '…量…', '…心']
# C1 x in norm, sk, and xsk: []
# C2 x in norm and sk, not in xsk: ['四', '無', '量', '心']
# C3 x in norm and xsk, not in sk: []
# C4 x in sk and xsk, not in norm: []
# D1 x in sk, not in xsk: ['四', '無', '量', '心']
# D2 x in xsk, not in sk: ['四…', '…無…', '…量…', '…心']
#  -------------
# 2g
# norm: ['四', '無', '量', '心', '四無', '無量', '量心']
# sk: ['四無', '四…量', '四…心', '四', '無量', '無…心', '無', '量心', '量', '心']
# xsk: ['四無…', '四…量…', '四…心', '四…', '…無量…', '…無…心', '…無…', '…量心', '…量…', '…心']
# C1 x in norm, sk, and xsk: []
# C2 x in norm and sk, not in xsk: ['四', '無', '量', '心', '四無', '無量', '量心']
# C3 x in norm and xsk, not in sk: []
# C4 x in sk and xsk, not in norm: ['四…心']
# D1 x in sk, not in xsk: ['四無', '四…量', '四', '無量', '無…心', '無', '量心', '量', '心']
# D2 x in xsk, not in sk: ['四無…', '四…量…', '四…', '…無量…', '…無…心', '…無…', '…量心', '…量…', '…心']
#  -------------
# 3g
# norm: ['四', '無', '量', '心', '四無', '無量', '量心', '四無量', '無量心']
# sk: ['四無量', '四無…心', '四無', '四…量心', '四…量', '四…心', '四', '無量心', '無量', '無…心', '無', '量心', '量', '心']
# xsk: ['四無量…', '四無…心', '四無…', '四…量心', '四…量…', '四…心', '四…', '…無量心', '…無量…', '…無…心', '…無…', '…量心', '…量…', '…心']
# C1 x in norm, sk, and xsk: []
# C2 x in norm and sk, not in xsk: ['四', '無', '量', '心', '四無', '無量', '量心', '四無量', '無量心']
# C3 x in norm and xsk, not in sk: []
# C4 x in sk and xsk, not in norm: ['四無…心', '四…量心', '四…心']
# D1 x in sk, not in xsk: ['四無量', '四無', '四…量', '四', '無量心', '無量', '無…心', '無', '量心', '量', '心']
# D2 x in xsk, not in sk: ['四無量…', '四無…', '四…量…', '四…', '…無量心', '…無量…', '…無…心', '…無…', '…量心', '…量…', '…心']
#  -------------
# 4g
# norm: ['四無量心']
# sk: ['四無量', '四無…心', '四無', '四…量心', '四…量', '四…心', '四', '無量心', '無量', '無…心', '無', '量心', '量', '心', '四無量心']
# xsk: ['四無量…', '四無…心', '四無…', '四…量心', '四…量…', '四…心', '四…', '…無量心', '…無量…', '…無…心', '…無…', '…量心', '…量…', '…心', '四無量心']
# C1 x in norm, sk, and xsk: ['四無量心']
# C2 x in norm and sk, not in xsk: []
# C3 x in norm and xsk, not in sk: []
# C4 x in sk and xsk, not in norm: ['四無…心', '四…量心', '四…心']
# D1 x in sk, not in xsk: ['四無量', '四無', '四…量', '四', '無量心', '無量', '無…心', '無', '量心', '量', '心']
# D2 x in xsk, not in sk: ['四無量…', '四無…', '四…量…', '四…', '…無量心', '…無量…', '…無…心', '…無…', '…量心', '…量…', '…心']
# --------------
# doc: 慈悲喜捨
#  -------------
# 1g
# norm: ['慈', '悲', '喜', '捨']
# sk: ['慈', '悲', '喜', '捨']
# xsk: ['慈…', '…悲…', '…喜…', '…捨']
# C1 x in norm, sk, and xsk: []
# C2 x in norm and sk, not in xsk: ['慈', '悲', '喜', '捨']
# C3 x in norm and xsk, not in sk: []
# C4 x in sk and xsk, not in norm: []
# D1 x in sk, not in xsk: ['慈', '悲', '喜', '捨']
# D2 x in xsk, not in sk: ['慈…', '…悲…', '…喜…', '…捨']
#  -------------
# 2g
# norm: ['慈', '悲', '喜', '捨', '慈悲', '悲喜', '喜捨']
# sk: ['慈悲', '慈…喜', '慈…捨', '慈', '悲喜', '悲…捨', '悲', '喜捨', '喜', '捨']
# xsk: ['慈悲…', '慈…喜…', '慈…捨', '慈…', '…悲喜…', '…悲…捨', '…悲…', '…喜捨', '…喜…', '…捨']
# C1 x in norm, sk, and xsk: []
# C2 x in norm and sk, not in xsk: ['慈', '悲', '喜', '捨', '慈悲', '悲喜', '喜捨']
# C3 x in norm and xsk, not in sk: []
# C4 x in sk and xsk, not in norm: ['慈…捨']
# D1 x in sk, not in xsk: ['慈悲', '慈…喜', '慈', '悲喜', '悲…捨', '悲', '喜捨', '喜', '捨']
# D2 x in xsk, not in sk: ['慈悲…', '慈…喜…', '慈…', '…悲喜…', '…悲…捨', '…悲…', '…喜捨', '…喜…', '…捨']
#  -------------
# 3g
# norm: ['慈', '悲', '喜', '捨', '慈悲', '悲喜', '喜捨', '慈悲喜', '悲喜捨']
# sk: ['慈悲喜', '慈悲…捨', '慈悲', '慈…喜捨', '慈…喜', '慈…捨', '慈', '悲喜捨', '悲喜', '悲…捨', '悲', '喜捨', '喜', '捨']
# xsk: ['慈悲喜…', '慈悲…捨', '慈悲…', '慈…喜捨', '慈…喜…', '慈…捨', '慈…', '…悲喜捨', '…悲喜…', '…悲…捨', '…悲…', '…喜捨', '…喜…', '…捨']
# C1 x in norm, sk, and xsk: []
# C2 x in norm and sk, not in xsk: ['慈', '悲', '喜', '捨', '慈悲', '悲喜', '喜捨', '慈悲喜', '悲喜捨']
# C3 x in norm and xsk, not in sk: []
# C4 x in sk and xsk, not in norm: ['慈悲…捨', '慈…喜捨', '慈…捨']
# D1 x in sk, not in xsk: ['慈悲喜', '慈悲', '慈…喜', '慈', '悲喜捨', '悲喜', '悲…捨', '悲', '喜捨', '喜', '捨']
# D2 x in xsk, not in sk: ['慈悲喜…', '慈悲…', '慈…喜…', '慈…', '…悲喜捨', '…悲喜…', '…悲…捨', '…悲…', '…喜捨', '…喜…', '…捨']
#  -------------
# 4g
# norm: ['慈悲喜捨']
# sk: ['慈悲喜', '慈悲…捨', '慈悲', '慈…喜捨', '慈…喜', '慈…捨', '慈', '悲喜捨', '悲喜', '悲…捨', '悲', '喜捨', '喜', '捨', '慈悲喜捨']
# xsk: ['慈悲喜…', '慈悲…捨', '慈悲…', '慈…喜捨', '慈…喜…', '慈…捨', '慈…', '…悲喜捨', '…悲喜…', '…悲…捨', '…悲…', '…喜捨', '…喜…', '…捨', '慈悲喜捨']
# C1 x in norm, sk, and xsk: ['慈悲喜捨']
# C2 x in norm and sk, not in xsk: []
# C3 x in norm and xsk, not in sk: []
# C4 x in sk and xsk, not in norm: ['慈悲…捨', '慈…喜捨', '慈…捨']
# D1 x in sk, not in xsk: ['慈悲喜', '慈悲', '慈…喜', '慈', '悲喜捨', '悲喜', '悲…捨', '悲', '喜捨', '喜', '捨']
# D2 x in xsk, not in sk: ['慈悲喜…', '慈悲…', '慈…喜…', '慈…', '…悲喜捨', '…悲喜…', '…悲…捨', '…悲…', '…喜捨', '…喜…', '…捨']
# --------------
# doc: 八風不動
#  -------------
# 1g
# norm: ['八', '風', '不', '動']
# sk: ['八', '風', '不', '動']
# xsk: ['八…', '…風…', '…不…', '…動']
# C1 x in norm, sk, and xsk: []
# C2 x in norm and sk, not in xsk: ['八', '風', '不', '動']
# C3 x in norm and xsk, not in sk: []
# C4 x in sk and xsk, not in norm: []
# D1 x in sk, not in xsk: ['八', '風', '不', '動']
# D2 x in xsk, not in sk: ['八…', '…風…', '…不…', '…動']
#  -------------
# 2g
# norm: ['八', '風', '不', '動', '八風', '風不', '不動']
# sk: ['八風', '八…不', '八…動', '八', '風不', '風…動', '風', '不動', '不', '動']
# xsk: ['八風…', '八…不…', '八…動', '八…', '…風不…', '…風…動', '…風…', '…不動', '…不…', '…動']
# C1 x in norm, sk, and xsk: []
# C2 x in norm and sk, not in xsk: ['八', '風', '不', '動', '八風', '風不', '不動']
# C3 x in norm and xsk, not in sk: []
# C4 x in sk and xsk, not in norm: ['八…動']
# D1 x in sk, not in xsk: ['八風', '八…不', '八', '風不', '風…動', '風', '不動', '不', '動']
# D2 x in xsk, not in sk: ['八風…', '八…不…', '八…', '…風不…', '…風…動', '…風…', '…不動', '…不…', '…動']
#  -------------
# 3g
# norm: ['八', '風', '不', '動', '八風', '風不', '不動', '八風不', '風不動']
# sk: ['八風不', '八風…動', '八風', '八…不動', '八…不', '八…動', '八', '風不動', '風不', '風…動', '風', '不動', '不', '動']
# xsk: ['八風不…', '八風…動', '八風…', '八…不動', '八…不…', '八…動', '八…', '…風不動', '…風不…', '…風…動', '…風…', '…不動', '…不…', '…動']
# C1 x in norm, sk, and xsk: []
# C2 x in norm and sk, not in xsk: ['八', '風', '不', '動', '八風', '風不', '不動', '八風不', '風不動']
# C3 x in norm and xsk, not in sk: []
# C4 x in sk and xsk, not in norm: ['八風…動', '八…不動', '八…動']
# D1 x in sk, not in xsk: ['八風不', '八風', '八…不', '八', '風不動', '風不', '風…動', '風', '不動', '不', '動']
# D2 x in xsk, not in sk: ['八風不…', '八風…', '八…不…', '八…', '…風不動', '…風不…', '…風…動', '…風…', '…不動', '…不…', '…動']
#  -------------
# 4g
# norm: ['八風不動']
# sk: ['八風不', '八風…動', '八風', '八…不動', '八…不', '八…動', '八', '風不動', '風不', '風…動', '風', '不動', '不', '動', '八風不動']
# xsk: ['八風不…', '八風…動', '八風…', '八…不動', '八…不…', '八…動', '八…', '…風不動', '…風不…', '…風…動', '…風…', '…不動', '…不…', '…動', '八風不動']
# C1 x in norm, sk, and xsk: ['八風不動']
# C2 x in norm and sk, not in xsk: []
# C3 x in norm and xsk, not in sk: []
# C4 x in sk and xsk, not in norm: ['八風…動', '八…不動', '八…動']
# D1 x in sk, not in xsk: ['八風不', '八風', '八…不', '八', '風不動', '風不', '風…動', '風', '不動', '不', '動']
# D2 x in xsk, not in sk: ['八風不…', '八風…', '八…不…', '八…', '…風不動', '…風不…', '…風…動', '…風…', '…不動', '…不…', '…動']
# --------------
# doc: 不退転
#  -------------
# 1g
# norm: ['不', '退', '転']
# sk: ['不', '退', '転']
# xsk: ['不…', '…退…', '…転']
# C1 x in norm, sk, and xsk: []
# C2 x in norm and sk, not in xsk: ['不', '退', '転']
# C3 x in norm and xsk, not in sk: []
# C4 x in sk and xsk, not in norm: []
# D1 x in sk, not in xsk: ['不', '退', '転']
# D2 x in xsk, not in sk: ['不…', '…退…', '…転']
#  -------------
# 2g
# norm: ['不', '退', '転', '不退', '退転']
# sk: ['不退', '不…転', '不', '退転', '退', '転']
# xsk: ['不退…', '不…転', '不…', '…退転', '…退…', '…転']
# C1 x in norm, sk, and xsk: []
# C2 x in norm and sk, not in xsk: ['不', '退', '転', '不退', '退転']
# C3 x in norm and xsk, not in sk: []
# C4 x in sk and xsk, not in norm: ['不…転']
# D1 x in sk, not in xsk: ['不退', '不', '退転', '退', '転']
# D2 x in xsk, not in sk: ['不退…', '不…', '…退転', '…退…', '…転']
#  -------------
# 3g
# norm: ['不退転']
# sk: ['不退', '不…転', '不', '退転', '退', '転', '不退転']
# xsk: ['不退…', '不…転', '不…', '…退転', '…退…', '…転', '不退転']
# C1 x in norm, sk, and xsk: ['不退転']
# C2 x in norm and sk, not in xsk: []
# C3 x in norm and xsk, not in sk: []
# C4 x in sk and xsk, not in norm: ['不…転']
# D1 x in sk, not in xsk: ['不退', '不', '退転', '退', '転']
# D2 x in xsk, not in sk: ['不退…', '不…', '…退転', '…退…', '…転']
#  -------------
# 4g
# norm: ['不退転']
# sk: ['不退', '不…転', '不', '退転', '退', '転', '不退転']
# xsk: ['不退…', '不…転', '不…', '…退転', '…退…', '…転', '不退転']
# C1 x in norm, sk, and xsk: ['不退転']
# C2 x in norm and sk, not in xsk: []
# C3 x in norm and xsk, not in sk: []
# C4 x in sk and xsk, not in norm: ['不…転']
# D1 x in sk, not in xsk: ['不退', '不', '退転', '退', '転']
# D2 x in xsk, not in sk: ['不退…', '不…', '…退転', '…退…', '…転']
# --------------
# doc: 阿耨多羅三藐三菩提
#  -------------
# 1g
# norm: ['阿', '耨', '多', '羅', '三', '藐', '三', '菩', '提']
# sk: ['阿', '耨', '多', '羅', '三', '藐', '菩', '提']
# xsk: ['阿…', '…耨…', '…多…', '…羅…', '…三…', '…藐…', '…菩…', '…提']
# C1 x in norm, sk, and xsk: []
# C2 x in norm and sk, not in xsk: ['阿', '耨', '多', '羅', '三', '藐', '三', '菩', '提']
# C3 x in norm and xsk, not in sk: []
# C4 x in sk and xsk, not in norm: []
# D1 x in sk, not in xsk: ['阿', '耨', '多', '羅', '三', '藐', '菩', '提']
# D2 x in xsk, not in sk: ['阿…', '…耨…', '…多…', '…羅…', '…三…', '…藐…', '…菩…', '…提']
#  -------------
# 2g
# norm: ['阿', '耨', '多', '羅', '三', '藐', '三', '菩', '提', '阿耨', '耨多', '多羅', '羅三', '三藐', '藐三', '三菩', '菩提']
# sk: ['阿耨', '阿…多', '阿…羅', '阿…三', '阿…藐', '阿…菩', '阿…提', '阿', '耨多', '耨…羅', '耨…三', '耨…藐', '耨…菩', '耨…提', '耨', '多羅', '多…三', '多…藐', '多…菩', '多…提', '多', '羅三', '羅…藐', '羅…三', '羅…菩', '羅…提', '羅', '三藐', '三…三', '三…菩', '三…提', '三', '藐三', '藐…菩', '藐…提', '藐', '三菩', '菩提', '菩', '提']
# xsk: ['阿耨…', '阿…多…', '阿…羅…', '阿…三…', '阿…藐…', '阿…菩…', '阿…提', '阿…', '…耨多…', '…耨…羅…', '…耨…三…', '…耨…藐…', '…耨…菩…', '…耨…提', '…耨…', '…多羅…', '…多…三…', '…多…藐…', '…多…菩…', '…多…提', '…多…', '…羅三…', '…羅…藐…', '…羅…三…', '…羅…菩…', '…羅…提', '…羅…', '…三藐…', '…三…三…', '…三…菩…', '…三…提', '…三…', '…藐三…', '…藐…菩…', '…藐…提', '…藐…', '…三菩…', '…菩提', '…菩…', '…提']
# C1 x in norm, sk, and xsk: []
# C2 x in norm and sk, not in xsk: ['阿', '耨', '多', '羅', '三', '藐', '三', '菩', '提', '阿耨', '耨多', '多羅', '羅三', '三藐', '藐三', '三菩', '菩提']
# C3 x in norm and xsk, not in sk: []
# C4 x in sk and xsk, not in norm: ['阿…提']
# D1 x in sk, not in xsk: ['阿耨', '阿…多', '阿…羅', '阿…三', '阿…藐', '阿…菩', '阿', '耨多', '耨…羅', '耨…三', '耨…藐', '耨…菩', '耨…提', '耨', '多羅', '多…三', '多…藐', '多…菩', '多…提', '多', '羅三', '羅…藐', '羅…三', '羅…菩', '羅…提', '羅', '三藐', '三…三', '三…菩', '三…提', '三', '藐三', '藐…菩', '藐…提', '藐', '三菩', '菩提', '菩', '提']
# D2 x in xsk, not in sk: ['阿耨…', '阿…多…', '阿…羅…', '阿…三…', '阿…藐…', '阿…菩…', '阿…', '…耨多…', '…耨…羅…', '…耨…三…', '…耨…藐…', '…耨…菩…', '…耨…提', '…耨…', '…多羅…', '…多…三…', '…多…藐…', '…多…菩…', '…多…提', '…多…', '…羅三…', '…羅…藐…', '…羅…三…', '…羅…菩…', '…羅…提', '…羅…', '…三藐…', '…三…三…', '…三…菩…', '…三…提', '…三…', '…藐三…', '…藐…菩…', '…藐…提', '…藐…', '…三菩…', '…菩提', '…菩…', '…提']
#  -------------
# 3g
# norm: ['阿', '耨', '多', '羅', '三', '藐', '三', '菩', '提', '阿耨', '耨多', '多羅', '羅三', '三藐', '藐三', '三菩', '菩提', '阿耨多', '耨多羅', '多羅三', '羅三藐', '三藐三', '藐三菩', '三菩提']
# sk: ['阿耨多', '阿耨…羅', '阿耨…三', '阿耨…藐', '阿耨…菩', '阿耨…提', '阿耨', '阿…多羅', '阿…多…三', '阿…多…藐', '阿…多…菩', '阿…多…提', '阿…多', '阿…羅三', '阿…羅…藐', '阿…羅…三', '阿…羅…菩', '阿…羅…提', '阿…羅', '阿…三藐', '阿…三…三', '阿…三…菩', '阿…三…提', '阿…三', '阿…藐三', '阿…藐…菩', '阿…藐…提', '阿…藐', '阿…三菩', '阿…菩提', '阿…菩', '阿…提', '阿', '耨多羅', '耨多…三', '耨多…藐', '耨多…菩', '耨多…提', '耨多', '耨…羅三', '耨…羅…藐', '耨…羅…三', '耨…羅…菩', '耨…羅…提', '耨…羅', '耨…三藐', '耨…三…三', '耨…三…菩', '耨…三…提', '耨…三', '耨…藐三', '耨…藐…菩', '耨…藐…提', '耨…藐', '耨…三菩', '耨…菩提', '耨…菩', '耨…提', '耨', '多羅三', '多羅…藐', '多羅…三', '多羅…菩', '多羅…提', '多羅', '多…三藐', '多…三…三', '多…三…菩', '多…三…提', '多…三', '多…藐三', '多…藐…菩', '多…藐…提', '多…藐', '多…三菩', '多…菩提', '多…菩', '多…提', '多', '羅三藐', '羅三…三', '羅三…菩', '羅三…提', '羅三', '羅…藐三', '羅…藐…菩', '羅…藐…提', '羅…藐', '羅…三菩', '羅…三…提', '羅…三', '羅…菩提', '羅…菩', '羅…提', '羅', '三藐三', '三藐…菩', '三藐…提', '三藐', '三…三菩', '三…三…提', '三…三', '三…菩提', '三…菩', '三…提', '三', '藐三菩', '藐三…提', '藐三', '藐…菩提', '藐…菩', '藐…提', '藐', '三菩提', '三菩', '菩提', '菩', '提']
# xsk: ['阿耨多…', '阿耨…羅…', '阿耨…三…', '阿耨…藐…', '阿耨…菩…', '阿耨…提', '阿耨…', '阿…多羅…', '阿…多…三…', '阿…多…藐…', '阿…多…菩…', '阿…多…提', '阿…多…', '阿…羅三…', '阿…羅…藐…', '阿…羅…三…', '阿…羅…菩…', '阿…羅…提', '阿…羅…', '阿…三藐…', '阿…三…三…', '阿…三…菩…', '阿…三…提', '阿…三…', '阿…藐三…', '阿…藐…菩…', '阿…藐…提', '阿…藐…', '阿…三菩…', '阿…菩提', '阿…菩…', '阿…提', '阿…', '…耨多羅…', '…耨多…三…', '…耨多…藐…', '…耨多…菩…', '…耨多…提', '…耨多…', '…耨…羅三…', '…耨…羅…藐…', '…耨…羅…三…', '…耨…羅…菩…', '…耨…羅…提', '…耨…羅…', '…耨…三藐…', '…耨…三…三…', '…耨…三…菩…', '…耨…三…提', '…耨…三…', '…耨…藐三…', '…耨…藐…菩…', '…耨…藐…提', '…耨…藐…', '…耨…三菩…', '…耨…菩提', '…耨…菩…', '…耨…提', '…耨…', '…多羅三…', '…多羅…藐…', '…多羅…三…', '…多羅…菩…', '…多羅…提', '…多羅…', '…多…三藐…', '…多…三…三…', '…多…三…菩…', '…多…三…提', '…多…三…', '…多…藐三…', '…多…藐…菩…', '…多…藐…提', '…多…藐…', '…多…三菩…', '…多…菩提', '…多…菩…', '…多…提', '…多…', '…羅三藐…', '…羅三…三…', '…羅三…菩…', '…羅三…提', '…羅三…', '…羅…藐三…', '…羅…藐…菩…', '…羅…藐…提', '…羅…藐…', '…羅…三菩…', '…羅…三…提', '…羅…三…', '…羅…菩提', '…羅…菩…', '…羅…提', '…羅…', '…三藐三…', '…三藐…菩…', '…三藐…提', '…三藐…', '…三…三菩…', '…三…三…提', '…三…三…', '…三…菩提', '…三…菩…', '…三…提', '…三…', '…藐三菩…', '…藐三…提', '…藐三…', '…藐…菩提', '…藐…菩…', '…藐…提', '…藐…', '…三菩提', '…三菩…', '…菩提', '…菩…', '…提']
# C1 x in norm, sk, and xsk: []
# C2 x in norm and sk, not in xsk: ['阿', '耨', '多', '羅', '三', '藐', '三', '菩', '提', '阿耨', '耨多', '多羅', '羅三', '三藐', '藐三', '三菩', '菩提', '阿耨多', '耨多羅', '多羅三', '羅三藐', '三藐三', '藐三菩', '三菩提']
# C3 x in norm and xsk, not in sk: []
# C4 x in sk and xsk, not in norm: ['阿耨…提', '阿…多…提', '阿…羅…提', '阿…三…提', '阿…藐…提', '阿…菩提', '阿…提']
# D1 x in sk, not in xsk: ['阿耨多', '阿耨…羅', '阿耨…三', '阿耨…藐', '阿耨…菩', '阿耨', '阿…多羅', '阿…多…三', '阿…多…藐', '阿…多…菩', '阿…多', '阿…羅三', '阿…羅…藐', '阿…羅…三', '阿…羅…菩', '阿…羅', '阿…三藐', '阿…三…三', '阿…三…菩', '阿…三', '阿…藐三', '阿…藐…菩', '阿…藐', '阿…三菩', '阿…菩', '阿', '耨多羅', '耨多…三', '耨多…藐', '耨多…菩', '耨多…提', '耨多', '耨…羅三', '耨…羅…藐', '耨…羅…三', '耨…羅…菩', '耨…羅…提', '耨…羅', '耨…三藐', '耨…三…三', '耨…三…菩', '耨…三…提', '耨…三', '耨…藐三', '耨…藐…菩', '耨…藐…提', '耨…藐', '耨…三菩', '耨…菩提', '耨…菩', '耨…提', '耨', '多羅三', '多羅…藐', '多羅…三', '多羅…菩', '多羅…提', '多羅', '多…三藐', '多…三…三', '多…三…菩', '多…三…提', '多…三', '多…藐三', '多…藐…菩', '多…藐…提', '多…藐', '多…三菩', '多…菩提', '多…菩', '多…提', '多', '羅三藐', '羅三…三', '羅三…菩', '羅三…提', '羅三', '羅…藐三', '羅…藐…菩', '羅…藐…提', '羅…藐', '羅…三菩', '羅…三…提', '羅…三', '羅…菩提', '羅…菩', '羅…提', '羅', '三藐三', '三藐…菩', '三藐…提', '三藐', '三…三菩', '三…三…提', '三…三', '三…菩提', '三…菩', '三…提', '三', '藐三菩', '藐三…提', '藐三', '藐…菩提', '藐…菩', '藐…提', '藐', '三菩提', '三菩', '菩提', '菩', '提']
# D2 x in xsk, not in sk: ['阿耨多…', '阿耨…羅…', '阿耨…三…', '阿耨…藐…', '阿耨…菩…', '阿耨…', '阿…多羅…', '阿…多…三…', '阿…多…藐…', '阿…多…菩…', '阿…多…', '阿…羅三…', '阿…羅…藐…', '阿…羅…三…', '阿…羅…菩…', '阿…羅…', '阿…三藐…', '阿…三…三…', '阿…三…菩…', '阿…三…', '阿…藐三…', '阿…藐…菩…', '阿…藐…', '阿…三菩…', '阿…菩…', '阿…', '…耨多羅…', '…耨多…三…', '…耨多…藐…', '…耨多…菩…', '…耨多…提', '…耨多…', '…耨…羅三…', '…耨…羅…藐…', '…耨…羅…三…', '…耨…羅…菩…', '…耨…羅…提', '…耨…羅…', '…耨…三藐…', '…耨…三…三…', '…耨…三…菩…', '…耨…三…提', '…耨…三…', '…耨…藐三…', '…耨…藐…菩…', '…耨…藐…提', '…耨…藐…', '…耨…三菩…', '…耨…菩提', '…耨…菩…', '…耨…提', '…耨…', '…多羅三…', '…多羅…藐…', '…多羅…三…', '…多羅…菩…', '…多羅…提', '…多羅…', '…多…三藐…', '…多…三…三…', '…多…三…菩…', '…多…三…提', '…多…三…', '…多…藐三…', '…多…藐…菩…', '…多…藐…提', '…多…藐…', '…多…三菩…', '…多…菩提', '…多…菩…', '…多…提', '…多…', '…羅三藐…', '…羅三…三…', '…羅三…菩…', '…羅三…提', '…羅三…', '…羅…藐三…', '…羅…藐…菩…', '…羅…藐…提', '…羅…藐…', '…羅…三菩…', '…羅…三…提', '…羅…三…', '…羅…菩提', '…羅…菩…', '…羅…提', '…羅…', '…三藐三…', '…三藐…菩…', '…三藐…提', '…三藐…', '…三…三菩…', '…三…三…提', '…三…三…', '…三…菩提', '…三…菩…', '…三…提', '…三…', '…藐三菩…', '…藐三…提', '…藐三…', '…藐…菩提', '…藐…菩…', '…藐…提', '…藐…', '…三菩提', '…三菩…', '…菩提', '…菩…', '…提']
#  -------------
# 4g
# norm: ['阿', '耨', '多', '羅', '三', '藐', '三', '菩', '提', '阿耨', '耨多', '多羅', '羅三', '三藐', '藐三', '三菩', '菩提', '阿耨多', '耨多羅', '多羅三', '羅三藐', '三藐三', '藐三菩', '三菩提', '阿耨多羅', '耨多羅三', '多羅三藐', '羅三藐三', '三藐三菩', '藐三菩提']
# sk: ['阿耨多羅', '阿耨多…三', '阿耨多…藐', '阿耨多…菩', '阿耨多…提', '阿耨多', '阿耨…羅三', '阿耨…羅…藐', '阿耨…羅…三', '阿耨…羅…菩', '阿耨…羅…提', '阿耨…羅', '阿耨…三藐', '阿耨…三…三', '阿耨…三…菩', '阿耨…三…提', '阿耨…三', '阿耨…藐三', '阿耨…藐…菩', '阿耨…藐…提', '阿耨…藐', '阿耨…三菩', '阿耨…菩提', '阿耨…菩', '阿耨…提', '阿耨', '阿…多羅三', '阿…多羅…藐', '阿…多羅…三', '阿…多羅…菩', '阿…多羅…提', '阿…多羅', '阿…多…三藐', '阿…多…三…三', '阿…多…三…菩', '阿…多…三…提', '阿…多…三', '阿…多…藐三', '阿…多…藐…菩', '阿…多…藐…提', '阿…多…藐', '阿…多…三菩', '阿…多…菩提', '阿…多…菩', '阿…多…提', '阿…多', '阿…羅三藐', '阿…羅三…三', '阿…羅三…菩', '阿…羅三…提', '阿…羅三', '阿…羅…藐三', '阿…羅…藐…菩', '阿…羅…藐…提', '阿…羅…藐', '阿…羅…三菩', '阿…羅…三…提', '阿…羅…三', '阿…羅…菩提', '阿…羅…菩', '阿…羅…提', '阿…羅', '阿…三藐三', '阿…三藐…菩', '阿…三藐…提', '阿…三藐', '阿…三…三菩', '阿…三…三…提', '阿…三…三', '阿…三…菩提', '阿…三…菩', '阿…三…提', '阿…三', '阿…藐三菩', '阿…藐三…提', '阿…藐三', '阿…藐…菩提', '阿…藐…菩', '阿…藐…提', '阿…藐', '阿…三菩提', '阿…三菩', '阿…菩提', '阿…菩', '阿…提', '阿', '耨多羅三', '耨多羅…藐', '耨多羅…三', '耨多羅…菩', '耨多羅…提', '耨多羅', '耨多…三藐', '耨多…三…三', '耨多…三…菩', '耨多…三…提', '耨多…三', '耨多…藐三', '耨多…藐…菩', '耨多…藐…提', '耨多…藐', '耨多…三菩', '耨多…菩提', '耨多…菩', '耨多…提', '耨多', '耨…羅三藐', '耨…羅三…三', '耨…羅三…菩', '耨…羅三…提', '耨…羅三', '耨…羅…藐三', '耨…羅…藐…菩', '耨…羅…藐…提', '耨…羅…藐', '耨…羅…三菩', '耨…羅…三…提', '耨…羅…三', '耨…羅…菩提', '耨…羅…菩', '耨…羅…提', '耨…羅', '耨…三藐三', '耨…三藐…菩', '耨…三藐…提', '耨…三藐', '耨…三…三菩', '耨…三…三…提', '耨…三…三', '耨…三…菩提', '耨…三…菩', '耨…三…提', '耨…三', '耨…藐三菩', '耨…藐三…提', '耨…藐三', '耨…藐…菩提', '耨…藐…菩', '耨…藐…提', '耨…藐', '耨…三菩提', '耨…三菩', '耨…菩提', '耨…菩', '耨…提', '耨', '多羅三藐', '多羅三…三', '多羅三…菩', '多羅三…提', '多羅三', '多羅…藐三', '多羅…藐…菩', '多羅…藐…提', '多羅…藐', '多羅…三菩', '多羅…三…提', '多羅…三', '多羅…菩提', '多羅…菩', '多羅…提', '多羅', '多…三藐三', '多…三藐…菩', '多…三藐…提', '多…三藐', '多…三…三菩', '多…三…三…提', '多…三…三', '多…三…菩提', '多…三…菩', '多…三…提', '多…三', '多…藐三菩', '多…藐三…提', '多…藐三', '多…藐…菩提', '多…藐…菩', '多…藐…提', '多…藐', '多…三菩提', '多…三菩', '多…菩提', '多…菩', '多…提', '多', '羅三藐三', '羅三藐…菩', '羅三藐…提', '羅三藐', '羅三…三菩', '羅三…三…提', '羅三…三', '羅三…菩提', '羅三…菩', '羅三…提', '羅三', '羅…藐三菩', '羅…藐三…提', '羅…藐三', '羅…藐…菩提', '羅…藐…菩', '羅…藐…提', '羅…藐', '羅…三菩提', '羅…三菩', '羅…三…提', '羅…三', '羅…菩提', '羅…菩', '羅…提', '羅', '三藐三菩', '三藐三…提', '三藐三', '三藐…菩提', '三藐…菩', '三藐…提', '三藐', '三…三菩提', '三…三菩', '三…三…提', '三…三', '三…菩提', '三…菩', '三…提', '三', '藐三菩提', '藐三菩', '藐三…提', '藐三', '藐…菩提', '藐…菩', '藐…提', '藐', '三菩提', '三菩', '菩提', '菩', '提']
# xsk: ['阿耨多羅…', '阿耨多…三…', '阿耨多…藐…', '阿耨多…菩…', '阿耨多…提', '阿耨多…', '阿耨…羅三…', '阿耨…羅…藐…', '阿耨…羅…三…', '阿耨…羅…菩…', '阿耨…羅…提', '阿耨…羅…', '阿耨…三藐…', '阿耨…三…三…', '阿耨…三…菩…', '阿耨…三…提', '阿耨…三…', '阿耨…藐三…', '阿耨…藐…菩…', '阿耨…藐…提', '阿耨…藐…', '阿耨…三菩…', '阿耨…菩提', '阿耨…菩…', '阿耨…提', '阿耨…', '阿…多羅三…', '阿…多羅…藐…', '阿…多羅…三…', '阿…多羅…菩…', '阿…多羅…提', '阿…多羅…', '阿…多…三藐…', '阿…多…三…三…', '阿…多…三…菩…', '阿…多…三…提', '阿…多…三…', '阿…多…藐三…', '阿…多…藐…菩…', '阿…多…藐…提', '阿…多…藐…', '阿…多…三菩…', '阿…多…菩提', '阿…多…菩…', '阿…多…提', '阿…多…', '阿…羅三藐…', '阿…羅三…三…', '阿…羅三…菩…', '阿…羅三…提', '阿…羅三…', '阿…羅…藐三…', '阿…羅…藐…菩…', '阿…羅…藐…提', '阿…羅…藐…', '阿…羅…三菩…', '阿…羅…三…提', '阿…羅…三…', '阿…羅…菩提', '阿…羅…菩…', '阿…羅…提', '阿…羅…', '阿…三藐三…', '阿…三藐…菩…', '阿…三藐…提', '阿…三藐…', '阿…三…三菩…', '阿…三…三…提', '阿…三…三…', '阿…三…菩提', '阿…三…菩…', '阿…三…提', '阿…三…', '阿…藐三菩…', '阿…藐三…提', '阿…藐三…', '阿…藐…菩提', '阿…藐…菩…', '阿…藐…提', '阿…藐…', '阿…三菩提', '阿…三菩…', '阿…菩提', '阿…菩…', '阿…提', '阿…', '…耨多羅三…', '…耨多羅…藐…', '…耨多羅…三…', '…耨多羅…菩…', '…耨多羅…提', '…耨多羅…', '…耨多…三藐…', '…耨多…三…三…', '…耨多…三…菩…', '…耨多…三…提', '…耨多…三…', '…耨多…藐三…', '…耨多…藐…菩…', '…耨多…藐…提', '…耨多…藐…', '…耨多…三菩…', '…耨多…菩提', '…耨多…菩…', '…耨多…提', '…耨多…', '…耨…羅三藐…', '…耨…羅三…三…', '…耨…羅三…菩…', '…耨…羅三…提', '…耨…羅三…', '…耨…羅…藐三…', '…耨…羅…藐…菩…', '…耨…羅…藐…提', '…耨…羅…藐…', '…耨…羅…三菩…', '…耨…羅…三…提', '…耨…羅…三…', '…耨…羅…菩提', '…耨…羅…菩…', '…耨…羅…提', '…耨…羅…', '…耨…三藐三…', '…耨…三藐…菩…', '…耨…三藐…提', '…耨…三藐…', '…耨…三…三菩…', '…耨…三…三…提', '…耨…三…三…', '…耨…三…菩提', '…耨…三…菩…', '…耨…三…提', '…耨…三…', '…耨…藐三菩…', '…耨…藐三…提', '…耨…藐三…', '…耨…藐…菩提', '…耨…藐…菩…', '…耨…藐…提', '…耨…藐…', '…耨…三菩提', '…耨…三菩…', '…耨…菩提', '…耨…菩…', '…耨…提', '…耨…', '…多羅三藐…', '…多羅三…三…', '…多羅三…菩…', '…多羅三…提', '…多羅三…', '…多羅…藐三…', '…多羅…藐…菩…', '…多羅…藐…提', '…多羅…藐…', '…多羅…三菩…', '…多羅…三…提', '…多羅…三…', '…多羅…菩提', '…多羅…菩…', '…多羅…提', '…多羅…', '…多…三藐三…', '…多…三藐…菩…', '…多…三藐…提', '…多…三藐…', '…多…三…三菩…', '…多…三…三…提', '…多…三…三…', '…多…三…菩提', '…多…三…菩…', '…多…三…提', '…多…三…', '…多…藐三菩…', '…多…藐三…提', '…多…藐三…', '…多…藐…菩提', '…多…藐…菩…', '…多…藐…提', '…多…藐…', '…多…三菩提', '…多…三菩…', '…多…菩提', '…多…菩…', '…多…提', '…多…', '…羅三藐三…', '…羅三藐…菩…', '…羅三藐…提', '…羅三藐…', '…羅三…三菩…', '…羅三…三…提', '…羅三…三…', '…羅三…菩提', '…羅三…菩…', '…羅三…提', '…羅三…', '…羅…藐三菩…', '…羅…藐三…提', '…羅…藐三…', '…羅…藐…菩提', '…羅…藐…菩…', '…羅…藐…提', '…羅…藐…', '…羅…三菩提', '…羅…三菩…', '…羅…三…提', '…羅…三…', '…羅…菩提', '…羅…菩…', '…羅…提', '…羅…', '…三藐三菩…', '…三藐三…提', '…三藐三…', '…三藐…菩提', '…三藐…菩…', '…三藐…提', '…三藐…', '…三…三菩提', '…三…三菩…', '…三…三…提', '…三…三…', '…三…菩提', '…三…菩…', '…三…提', '…三…', '…藐三菩提', '…藐三菩…', '…藐三…提', '…藐三…', '…藐…菩提', '…藐…菩…', '…藐…提', '…藐…', '…三菩提', '…三菩…', '…菩提', '…菩…', '…提']
# C1 x in norm, sk, and xsk: []
# C2 x in norm and sk, not in xsk: ['阿', '耨', '多', '羅', '三', '藐', '三', '菩', '提', '阿耨', '耨多', '多羅', '羅三', '三藐', '藐三', '三菩', '菩提', '阿耨多', '耨多羅', '多羅三', '羅三藐', '三藐三', '藐三菩', '三菩提', '阿耨多羅', '耨多羅三', '多羅三藐', '羅三藐三', '三藐三菩', '藐三菩提']
# C3 x in norm and xsk, not in sk: []
# C4 x in sk and xsk, not in norm: ['阿耨多…提', '阿耨…羅…提', '阿耨…三…提', '阿耨…藐…提', '阿耨…菩提', '阿耨…提', '阿…多羅…提', '阿…多…三…提', '阿…多…藐…提', '阿…多…菩提', '阿…多…提', '阿…羅三…提', '阿…羅…藐…提', '阿…羅…三…提', '阿…羅…菩提', '阿…羅…提', '阿…三藐…提', '阿…三…三…提', '阿…三…菩提', '阿…三…提', '阿…藐三…提', '阿…藐…菩提', '阿…藐…提', '阿…三菩提', '阿…菩提', '阿…提']
# D1 x in sk, not in xsk: ['阿耨多羅', '阿耨多…三', '阿耨多…藐', '阿耨多…菩', '阿耨多', '阿耨…羅三', '阿耨…羅…藐', '阿耨…羅…三', '阿耨…羅…菩', '阿耨…羅', '阿耨…三藐', '阿耨…三…三', '阿耨…三…菩', '阿耨…三', '阿耨…藐三', '阿耨…藐…菩', '阿耨…藐', '阿耨…三菩', '阿耨…菩', '阿耨', '阿…多羅三', '阿…多羅…藐', '阿…多羅…三', '阿…多羅…菩', '阿…多羅', '阿…多…三藐', '阿…多…三…三', '阿…多…三…菩', '阿…多…三', '阿…多…藐三', '阿…多…藐…菩', '阿…多…藐', '阿…多…三菩', '阿…多…菩', '阿…多', '阿…羅三藐', '阿…羅三…三', '阿…羅三…菩', '阿…羅三', '阿…羅…藐三', '阿…羅…藐…菩', '阿…羅…藐', '阿…羅…三菩', '阿…羅…三', '阿…羅…菩', '阿…羅', '阿…三藐三', '阿…三藐…菩', '阿…三藐', '阿…三…三菩', '阿…三…三', '阿…三…菩', '阿…三', '阿…藐三菩', '阿…藐三', '阿…藐…菩', '阿…藐', '阿…三菩', '阿…菩', '阿', '耨多羅三', '耨多羅…藐', '耨多羅…三', '耨多羅…菩', '耨多羅…提', '耨多羅', '耨多…三藐', '耨多…三…三', '耨多…三…菩', '耨多…三…提', '耨多…三', '耨多…藐三', '耨多…藐…菩', '耨多…藐…提', '耨多…藐', '耨多…三菩', '耨多…菩提', '耨多…菩', '耨多…提', '耨多', '耨…羅三藐', '耨…羅三…三', '耨…羅三…菩', '耨…羅三…提', '耨…羅三', '耨…羅…藐三', '耨…羅…藐…菩', '耨…羅…藐…提', '耨…羅…藐', '耨…羅…三菩', '耨…羅…三…提', '耨…羅…三', '耨…羅…菩提', '耨…羅…菩', '耨…羅…提', '耨…羅', '耨…三藐三', '耨…三藐…菩', '耨…三藐…提', '耨…三藐', '耨…三…三菩', '耨…三…三…提', '耨…三…三', '耨…三…菩提', '耨…三…菩', '耨…三…提', '耨…三', '耨…藐三菩', '耨…藐三…提', '耨…藐三', '耨…藐…菩提', '耨…藐…菩', '耨…藐…提', '耨…藐', '耨…三菩提', '耨…三菩', '耨…菩提', '耨…菩', '耨…提', '耨', '多羅三藐', '多羅三…三', '多羅三…菩', '多羅三…提', '多羅三', '多羅…藐三', '多羅…藐…菩', '多羅…藐…提', '多羅…藐', '多羅…三菩', '多羅…三…提', '多羅…三', '多羅…菩提', '多羅…菩', '多羅…提', '多羅', '多…三藐三', '多…三藐…菩', '多…三藐…提', '多…三藐', '多…三…三菩', '多…三…三…提', '多…三…三', '多…三…菩提', '多…三…菩', '多…三…提', '多…三', '多…藐三菩', '多…藐三…提', '多…藐三', '多…藐…菩提', '多…藐…菩', '多…藐…提', '多…藐', '多…三菩提', '多…三菩', '多…菩提', '多…菩', '多…提', '多', '羅三藐三', '羅三藐…菩', '羅三藐…提', '羅三藐', '羅三…三菩', '羅三…三…提', '羅三…三', '羅三…菩提', '羅三…菩', '羅三…提', '羅三', '羅…藐三菩', '羅…藐三…提', '羅…藐三', '羅…藐…菩提', '羅…藐…菩', '羅…藐…提', '羅…藐', '羅…三菩提', '羅…三菩', '羅…三…提', '羅…三', '羅…菩提', '羅…菩', '羅…提', '羅', '三藐三菩', '三藐三…提', '三藐三', '三藐…菩提', '三藐…菩', '三藐…提', '三藐', '三…三菩提', '三…三菩', '三…三…提', '三…三', '三…菩提', '三…菩', '三…提', '三', '藐三菩提', '藐三菩', '藐三…提', '藐三', '藐…菩提', '藐…菩', '藐…提', '藐', '三菩提', '三菩', '菩提', '菩', '提']
# D2 x in xsk, not in sk: ['阿耨多羅…', '阿耨多…三…', '阿耨多…藐…', '阿耨多…菩…', '阿耨多…', '阿耨…羅三…', '阿耨…羅…藐…', '阿耨…羅…三…', '阿耨…羅…菩…', '阿耨…羅…', '阿耨…三藐…', '阿耨…三…三…', '阿耨…三…菩…', '阿耨…三…', '阿耨…藐三…', '阿耨…藐…菩…', '阿耨…藐…', '阿耨…三菩…', '阿耨…菩…', '阿耨…', '阿…多羅三…', '阿…多羅…藐…', '阿…多羅…三…', '阿…多羅…菩…', '阿…多羅…', '阿…多…三藐…', '阿…多…三…三…', '阿…多…三…菩…', '阿…多…三…', '阿…多…藐三…', '阿…多…藐…菩…', '阿…多…藐…', '阿…多…三菩…', '阿…多…菩…', '阿…多…', '阿…羅三藐…', '阿…羅三…三…', '阿…羅三…菩…', '阿…羅三…', '阿…羅…藐三…', '阿…羅…藐…菩…', '阿…羅…藐…', '阿…羅…三菩…', '阿…羅…三…', '阿…羅…菩…', '阿…羅…', '阿…三藐三…', '阿…三藐…菩…', '阿…三藐…', '阿…三…三菩…', '阿…三…三…', '阿…三…菩…', '阿…三…', '阿…藐三菩…', '阿…藐三…', '阿…藐…菩…', '阿…藐…', '阿…三菩…', '阿…菩…', '阿…', '…耨多羅三…', '…耨多羅…藐…', '…耨多羅…三…', '…耨多羅…菩…', '…耨多羅…提', '…耨多羅…', '…耨多…三藐…', '…耨多…三…三…', '…耨多…三…菩…', '…耨多…三…提', '…耨多…三…', '…耨多…藐三…', '…耨多…藐…菩…', '…耨多…藐…提', '…耨多…藐…', '…耨多…三菩…', '…耨多…菩提', '…耨多…菩…', '…耨多…提', '…耨多…', '…耨…羅三藐…', '…耨…羅三…三…', '…耨…羅三…菩…', '…耨…羅三…提', '…耨…羅三…', '…耨…羅…藐三…', '…耨…羅…藐…菩…', '…耨…羅…藐…提', '…耨…羅…藐…', '…耨…羅…三菩…', '…耨…羅…三…提', '…耨…羅…三…', '…耨…羅…菩提', '…耨…羅…菩…', '…耨…羅…提', '…耨…羅…', '…耨…三藐三…', '…耨…三藐…菩…', '…耨…三藐…提', '…耨…三藐…', '…耨…三…三菩…', '…耨…三…三…提', '…耨…三…三…', '…耨…三…菩提', '…耨…三…菩…', '…耨…三…提', '…耨…三…', '…耨…藐三菩…', '…耨…藐三…提', '…耨…藐三…', '…耨…藐…菩提', '…耨…藐…菩…', '…耨…藐…提', '…耨…藐…', '…耨…三菩提', '…耨…三菩…', '…耨…菩提', '…耨…菩…', '…耨…提', '…耨…', '…多羅三藐…', '…多羅三…三…', '…多羅三…菩…', '…多羅三…提', '…多羅三…', '…多羅…藐三…', '…多羅…藐…菩…', '…多羅…藐…提', '…多羅…藐…', '…多羅…三菩…', '…多羅…三…提', '…多羅…三…', '…多羅…菩提', '…多羅…菩…', '…多羅…提', '…多羅…', '…多…三藐三…', '…多…三藐…菩…', '…多…三藐…提', '…多…三藐…', '…多…三…三菩…', '…多…三…三…提', '…多…三…三…', '…多…三…菩提', '…多…三…菩…', '…多…三…提', '…多…三…', '…多…藐三菩…', '…多…藐三…提', '…多…藐三…', '…多…藐…菩提', '…多…藐…菩…', '…多…藐…提', '…多…藐…', '…多…三菩提', '…多…三菩…', '…多…菩提', '…多…菩…', '…多…提', '…多…', '…羅三藐三…', '…羅三藐…菩…', '…羅三藐…提', '…羅三藐…', '…羅三…三菩…', '…羅三…三…提', '…羅三…三…', '…羅三…菩提', '…羅三…菩…', '…羅三…提', '…羅三…', '…羅…藐三菩…', '…羅…藐三…提', '…羅…藐三…', '…羅…藐…菩提', '…羅…藐…菩…', '…羅…藐…提', '…羅…藐…', '…羅…三菩提', '…羅…三菩…', '…羅…三…提', '…羅…三…', '…羅…菩提', '…羅…菩…', '…羅…提', '…羅…', '…三藐三菩…', '…三藐三…提', '…三藐三…', '…三藐…菩提', '…三藐…菩…', '…三藐…提', '…三藐…', '…三…三菩提', '…三…三菩…', '…三…三…提', '…三…三…', '…三…菩提', '…三…菩…', '…三…提', '…三…', '…藐三菩提', '…藐三菩…', '…藐三…提', '…藐三…', '…藐…菩提', '…藐…菩…', '…藐…提', '…藐…', '…三菩提', '…三菩…', '…菩提', '…菩…', '…提']
# --------------
# doc: 一切智
#  -------------
# 1g
# norm: ['一', '切', '智']
# ...
# sk: ['両祖忌', '両祖…法', '両祖…要', '両祖', '両…忌法', '両…忌…要', '両…忌', '両…法要', '両…法', '両…要', '両', '祖忌法', '祖忌…要', '祖忌', '祖…法要', '祖…法', '祖…要', '祖', '忌法要', '忌法', '忌…要', '忌', '法要', '法', '要']
# xsk: ['両祖忌…', '両祖…法…', '両祖…要', '両祖…', '両…忌法…', '両…忌…要', '両…忌…', '両…法要', '両…法…', '両…要', '両…', '…祖忌法…', '…祖忌…要', '…祖忌…', '…祖…法要', '…祖…法…', '…祖…要', '…祖…', '…忌法要', '…忌法…', '…忌…要', '…忌…', '…法要', '…法…', '…要']
# C1 x in norm, sk, and xsk: []
# C2 x in norm and sk, not in xsk: ['両', '祖', '忌', '法', '要', '両祖', '祖忌', '忌法', '法要', '両祖忌', '祖忌法', '忌法要']
# C3 x in norm and xsk, not in sk: []
# C4 x in sk and xsk, not in norm: ['両祖…要', '両…忌…要', '両…法要', '両…要']
# D1 x in sk, not in xsk: ['両祖忌', '両祖…法', '両祖', '両…忌法', '両…忌', '両…法', '両', '祖忌法', '祖忌…要', '祖忌', '祖…法要', '祖…法', '祖…要', '祖', '忌法要', '忌法', '忌…要', '忌', '法要', '法', '要']
# D2 x in xsk, not in sk: ['両祖忌…', '両祖…法…', '両祖…', '両…忌法…', '両…忌…', '両…法…', '両…', '…祖忌法…', '…祖忌…要', '…祖忌…', '…祖…法要', '…祖…法…', '…祖…要', '…祖…', '…忌法要', '…忌法…', '…忌…要', '…忌…', '…法要', '…法…', '…要']
#  -------------
# 4g
# norm: ['両', '祖', '忌', '法', '要', '両祖', '祖忌', '忌法', '法要', '両祖忌', '祖忌法', '忌法要', '両祖忌法', '祖忌法要']
# sk: ['両祖忌法', '両祖忌…要', '両祖忌', '両祖…法要', '両祖…法', '両祖…要', '両祖', '両…忌法要', '両…忌法', '両…忌…要', '両…忌', '両…法要', '両…法', '両…要', '両', '祖忌法要', '祖忌法', '祖忌…要', '祖忌', '祖…法要', '祖…法', '祖…要', '祖', '忌法要', '忌法', '忌…要', '忌', '法要', '法', '要']
# xsk: ['両祖忌法…', '両祖忌…要', '両祖忌…', '両祖…法要', '両祖…法…', '両祖…要', '両祖…', '両…忌法要', '両…忌法…', '両…忌…要', '両…忌…', '両…法要', '両…法…', '両…要', '両…', '…祖忌法要', '…祖忌法…', '…祖忌…要', '…祖忌…', '…祖…法要', '…祖…法…', '…祖…要', '…祖…', '…忌法要', '…忌法…', '…忌…要', '…忌…', '…法要', '…法…', '…要']
# C1 x in norm, sk, and xsk: []
# C2 x in norm and sk, not in xsk: ['両', '祖', '忌', '法', '要', '両祖', '祖忌', '忌法', '法要', '両祖忌', '祖忌法', '忌法要', '両祖忌法', '祖忌法要']
# C3 x in norm and xsk, not in sk: []
# C4 x in sk and xsk, not in norm: ['両祖忌…要', '両祖…法要', '両祖…要', '両…忌法要', '両…忌…要', '両…法要', '両…要']
# D1 x in sk, not in xsk: ['両祖忌法', '両祖忌', '両祖…法', '両祖', '両…忌法', '両…忌', '両…法', '両', '祖忌法要', '祖忌法', '祖忌…要', '祖忌', '祖…法要', '祖…法', '祖…要', '祖', '忌法要', '忌法', '忌…要', '忌', '法要', '法', '要']
# D2 x in xsk, not in sk: ['両祖忌法…', '両祖忌…', '両祖…法…', '両祖…', '両…忌法…', '両…忌…', '両…法…', '両…', '…祖忌法要', '…祖忌法…', '…祖忌…要', '…祖忌…', '…祖…法要', '…祖…法…', '…祖…要', '…祖…', '…忌法要', '…忌法…', '…忌…要', '…忌…', '…法要', '…法…', '…要']
# --------------
# doc: 宗祖忌法要
#  -------------
# 1g
# norm: ['宗', '祖', '忌', '法', '要']
# sk: ['宗', '祖', '忌', '法', '要']
# xsk: ['宗…', '…祖…', '…忌…', '…法…', '…要']
# C1 x in norm, sk, and xsk: []
# C2 x in norm and sk, not in xsk: ['宗', '祖', '忌', '法', '要']
# C3 x in norm and xsk, not in sk: []
# C4 x in sk and xsk, not in norm: []
# D1 x in sk, not in xsk: ['宗', '祖', '忌', '法', '要']
# D2 x in xsk, not in sk: ['宗…', '…祖…', '…忌…', '…法…', '…要']
#  -------------
# 2g
# norm: ['宗', '祖', '忌', '法', '要', '宗祖', '祖忌', '忌法', '法要']
# sk: ['宗祖', '宗…忌', '宗…法', '宗…要', '宗', '祖忌', '祖…法', '祖…要', '祖', '忌法', '忌…要', '忌', '法要', '法', '要']
# xsk: ['宗祖…', '宗…忌…', '宗…法…', '宗…要', '宗…', '…祖忌…', '…祖…法…', '…祖…要', '…祖…', '…忌法…', '…忌…要', '…忌…', '…法要', '…法…', '…要']
# C1 x in norm, sk, and xsk: []
# C2 x in norm and sk, not in xsk: ['宗', '祖', '忌', '法', '要', '宗祖', '祖忌', '忌法', '法要']
# C3 x in norm and xsk, not in sk: []
# C4 x in sk and xsk, not in norm: ['宗…要']
# D1 x in sk, not in xsk: ['宗祖', '宗…忌', '宗…法', '宗', '祖忌', '祖…法', '祖…要', '祖', '忌法', '忌…要', '忌', '法要', '法', '要']
# D2 x in xsk, not in sk: ['宗祖…', '宗…忌…', '宗…法…', '宗…', '…祖忌…', '…祖…法…', '…祖…要', '…祖…', '…忌法…', '…忌…要', '…忌…', '…法要', '…法…', '…要']
#  -------------
# 3g
# norm: ['宗', '祖', '忌', '法', '要', '宗祖', '祖忌', '忌法', '法要', '宗祖忌', '祖忌法', '忌法要']
# sk: ['宗祖忌', '宗祖…法', '宗祖…要', '宗祖', '宗…忌法', '宗…忌…要', '宗…忌', '宗…法要', '宗…法', '宗…要', '宗', '祖忌法', '祖忌…要', '祖忌', '祖…法要', '祖…法', '祖…要', '祖', '忌法要', '忌法', '忌…要', '忌', '法要', '法', '要']
# xsk: ['宗祖忌…', '宗祖…法…', '宗祖…要', '宗祖…', '宗…忌法…', '宗…忌…要', '宗…忌…', '宗…法要', '宗…法…', '宗…要', '宗…', '…祖忌法…', '…祖忌…要', '…祖忌…', '…祖…法要', '…祖…法…', '…祖…要', '…祖…', '…忌法要', '…忌法…', '…忌…要', '…忌…', '…法要', '…法…', '…要']
# C1 x in norm, sk, and xsk: []
# C2 x in norm and sk, not in xsk: ['宗', '祖', '忌', '法', '要', '宗祖', '祖忌', '忌法', '法要', '宗祖忌', '祖忌法', '忌法要']
# C3 x in norm and xsk, not in sk: []
# C4 x in sk and xsk, not in norm: ['宗祖…要', '宗…忌…要', '宗…法要', '宗…要']
# D1 x in sk, not in xsk: ['宗祖忌', '宗祖…法', '宗祖', '宗…忌法', '宗…忌', '宗…法', '宗', '祖忌法', '祖忌…要', '祖忌', '祖…法要', '祖…法', '祖…要', '祖', '忌法要', '忌法', '忌…要', '忌', '法要', '法', '要']
# D2 x in xsk, not in sk: ['宗祖忌…', '宗祖…法…', '宗祖…', '宗…忌法…', '宗…忌…', '宗…法…', '宗…', '…祖忌法…', '…祖忌…要', '…祖忌…', '…祖…法要', '…祖…法…', '…祖…要', '…祖…', '…忌法要', '…忌法…', '…忌…要', '…忌…', '…法要', '…法…', '…要']
#  -------------
# 4g
# norm: ['宗', '祖', '忌', '法', '要', '宗祖', '祖忌', '忌法', '法要', '宗祖忌', '祖忌法', '忌法要', '宗祖忌法', '祖忌法要']
# sk: ['宗祖忌法', '宗祖忌…要', '宗祖忌', '宗祖…法要', '宗祖…法', '宗祖…要', '宗祖', '宗…忌法要', '宗…忌法', '宗…忌…要', '宗…忌', '宗…法要', '宗…法', '宗…要', '宗', '祖忌法要', '祖忌法', '祖忌…要', '祖忌', '祖…法要', '祖…法', '祖…要', '祖', '忌法要', '忌法', '忌…要', '忌', '法要', '法', '要']
# xsk: ['宗祖忌法…', '宗祖忌…要', '宗祖忌…', '宗祖…法要', '宗祖…法…', '宗祖…要', '宗祖…', '宗…忌法要', '宗…忌法…', '宗…忌…要', '宗…忌…', '宗…法要', '宗…法…', '宗…要', '宗…', '…祖忌法要', '…祖忌法…', '…祖忌…要', '…祖忌…', '…祖…法要', '…祖…法…', '…祖…要', '…祖…', '…忌法要', '…忌法…', '…忌…要', '…忌…', '…法要', '…法…', '…要']
# C1 x in norm, sk, and xsk: []
# C2 x in norm and sk, not in xsk: ['宗', '祖', '忌', '法', '要', '宗祖', '祖忌', '忌法', '法要', '宗祖忌', '祖忌法', '忌法要', '宗祖忌法', '祖忌法要']
# C3 x in norm and xsk, not in sk: []
# C4 x in sk and xsk, not in norm: ['宗祖忌…要', '宗祖…法要', '宗祖…要', '宗…忌法要', '宗…忌…要', '宗…法要', '宗…要']
# D1 x in sk, not in xsk: ['宗祖忌法', '宗祖忌', '宗祖…法', '宗祖', '宗…忌法', '宗…忌', '宗…法', '宗', '祖忌法要', '祖忌法', '祖忌…要', '祖忌', '祖…法要', '祖…法', '祖…要', '祖', '忌法要', '忌法', '忌…要', '忌', '法要', '法', '要']
# D2 x in xsk, not in sk: ['宗祖忌法…', '宗祖忌…', '宗祖…法…', '宗祖…', '宗…忌法…', '宗…忌…', '宗…法…', '宗…', '…祖忌法要', '…祖忌法…', '…祖忌…要', '…祖忌…', '…祖…法要', '…祖…法…', '…祖…要', '…祖…', '…忌法要', '…忌法…', '…忌…要', '…忌…', '…法要', '…法…', '…要']
# --------------
# doc: 御会式法要
#  -------------
# 1g
# norm: ['御', '会', '式', '法', '要']
# sk: ['御', '会', '式', '法', '要']
# xsk: ['御…', '…会…', '…式…', '…法…', '…要']
# C1 x in norm, sk, and xsk: []
# C2 x in norm and sk, not in xsk: ['御', '会', '式', '法', '要']
# C3 x in norm and xsk, not in sk: []
# C4 x in sk and xsk, not in norm: []
# D1 x in sk, not in xsk: ['御', '会', '式', '法', '要']
# D2 x in xsk, not in sk: ['御…', '…会…', '…式…', '…法…', '…要']
#  -------------
# 2g
# norm: ['御', '会', '式', '法', '要', '御会', '会式', '式法', '法要']
# sk: ['御会', '御…式', '御…法', '御…要', '御', '会式', '会…法', '会…要', '会', '式法', '式…要', '式', '法要', '法', '要']
# xsk: ['御会…', '御…式…', '御…法…', '御…要', '御…', '…会式…', '…会…法…', '…会…要', '…会…', '…式法…', '…式…要', '…式…', '…法要', '…法…', '…要']
# C1 x in norm, sk, and xsk: []
# C2 x in norm and sk, not in xsk: ['御', '会', '式', '法', '要', '御会', '会式', '式法', '法要']
# C3 x in norm and xsk, not in sk: []
# C4 x in sk and xsk, not in norm: ['御…要']
# D1 x in sk, not in xsk: ['御会', '御…式', '御…法', '御', '会式', '会…法', '会…要', '会', '式法', '式…要', '式', '法要', '法', '要']
# D2 x in xsk, not in sk: ['御会…', '御…式…', '御…法…', '御…', '…会式…', '…会…法…', '…会…要', '…会…', '…式法…', '…式…要', '…式…', '…法要', '…法…', '…要']
#  -------------
# 3g
# norm: ['御', '会', '式', '法', '要', '御会', '会式', '式法', '法要', '御会式', '会式法', '式法要']
# sk: ['御会式', '御会…法', '御会…要', '御会', '御…式法', '御…式…要', '御…式', '御…法要', '御…法', '御…要', '御', '会式法', '会式…要', '会式', '会…法要', '会…法', '会…要', '会', '式法要', '式法', '式…要', '式', '法要', '法', '要']
# xsk: ['御会式…', '御会…法…', '御会…要', '御会…', '御…式法…', '御…式…要', '御…式…', '御…法要', '御…法…', '御…要', '御…', '…会式法…', '…会式…要', '…会式…', '…会…法要', '…会…法…', '…会…要', '…会…', '…式法要', '…式法…', '…式…要', '…式…', '…法要', '…法…', '…要']
# C1 x in norm, sk, and xsk: []
# C2 x in norm and sk, not in xsk: ['御', '会', '式', '法', '要', '御会', '会式', '式法', '法要', '御会式', '会式法', '式法要']
# C3 x in norm and xsk, not in sk: []
# C4 x in sk and xsk, not in norm: ['御会…要', '御…式…要', '御…法要', '御…要']
# D1 x in sk, not in xsk: ['御会式', '御会…法', '御会', '御…式法', '御…式', '御…法', '御', '会式法', '会式…要', '会式', '会…法要', '会…法', '会…要', '会', '式法要', '式法', '式…要', '式', '法要', '法', '要']
# D2 x in xsk, not in sk: ['御会式…', '御会…法…', '御会…', '御…式法…', '御…式…', '御…法…', '御…', '…会式法…', '…会式…要', '…会式…', '…会…法要', '…会…法…', '…会…要', '…会…', '…式法要', '…式法…', '…式…要', '…式…', '…法要', '…法…', '…要']
#  -------------
# 4g
# norm: ['御', '会', '式', '法', '要', '御会', '会式', '式法', '法要', '御会式', '会式法', '式法要', '御会式法', '会式法要']
# sk: ['御会式法', '御会式…要', '御会式', '御会…法要', '御会…法', '御会…要', '御会', '御…式法要', '御…式法', '御…式…要', '御…式', '御…法要', '御…法', '御…要', '御', '会式法要', '会式法', '会式…要', '会式', '会…法要', '会…法', '会…要', '会', '式法要', '式法', '式…要', '式', '法要', '法', '要']
# xsk: ['御会式法…', '御会式…要', '御会式…', '御会…法要', '御会…法…', '御会…要', '御会…', '御…式法要', '御…式法…', '御…式…要', '御…式…', '御…法要', '御…法…', '御…要', '御…', '…会式法要', '…会式法…', '…会式…要', '…会式…', '…会…法要', '…会…法…', '…会…要', '…会…', '…式法要', '…式法…', '…式…要', '…式…', '…法要', '…法…', '…要']
# C1 x in norm, sk, and xsk: []
# C2 x in norm and sk, not in xsk: ['御', '会', '式', '法', '要', '御会', '会式', '式法', '法要', '御会式', '会式法', '式法要', '御会式法', '会式法要']
# C3 x in norm and xsk, not in sk: []
# C4 x in sk and xsk, not in norm: ['御会式…要', '御会…法要', '御会…要', '御…式法要', '御…式…要', '御…法要', '御…要']
# D1 x in sk, not in xsk: ['御会式法', '御会式', '御会…法', '御会', '御…式法', '御…式', '御…法', '御', '会式法要', '会式法', '会式…要', '会式', '会…法要', '会…法', '会…要', '会', '式法要', '式法', '式…要', '式', '法要', '法', '要']
# D2 x in xsk, not in sk: ['御会式法…', '御会式…', '御会…法…', '御会…', '御…式法…', '御…式…', '御…法…', '御…', '…会式法要', '…会式法…', '…会式…要', '…会式…', '…会…法要', '…会…法…', '…会…要', '…会…', '…式法要', '…式法…', '…式…要', '…式…', '…法要', '…法…', '…要']
# --------------
# doc: 報恩講法要
#  -------------
# 1g
# norm: ['報', '恩', '講', '法', '要']
# sk: ['報', '恩', '講', '法', '要']
# xsk: ['報…', '…恩…', '…講…', '…法…', '…要']
# C1 x in norm, sk, and xsk: []
# C2 x in norm and sk, not in xsk: ['報', '恩', '講', '法', '要']
# C3 x in norm and xsk, not in sk: []
# C4 x in sk and xsk, not in norm: []
# D1 x in sk, not in xsk: ['報', '恩', '講', '法', '要']
# D2 x in xsk, not in sk: ['報…', '…恩…', '…講…', '…法…', '…要']
#  -------------
# 2g
# norm: ['報', '恩', '講', '法', '要', '報恩', '恩講', '講法', '法要']
# sk: ['報恩', '報…講', '報…法', '報…要', '報', '恩講', '恩…法', '恩…要', '恩', '講法', '講…要', '講', '法要', '法', '要']
# xsk: ['報恩…', '報…講…', '報…法…', '報…要', '報…', '…恩講…', '…恩…法…', '…恩…要', '…恩…', '…講法…', '…講…要', '…講…', '…法要', '…法…', '…要']
# C1 x in norm, sk, and xsk: []
# C2 x in norm and sk, not in xsk: ['報', '恩', '講', '法', '要', '報恩', '恩講', '講法', '法要']
# C3 x in norm and xsk, not in sk: []
# C4 x in sk and xsk, not in norm: ['報…要']
# D1 x in sk, not in xsk: ['報恩', '報…講', '報…法', '報', '恩講', '恩…法', '恩…要', '恩', '講法', '講…要', '講', '法要', '法', '要']
# D2 x in xsk, not in sk: ['報恩…', '報…講…', '報…法…', '報…', '…恩講…', '…恩…法…', '…恩…要', '…恩…', '…講法…', '…講…要', '…講…', '…法要', '…法…', '…要']
#  -------------
# 3g
# norm: ['報', '恩', '講', '法', '要', '報恩', '恩講', '講法', '法要', '報恩講', '恩講法', '講法要']
# sk: ['報恩講', '報恩…法', '報恩…要', '報恩', '報…講法', '報…講…要', '報…講', '報…法要', '報…法', '報…要', '報', '恩講法', '恩講…要', '恩講', '恩…法要', '恩…法', '恩…要', '恩', '講法要', '講法', '講…要', '講', '法要', '法', '要']
# xsk: ['報恩講…', '報恩…法…', '報恩…要', '報恩…', '報…講法…', '報…講…要', '報…講…', '報…法要', '報…法…', '報…要', '報…', '…恩講法…', '…恩講…要', '…恩講…', '…恩…法要', '…恩…法…', '…恩…要', '…恩…', '…講法要', '…講法…', '…講…要', '…講…', '…法要', '…法…', '…要']
# C1 x in norm, sk, and xsk: []
# C2 x in norm and sk, not in xsk: ['報', '恩', '講', '法', '要', '報恩', '恩講', '講法', '法要', '報恩講', '恩講法', '講法要']
# C3 x in norm and xsk, not in sk: []
# C4 x in sk and xsk, not in norm: ['報恩…要', '報…講…要', '報…法要', '報…要']
# D1 x in sk, not in xsk: ['報恩講', '報恩…法', '報恩', '報…講法', '報…講', '報…法', '報', '恩講法', '恩講…要', '恩講', '恩…法要', '恩…法', '恩…要', '恩', '講法要', '講法', '講…要', '講', '法要', '法', '要']
# D2 x in xsk, not in sk: ['報恩講…', '報恩…法…', '報恩…', '報…講法…', '報…講…', '報…法…', '報…', '…恩講法…', '…恩講…要', '…恩講…', '…恩…法要', '…恩…法…', '…恩…要', '…恩…', '…講法要', '…講法…', '…講…要', '…講…', '…法要', '…法…', '…要']
#  -------------
# 4g
# norm: ['報', '恩', '講', '法', '要', '報恩', '恩講', '講法', '法要', '報恩講', '恩講法', '講法要', '報恩講法', '恩講法要']
# sk: ['報恩講法', '報恩講…要', '報恩講', '報恩…法要', '報恩…法', '報恩…要', '報恩', '報…講法要', '報…講法', '報…講…要', '報…講', '報…法要', '報…法', '報…要', '報', '恩講法要', '恩講法', '恩講…要', '恩講', '恩…法要', '恩…法', '恩…要', '恩', '講法要', '講法', '講…要', '講', '法要', '法', '要']
# xsk: ['報恩講法…', '報恩講…要', '報恩講…', '報恩…法要', '報恩…法…', '報恩…要', '報恩…', '報…講法要', '報…講法…', '報…講…要', '報…講…', '報…法要', '報…法…', '報…要', '報…', '…恩講法要', '…恩講法…', '…恩講…要', '…恩講…', '…恩…法要', '…恩…法…', '…恩…要', '…恩…', '…講法要', '…講法…', '…講…要', '…講…', '…法要', '…法…', '…要']
# C1 x in norm, sk, and xsk: []
# C2 x in norm and sk, not in xsk: ['報', '恩', '講', '法', '要', '報恩', '恩講', '講法', '法要', '報恩講', '恩講法', '講法要', '報恩講法', '恩講法要']
# C3 x in norm and xsk, not in sk: []
# C4 x in sk and xsk, not in norm: ['報恩講…要', '報恩…法要', '報恩…要', '報…講法要', '報…講…要', '報…法要', '報…要']
# D1 x in sk, not in xsk: ['報恩講法', '報恩講', '報恩…法', '報恩', '報…講法', '報…講', '報…法', '報', '恩講法要', '恩講法', '恩講…要', '恩講', '恩…法要', '恩…法', '恩…要', '恩', '講法要', '講法', '講…要', '講', '法要', '法', '要']
# D2 x in xsk, not in sk: ['報恩講法…', '報恩講…', '報恩…法…', '報恩…', '報…講法…', '報…講…', '報…法…', '報…', '…恩講法要', '…恩講法…', '…恩講…要', '…恩講…', '…恩…法要', '…恩…法…', '…恩…要', '…恩…', '…講法要', '…講法…', '…講…要', '…講…', '…法要', '…法…', '…要']
# --------------
# doc: 追悼法要式
#  -------------
# 1g
# norm: ['追', '悼', '法', '要', '式']
# sk: ['追', '悼', '法', '要', '式']
# xsk: ['追…', '…悼…', '…法…', '…要…', '…式']
# C1 x in norm, sk, and xsk: []
# C2 x in norm and sk, not in xsk: ['追', '悼', '法', '要', '式']
# C3 x in norm and xsk, not in sk: []
# C4 x in sk and xsk, not in norm: []
# D1 x in sk, not in xsk: ['追', '悼', '法', '要', '式']
# D2 x in xsk, not in sk: ['追…', '…悼…', '…法…', '…要…', '…式']
#  -------------
# 2g
# norm: ['追', '悼', '法', '要', '式', '追悼', '悼法', '法要', '要式']
# sk: ['追悼', '追…法', '追…要', '追…式', '追', '悼法', '悼…要', '悼…式', '悼', '法要', '法…式', '法', '要式', '要', '式']
# xsk: ['追悼…', '追…法…', '追…要…', '追…式', '追…', '…悼法…', '…悼…要…', '…悼…式', '…悼…', '…法要…', '…法…式', '…法…', '…要式', '…要…', '…式']
# C1 x in norm, sk, and xsk: []
# C2 x in norm and sk, not in xsk: ['追', '悼', '法', '要', '式', '追悼', '悼法', '法要', '要式']
# C3 x in norm and xsk, not in sk: []
# C4 x in sk and xsk, not in norm: ['追…式']
# D1 x in sk, not in xsk: ['追悼', '追…法', '追…要', '追', '悼法', '悼…要', '悼…式', '悼', '法要', '法…式', '法', '要式', '要', '式']
# D2 x in xsk, not in sk: ['追悼…', '追…法…', '追…要…', '追…', '…悼法…', '…悼…要…', '…悼…式', '…悼…', '…法要…', '…法…式', '…法…', '…要式', '…要…', '…式']
#  -------------
# 3g
# norm: ['追', '悼', '法', '要', '式', '追悼', '悼法', '法要', '要式', '追悼法', '悼法要', '法要式']
# sk: ['追悼法', '追悼…要', '追悼…式', '追悼', '追…法要', '追…法…式', '追…法', '追…要式', '追…要', '追…式', '追', '悼法要', '悼法…式', '悼法', '悼…要式', '悼…要', '悼…式', '悼', '法要式', '法要', '法…式', '法', '要式', '要', '式']
# xsk: ['追悼法…', '追悼…要…', '追悼…式', '追悼…', '追…法要…', '追…法…式', '追…法…', '追…要式', '追…要…', '追…式', '追…', '…悼法要…', '…悼法…式', '…悼法…', '…悼…要式', '…悼…要…', '…悼…式', '…悼…', '…法要式', '…法要…', '…法…式', '…法…', '…要式', '…要…', '…式']
# C1 x in norm, sk, and xsk: []
# C2 x in norm and sk, not in xsk: ['追', '悼', '法', '要', '式', '追悼', '悼法', '法要', '要式', '追悼法', '悼法要', '法要式']
# C3 x in norm and xsk, not in sk: []
# C4 x in sk and xsk, not in norm: ['追悼…式', '追…法…式', '追…要式', '追…式']
# D1 x in sk, not in xsk: ['追悼法', '追悼…要', '追悼', '追…法要', '追…法', '追…要', '追', '悼法要', '悼法…式', '悼法', '悼…要式', '悼…要', '悼…式', '悼', '法要式', '法要', '法…式', '法', '要式', '要', '式']
# D2 x in xsk, not in sk: ['追悼法…', '追悼…要…', '追悼…', '追…法要…', '追…法…', '追…要…', '追…', '…悼法要…', '…悼法…式', '…悼法…', '…悼…要式', '…悼…要…', '…悼…式', '…悼…', '…法要式', '…法要…', '…法…式', '…法…', '…要式', '…要…', '…式']
#  -------------
# 4g
# norm: ['追', '悼', '法', '要', '式', '追悼', '悼法', '法要', '要式', '追悼法', '悼法要', '法要式', '追悼法要', '悼法要式']
# sk: ['追悼法要', '追悼法…式', '追悼法', '追悼…要式', '追悼…要', '追悼…式', '追悼', '追…法要式', '追…法要', '追…法…式', '追…法', '追…要式', '追…要', '追…式', '追', '悼法要式', '悼法要', '悼法…式', '悼法', '悼…要式', '悼…要', '悼…式', '悼', '法要式', '法要', '法…式', '法', '要式', '要', '式']
# xsk: ['追悼法要…', '追悼法…式', '追悼法…', '追悼…要式', '追悼…要…', '追悼…式', '追悼…', '追…法要式', '追…法要…', '追…法…式', '追…法…', '追…要式', '追…要…', '追…式', '追…', '…悼法要式', '…悼法要…', '…悼法…式', '…悼法…', '…悼…要式', '…悼…要…', '…悼…式', '…悼…', '…法要式', '…法要…', '…法…式', '…法…', '…要式', '…要…', '…式']
# C1 x in norm, sk, and xsk: []
# C2 x in norm and sk, not in xsk: ['追', '悼', '法', '要', '式', '追悼', '悼法', '法要', '要式', '追悼法', '悼法要', '法要式', '追悼法要', '悼法要式']
# C3 x in norm and xsk, not in sk: []
# C4 x in sk and xsk, not in norm: ['追悼法…式', '追悼…要式', '追悼…式', '追…法要式', '追…法…式', '追…要式', '追…式']
# D1 x in sk, not in xsk: ['追悼法要', '追悼法', '追悼…要', '追悼', '追…法要', '追…法', '追…要', '追', '悼法要式', '悼法要', '悼法…式', '悼法', '悼…要式', '悼…要', '悼…式', '悼', '法要式', '法要', '法…式', '法', '要式', '要', '式']
# D2 x in xsk, not in sk: ['追悼法要…', '追悼法…', '追悼…要…', '追悼…', '追…法要…', '追…法…', '追…要…', '追…', '…悼法要式', '…悼法要…', '…悼法…式', '…悼法…', '…悼…要式', '…悼…要…', '…悼…式', '…悼…', '…法要式', '…法要…', '…法…式', '…法…', '…要式', '…要…', '…式']

# %% [markdown]
# ## 結果の保存

# %%
if save_results:
    file_name = f"{save_dir}/gen2_{source_name}-reg-sk-xsk-df.csv"
    df.to_csv(file_name, header = True)

# %% [markdown]
# # end of file
