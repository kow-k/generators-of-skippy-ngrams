# %% [markdown]
# # Generator of (extended) (skippy) n-grams out of words or sentences
#
# developed by Kow Kuroda (kow.kuroda@gmail.com)
#
# This Jupyter notebook demonstrates how to use gen2_ngrams.py (or gen2_ngrams_cy.pyx) developed to enhance the usability of its predecessor "gen_ngrams.py".
#
# There are two main differences from its predecessor. First, gen_skippy_ngrams(..) generates extended skippy n-grams with "extended = True" option. Second, gen_skippy_ngrams(..) cann generate inclusive n-grams, thereby dispensing with incremental generation of n-grams from 1-grams.
#
# Limitations
# - Availablity of Cython-enhancement is limited. Apple Silicons like M1 and M2 (M3 is not tested yet) do not accept it, though it is available under Python 3.10 on M1.
#
# Creation
# - 2025/08/19
#
# Modifications
# - 2025/08/21 minor changes;
# - 2025/08/22 i) minor changes; Cython-enhancement was implemented;
# - 2025/08/28 fixed bugs in gen_skippy_ngrams in gen2_ngrams.py;
# - 2025/08/29 adapted to release 1; adapted to gen2_ngrams_cy.py;

# %% [markdown]
# # Set up Cython

# %%
#conda update -n base -c defaults conda -y

# %%
## Cython の導入 (必要に応じて)
#!conda uninstall cython -y # seems necessary in certain situations
#!conda install cython -y
## Try the following if the above fails
#!pip install cython --upgrade --force-reinstall
#!conda update -n base -c defaults conda -y

# %%
#!pip show cython

# %%
## Cython を使うかどうか
use_Cython = False

# %%
## Cython extension の(再)構築が必要な場合は True に
build_Cython_extension = False
if build_Cython_extension:
    # !python setup.py clean build_ext --inplace

# %%
## Cython 版の読込み: Cython-version will not run on Apple Silicons like M1, M2
if use_Cython:
    try:
        # %reload_ext Cython
    except ImportError:
        # %load_ext Cython
    import gen2_ngrams_cy as gen_ngrams
else:
    import gen2_ngrams as gen_ngrams

# %% [markdown]
# # Set up data

# %%
analyze_words = True # if False, analyze sentential/phrasal objects

## parameters for analysis
if analyze_words:
    segmenter: str = r""
    sep_local: str = ""
else:
    segmenter: str = r" "
    sep_local: str = " "

# %%
import pathlib
if analyze_words:
    data_dir = 'data/words'
    files = list(pathlib.Path(data_dir).glob('buddhist-listed2.txt'))
else:
    data_dir = 'data/phrases'
    files = list(pathlib.Path(data_dir).glob('austen-j-sample100.txt'))
##
print(files)

##
file = files[0]
source_name = file.stem
print(f"source_name: {source_name}")
# Out:
# [PosixPath('data/words/buddhist-listed2.txt')]
# source_name: buddhist-listed2

# %%
## get data
docs = file.read_text(encoding = 'utf-8').splitlines()

## lowercase
docs = [ doc.lower() for doc in docs if len(doc) > 0 ]
print(docs[:10])
# Out:
# ['阿羅漢', '辟支仏', '転法輪', '十二因縁', '五蘊盛苦', '三法印', '四念処', '四神足', '五根五力', '七覚支']

# %% [markdown]
# # Generation of (extended) (skippy) n-grams

# %%
## flags
check: bool = False

## saving results
save_results: bool = False
save_dir: str = "saves"

# %%
## n の最大値
max_n_for_ngram: int = 4

## max_gap_size
max_gap_size = 3

## n-gram
ngram_is_inclusive = True
#skippy_means_extended = True

## n-gram を文字列として生成するか否か
generated_as_string: bool = True
generated_as_list: bool = not(generated_as_string)

# %%
## 入力の要素数が n_for_ngram 以下の時に再帰的に (n-1)gram を生成するか
recursively = True

# %%
#!conda install pandas -y

# %%
import pandas as pd
columns0 = ['doc']
columns1 = [ f"{i}g" for i in range(1, max_n_for_ngram + 1)]
columns2 = [ f"sk{i}g" for i in range(1, max_n_for_ngram + 1)]
columns3 = [ f"xsk{i}g" for i in range(1, max_n_for_ngram + 1)]

used_columns = columns0 + columns1 + columns2 + columns3
df = pd.DataFrame(columns = used_columns)

# %% [markdown]
# ## Normal

# %%
## generate non-skippy n-grams
import re
for i, doc in enumerate(docs):
    ## update df for word
    df.loc[i,'doc'] = doc
    ##
    print(f"Processing word {i} [use_Cython: {use_Cython}]: {doc}")
    word_segs = [ x for x in re.split(segmenter, doc) if len(x) > 0 ]
    for j in range(1, max_n_for_ngram + 1):
        print(f"generating {j}-grams ...")
        ngrams = gen_ngrams.gen_ngrams(word_segs, j, inclusive = ngram_is_inclusive, sep = sep_local, as_list = generated_as_list, check = False)
        if check:
            print(ngrams)
        ## update df
        df.loc[i, f'{j}g'] = ngrams
# Out:
# Processing word 0 [use_Cython: False]: 阿羅漢
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 1 [use_Cython: False]: 辟支仏
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 2 [use_Cython: False]: 転法輪
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 3 [use_Cython: False]: 十二因縁
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 4 [use_Cython: False]: 五蘊盛苦
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 5 [use_Cython: False]: 三法印
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 6 [use_Cython: False]: 四念処
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 7 [use_Cython: False]: 四神足
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 8 [use_Cython: False]: 五根五力
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 9 [use_Cython: False]: 七覚支
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 10 [use_Cython: False]: 三十七道品
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 11 [use_Cython: False]: 十善戒
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 12 [use_Cython: False]: 六神通
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 13 [use_Cython: False]: 四無量心
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 14 [use_Cython: False]: 慈悲喜捨
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 15 [use_Cython: False]: 八風不動
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 16 [use_Cython: False]: 不退転
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 17 [use_Cython: False]: 阿耨多羅三藐三菩提
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 18 [use_Cython: False]: 一切智
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 19 [use_Cython: False]: 無生法忍
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 20 [use_Cython: False]: 止観双修
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 21 [use_Cython: False]: 四禅定
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 22 [use_Cython: False]: 九次第定
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 23 [use_Cython: False]: 滅尽定
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 24 [use_Cython: False]: 無想定
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 25 [use_Cython: False]: 観呼吸
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 26 [use_Cython: False]: 観身不浄
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 27 [use_Cython: False]: 数息観
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 28 [use_Cython: False]: 白骨観
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 29 [use_Cython: False]: 不浄観
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 30 [use_Cython: False]: 慈心観
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 31 [use_Cython: False]: 因縁観
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 32 [use_Cython: False]: 念死観
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 33 [use_Cython: False]: 随念三宝
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 34 [use_Cython: False]: 経行禅
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 35 [use_Cython: False]: 立禅法
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 36 [use_Cython: False]: 食禅法
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 37 [use_Cython: False]: 作務禅
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 38 [use_Cython: False]: 公案禅
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 39 [use_Cython: False]: 只管打坐
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 40 [use_Cython: False]: 阿含経
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 41 [use_Cython: False]: 大般涅槃経
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 42 [use_Cython: False]: 大日経
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 43 [use_Cython: False]: 金剛頂経
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 44 [use_Cython: False]: 理趣経
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 45 [use_Cython: False]: 観音経
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 46 [use_Cython: False]: 地蔵経
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 47 [use_Cython: False]: 薬師経
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 48 [use_Cython: False]: 無量寿経
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 49 [use_Cython: False]: 観無量寿経
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 50 [use_Cython: False]: 倶舎論
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 51 [use_Cython: False]: 成実論
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 52 [use_Cython: False]: 大智度論
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 53 [use_Cython: False]: 中論頌
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 54 [use_Cython: False]: 唯識論
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 55 [use_Cython: False]: 起信論
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 56 [use_Cython: False]: 摩訶止観
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 57 [use_Cython: False]: 法界次第
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 58 [use_Cython: False]: 禅源諸詮集
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 59 [use_Cython: False]: 景徳伝灯録
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 60 [use_Cython: False]: 小乗仏教
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 61 [use_Cython: False]: 大乗仏教
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 62 [use_Cython: False]: 金剛乗
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 63 [use_Cython: False]: 秘密仏教
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 64 [use_Cython: False]: 南都六宗
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 65 [use_Cython: False]: 三論宗
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 66 [use_Cython: False]: 成実宗
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 67 [use_Cython: False]: 俱舎宗
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 68 [use_Cython: False]: 法相宗
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 69 [use_Cython: False]: 律宗派
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 70 [use_Cython: False]: 時宗派
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 71 [use_Cython: False]: 融通念仏宗
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 72 [use_Cython: False]: 一遍上人
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 73 [use_Cython: False]: 親鸞聖人
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 74 [use_Cython: False]: 法然上人
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 75 [use_Cython: False]: 道元禅師
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 76 [use_Cython: False]: 栄西禅師
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 77 [use_Cython: False]: 空海大師
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 78 [use_Cython: False]: 最澄大師
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 79 [use_Cython: False]: 鑑真和上
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 80 [use_Cython: False]: 開眼供養
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 81 [use_Cython: False]: 入仏供養
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 82 [use_Cython: False]: 落慶法要
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 83 [use_Cython: False]: 授戒会
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 84 [use_Cython: False]: 結縁灌頂
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 85 [use_Cython: False]: 伝法灌頂
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 86 [use_Cython: False]: 護摩供養
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 87 [use_Cython: False]: 千体仏供養
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 88 [use_Cython: False]: 水子供養
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 89 [use_Cython: False]: 先祖供養
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 90 [use_Cython: False]: 施餓鬼会
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 91 [use_Cython: False]: 大施食会
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 92 [use_Cython: False]: 盆踊り
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 93 [use_Cython: False]: 精霊流し
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 94 [use_Cython: False]: 迎え火
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 95 [use_Cython: False]: 送り火
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 96 [use_Cython: False]: 棚経参り
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 97 [use_Cython: False]: お数珠
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 98 [use_Cython: False]: 線香供養
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 99 [use_Cython: False]: 献花供養
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 100 [use_Cython: False]: 五重塔
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 101 [use_Cython: False]: 三重塔
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 102 [use_Cython: False]: 多宝塔
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 103 [use_Cython: False]: 仏舎利塔
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 104 [use_Cython: False]: 観音堂
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 105 [use_Cython: False]: 薬師堂
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 106 [use_Cython: False]: 阿弥陀堂
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 107 [use_Cython: False]: 大雄宝殿
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 108 [use_Cython: False]: 法堂建築
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 109 [use_Cython: False]: 禅堂建築
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 110 [use_Cython: False]: 客殿建築
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 111 [use_Cython: False]: 庫裏建築
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 112 [use_Cython: False]: 山門建築
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 113 [use_Cython: False]: 鐘楼建築
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 114 [use_Cython: False]: 経蔵建築
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 115 [use_Cython: False]: 宝蔵建築
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 116 [use_Cython: False]: 石庭造園
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 117 [use_Cython: False]: 枯山水
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 118 [use_Cython: False]: 借景技法
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 119 [use_Cython: False]: 禅庭設計
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 120 [use_Cython: False]: 千手観音
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 121 [use_Cython: False]: 十一面観音
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 122 [use_Cython: False]: 馬頭観音
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 123 [use_Cython: False]: 如意輪観音
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 124 [use_Cython: False]: 准胝観音
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 125 [use_Cython: False]: 不空羂索観音
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 126 [use_Cython: False]: 聖観音菩薩
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 127 [use_Cython: False]: 勢至菩薩
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 128 [use_Cython: False]: 文殊菩薩
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 129 [use_Cython: False]: 普賢菩薩
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 130 [use_Cython: False]: 弥勒菩薩
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 131 [use_Cython: False]: 薬王菩薩
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 132 [use_Cython: False]: 薬上菩薩
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 133 [use_Cython: False]: 虚空蔵菩薩
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 134 [use_Cython: False]: 大勢至菩薩
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 135 [use_Cython: False]: 金剛界曼荼羅
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 136 [use_Cython: False]: 胎蔵界曼荼羅
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 137 [use_Cython: False]: 両部曼荼羅
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 138 [use_Cython: False]: 八葉蓮華
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 139 [use_Cython: False]: 宝相華文様
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 140 [use_Cython: False]: 出家得度
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 141 [use_Cython: False]: 在家信者
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 142 [use_Cython: False]: 優婆塞
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 143 [use_Cython: False]: 優婆夷
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 144 [use_Cython: False]: 沙弥僧
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 145 [use_Cython: False]: 沙弥尼
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 146 [use_Cython: False]: 比丘僧
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 147 [use_Cython: False]: 比丘尼
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 148 [use_Cython: False]: 阿闍梨
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 149 [use_Cython: False]: 三蔵法師
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 150 [use_Cython: False]: 律師職位
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 151 [use_Cython: False]: 禅師職位
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 152 [use_Cython: False]: 大僧正
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 153 [use_Cython: False]: 僧正職位
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 154 [use_Cython: False]: 権僧正
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 155 [use_Cython: False]: 少僧都
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 156 [use_Cython: False]: 権少僧都
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 157 [use_Cython: False]: 法印大和尚
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 158 [use_Cython: False]: 伝燈大阿闍梨
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 159 [use_Cython: False]: 権大僧都
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 160 [use_Cython: False]: 三論教学
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 161 [use_Cython: False]: 法相教学
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 162 [use_Cython: False]: 華厳教学
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 163 [use_Cython: False]: 天台教学
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 164 [use_Cython: False]: 真言教学
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 165 [use_Cython: False]: 浄土教学
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 166 [use_Cython: False]: 禅宗教学
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 167 [use_Cython: False]: 日蓮教学
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 168 [use_Cython: False]: 唯識思想
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 169 [use_Cython: False]: 如来蔵思想
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 170 [use_Cython: False]: 本覚思想
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 171 [use_Cython: False]: 末法思想
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 172 [use_Cython: False]: 易行道
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 173 [use_Cython: False]: 難行道
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 174 [use_Cython: False]: 聖道門
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 175 [use_Cython: False]: 浄土門
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 176 [use_Cython: False]: 権教方便
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 177 [use_Cython: False]: 実教真実
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 178 [use_Cython: False]: 五時八教
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 179 [use_Cython: False]: 化法四教
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 180 [use_Cython: False]: 降誕会法要
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 181 [use_Cython: False]: 成道会法要
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 182 [use_Cython: False]: 涅槃会法要
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 183 [use_Cython: False]: 春彼岸法要
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 184 [use_Cython: False]: 秋彼岸法要
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 185 [use_Cython: False]: 盂蘭盆会
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 186 [use_Cython: False]: 十夜法要
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 187 [use_Cython: False]: 修正会法要
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 188 [use_Cython: False]: 節分会法要
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 189 [use_Cython: False]: 灌仏会法要
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 190 [use_Cython: False]: 花祭り行事
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 191 [use_Cython: False]: 除夜の鐘
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 192 [use_Cython: False]: 初詣参拝
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 193 [use_Cython: False]: 初護摩法要
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 194 [use_Cython: False]: 開山忌法要
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 195 [use_Cython: False]: 両祖忌法要
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 196 [use_Cython: False]: 宗祖忌法要
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 197 [use_Cython: False]: 御会式法要
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 198 [use_Cython: False]: 報恩講法要
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# Processing word 199 [use_Cython: False]: 追悼法要式
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...

# %%
df[columns0 + columns1]
# Out:
#        doc               1g                               2g  \
# 0      阿羅漢        [阿, 羅, 漢]                [阿, 羅, 漢, 阿羅, 羅漢]
# 1      辟支仏        [辟, 支, 仏]                [辟, 支, 仏, 辟支, 支仏]
# 2      転法輪        [転, 法, 輪]                [転, 法, 輪, 転法, 法輪]
# 3     十二因縁     [十, 二, 因, 縁]         [十, 二, 因, 縁, 十二, 二因, 因縁]
# 4     五蘊盛苦     [五, 蘊, 盛, 苦]         [五, 蘊, 盛, 苦, 五蘊, 蘊盛, 盛苦]
# ..     ...              ...                              ...
# 195  両祖忌法要  [両, 祖, 忌, 法, 要]  [両, 祖, 忌, 法, 要, 両祖, 祖忌, 忌法, 法要]
# 196  宗祖忌法要  [宗, 祖, 忌, 法, 要]  [宗, 祖, 忌, 法, 要, 宗祖, 祖忌, 忌法, 法要]
# 197  御会式法要  [御, 会, 式, 法, 要]  [御, 会, 式, 法, 要, 御会, 会式, 式法, 法要]
# 198  報恩講法要  [報, 恩, 講, 法, 要]  [報, 恩, 講, 法, 要, 報恩, 恩講, 講法, 法要]
# 199  追悼法要式  [追, 悼, 法, 要, 式]  [追, 悼, 法, 要, 式, 追悼, 悼法, 法要, 要式]
#
#                                                  3g  \
# 0                            [阿, 羅, 漢, 阿羅, 羅漢, 阿羅漢]
# 1                            [辟, 支, 仏, 辟支, 支仏, 辟支仏]
# 2                            [転, 法, 輪, 転法, 法輪, 転法輪]
# 3                [十, 二, 因, 縁, 十二, 二因, 因縁, 十二因, 二因縁]
# 4                [五, 蘊, 盛, 苦, 五蘊, 蘊盛, 盛苦, 五蘊盛, 蘊盛苦]
# ..                                              ...
# 195  [両, 祖, 忌, 法, 要, 両祖, 祖忌, 忌法, 法要, 両祖忌, 祖忌法, 忌法要]
# 196  [宗, 祖, 忌, 法, 要, 宗祖, 祖忌, 忌法, 法要, 宗祖忌, 祖忌法, 忌法要]
# 197  [御, 会, 式, 法, 要, 御会, 会式, 式法, 法要, 御会式, 会式法, 式法要]
# 198  [報, 恩, 講, 法, 要, 報恩, 恩講, 講法, 法要, 報恩講, 恩講法, 講法要]
# 199  [追, 悼, 法, 要, 式, 追悼, 悼法, 法要, 要式, 追悼法, 悼法要, 法要式]
#
#                                                     4g
# 0                                                [阿羅漢]
# 1                                                [辟支仏]
# 2                                                [転法輪]
# 3             [十, 二, 因, 縁, 十二, 二因, 因縁, 十二因, 二因縁, 十二因縁]
# 4             [五, 蘊, 盛, 苦, 五蘊, 蘊盛, 盛苦, 五蘊盛, 蘊盛苦, 五蘊盛苦]
# ..                                                 ...
# 195  [両, 祖, 忌, 法, 要, 両祖, 祖忌, 忌法, 法要, 両祖忌, 祖忌法, 忌法要,...
# 196  [宗, 祖, 忌, 法, 要, 宗祖, 祖忌, 忌法, 法要, 宗祖忌, 祖忌法, 忌法要,...
# 197  [御, 会, 式, 法, 要, 御会, 会式, 式法, 法要, 御会式, 会式法, 式法要,...
# 198  [報, 恩, 講, 法, 要, 報恩, 恩講, 講法, 法要, 報恩講, 恩講法, 講法要,...
# 199  [追, 悼, 法, 要, 式, 追悼, 悼法, 法要, 要式, 追悼法, 悼法要, 法要式,...
#
# [200 rows x 5 columns]

# %% [markdown]
# ## Skippy

# %%
## generate regular skippy n-grams
import re
for i, doc in enumerate(docs):
    print(f"Processing word {i} [use_Cython: {use_Cython}]: {doc}")
    word_segs = [ seg for seg in re.split(segmenter, doc) if len(seg) > 0 ]
    for j in range(1, max_n_for_ngram + 1):
        print(f"generating skippy {j}-grams ...")
        ngrams = gen_ngrams.gen_skippy_ngrams(word_segs, j, extended = False, inclusive = ngram_is_inclusive, recursively = recursively, max_gap_size = max_gap_size, sep = sep_local, as_list = generated_as_list, check = False)
        if check:
            print(ngrams)
        ## update df
        df.loc[i, f'sk{j}g'] = ngrams
# Out:
# Processing word 0 [use_Cython: False]: 阿羅漢
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 1 [use_Cython: False]: 辟支仏
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 2 [use_Cython: False]: 転法輪
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 3 [use_Cython: False]: 十二因縁
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 4 [use_Cython: False]: 五蘊盛苦
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 5 [use_Cython: False]: 三法印
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 6 [use_Cython: False]: 四念処
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 7 [use_Cython: False]: 四神足
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 8 [use_Cython: False]: 五根五力
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 9 [use_Cython: False]: 七覚支
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 10 [use_Cython: False]: 三十七道品
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 11 [use_Cython: False]: 十善戒
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 12 [use_Cython: False]: 六神通
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 13 [use_Cython: False]: 四無量心
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 14 [use_Cython: False]: 慈悲喜捨
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 15 [use_Cython: False]: 八風不動
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 16 [use_Cython: False]: 不退転
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 17 [use_Cython: False]: 阿耨多羅三藐三菩提
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 18 [use_Cython: False]: 一切智
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 19 [use_Cython: False]: 無生法忍
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 20 [use_Cython: False]: 止観双修
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 21 [use_Cython: False]: 四禅定
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 22 [use_Cython: False]: 九次第定
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 23 [use_Cython: False]: 滅尽定
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 24 [use_Cython: False]: 無想定
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 25 [use_Cython: False]: 観呼吸
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 26 [use_Cython: False]: 観身不浄
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 27 [use_Cython: False]: 数息観
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 28 [use_Cython: False]: 白骨観
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 29 [use_Cython: False]: 不浄観
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 30 [use_Cython: False]: 慈心観
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 31 [use_Cython: False]: 因縁観
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 32 [use_Cython: False]: 念死観
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 33 [use_Cython: False]: 随念三宝
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 34 [use_Cython: False]: 経行禅
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 35 [use_Cython: False]: 立禅法
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 36 [use_Cython: False]: 食禅法
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 37 [use_Cython: False]: 作務禅
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 38 [use_Cython: False]: 公案禅
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 39 [use_Cython: False]: 只管打坐
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 40 [use_Cython: False]: 阿含経
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 41 [use_Cython: False]: 大般涅槃経
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 42 [use_Cython: False]: 大日経
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 43 [use_Cython: False]: 金剛頂経
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 44 [use_Cython: False]: 理趣経
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 45 [use_Cython: False]: 観音経
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 46 [use_Cython: False]: 地蔵経
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 47 [use_Cython: False]: 薬師経
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 48 [use_Cython: False]: 無量寿経
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 49 [use_Cython: False]: 観無量寿経
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 50 [use_Cython: False]: 倶舎論
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 51 [use_Cython: False]: 成実論
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 52 [use_Cython: False]: 大智度論
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 53 [use_Cython: False]: 中論頌
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 54 [use_Cython: False]: 唯識論
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 55 [use_Cython: False]: 起信論
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 56 [use_Cython: False]: 摩訶止観
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 57 [use_Cython: False]: 法界次第
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 58 [use_Cython: False]: 禅源諸詮集
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 59 [use_Cython: False]: 景徳伝灯録
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 60 [use_Cython: False]: 小乗仏教
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 61 [use_Cython: False]: 大乗仏教
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 62 [use_Cython: False]: 金剛乗
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 63 [use_Cython: False]: 秘密仏教
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 64 [use_Cython: False]: 南都六宗
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 65 [use_Cython: False]: 三論宗
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 66 [use_Cython: False]: 成実宗
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 67 [use_Cython: False]: 俱舎宗
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 68 [use_Cython: False]: 法相宗
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 69 [use_Cython: False]: 律宗派
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 70 [use_Cython: False]: 時宗派
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 71 [use_Cython: False]: 融通念仏宗
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 72 [use_Cython: False]: 一遍上人
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 73 [use_Cython: False]: 親鸞聖人
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 74 [use_Cython: False]: 法然上人
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 75 [use_Cython: False]: 道元禅師
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 76 [use_Cython: False]: 栄西禅師
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 77 [use_Cython: False]: 空海大師
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 78 [use_Cython: False]: 最澄大師
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 79 [use_Cython: False]: 鑑真和上
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 80 [use_Cython: False]: 開眼供養
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 81 [use_Cython: False]: 入仏供養
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 82 [use_Cython: False]: 落慶法要
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 83 [use_Cython: False]: 授戒会
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 84 [use_Cython: False]: 結縁灌頂
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 85 [use_Cython: False]: 伝法灌頂
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 86 [use_Cython: False]: 護摩供養
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 87 [use_Cython: False]: 千体仏供養
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 88 [use_Cython: False]: 水子供養
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 89 [use_Cython: False]: 先祖供養
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 90 [use_Cython: False]: 施餓鬼会
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 91 [use_Cython: False]: 大施食会
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 92 [use_Cython: False]: 盆踊り
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 93 [use_Cython: False]: 精霊流し
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 94 [use_Cython: False]: 迎え火
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 95 [use_Cython: False]: 送り火
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 96 [use_Cython: False]: 棚経参り
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 97 [use_Cython: False]: お数珠
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 98 [use_Cython: False]: 線香供養
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 99 [use_Cython: False]: 献花供養
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 100 [use_Cython: False]: 五重塔
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 101 [use_Cython: False]: 三重塔
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 102 [use_Cython: False]: 多宝塔
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 103 [use_Cython: False]: 仏舎利塔
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 104 [use_Cython: False]: 観音堂
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 105 [use_Cython: False]: 薬師堂
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 106 [use_Cython: False]: 阿弥陀堂
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 107 [use_Cython: False]: 大雄宝殿
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 108 [use_Cython: False]: 法堂建築
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 109 [use_Cython: False]: 禅堂建築
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 110 [use_Cython: False]: 客殿建築
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 111 [use_Cython: False]: 庫裏建築
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 112 [use_Cython: False]: 山門建築
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 113 [use_Cython: False]: 鐘楼建築
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 114 [use_Cython: False]: 経蔵建築
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 115 [use_Cython: False]: 宝蔵建築
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 116 [use_Cython: False]: 石庭造園
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 117 [use_Cython: False]: 枯山水
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 118 [use_Cython: False]: 借景技法
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 119 [use_Cython: False]: 禅庭設計
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 120 [use_Cython: False]: 千手観音
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 121 [use_Cython: False]: 十一面観音
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 122 [use_Cython: False]: 馬頭観音
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 123 [use_Cython: False]: 如意輪観音
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 124 [use_Cython: False]: 准胝観音
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 125 [use_Cython: False]: 不空羂索観音
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 126 [use_Cython: False]: 聖観音菩薩
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 127 [use_Cython: False]: 勢至菩薩
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 128 [use_Cython: False]: 文殊菩薩
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 129 [use_Cython: False]: 普賢菩薩
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 130 [use_Cython: False]: 弥勒菩薩
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 131 [use_Cython: False]: 薬王菩薩
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 132 [use_Cython: False]: 薬上菩薩
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 133 [use_Cython: False]: 虚空蔵菩薩
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 134 [use_Cython: False]: 大勢至菩薩
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 135 [use_Cython: False]: 金剛界曼荼羅
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 136 [use_Cython: False]: 胎蔵界曼荼羅
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 137 [use_Cython: False]: 両部曼荼羅
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 138 [use_Cython: False]: 八葉蓮華
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 139 [use_Cython: False]: 宝相華文様
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 140 [use_Cython: False]: 出家得度
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 141 [use_Cython: False]: 在家信者
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 142 [use_Cython: False]: 優婆塞
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 143 [use_Cython: False]: 優婆夷
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 144 [use_Cython: False]: 沙弥僧
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 145 [use_Cython: False]: 沙弥尼
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 146 [use_Cython: False]: 比丘僧
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 147 [use_Cython: False]: 比丘尼
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 148 [use_Cython: False]: 阿闍梨
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 149 [use_Cython: False]: 三蔵法師
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 150 [use_Cython: False]: 律師職位
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 151 [use_Cython: False]: 禅師職位
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 152 [use_Cython: False]: 大僧正
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 153 [use_Cython: False]: 僧正職位
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 154 [use_Cython: False]: 権僧正
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 155 [use_Cython: False]: 少僧都
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 156 [use_Cython: False]: 権少僧都
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 157 [use_Cython: False]: 法印大和尚
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 158 [use_Cython: False]: 伝燈大阿闍梨
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 159 [use_Cython: False]: 権大僧都
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 160 [use_Cython: False]: 三論教学
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 161 [use_Cython: False]: 法相教学
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 162 [use_Cython: False]: 華厳教学
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 163 [use_Cython: False]: 天台教学
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 164 [use_Cython: False]: 真言教学
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 165 [use_Cython: False]: 浄土教学
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 166 [use_Cython: False]: 禅宗教学
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 167 [use_Cython: False]: 日蓮教学
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 168 [use_Cython: False]: 唯識思想
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 169 [use_Cython: False]: 如来蔵思想
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 170 [use_Cython: False]: 本覚思想
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 171 [use_Cython: False]: 末法思想
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 172 [use_Cython: False]: 易行道
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 173 [use_Cython: False]: 難行道
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 174 [use_Cython: False]: 聖道門
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 175 [use_Cython: False]: 浄土門
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 176 [use_Cython: False]: 権教方便
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 177 [use_Cython: False]: 実教真実
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 178 [use_Cython: False]: 五時八教
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 179 [use_Cython: False]: 化法四教
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 180 [use_Cython: False]: 降誕会法要
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 181 [use_Cython: False]: 成道会法要
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 182 [use_Cython: False]: 涅槃会法要
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 183 [use_Cython: False]: 春彼岸法要
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 184 [use_Cython: False]: 秋彼岸法要
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 185 [use_Cython: False]: 盂蘭盆会
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 186 [use_Cython: False]: 十夜法要
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 187 [use_Cython: False]: 修正会法要
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 188 [use_Cython: False]: 節分会法要
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 189 [use_Cython: False]: 灌仏会法要
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 190 [use_Cython: False]: 花祭り行事
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 191 [use_Cython: False]: 除夜の鐘
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 192 [use_Cython: False]: 初詣参拝
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 193 [use_Cython: False]: 初護摩法要
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 194 [use_Cython: False]: 開山忌法要
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 195 [use_Cython: False]: 両祖忌法要
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 196 [use_Cython: False]: 宗祖忌法要
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 197 [use_Cython: False]: 御会式法要
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 198 [use_Cython: False]: 報恩講法要
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# Processing word 199 [use_Cython: False]: 追悼法要式
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...

# %%
df[columns0 + columns2]
# Out:
#        doc             sk1g  \
# 0      阿羅漢        [阿, 羅, 漢]
# 1      辟支仏        [辟, 支, 仏]
# 2      転法輪        [転, 法, 輪]
# 3     十二因縁     [十, 二, 因, 縁]
# 4     五蘊盛苦     [五, 蘊, 盛, 苦]
# ..     ...              ...
# 195  両祖忌法要  [両, 祖, 忌, 法, 要]
# 196  宗祖忌法要  [宗, 祖, 忌, 法, 要]
# 197  御会式法要  [御, 会, 式, 法, 要]
# 198  報恩講法要  [報, 恩, 講, 法, 要]
# 199  追悼法要式  [追, 悼, 法, 要, 式]
#
#                                                   sk2g  \
# 0                               [阿, 羅, 漢, 阿羅, 羅漢, 阿…漢]
# 1                               [辟, 支, 仏, 辟支, 支仏, 辟…仏]
# 2                               [転, 法, 輪, 転法, 法輪, 転…輪]
# 3              [十, 二, 因, 縁, 十二, 二因, 因縁, 十…因, 二…縁, 十…縁]
# 4              [五, 蘊, 盛, 苦, 五蘊, 蘊盛, 盛苦, 五…盛, 蘊…苦, 五…苦]
# ..                                                 ...
# 195  [両, 祖, 忌, 法, 要, 両祖, 祖忌, 忌法, 法要, 両…忌, 祖…法, 忌…要,...
# 196  [宗, 祖, 忌, 法, 要, 宗祖, 祖忌, 忌法, 法要, 宗…忌, 祖…法, 忌…要,...
# 197  [御, 会, 式, 法, 要, 御会, 会式, 式法, 法要, 御…式, 会…法, 式…要,...
# 198  [報, 恩, 講, 法, 要, 報恩, 恩講, 講法, 法要, 報…講, 恩…法, 講…要,...
# 199  [追, 悼, 法, 要, 式, 追悼, 悼法, 法要, 要式, 追…法, 悼…要, 法…式,...
#
#                                                   sk3g  \
# 0                          [阿, 羅, 漢, 阿羅, 羅漢, 阿羅漢, 阿…漢]
# 1                          [辟, 支, 仏, 辟支, 支仏, 辟支仏, 辟…仏]
# 2                          [転, 法, 輪, 転法, 法輪, 転法輪, 転…輪]
# 3    [十, 二, 因, 縁, 十二, 二因, 因縁, 十二因, 十…因, 二因縁, 二…縁, 十...
# 4    [五, 蘊, 盛, 苦, 五蘊, 蘊盛, 盛苦, 五蘊盛, 五…盛, 蘊盛苦, 蘊…苦, 五...
# ..                                                 ...
# 195  [両, 祖, 忌, 法, 要, 両祖, 祖忌, 忌法, 法要, 両祖忌, 両…忌, 祖忌法,...
# 196  [宗, 祖, 忌, 法, 要, 宗祖, 祖忌, 忌法, 法要, 宗祖忌, 宗…忌, 祖忌法,...
# 197  [御, 会, 式, 法, 要, 御会, 会式, 式法, 法要, 御会式, 御…式, 会式法,...
# 198  [報, 恩, 講, 法, 要, 報恩, 恩講, 講法, 法要, 報恩講, 報…講, 恩講法,...
# 199  [追, 悼, 法, 要, 式, 追悼, 悼法, 法要, 要式, 追悼法, 追…法, 悼法要,...
#
#                                                   sk4g
# 0                          [阿, 羅, 漢, 阿羅, 羅漢, 阿羅漢, 阿…漢]
# 1                          [辟, 支, 仏, 辟支, 支仏, 辟支仏, 辟…仏]
# 2                          [転, 法, 輪, 転法, 法輪, 転法輪, 転…輪]
# 3    [十, 二, 因, 縁, 十二, 二因, 因縁, 十二因, 十…因, 二因縁, 二…縁, 十...
# 4    [五, 蘊, 盛, 苦, 五蘊, 蘊盛, 盛苦, 五蘊盛, 五…盛, 蘊盛苦, 蘊…苦, 五...
# ..                                                 ...
# 195  [両, 祖, 忌, 法, 要, 両祖, 祖忌, 忌法, 法要, 両祖忌, 両…忌, 祖忌法,...
# 196  [宗, 祖, 忌, 法, 要, 宗祖, 祖忌, 忌法, 法要, 宗祖忌, 宗…忌, 祖忌法,...
# 197  [御, 会, 式, 法, 要, 御会, 会式, 式法, 法要, 御会式, 御…式, 会式法,...
# 198  [報, 恩, 講, 法, 要, 報恩, 恩講, 講法, 法要, 報恩講, 報…講, 恩講法,...
# 199  [追, 悼, 法, 要, 式, 追悼, 悼法, 法要, 要式, 追悼法, 追…法, 悼法要,...
#
# [200 rows x 5 columns]

# %% [markdown]
# ## Extended skippy

# %%
## generate extended skippy n-grams
import re, unicodedata
for i, doc in enumerate(docs):
    ## update df for word
    df.loc[i,'doc'] = doc
    
    print(f"Processing word {i} [use_Cython: {use_Cython}]: {doc}")
    ## Unicode normalization is necessay to proper handling of accents in languages like Irish and Welsh
    word_segs = [ seg for seg in re.split(segmenter, unicodedata.normalize('NFC', doc)) if len(seg) > 0 ]
    for j in range(1, max_n_for_ngram + 1):
        print(f"generating extended skippy {j}-grams ...")
        ngrams = gen_ngrams.gen_skippy_ngrams(word_segs, j, extended = True, inclusive = ngram_is_inclusive, recursively = recursively, max_gap_size = max_gap_size, sep = sep_local, as_list = generated_as_list, check = False)
        if check:
            print(ngrams)
        ## update df
        df.loc[i, f'xsk{j}g'] = ngrams
# Out:
# Processing word 0 [use_Cython: False]: 阿羅漢
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 1 [use_Cython: False]: 辟支仏
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 2 [use_Cython: False]: 転法輪
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 3 [use_Cython: False]: 十二因縁
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 4 [use_Cython: False]: 五蘊盛苦
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 5 [use_Cython: False]: 三法印
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 6 [use_Cython: False]: 四念処
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 7 [use_Cython: False]: 四神足
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 8 [use_Cython: False]: 五根五力
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 9 [use_Cython: False]: 七覚支
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 10 [use_Cython: False]: 三十七道品
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 11 [use_Cython: False]: 十善戒
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 12 [use_Cython: False]: 六神通
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 13 [use_Cython: False]: 四無量心
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 14 [use_Cython: False]: 慈悲喜捨
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 15 [use_Cython: False]: 八風不動
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 16 [use_Cython: False]: 不退転
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 17 [use_Cython: False]: 阿耨多羅三藐三菩提
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 18 [use_Cython: False]: 一切智
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 19 [use_Cython: False]: 無生法忍
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 20 [use_Cython: False]: 止観双修
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 21 [use_Cython: False]: 四禅定
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 22 [use_Cython: False]: 九次第定
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 23 [use_Cython: False]: 滅尽定
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 24 [use_Cython: False]: 無想定
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 25 [use_Cython: False]: 観呼吸
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 26 [use_Cython: False]: 観身不浄
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 27 [use_Cython: False]: 数息観
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 28 [use_Cython: False]: 白骨観
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 29 [use_Cython: False]: 不浄観
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 30 [use_Cython: False]: 慈心観
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 31 [use_Cython: False]: 因縁観
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 32 [use_Cython: False]: 念死観
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 33 [use_Cython: False]: 随念三宝
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 34 [use_Cython: False]: 経行禅
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 35 [use_Cython: False]: 立禅法
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 36 [use_Cython: False]: 食禅法
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 37 [use_Cython: False]: 作務禅
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 38 [use_Cython: False]: 公案禅
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 39 [use_Cython: False]: 只管打坐
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 40 [use_Cython: False]: 阿含経
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 41 [use_Cython: False]: 大般涅槃経
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 42 [use_Cython: False]: 大日経
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 43 [use_Cython: False]: 金剛頂経
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 44 [use_Cython: False]: 理趣経
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 45 [use_Cython: False]: 観音経
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 46 [use_Cython: False]: 地蔵経
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 47 [use_Cython: False]: 薬師経
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 48 [use_Cython: False]: 無量寿経
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 49 [use_Cython: False]: 観無量寿経
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 50 [use_Cython: False]: 倶舎論
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 51 [use_Cython: False]: 成実論
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 52 [use_Cython: False]: 大智度論
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 53 [use_Cython: False]: 中論頌
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 54 [use_Cython: False]: 唯識論
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 55 [use_Cython: False]: 起信論
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 56 [use_Cython: False]: 摩訶止観
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 57 [use_Cython: False]: 法界次第
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 58 [use_Cython: False]: 禅源諸詮集
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 59 [use_Cython: False]: 景徳伝灯録
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 60 [use_Cython: False]: 小乗仏教
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 61 [use_Cython: False]: 大乗仏教
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 62 [use_Cython: False]: 金剛乗
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 63 [use_Cython: False]: 秘密仏教
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 64 [use_Cython: False]: 南都六宗
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 65 [use_Cython: False]: 三論宗
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 66 [use_Cython: False]: 成実宗
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 67 [use_Cython: False]: 俱舎宗
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 68 [use_Cython: False]: 法相宗
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 69 [use_Cython: False]: 律宗派
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 70 [use_Cython: False]: 時宗派
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 71 [use_Cython: False]: 融通念仏宗
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 72 [use_Cython: False]: 一遍上人
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 73 [use_Cython: False]: 親鸞聖人
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 74 [use_Cython: False]: 法然上人
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 75 [use_Cython: False]: 道元禅師
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 76 [use_Cython: False]: 栄西禅師
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 77 [use_Cython: False]: 空海大師
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 78 [use_Cython: False]: 最澄大師
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 79 [use_Cython: False]: 鑑真和上
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 80 [use_Cython: False]: 開眼供養
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 81 [use_Cython: False]: 入仏供養
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 82 [use_Cython: False]: 落慶法要
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 83 [use_Cython: False]: 授戒会
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 84 [use_Cython: False]: 結縁灌頂
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 85 [use_Cython: False]: 伝法灌頂
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 86 [use_Cython: False]: 護摩供養
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 87 [use_Cython: False]: 千体仏供養
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 88 [use_Cython: False]: 水子供養
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 89 [use_Cython: False]: 先祖供養
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 90 [use_Cython: False]: 施餓鬼会
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 91 [use_Cython: False]: 大施食会
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 92 [use_Cython: False]: 盆踊り
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 93 [use_Cython: False]: 精霊流し
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 94 [use_Cython: False]: 迎え火
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 95 [use_Cython: False]: 送り火
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 96 [use_Cython: False]: 棚経参り
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 97 [use_Cython: False]: お数珠
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 98 [use_Cython: False]: 線香供養
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 99 [use_Cython: False]: 献花供養
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 100 [use_Cython: False]: 五重塔
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 101 [use_Cython: False]: 三重塔
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 102 [use_Cython: False]: 多宝塔
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 103 [use_Cython: False]: 仏舎利塔
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 104 [use_Cython: False]: 観音堂
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 105 [use_Cython: False]: 薬師堂
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 106 [use_Cython: False]: 阿弥陀堂
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 107 [use_Cython: False]: 大雄宝殿
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 108 [use_Cython: False]: 法堂建築
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 109 [use_Cython: False]: 禅堂建築
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 110 [use_Cython: False]: 客殿建築
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 111 [use_Cython: False]: 庫裏建築
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 112 [use_Cython: False]: 山門建築
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 113 [use_Cython: False]: 鐘楼建築
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 114 [use_Cython: False]: 経蔵建築
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 115 [use_Cython: False]: 宝蔵建築
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 116 [use_Cython: False]: 石庭造園
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 117 [use_Cython: False]: 枯山水
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 118 [use_Cython: False]: 借景技法
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 119 [use_Cython: False]: 禅庭設計
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 120 [use_Cython: False]: 千手観音
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 121 [use_Cython: False]: 十一面観音
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 122 [use_Cython: False]: 馬頭観音
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 123 [use_Cython: False]: 如意輪観音
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 124 [use_Cython: False]: 准胝観音
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 125 [use_Cython: False]: 不空羂索観音
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 126 [use_Cython: False]: 聖観音菩薩
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 127 [use_Cython: False]: 勢至菩薩
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 128 [use_Cython: False]: 文殊菩薩
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 129 [use_Cython: False]: 普賢菩薩
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 130 [use_Cython: False]: 弥勒菩薩
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 131 [use_Cython: False]: 薬王菩薩
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 132 [use_Cython: False]: 薬上菩薩
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 133 [use_Cython: False]: 虚空蔵菩薩
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 134 [use_Cython: False]: 大勢至菩薩
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 135 [use_Cython: False]: 金剛界曼荼羅
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 136 [use_Cython: False]: 胎蔵界曼荼羅
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 137 [use_Cython: False]: 両部曼荼羅
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 138 [use_Cython: False]: 八葉蓮華
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 139 [use_Cython: False]: 宝相華文様
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 140 [use_Cython: False]: 出家得度
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 141 [use_Cython: False]: 在家信者
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 142 [use_Cython: False]: 優婆塞
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 143 [use_Cython: False]: 優婆夷
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 144 [use_Cython: False]: 沙弥僧
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 145 [use_Cython: False]: 沙弥尼
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 146 [use_Cython: False]: 比丘僧
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 147 [use_Cython: False]: 比丘尼
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 148 [use_Cython: False]: 阿闍梨
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 149 [use_Cython: False]: 三蔵法師
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 150 [use_Cython: False]: 律師職位
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 151 [use_Cython: False]: 禅師職位
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 152 [use_Cython: False]: 大僧正
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 153 [use_Cython: False]: 僧正職位
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 154 [use_Cython: False]: 権僧正
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 155 [use_Cython: False]: 少僧都
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 156 [use_Cython: False]: 権少僧都
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 157 [use_Cython: False]: 法印大和尚
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 158 [use_Cython: False]: 伝燈大阿闍梨
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 159 [use_Cython: False]: 権大僧都
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 160 [use_Cython: False]: 三論教学
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 161 [use_Cython: False]: 法相教学
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 162 [use_Cython: False]: 華厳教学
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 163 [use_Cython: False]: 天台教学
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 164 [use_Cython: False]: 真言教学
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 165 [use_Cython: False]: 浄土教学
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 166 [use_Cython: False]: 禅宗教学
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 167 [use_Cython: False]: 日蓮教学
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 168 [use_Cython: False]: 唯識思想
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 169 [use_Cython: False]: 如来蔵思想
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 170 [use_Cython: False]: 本覚思想
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 171 [use_Cython: False]: 末法思想
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 172 [use_Cython: False]: 易行道
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 173 [use_Cython: False]: 難行道
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 174 [use_Cython: False]: 聖道門
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 175 [use_Cython: False]: 浄土門
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 176 [use_Cython: False]: 権教方便
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 177 [use_Cython: False]: 実教真実
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 178 [use_Cython: False]: 五時八教
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 179 [use_Cython: False]: 化法四教
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 180 [use_Cython: False]: 降誕会法要
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 181 [use_Cython: False]: 成道会法要
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 182 [use_Cython: False]: 涅槃会法要
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 183 [use_Cython: False]: 春彼岸法要
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 184 [use_Cython: False]: 秋彼岸法要
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 185 [use_Cython: False]: 盂蘭盆会
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 186 [use_Cython: False]: 十夜法要
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 187 [use_Cython: False]: 修正会法要
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 188 [use_Cython: False]: 節分会法要
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 189 [use_Cython: False]: 灌仏会法要
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 190 [use_Cython: False]: 花祭り行事
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 191 [use_Cython: False]: 除夜の鐘
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 192 [use_Cython: False]: 初詣参拝
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 193 [use_Cython: False]: 初護摩法要
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 194 [use_Cython: False]: 開山忌法要
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 195 [use_Cython: False]: 両祖忌法要
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 196 [use_Cython: False]: 宗祖忌法要
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 197 [use_Cython: False]: 御会式法要
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 198 [use_Cython: False]: 報恩講法要
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# Processing word 199 [use_Cython: False]: 追悼法要式
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...

# %%
df[columns0 + columns3]
# Out:
#        doc                    xsk1g  \
# 0      阿羅漢            [阿…, …漢, …羅…]
# 1      辟支仏            [辟…, …仏, …支…]
# 2      転法輪            [転…, …輪, …法…]
# 3     十二因縁       [十…, …縁, …二…, …因…]
# 4     五蘊盛苦       [五…, …苦, …蘊…, …盛…]
# ..     ...                      ...
# 195  両祖忌法要  [両…, …要, …祖…, …忌…, …法…]
# 196  宗祖忌法要  [宗…, …要, …祖…, …忌…, …法…]
# 197  御会式法要  [御…, …要, …会…, …式…, …法…]
# 198  報恩講法要  [報…, …要, …恩…, …講…, …法…]
# 199  追悼法要式  [追…, …式, …悼…, …法…, …要…]
#
#                                                  xsk2g  \
# 0                         [阿…, …漢, 阿羅…, 阿…漢, …羅漢, …羅…]
# 1                         [辟…, …仏, 辟支…, 辟…仏, …支仏, …支…]
# 2                         [転…, …輪, 転法…, 転…輪, …法輪, …法…]
# 3    [十…, …縁, 十二…, …二…, …因縁, …因…, 十…因…, 十…縁, …二因…, ...
# 4    [五…, …苦, 五蘊…, …蘊…, …盛苦, …盛…, 五…盛…, 五…苦, …蘊盛…, ...
# ..                                                 ...
# 195  [両…, …要, 両祖…, …祖…, …忌…, …法要, …法…, 両…忌…, …祖忌…, ...
# 196  [宗…, …要, 宗祖…, …祖…, …忌…, …法要, …法…, 宗…忌…, …祖忌…, ...
# 197  [御…, …要, 御会…, …会…, …式…, …法要, …法…, 御…式…, …会式…, ...
# 198  [報…, …要, 報恩…, …恩…, …講…, …法要, …法…, 報…講…, …恩講…, ...
# 199  [追…, …式, 追悼…, …悼…, …法…, …要式, …要…, 追…法…, …悼法…, ...
#
#                                                  xsk3g  \
# 0                    [阿…, …漢, 阿羅漢, 阿羅…, 阿…漢, …羅漢, …羅…]
# 1                    [辟…, …仏, 辟支仏, 辟支…, 辟…仏, …支仏, …支…]
# 2                    [転…, …輪, 転法輪, 転法…, 転…輪, …法輪, …法…]
# 3    [十…, …縁, 十二…, …二…, …因縁, …因…, 十二因…, 十二…縁, 十…因縁,...
# 4    [五…, …苦, 五蘊…, …蘊…, …盛苦, …盛…, 五蘊盛…, 五蘊…苦, 五…盛苦,...
# ..                                                 ...
# 195  [両…, …要, 両祖…, …祖…, …忌…, …法要, …法…, 両祖忌…, 両…忌…, ...
# 196  [宗…, …要, 宗祖…, …祖…, …忌…, …法要, …法…, 宗祖忌…, 宗…忌…, ...
# 197  [御…, …要, 御会…, …会…, …式…, …法要, …法…, 御会式…, 御…式…, ...
# 198  [報…, …要, 報恩…, …恩…, …講…, …法要, …法…, 報恩講…, 報…講…, ...
# 199  [追…, …式, 追悼…, …悼…, …法…, …要式, …要…, 追悼法…, 追…法…, ...
#
#                                                  xsk4g
# 0                    [阿…, …漢, 阿羅漢, 阿羅…, 阿…漢, …羅漢, …羅…]
# 1                    [辟…, …仏, 辟支仏, 辟支…, 辟…仏, …支仏, …支…]
# 2                    [転…, …輪, 転法輪, 転法…, 転…輪, …法輪, …法…]
# 3    [十…, …縁, 十二…, …二…, …因縁, …因…, 十二因縁, 十二因…, 十二…縁,...
# 4    [五…, …苦, 五蘊…, …蘊…, …盛苦, …盛…, 五蘊盛苦, 五蘊盛…, 五蘊…苦,...
# ..                                                 ...
# 195  [両…, …要, 両祖…, …祖…, …忌…, …法要, …法…, 両祖忌…, 両…忌…, ...
# 196  [宗…, …要, 宗祖…, …祖…, …忌…, …法要, …法…, 宗祖忌…, 宗…忌…, ...
# 197  [御…, …要, 御会…, …会…, …式…, …法要, …法…, 御会式…, 御…式…, ...
# 198  [報…, …要, 報恩…, …恩…, …講…, …法要, …法…, 報恩講…, 報…講…, ...
# 199  [追…, …式, 追悼…, …悼…, …法…, …要式, …要…, 追悼法…, 追…法…, ...
#
# [200 rows x 5 columns]

# %% [markdown]
# ## Check differences

# %%
for i, row in df.iterrows():
    doc = row['doc']
    print("--------------")
    print(f"doc: {doc}")
    
    ## compare xsk, sk and norm
    for j in range(1, max_n_for_ngram + 1):
        print(" -------------")
        print(f"{j}g")
        norm_var = f"{j}g"
        sk_var = f"sk{j}g"
        xsk_var = f"xsk{j}g"
        norm  = list(df.loc[i,norm_var])
        print(f"norm: {norm}")
        sk  = list(df.loc[i,sk_var])
        print(f"sk: {sk}")
        xsk = list(df.loc[i,xsk_var])
        print(f"xsk: {xsk}")
        
        ## Differences
        D1 = [ x for x in norm if not x in sk and not x in xsk ]
        print(f"D1: x in norm, not in sk and xsk: {D1}")
        ##
        D2 = [ x for x in sk if not x in norm and not x in xsk ]
        print(f"D2: x in sk, not in norm and xsk: {D2}")
        ##
        D3 = [ x for x in xsk if not x in norm and not x in sk ]
        print(f"D3: x in xsk, not in norm and sk: {D3}")

        ## Commonalities
        C1 = [ x for x in xsk if x in sk and x in norm ]
        print(f"C1: x in xsk, sk, and norm: {C1}")
        ##
        C2 = [ x for x in xsk if x in sk ]
        print(f"C2: x in xsk and sk {C2}")
        ##
        C3 = [ x for x in sk if x in norm ]
        print(f"C3: x in sk and norm: {C3}")
# Out:
# --------------
# doc: 阿羅漢
#  -------------
# 1g
# norm: ['阿', '羅', '漢']
# sk: ['阿', '羅', '漢']
# xsk: ['阿…', '…漢', '…羅…']
# D1: x in norm, not in sk and xsk: []
# D2: x in sk, not in norm and xsk: []
# D3: x in xsk, not in norm and sk: ['阿…', '…漢', '…羅…']
# C1: x in xsk, sk, and norm: []
# C2: x in xsk and sk []
# C3: x in sk and norm: ['阿', '羅', '漢']
#  -------------
# 2g
# norm: ['阿', '羅', '漢', '阿羅', '羅漢']
# sk: ['阿', '羅', '漢', '阿羅', '羅漢', '阿…漢']
# xsk: ['阿…', '…漢', '阿羅…', '阿…漢', '…羅漢', '…羅…']
# D1: x in norm, not in sk and xsk: []
# D2: x in sk, not in norm and xsk: []
# D3: x in xsk, not in norm and sk: ['阿…', '…漢', '阿羅…', '…羅漢', '…羅…']
# C1: x in xsk, sk, and norm: []
# C2: x in xsk and sk ['阿…漢']
# C3: x in sk and norm: ['阿', '羅', '漢', '阿羅', '羅漢']
#  -------------
# 3g
# norm: ['阿', '羅', '漢', '阿羅', '羅漢', '阿羅漢']
# sk: ['阿', '羅', '漢', '阿羅', '羅漢', '阿羅漢', '阿…漢']
# xsk: ['阿…', '…漢', '阿羅漢', '阿羅…', '阿…漢', '…羅漢', '…羅…']
# D1: x in norm, not in sk and xsk: []
# D2: x in sk, not in norm and xsk: []
# D3: x in xsk, not in norm and sk: ['阿…', '…漢', '阿羅…', '…羅漢', '…羅…']
# C1: x in xsk, sk, and norm: ['阿羅漢']
# C2: x in xsk and sk ['阿羅漢', '阿…漢']
# C3: x in sk and norm: ['阿', '羅', '漢', '阿羅', '羅漢', '阿羅漢']
#  -------------
# 4g
# norm: ['阿羅漢']
# sk: ['阿', '羅', '漢', '阿羅', '羅漢', '阿羅漢', '阿…漢']
# xsk: ['阿…', '…漢', '阿羅漢', '阿羅…', '阿…漢', '…羅漢', '…羅…']
# D1: x in norm, not in sk and xsk: []
# D2: x in sk, not in norm and xsk: ['阿', '羅', '漢', '阿羅', '羅漢']
# D3: x in xsk, not in norm and sk: ['阿…', '…漢', '阿羅…', '…羅漢', '…羅…']
# C1: x in xsk, sk, and norm: ['阿羅漢']
# C2: x in xsk and sk ['阿羅漢', '阿…漢']
# C3: x in sk and norm: ['阿羅漢']
# --------------
# doc: 辟支仏
#  -------------
# 1g
# norm: ['辟', '支', '仏']
# sk: ['辟', '支', '仏']
# xsk: ['辟…', '…仏', '…支…']
# D1: x in norm, not in sk and xsk: []
# D2: x in sk, not in norm and xsk: []
# D3: x in xsk, not in norm and sk: ['辟…', '…仏', '…支…']
# C1: x in xsk, sk, and norm: []
# C2: x in xsk and sk []
# C3: x in sk and norm: ['辟', '支', '仏']
#  -------------
# 2g
# norm: ['辟', '支', '仏', '辟支', '支仏']
# sk: ['辟', '支', '仏', '辟支', '支仏', '辟…仏']
# xsk: ['辟…', '…仏', '辟支…', '辟…仏', '…支仏', '…支…']
# D1: x in norm, not in sk and xsk: []
# D2: x in sk, not in norm and xsk: []
# D3: x in xsk, not in norm and sk: ['辟…', '…仏', '辟支…', '…支仏', '…支…']
# C1: x in xsk, sk, and norm: []
# C2: x in xsk and sk ['辟…仏']
# C3: x in sk and norm: ['辟', '支', '仏', '辟支', '支仏']
#  -------------
# 3g
# norm: ['辟', '支', '仏', '辟支', '支仏', '辟支仏']
# sk: ['辟', '支', '仏', '辟支', '支仏', '辟支仏', '辟…仏']
# xsk: ['辟…', '…仏', '辟支仏', '辟支…', '辟…仏', '…支仏', '…支…']
# D1: x in norm, not in sk and xsk: []
# D2: x in sk, not in norm and xsk: []
# D3: x in xsk, not in norm and sk: ['辟…', '…仏', '辟支…', '…支仏', '…支…']
# C1: x in xsk, sk, and norm: ['辟支仏']
# C2: x in xsk and sk ['辟支仏', '辟…仏']
# C3: x in sk and norm: ['辟', '支', '仏', '辟支', '支仏', '辟支仏']
#  -------------
# 4g
# norm: ['辟支仏']
# sk: ['辟', '支', '仏', '辟支', '支仏', '辟支仏', '辟…仏']
# xsk: ['辟…', '…仏', '辟支仏', '辟支…', '辟…仏', '…支仏', '…支…']
# D1: x in norm, not in sk and xsk: []
# D2: x in sk, not in norm and xsk: ['辟', '支', '仏', '辟支', '支仏']
# D3: x in xsk, not in norm and sk: ['辟…', '…仏', '辟支…', '…支仏', '…支…']
# C1: x in xsk, sk, and norm: ['辟支仏']
# C2: x in xsk and sk ['辟支仏', '辟…仏']
# C3: x in sk and norm: ['辟支仏']
# --------------
# doc: 転法輪
#  -------------
# 1g
# norm: ['転', '法', '輪']
# sk: ['転', '法', '輪']
# xsk: ['転…', '…輪', '…法…']
# D1: x in norm, not in sk and xsk: []
# D2: x in sk, not in norm and xsk: []
# D3: x in xsk, not in norm and sk: ['転…', '…輪', '…法…']
# C1: x in xsk, sk, and norm: []
# C2: x in xsk and sk []
# C3: x in sk and norm: ['転', '法', '輪']
#  -------------
# 2g
# norm: ['転', '法', '輪', '転法', '法輪']
# sk: ['転', '法', '輪', '転法', '法輪', '転…輪']
# xsk: ['転…', '…輪', '転法…', '転…輪', '…法輪', '…法…']
# D1: x in norm, not in sk and xsk: []
# D2: x in sk, not in norm and xsk: []
# D3: x in xsk, not in norm and sk: ['転…', '…輪', '転法…', '…法輪', '…法…']
# C1: x in xsk, sk, and norm: []
# C2: x in xsk and sk ['転…輪']
# C3: x in sk and norm: ['転', '法', '輪', '転法', '法輪']
#  -------------
# 3g
# norm: ['転', '法', '輪', '転法', '法輪', '転法輪']
# sk: ['転', '法', '輪', '転法', '法輪', '転法輪', '転…輪']
# xsk: ['転…', '…輪', '転法輪', '転法…', '転…輪', '…法輪', '…法…']
# D1: x in norm, not in sk and xsk: []
# D2: x in sk, not in norm and xsk: []
# D3: x in xsk, not in norm and sk: ['転…', '…輪', '転法…', '…法輪', '…法…']
# C1: x in xsk, sk, and norm: ['転法輪']
# C2: x in xsk and sk ['転法輪', '転…輪']
# C3: x in sk and norm: ['転', '法', '輪', '転法', '法輪', '転法輪']
#  -------------
# 4g
# norm: ['転法輪']
# sk: ['転', '法', '輪', '転法', '法輪', '転法輪', '転…輪']
# xsk: ['転…', '…輪', '転法輪', '転法…', '転…輪', '…法輪', '…法…']
# D1: x in norm, not in sk and xsk: []
# D2: x in sk, not in norm and xsk: ['転', '法', '輪', '転法', '法輪']
# D3: x in xsk, not in norm and sk: ['転…', '…輪', '転法…', '…法輪', '…法…']
# C1: x in xsk, sk, and norm: ['転法輪']
# C2: x in xsk and sk ['転法輪', '転…輪']
# C3: x in sk and norm: ['転法輪']
# --------------
# doc: 十二因縁
#  -------------
# 1g
# norm: ['十', '二', '因', '縁']
# sk: ['十', '二', '因', '縁']
# xsk: ['十…', '…縁', '…二…', '…因…']
# D1: x in norm, not in sk and xsk: []
# D2: x in sk, not in norm and xsk: []
# D3: x in xsk, not in norm and sk: ['十…', '…縁', '…二…', '…因…']
# C1: x in xsk, sk, and norm: []
# C2: x in xsk and sk []
# C3: x in sk and norm: ['十', '二', '因', '縁']
#  -------------
# 2g
# norm: ['十', '二', '因', '縁', '十二', '二因', '因縁']
# sk: ['十', '二', '因', '縁', '十二', '二因', '因縁', '十…因', '二…縁', '十…縁']
# xsk: ['十…', '…縁', '十二…', '…二…', '…因縁', '…因…', '十…因…', '十…縁', '…二因…', '…二…縁']
# D1: x in norm, not in sk and xsk: []
# D2: x in sk, not in norm and xsk: ['十…因', '二…縁']
# D3: x in xsk, not in norm and sk: ['十…', '…縁', '十二…', '…二…', '…因縁', '…因…', '十…因…', '…二因…', '…二…縁']
# C1: x in xsk, sk, and norm: []
# C2: x in xsk and sk ['十…縁']
# C3: x in sk and norm: ['十', '二', '因', '縁', '十二', '二因', '因縁']
#  -------------
# 3g
# norm: ['十', '二', '因', '縁', '十二', '二因', '因縁', '十二因', '二因縁']
# sk: ['十', '二', '因', '縁', '十二', '二因', '因縁', '十二因', '十…因', '二因縁', '二…縁', '十二…縁', '十…因縁', '十…縁']
# xsk: ['十…', '…縁', '十二…', '…二…', '…因縁', '…因…', '十二因…', '十二…縁', '十…因縁', '十…因…', '十…縁', '…二因縁', '…二因…', '…二…縁']
# D1: x in norm, not in sk and xsk: []
# D2: x in sk, not in norm and xsk: 

# C1: x in xsk, sk, and norm: []
# C2: x in xsk and sk ['五蘊…苦', '五…盛苦', '五…苦']
# C3: x in sk and norm: ['五', '蘊', '盛', '苦', '五蘊', '蘊盛', '盛苦', '五蘊盛', '蘊盛苦']
#  -------------
# 4g
# norm: ['五', '蘊', '盛', '苦', '五蘊', '蘊盛', '盛苦', '五蘊盛', '蘊盛苦', '五蘊盛苦']
# sk: ['五', '蘊', '盛', '苦', '五蘊', '蘊盛', '盛苦', '五蘊盛', '五…盛', '蘊盛苦', '蘊…苦', '五蘊盛苦', '五蘊…苦', '五…盛苦', '五…苦']
# xsk: ['五…', '…苦', '五蘊…', '…蘊…', '…盛苦', '…盛…', '五蘊盛苦', '五蘊盛…', '五蘊…苦', '五…盛苦', '五…盛…', '五…苦', '…蘊盛苦', '…蘊盛…', '…蘊…苦']
# D1: x in norm, not in sk and xsk: []
# D2: x in sk, not in norm and xsk: ['五…盛', '蘊…苦']
# D3: x in xsk, not in norm and sk: ['五…', '…苦', '五蘊…', '…蘊…', '…盛苦', '…盛…', '五蘊盛…', '五…盛…', '…蘊盛苦', '…蘊盛…', '…蘊…苦']
# C1: x in xsk, sk, and norm: ['五蘊盛苦']
# C2: x in xsk and sk ['五蘊盛苦', '五蘊…苦', '五…盛苦', '五…苦']
# C3: x in sk and norm: ['五', '蘊', '盛', '苦', '五蘊', '蘊盛', '盛苦', '五蘊盛', '蘊盛苦', '五蘊盛苦']
# --------------
# doc: 三法印
#  -------------
# 1g
# norm: ['三', '法', '印']
# sk: ['三', '法', '印']
# xsk: ['三…', '…印', '…法…']
# D1: x in norm, not in sk and xsk: []
# D2: x in sk, not in norm and xsk: []
# D3: x in xsk, not in norm and sk: ['三…', '…印', '…法…']
# C1: x in xsk, sk, and norm: []
# C2: x in xsk and sk []
# C3: x in sk and norm: ['三', '法', '印']
#  -------------
# 2g
# norm: ['三', '法', '印', '三法', '法印']
# sk: ['三', '法', '印', '三法', '法印', '三…印']
# xsk: ['三…', '…印', '三法…', '三…印', '…法印', '…法…']
# D1: x in norm, not in sk and xsk: []
# D2: x in sk, not in norm and xsk: []
# D3: x in xsk, not in norm and sk: ['三…', '…印', '三法…', '…法印', '…法…']
# C1: x in xsk, sk, and norm: []
# C2: x in xsk and sk ['三…印']
# C3: x in sk and norm: ['三', '法', '印', '三法', '法印']
#  -------------
# 3g
# norm: ['三', '法', '印', '三法', '法印', '三法印']
# sk: ['三', '法', '印', '三法', '法印', '三法印', '三…印']
# xsk: ['三…', '…印', '三法印', '三法…', '三…印', '…法印', '…法…']
# D1: x in norm, not in sk and xsk: []
# D2: x in sk, not in norm and xsk: []
# D3: x in xsk, not in norm and sk: ['三…', '…印', '三法…', '…法印', '…法…']
# C1: x in xsk, sk, and norm: ['三法印']
# C2: x in xsk and sk ['三法印', '三…印']
# C3: x in sk and norm: ['三', '法', '印', '三法', '法印', '三法印']
#  -------------
# 4g
# norm: ['三法印']
# sk: ['三', '法', '印', '三法', '法印', '三法印', '三…印']
# xsk: ['三…', '…印', '三法印', '三法…', '三…印', '…法印', '…法…']
# D1: x in norm, not in sk and xsk: []
# D2: x in sk, not in norm and xsk: ['三', '法', '印', '三法', '法印']
# D3: x in xsk, not in norm and sk: ['三…', '…印', '三法…', '…法印', '…法…']
# C1: x in xsk, sk, and norm: ['三法印']
# C2: x in xsk and sk ['三法印', '三…印']
# C3: x in sk and norm: ['三法印']
# --------------
# doc: 四念処
#  -------------
# 1g
# norm: ['四', '念', '処']
# sk: ['四', '念', '処']
# xsk: ['四…', '…処', '…念…']
# D1: x in norm, not in sk and xsk: []
# D2: x in sk, not in norm and xsk: []
# D3: x in xsk, not in norm and sk: ['四…', '…処', '…念…']
# C1: x in xsk, sk, and norm: []
# C2: x in xsk and sk []
# C3: x in sk and norm: ['四', '念', '処']
#  -------------
# 2g
# norm: ['四', '念', '処', '四念', '念処']
# sk: ['四', '念', '処', '四念', '念処', '四…処']
# xsk: ['四…', '…処', '四念…', '四…処', '…念処', '…念…']
# D1: x in norm, not in sk and xsk: []
# D2: x in sk, not in norm and xsk: []
# D3: x in xsk, not in norm and sk: ['四…', '…処', '四念…', '…念処', '…念…']
# C1: x in xsk, sk, and norm: []
# C2: x in xsk and sk ['四…処']
# C3: x in sk and norm: ['四', '念', '処', '四念', '念処']
#  -------------
# 3g
# norm: ['四', '念', '処', '四念', '念処', '四念処']
# sk: ['四', '念', '処', '四念', '念処', '四念処', '四…処']
# xsk: ['四…', '…処', '四念処', '四念…', '四…処', '…念処', '…念…']
# D1: x in norm, not in sk and xsk: []
# D2: x in sk, not in norm and xsk: []
# D3: x in xsk, not in norm and sk: ['四…', '…処', '四念…', '…念処', '…念…']
# C1: x in xsk, sk, and norm: ['四念処']
# C2: x in xsk and sk ['四念処', '四…処']
# C3: x in sk and norm: ['四', '念', '処', '四念', '念処', '四念処']
#  -------------
# 4g
# norm: ['四念処']
# sk: ['四', '念', '処', '四念', '念処', '四念処', '四…処']
# xsk: ['四…', '…処', '四念処', '四念…', '四…処', '…念処', '…念…']
# D1: x in norm, not in sk and xsk: []
# D2: x in sk, not in norm and xsk: ['四', '念', '処', '四念', '念処']
# D3: x in xsk, not in norm and sk: ['四…', '…処', '四念…', '…念処', '…念…']
# C1: x in xsk, sk, and norm: ['四念処']
# C2: x in xsk and sk ['四念処', '四…処']
# C3: x in sk and norm: ['四念処']
# --------------
# doc: 四神足
#  -------------
# 1g
# norm: ['四', '神', '足']
# sk: ['四', '神', '足']
# xsk: ['四…', '…足', '…神…']
# D1: x in norm, not in sk and xsk: []
# D2: x in sk, not in norm and xsk: []
# D3: x in xsk, not in norm and sk: ['四…', '…足', '…神…']
# C1: x in xsk, sk, and norm: []
# C2: x in xsk and sk []
# C3: x in sk and norm: ['四', '神', '足']
#  -------------
# 2g
# norm: ['四', '神', '足', '四神', '神足']
# sk: ['四', '神', '足', '四神', '神足', '四…足']
# xsk: ['四…', '…足', '四神…', '四…足', '…神足', '…神…']
# D1: x in norm, not in sk and xsk: []
# D2: x in sk, not in norm and xsk: []
# D3: x in xsk, not in norm and sk: ['四…', '…足', '四神…', '…神足', '…神…']
# C1: x in xsk, sk, and norm: []
# C2: x in xsk and sk ['四…足']
# C3: x in sk and norm: ['四', '神', '足', '四神', '神足']
#  -------------
# 3g
# norm: ['四', '神', '足', '四神', '神足', '四神足']
# sk: ['四', '神', '足', '四神', '神足', '四神足', '四…足']
# xsk: ['四…', '…足', '四神足', '四神…', '四…足', '…神足', '…神…']
# D1: x in norm, not in sk and xsk: []
# D2: x in sk, not in norm and xsk: []
# D3: x in xsk, not in norm and sk: ['四…', '…足', '四神…', '…神足', '…神…']
# C1: x in xsk, sk, and norm: ['四神足']
# C2: x in xsk and sk ['四神足', '四…足']
# C3: x in sk and norm: ['四', '神', '足', '四神', '神足', '四神足']
#  -------------
# 4g
# norm: ['四神足']
# sk: ['四', '神', '足', '四神', '神足', '四神足', '四…足']
# xsk: ['四…', '…足', '四神足', '四神…', '四…足', '…神足', '…神…']
# D1: x in norm, not in sk and xsk: []
# D2: x in sk, not in norm and xsk: ['四', '神', '足', '四神', '神足']
# D3: x in xsk, not in norm and sk: ['四…', '…足', '四神…', '…神足', '…神…']
# C1: x in xsk, sk, and norm: ['四神足']
# C2: x in xsk and sk ['四神足', '四…足']
# C3: x in sk and norm: ['四神足']
# --------------
# doc: 五根五力
#  -------------
# 1g
# norm: ['五', '根', '五', '力']
# sk: ['五', '根', '力']
# xsk: ['…力', '…根…', '…五…']
# D1: x in norm, not in sk and xsk: []
# D2: x in sk, not in norm and xsk: []
# D3: x in xsk, not in norm and sk: ['…力', '…根…', '…五…']
# C1: x in xsk, sk, and norm: []
# C2: x in xsk and sk []
# C3: x in sk and norm: ['五', '根', '力']
#  -------------
# 2g
# norm: ['五', '根', '五', '力', '五根', '根五', '五力']
# sk: ['五', '根', '力', '五根', '根五', '五力', '五…五', '根…力', '五…力']
# xsk: ['…力', '五根…', '…根…', '…五力', '…五…', '五…五…', '五…力', '…根五…', '…根…力']
# D1: x in norm, not in sk and xsk: []
# D2: x in sk, not in norm and xsk: ['五…五', '根…力']
# D3: x in xsk, not in norm and sk: ['…力', '五根…', '…根…', '…五力', '…五…', '五…五…', '…根五…', '…根…力']
# C1: x in xsk, sk, and norm: []
# C2: x in xsk and sk ['五…力']
# C3: x in sk and norm: ['五', '根', '力', '五根', '根五', '五力']
#  -------------
# 3g
# norm: ['五', '根', '五', '力', '五根', '根五', '五力', '五根五', '根五力']
# sk: ['五', '根', '力', '五根', '根五', '五力', '五根五', '五…五', '根五力', '根…力', '五根…力', '五…五力', '五…力']
# xsk: ['…力', '五根…', '…根…', '…五力', '…五…', '五根五…', '五根…力', '五…五力', '五…五…', '五…力', '…根五力', '…根五…', '…根…力']
# D1: x in norm, not in sk and xsk: []
# D2: x in sk, not in norm and xsk: ['五…五', '根…力']
# D3: x in xsk, not in norm and sk: ['…力', '五根…', '…根…', '…五力', '…五…', '五根五…', '五…五…', '…根五力', '…根五…', '…根…力']
# C1: x in xsk, sk, and norm: []
# C2: x in xsk and sk ['五根…力', '五…五力', '五…力']
# C3: x in sk and norm: ['五', '根', '力', '五根', '根五', '五力', '五根五', '根五力']
#  -------------
# 4g
# norm: ['五', '根', '五', '力', '五根', '根五', '五力', '五根五', '根五力', '五根五力']
# sk: ['五', '根', '力', '五根', '根五', '五力', '五根五', '五…五', '根五力', '根…力', '五根五力', '五根…力', '五…五力', '五…力']
# xsk: ['…力', '五根…', '…根…', '…五力', '…五…', '五根五力', '五根五…', '五根…力', '五…五力', '五…五…', '五…力', '…根五力', '…根五…', '…根…力']
# D1: x in norm, not in sk and xsk: []
# D2: x in sk, not in norm and xsk: ['五…五', '根…力']
# D3: x in xsk, not in norm and sk: ['…力', '五根…', '…根…', '…五力', '…五…', '五根五…', '五…五…', '…根五力', '…根五…', '…根…力']
# C1: x in xsk, sk, and norm: ['五根五力']
# C2: x in xsk and sk ['五根五力', '五根…力', '五…五力', '五…力']
# C3: x in sk and norm: ['五', '根', '力', '五根', '根五', '五力', '五根五', '根五力', '五根五力']
# --------------
# doc: 七覚支
#  -------------
# 1g
# norm: ['七', '覚', '支']
# sk: ['七', '覚', '支']
# xsk: ['七…', '…支', '…覚…']
# D1: x in norm, not in sk and xsk: []
# D2: x in sk, not in norm and xsk: []
# D3: x in xsk, not in norm and sk: ['七…', '…支', '…覚…']
# C1: x in xsk, sk, and norm: []
# C2: x in xsk and sk []
# C3: x in sk and norm: ['七', '覚', '支']
#  -------------
# 2g
# norm: ['七', '覚', '支', '七覚', '覚支']
# sk: ['七', '覚', '支', '七覚', '覚支', '七…支']
# xsk: ['七…', '…支', '七覚…', '七…支', '…覚支', '…覚…']
# D1: x in norm, not in sk and xsk: []
# D2: x in sk, not in norm and xsk: []
# D3: x in xsk, not in norm and sk: ['七…', '…支', '七覚…', '…覚支', '…覚…']
# C1: x in xsk, sk, and norm: []
# C2: x in xsk and sk ['七…支']
# C3: x in sk and norm: ['七', '覚', '支', '七覚', '覚支']
#  -------------
# 3g
# norm: ['七', '覚', '支', '七覚', '覚支', '七覚支']
# sk: ['七', '覚', '支', '七覚', '覚支', '七覚支', '七…支']
# xsk: ['七…', '…支', '七覚支', '七覚…', '七…支', '…覚支', '…覚…']
# D1: x in norm, not in sk and xsk: []
# D2: x in sk, not in norm and xsk: []
# D3: x in xsk, not in norm and sk: ['七…', '…支', '七覚…', '…覚支', '…覚…']
# C1: x in xsk, sk, and norm: ['七覚支']
# C2: x in xsk and sk ['七覚支', '七…支']
# C3: x in sk and norm: ['七', '覚', '支', '七覚', '覚支', '七覚支']
#  -------------
# 4g
# norm: ['七覚支']
# sk: ['七', '覚', '支', '七覚', '覚支', '七覚支', '七…支']
# xsk: ['七…', '…支', '七覚支', '七覚…', '七…支', '…覚支', '…覚…']
# D1: x in norm, not in sk and xsk: []
# D2: x in sk, not in norm and xsk: ['七', '覚', '支', '七覚', '覚支']
# D3: x in xsk, not in norm and sk: ['七…', '…支', '七覚…', '…覚支', '…覚…']
# C1: x in xsk, sk, and norm: ['七覚支']
# C2: x in xsk and sk ['七覚支', '七…支']
# C3: x in sk and norm: ['七覚支']
# --------------
# doc: 三十七道品
#  -------------
# 1g
# norm: ['三', '十', '七', '道', '品']
# sk: ['三', '十', '七', '道', '品']
# xsk: ['三…', '…品', '…十…', '…七…', '…道…']
# D1: x in norm, not in sk and xsk: []
# D2: x in sk, not in norm and xsk: []
# D3: x in xsk, not in norm and sk: 
']
# D1: x in norm, not in sk and xsk: []
# D2: x in sk, not in norm and xsk: ['六', '神', '通', '六神', '神通']
# D3: x in xsk, not in norm and sk: ['六…', '…通', '六神…', '…神通', '…神…']
# C1: x in xsk, sk, and norm: ['六神通']
# C2: x in xsk and sk ['六神通', '六…通']
# C3: x in sk and norm: ['六神通']
# --------------
# doc: 四無量心
#  -------------
# 1g
# norm: ['四', '無', '量', '心']
# sk: ['四', '無', '量', '心']
# xsk: ['四…', '…心', '…無…', '…量…']
# D1: x in norm, not in sk and xsk: []
# D2: x in sk, not in norm and xsk: []
# D3: x in xsk, not in norm and sk: ['四…', '…心', '…無…', '…量…']
# C1: x in xsk, sk, and norm: []
# C2: x in xsk and sk []
# C3: x in sk and norm: ['四', '無', '量', '心']
#  -------------
# 2g
# norm: ['四', '無', '量', '心', '四無', '無量', '量心']
# sk: ['四', '無', '量', '心', '四無', '無量', '量心', '四…量', '無…心', '四…心']
# xsk: ['四…', '…心', '四無…', '…無…', '…量心', '…量…', '四…量…', '四…心', '…無量…', '…無…心']
# D1: x in norm, not in sk and xsk: []
# D2: x in sk, not in norm and xsk: ['四…量', '無…心']
# D3: x in xsk, not in norm and sk: ['四…', '…心', '四無…', '…無…', '…量心', '…量…', '四…量…', '…無量…', '…無…心']
# C1: x in xsk, sk, and norm: []
# C2: x in xsk and sk ['四…心']
# C3: x in sk and norm: ['四', '無', '量', '心', '四無', '無量', '量心']
#  -------------
# 3g
# norm: ['四', '無', '量', '心', '四無', '無量', '量心', '四無量', '無量心']
# sk: ['四', '無', '量', '心', '四無', '無量', '量心', '四無量', '四…量', '無量心', '無…心', '四無…心', '四…量心', '四…心']
# xsk: ['四…', '…心', '四無…', '…無…', '…量心', '…量…', '四無量…', '四無…心', '四…量心', '四…量…', '四…心', '…無量心', '…無量…', '…無…心']
# D1: x in norm, not in sk and xsk: []
# D2: x in sk, not in norm and xsk: ['四…量', '無…心']
# D3: x in xsk, not in norm and sk: ['四…', '…心', '四無…', '…無…', '…量心', '…量…', '四無量…', '四…量…', '…無量心', '…無量…', '…無…心']
# C1: x in xsk, sk, and norm: []
# C2: x in xsk and sk ['四無…心', '四…量心', '四…心']
# C3: x in sk and norm: ['四', '無', '量', '心', '四無', '無量', '量心', '四無量', '無量心']
#  -------------
# 4g
# norm: ['四', '無', '量', '心', '四無', '無量', '量心', '四無量', '無量心', '四無量心']
# sk: ['四', '無', '量', '心', '四無', '無量', '量心', '四無量', '四…量', '無量心', '無…心', '四無量心', '四無…心', '四…量心', '四…心']
# xsk: ['四…', '…心', '四無…', '…無…', '…量心', '…量…', '四無量心', '四無量…', '四無…心', '四…量心', '四…量…', '四…心', '…無量心', '…無量…', '…無…心']
# D1: x in norm, not in sk and xsk: []
# D2: x in sk, not in norm and xsk: ['四…量', '無…心']
# D3: x in xsk, not in norm and sk: ['四…', '…心', '四無…', '…無…', '…量心', '…量…', '四無量…', '四…量…', '…無量心', '…無量…', '…無…心']
# C1: x in xsk, sk, and norm: ['四無量心']
# C2: x in xsk and sk ['四無量心', '四無…心', '四…量心', '四…心']
# C3: x in sk and norm: ['四', '無', '量', '心', '四無', '無量', '量心', '四無量', '無量心', '四無量心']
# --------------
# doc: 慈悲喜捨
#  -------------
# 1g
# norm: ['慈', '悲', '喜', '捨']
# sk: ['慈', '悲', '喜', '捨']
# xsk: ['慈…', '…捨', '…悲…', '…喜…']
# D1: x in norm, not in sk and xsk: []
# D2: x in sk, not in norm and xsk: []
# D3: x in xsk, not in norm and sk: ['慈…', '…捨', '…悲…', '…喜…']
# C1: x in xsk, sk, and norm: []
# C2: x in xsk and sk []
# C3: x in sk and norm: 

# D1: x in norm, not in sk and xsk: []
# D2: x in sk, not in norm and xsk: ['止…双', '観…修']
# D3: x in xsk, not in norm and sk: ['止…', '…修', '止観…', '…観…', '…双修', '…双…', '止観双…', '止…双…', '…観双修', '…観双…', '…観…修']
# C1: x in xsk, sk, and norm: ['止観双修']
# C2: x in xsk and sk ['止観双修', '止観…修', '止…双修', '止…修']
# C3: x in sk and norm: ['止', '観', '双', '修', '止観', '観双', '双修', '止観双', '観双修', '止観双修']
# --------------
# doc: 四禅定
#  -------------
# 1g
# norm: ['四', '禅', '定']
# sk: ['四', '禅', '定']
# xsk: ['四…', '…定', '…禅…']
# D1: x in norm, not in sk and xsk: []
# D2: x in sk, not in norm and xsk: []
# D3: x in xsk, not in norm and sk: ['四…', '…定', '…禅…']
# C1: x in xsk, sk, and norm: []
# C2: x in xsk and sk []
# C3: x in sk and norm: ['四', '禅', '定']
#  -------------
# 2g
# norm: ['四', '禅', '定', '四禅', '禅定']
# sk: ['四', '禅', '定', '四禅', '禅定', '四…定']
# xsk: ['四…', '…定', '四禅…', '四…定', '…禅定', '…禅…']
# D1: x in norm, not in sk and xsk: []
# D2: x in sk, not in norm and xsk: []
# D3: x in xsk, not in norm and sk: ['四…', '…定', '四禅…', '…禅定', '…禅…']
# C1: x in xsk, sk, and norm: []
# C2: x in xsk and sk ['四…定']
# C3: x in sk and norm: ['四', '禅', '定', '四禅', '禅定']
#  -------------
# 3g
# norm: ['四', '禅', '定', '四禅', '禅定', '四禅定']
# sk: ['四', '禅', '定', '四禅', '禅定', '四禅定', '四…定']
# xsk: ['四…', '…定', '四禅定', '四禅…', '四…定', '…禅定', '…禅…']
# D1: x in norm, not in sk and xsk: []
# D2: x in sk, not in norm and xsk: []
# D3: x in xsk, not in norm and sk: ['四…', '…定', '四禅…', '…禅定', '…禅…']
# C1: x in xsk, sk, and norm: ['四禅定']
# C2: x in xsk and sk ['四禅定', '四…定']
# C3: x in sk and norm: ['四', '禅', '定', '四禅', '禅定', '四禅定']
#  -------------
# 4g
# norm: ['四禅定']
# sk: ['四', '禅', '定', '四禅', '禅定', '四禅定', '四…定']
# xsk: ['四…', '…定', '四禅定', '四禅…', '四…定', '…禅定', '…禅…']
# D1: x in norm, not in sk and xsk: []
# D2: x in sk, not in norm and xsk: ['四', '禅', '定', '四禅', '禅定']
# D3: x in xsk, not in norm and sk: ['四…', '…定', '四禅…', '…禅定', '…禅…']
# C1: x in xsk, sk, and norm: ['四禅定']
# C2: x in xsk and sk ['四禅定', '四…定']
# C3: x in sk and norm: ['四禅定']
# --------------
# doc: 九次第定
#  -------------
# 1g
# norm: ['九', '次', '第', '定']
# sk: ['九', '次', '第', '定']
# xsk: ['九…', '…定', '…次…', '…第…']
# D1: x in norm, not in sk and xsk: []
# D2: x in sk, not in norm and xsk: []
# D3: x in xsk, not in norm and sk: ['九…', '…定', '…次…', '…第…']
# C1: x in xsk, sk, and norm: []
# C2: x in xsk and sk []
# C3: x in sk and norm: ['九', '次', '第', '定']
#  -------------
# 2g
# norm: ['九', '次', '第', '定', '九次', '次第', '第定']
# sk: ['九', '次', '第', '定', '九次', '次第', '第定', '九…第', '次…定', '九…定']
# xsk: ['九…', '…定', '九次…', '…次…', '…第定', '…第…', '九…第…', '九…定', '…次第…', '…次…定']
# D1: x in norm, not in sk and xsk: []
# D2: x in sk, not in norm and xsk: ['九…第', '次…定']
# D3: x in xsk, not in norm and sk: ['九…', '…定', '九次…', '…次…', '…第定', '…第…', '九…第…', '…次第…', '…次…定']
# C1: x in xsk, sk, and norm: []
# C2: x in xsk and sk ['九…定']
# C3: x in sk and norm: ['九', '次', '第', '定', '九次', '次第', '第定']
#  -------------
# 3g
# norm: ['九', '次', '第', '定', '九次', '次第', '第定', '九次第', '次第定']
# sk: ['九', '次', '第', '定', '九次', '次第', '第定', '九次第', '九…第', '次第定', '次…定', '九次…定', '九…第定', '九…定']
# xsk: ['九…', '…定', '九次…', '…次…', '…第定', '…第…', '九次第…', '九次…定', '九…第定', '九…第…', '九…定', '…次第定', '…次第…', '…次…定']
# D1: x in norm, not in sk and xsk: []
# D2: x in sk, not in norm and xsk: ['九…第', '次…定']
# D3: x in xsk, not in norm and sk: ['九…', '…定', '九次…', '…次…', '…第定', '…第…', '九次第…', '九…第…', '…次第定', '…次第…', '…次…定']
# C1: x in xsk, sk, and norm: []
# C2: x in xsk and sk 