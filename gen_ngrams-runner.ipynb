# %% [markdown]
# # Generator of (extended) (skippy) n-grams out of words or sentences
#
# developed by Kow Kuroda (kow.kuroda@gmail.com)
#
# This Jupyter notebook demonstrates how to use gen2_ngrams.py (or gen2_ngrams_cy.pyx) developed to enhance the usability of its predecessor "gen_ngrams.py".
#
# There are two main differences from its predecessor. First, gen_skippy_ngrams(..) generates extended skippy n-grams with "extended = True" option. Second, gen_skippy_ngrams(..) cann generate inclusive n-grams, thereby dispensing with incremental generation of n-grams from 1-grams.
#
# Limitations
# - Availablity of Cython-enhancement is limited. Apple Silicons like M1 and M2 (M3 is not tested yet) do not accept it, though it is available under Python 3.10 on M1.
#
# Creation
# - 2025/08/19
#
# Modifications
# - 2025/08/21 minor changes;
# - 2025/08/22 i) minor changes; Cython-enhancement was implemented;

# %% [markdown]
# # Set up Cython

# %%
#conda update -n base -c defaults conda -y

# %%
## Cython の導入 (必要に応じて)
#!conda uninstall cython -y # seems necessary in certain situations
#!conda install cython -y
## Try the following if the above fails
#!pip install cython --upgrade --force-reinstall
#!conda update -n base -c defaults conda -y

# %%
#!pip show cython

# %%
## Cython を使うかどうか
use_Cython = True

# %%
## Cython extension の(再)構築が必要な場合は True に
build_Cython_extension = False
if use_Cython and build_Cython_extension:
    # !python setup.py clean build_ext --inplace

# %%
## Cython 版の読込み
if use_Cython:
    try:
        # %reload_ext Cython
    except ImportError:
        # %load_ext Cython
    ## Apple Silicons like M1, M2 do not accept the following
    import gen2_ngrams_cy as gen_ngrams
else:
    try:
        import gen2_ngrams as gen_ngrams # gen_ngrams is now obsolete
    except NameError:
        import gen_ngrams

# %% [markdown]
# # Set up data

# %%
analyze_words = True # if False, analyze sentential/phrasal objects

## parameters for analysis
if analyze_words:
    segmenter: str = r""
    sep_local: str = ""
else:
    segmenter: str = r" "
    sep_local: str = " "

# %%
import pathlib
if analyze_words:
    data_dir = 'data/words'
    files = list(pathlib.Path(data_dir).glob('buddhist-listed2.txt'))
else:
    data_dir = 'data/phrases'
    files = list(pathlib.Path(data_dir).glob('austen-j-sample100.txt'))
##
print(files)

##
file = files[0]
source_name = file.stem
print(f"source_name: {source_name}")
# Out:
# [PosixPath('data/words/buddhist-listed2.txt')]
# source_name: buddhist-listed2

# %%
## get data
docs = file.read_text(encoding = 'utf-8').splitlines()

## lowercase
docs = [ doc.lower() for doc in docs if len(doc) > 0 ]
print(docs[:10])
# Out:
# ['阿羅漢', '辟支仏', '転法輪', '十二因縁', '五蘊盛苦', '三法印', '四念処', '四神足', '五根五力', '七覚支']

# %% [markdown]
# # Generation of (extended) (skippy) n-grams

# %%
## flags
check: bool = False

## saving results
save_results: bool = False
save_dir: str = "saves"

# %%
### n-gram
## n の最大値
max_n_for_ngram: int = 5

## n-gram
ngram_is_inclusive = True
skippy_means_extended = True

## n-gram を文字列として生成するか否か
generated_as_string: bool = True
generated_as_list: bool = not(generated_as_string)

# %%
#!conda install pandas -y

# %%
import pandas as pd
columns0 = ['doc']
columns1 = [ f"xsk{i}g" for i in range(1, max_n_for_ngram + 1)]
columns2 = [ f"sk{i}g" for i in range(1, max_n_for_ngram + 1)]
columns3 = [ f"{i}g" for i in range(1, max_n_for_ngram + 1)]

used_columns = columns0 + columns1 + columns2 + columns3
df = pd.DataFrame(columns = used_columns)

# %%
## generate extended skippy n-grams
import re
for i, doc in enumerate(docs):
    print(f"Processing word {i} [use_Cython: {use_Cython}]: {doc}")
    word_segs = [ seg for seg in re.split(segmenter, doc) if len(seg) > 0 ]
    for j in range(1, max_n_for_ngram + 1):
        print(f"generating extended skippy {j}-grams ...")
        ngrams = gen_ngrams.gen_skippy_ngrams(word_segs, j, extended = skippy_means_extended, inclusive = ngram_is_inclusive, sep = sep_local, as_list = generated_as_list, check = False)
        if check:
            print(ngrams)
        ## update df
        df.loc[i, f'xsk{j}g'] = ngrams
# Out:
# Processing word 0 [use_Cython: True]: 阿羅漢
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 1 [use_Cython: True]: 辟支仏
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 2 [use_Cython: True]: 転法輪
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 3 [use_Cython: True]: 十二因縁
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 4 [use_Cython: True]: 五蘊盛苦
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 5 [use_Cython: True]: 三法印
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 6 [use_Cython: True]: 四念処
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 7 [use_Cython: True]: 四神足
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 8 [use_Cython: True]: 五根五力
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 9 [use_Cython: True]: 七覚支
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 10 [use_Cython: True]: 三十七道品
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 11 [use_Cython: True]: 十善戒
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 12 [use_Cython: True]: 六神通
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 13 [use_Cython: True]: 四無量心
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 14 [use_Cython: True]: 慈悲喜捨
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 15 [use_Cython: True]: 八風不動
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 16 [use_Cython: True]: 不退転
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 17 [use_Cython: True]: 阿耨多羅三藐三菩提
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 18 [use_Cython: True]: 一切智
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 19 [use_Cython: True]: 無生法忍
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 20 [use_Cython: True]: 止観双修
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 21 [use_Cython: True]: 四禅定
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 22 [use_Cython: True]: 九次第定
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 23 [use_Cython: True]: 滅尽定
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 24 [use_Cython: True]: 無想定
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 25 [use_Cython: True]: 観呼吸
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 26 [use_Cython: True]: 観身不浄
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 27 [use_Cython: True]: 数息観
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 28 [use_Cython: True]: 白骨観
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 29 [use_Cython: True]: 不浄観
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 30 [use_Cython: True]: 慈心観
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 31 [use_Cython: True]: 因縁観
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 32 [use_Cython: True]: 念死観
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 33 [use_Cython: True]: 随念三宝
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 34 [use_Cython: True]: 経行禅
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 35 [use_Cython: True]: 立禅法
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 36 [use_Cython: True]: 食禅法
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 37 [use_Cython: True]: 作務禅
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 38 [use_Cython: True]: 公案禅
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 39 [use_Cython: True]: 只管打坐
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 40 [use_Cython: True]: 阿含経
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 41 [use_Cython: True]: 大般涅槃経
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 42 [use_Cython: True]: 大日経
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 43 [use_Cython: True]: 金剛頂経
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 44 [use_Cython: True]: 理趣経
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 45 [use_Cython: True]: 観音経
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 46 [use_Cython: True]: 地蔵経
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 47 [use_Cython: True]: 薬師経
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 48 [use_Cython: True]: 無量寿経
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 49 [use_Cython: True]: 観無量寿経
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 50 [use_Cython: True]: 倶舎論
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 51 [use_Cython: True]: 成実論
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 52 [use_Cython: True]: 大智度論
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 53 [use_Cython: True]: 中論頌
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 54 [use_Cython: True]: 唯識論
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 55 [use_Cython: True]: 起信論
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 56 [use_Cython: True]: 摩訶止観
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 57 [use_Cython: True]: 法界次第
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 58 [use_Cython: True]: 禅源諸詮集
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 59 [use_Cython: True]: 景徳伝灯録
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 60 [use_Cython: True]: 小乗仏教
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 61 [use_Cython: True]: 大乗仏教
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 62 [use_Cython: True]: 金剛乗
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 63 [use_Cython: True]: 秘密仏教
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 64 [use_Cython: True]: 南都六宗
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 65 [use_Cython: True]: 三論宗
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 66 [use_Cython: True]: 成実宗
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 67 [use_Cython: True]: 俱舎宗
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 68 [use_Cython: True]: 法相宗
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 69 [use_Cython: True]: 律宗派
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 70 [use_Cython: True]: 時宗派
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 71 [use_Cython: True]: 融通念仏宗
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 72 [use_Cython: True]: 一遍上人
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 73 [use_Cython: True]: 親鸞聖人
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 74 [use_Cython: True]: 法然上人
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 75 [use_Cython: True]: 道元禅師
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 76 [use_Cython: True]: 栄西禅師
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 77 [use_Cython: True]: 空海大師
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 78 [use_Cython: True]: 最澄大師
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 79 [use_Cython: True]: 鑑真和上
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 80 [use_Cython: True]: 開眼供養
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 81 [use_Cython: True]: 入仏供養
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 82 [use_Cython: True]: 落慶法要
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 83 [use_Cython: True]: 授戒会
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 84 [use_Cython: True]: 結縁灌頂
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 85 [use_Cython: True]: 伝法灌頂
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 86 [use_Cython: True]: 護摩供養
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 87 [use_Cython: True]: 千体仏供養
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 88 [use_Cython: True]: 水子供養
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 89 [use_Cython: True]: 先祖供養
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 90 [use_Cython: True]: 施餓鬼会
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 91 [use_Cython: True]: 大施食会
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 92 [use_Cython: True]: 盆踊り
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 93 [use_Cython: True]: 精霊流し
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 94 [use_Cython: True]: 迎え火
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 95 [use_Cython: True]: 送り火
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 96 [use_Cython: True]: 棚経参り
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 97 [use_Cython: True]: お数珠
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 98 [use_Cython: True]: 線香供養
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 99 [use_Cython: True]: 献花供養
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 100 [use_Cython: True]: 五重塔
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 101 [use_Cython: True]: 三重塔
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 102 [use_Cython: True]: 多宝塔
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 103 [use_Cython: True]: 仏舎利塔
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 104 [use_Cython: True]: 観音堂
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 105 [use_Cython: True]: 薬師堂
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 106 [use_Cython: True]: 阿弥陀堂
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 107 [use_Cython: True]: 大雄宝殿
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 108 [use_Cython: True]: 法堂建築
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 109 [use_Cython: True]: 禅堂建築
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 110 [use_Cython: True]: 客殿建築
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 111 [use_Cython: True]: 庫裏建築
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 112 [use_Cython: True]: 山門建築
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 113 [use_Cython: True]: 鐘楼建築
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 114 [use_Cython: True]: 経蔵建築
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 115 [use_Cython: True]: 宝蔵建築
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 116 [use_Cython: True]: 石庭造園
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 117 [use_Cython: True]: 枯山水
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 118 [use_Cython: True]: 借景技法
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 119 [use_Cython: True]: 禅庭設計
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 120 [use_Cython: True]: 千手観音
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 121 [use_Cython: True]: 十一面観音
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 122 [use_Cython: True]: 馬頭観音
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 123 [use_Cython: True]: 如意輪観音
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 124 [use_Cython: True]: 准胝観音
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 125 [use_Cython: True]: 不空羂索観音
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 126 [use_Cython: True]: 聖観音菩薩
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 127 [use_Cython: True]: 勢至菩薩
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 128 [use_Cython: True]: 文殊菩薩
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 129 [use_Cython: True]: 普賢菩薩
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 130 [use_Cython: True]: 弥勒菩薩
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 131 [use_Cython: True]: 薬王菩薩
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 132 [use_Cython: True]: 薬上菩薩
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 133 [use_Cython: True]: 虚空蔵菩薩
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 134 [use_Cython: True]: 大勢至菩薩
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 135 [use_Cython: True]: 金剛界曼荼羅
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 136 [use_Cython: True]: 胎蔵界曼荼羅
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 137 [use_Cython: True]: 両部曼荼羅
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 138 [use_Cython: True]: 八葉蓮華
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 139 [use_Cython: True]: 宝相華文様
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 140 [use_Cython: True]: 出家得度
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 141 [use_Cython: True]: 在家信者
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 142 [use_Cython: True]: 優婆塞
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 143 [use_Cython: True]: 優婆夷
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 144 [use_Cython: True]: 沙弥僧
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 145 [use_Cython: True]: 沙弥尼
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 146 [use_Cython: True]: 比丘僧
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 147 [use_Cython: True]: 比丘尼
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 148 [use_Cython: True]: 阿闍梨
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 149 [use_Cython: True]: 三蔵法師
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 150 [use_Cython: True]: 律師職位
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 151 [use_Cython: True]: 禅師職位
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 152 [use_Cython: True]: 大僧正
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 153 [use_Cython: True]: 僧正職位
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 154 [use_Cython: True]: 権僧正
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 155 [use_Cython: True]: 少僧都
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 156 [use_Cython: True]: 権少僧都
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 157 [use_Cython: True]: 法印大和尚
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 158 [use_Cython: True]: 伝燈大阿闍梨
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 159 [use_Cython: True]: 権大僧都
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 160 [use_Cython: True]: 三論教学
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 161 [use_Cython: True]: 法相教学
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 162 [use_Cython: True]: 華厳教学
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 163 [use_Cython: True]: 天台教学
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 164 [use_Cython: True]: 真言教学
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 165 [use_Cython: True]: 浄土教学
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 166 [use_Cython: True]: 禅宗教学
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 167 [use_Cython: True]: 日蓮教学
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 168 [use_Cython: True]: 唯識思想
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 169 [use_Cython: True]: 如来蔵思想
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 170 [use_Cython: True]: 本覚思想
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 171 [use_Cython: True]: 末法思想
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 172 [use_Cython: True]: 易行道
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 173 [use_Cython: True]: 難行道
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 174 [use_Cython: True]: 聖道門
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 175 [use_Cython: True]: 浄土門
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 176 [use_Cython: True]: 権教方便
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 177 [use_Cython: True]: 実教真実
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 178 [use_Cython: True]: 五時八教
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 179 [use_Cython: True]: 化法四教
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 180 [use_Cython: True]: 降誕会法要
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 181 [use_Cython: True]: 成道会法要
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 182 [use_Cython: True]: 涅槃会法要
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 183 [use_Cython: True]: 春彼岸法要
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 184 [use_Cython: True]: 秋彼岸法要
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 185 [use_Cython: True]: 盂蘭盆会
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 186 [use_Cython: True]: 十夜法要
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 187 [use_Cython: True]: 修正会法要
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 188 [use_Cython: True]: 節分会法要
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 189 [use_Cython: True]: 灌仏会法要
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 190 [use_Cython: True]: 花祭り行事
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 191 [use_Cython: True]: 除夜の鐘
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 192 [use_Cython: True]: 初詣参拝
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 193 [use_Cython: True]: 初護摩法要
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 194 [use_Cython: True]: 開山忌法要
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 195 [use_Cython: True]: 両祖忌法要
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 196 [use_Cython: True]: 宗祖忌法要
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 197 [use_Cython: True]: 御会式法要
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 198 [use_Cython: True]: 報恩講法要
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...
# Processing word 199 [use_Cython: True]: 追悼法要式
# generating extended skippy 1-grams ...
# generating extended skippy 2-grams ...
# generating extended skippy 3-grams ...
# generating extended skippy 4-grams ...
# generating extended skippy 5-grams ...

# %%
df[columns1]
# Out:
#                        xsk1g  \
# 0              [阿…, …羅…, …漢]
# 1              [辟…, …支…, …仏]
# 2              [転…, …法…, …輪]
# 3         [十…, …二…, …因…, …縁]
# 4         [五…, …蘊…, …盛…, …苦]
# ..                       ...
# 195  [両…, …祖…, …忌…, …法…, …要]
# 196  [宗…, …祖…, …忌…, …法…, …要]
# 197  [御…, …会…, …式…, …法…, …要]
# 198  [報…, …恩…, …講…, …法…, …要]
# 199  [追…, …悼…, …法…, …要…, …式]
#
#                                                  xsk2g  \
# 0                         [阿羅…, 阿…漢, 阿…, …羅漢, …羅…, …漢]
# 1                         [辟支…, 辟…仏, 辟…, …支仏, …支…, …仏]
# 2                         [転法…, 転…輪, 転…, …法輪, …法…, …輪]
# 3    [十二…, 十…因…, 十…縁, 十…, …二因…, …二…縁, …二…, …因縁, …因…...
# 4    [五蘊…, 五…盛…, 五…苦, 五…, …蘊盛…, …蘊…苦, …蘊…, …盛苦, …盛…...
# ..                                                 ...
# 195  [両祖…, 両…忌…, 両…法…, 両…要, 両…, …祖忌…, …祖…法…, …祖…要, ...
# 196  [宗祖…, 宗…忌…, 宗…法…, 宗…要, 宗…, …祖忌…, …祖…法…, …祖…要, ...
# 197  [御会…, 御…式…, 御…法…, 御…要, 御…, …会式…, …会…法…, …会…要, ...
# 198  [報恩…, 報…講…, 報…法…, 報…要, 報…, …恩講…, …恩…法…, …恩…要, ...
# 199  [追悼…, 追…法…, 追…要…, 追…式, 追…, …悼法…, …悼…要…, …悼…式, ...
#
#                                                  xsk3g  \
# 0                    [阿羅漢, 阿羅…, 阿…漢, 阿…, …羅漢, …羅…, …漢]
# 1                    [辟支仏, 辟支…, 辟…仏, 辟…, …支仏, …支…, …仏]
# 2                    [転法輪, 転法…, 転…輪, 転…, …法輪, …法…, …輪]
# 3    [十二因…, 十二…縁, 十二…, 十…因縁, 十…因…, 十…縁, 十…, …二因縁, …...
# 4    [五蘊盛…, 五蘊…苦, 五蘊…, 五…盛苦, 五…盛…, 五…苦, 五…, …蘊盛苦, …...
# ..                                                 ...
# 195  [両祖忌…, 両祖…法…, 両祖…要, 両祖…, 両…忌法…, 両…忌…要, 両…忌…, 両...
# 196  [宗祖忌…, 宗祖…法…, 宗祖…要, 宗祖…, 宗…忌法…, 宗…忌…要, 宗…忌…, 宗...
# 197  [御会式…, 御会…法…, 御会…要, 御会…, 御…式法…, 御…式…要, 御…式…, 御...
# 198  [報恩講…, 報恩…法…, 報恩…要, 報恩…, 報…講法…, 報…講…要, 報…講…, 報...
# 199  [追悼法…, 追悼…要…, 追悼…式, 追悼…, 追…法要…, 追…法…式, 追…法…, 追...
#
#                                                  xsk4g  \
# 0                    [阿羅漢, 阿羅…, 阿…漢, 阿…, …羅漢, …羅…, …漢]
# 1                    [辟支仏, 辟支…, 辟…仏, 辟…, …支仏, …支…, …仏]
# 2                    [転法輪, 転法…, 転…輪, 転…, …法輪, …法…, …輪]
# 3    [十二因縁, 十二因…, 十二…縁, 十二…, 十…因縁, 十…因…, 十…縁, 十…, …...
# 4    [五蘊盛苦, 五蘊盛…, 五蘊…苦, 五蘊…, 五…盛苦, 五…盛…, 五…苦, 五…, …...
# ..                                                 ...
# 195  [両祖忌法…, 両祖忌…要, 両祖忌…, 両祖…法要, 両祖…法…, 両祖…要, 両祖…, ...
# 196  [宗祖忌法…, 宗祖忌…要, 宗祖忌…, 宗祖…法要, 宗祖…法…, 宗祖…要, 宗祖…, ...
# 197  [御会式法…, 御会式…要, 御会式…, 御会…法要, 御会…法…, 御会…要, 御会…, ...
# 198  [報恩講法…, 報恩講…要, 報恩講…, 報恩…法要, 報恩…法…, 報恩…要, 報恩…, ...
# 199  [追悼法要…, 追悼法…式, 追悼法…, 追悼…要式, 追悼…要…, 追悼…式, 追悼…, ...
#
#                                                  xsk5g
# 0                    [阿羅漢, 阿羅…, 阿…漢, 阿…, …羅漢, …羅…, …漢]
# 1                    [辟支仏, 辟支…, 辟…仏, 辟…, …支仏, …支…, …仏]
# 2                    [転法輪, 転法…, 転…輪, 転…, …法輪, …法…, …輪]
# 3    [十二因縁, 十二因…, 十二…縁, 十二…, 十…因縁, 十…因…, 十…縁, 十…, …...
# 4    [五蘊盛苦, 五蘊盛…, 五蘊…苦, 五蘊…, 五…盛苦, 五…盛…, 五…苦, 五…, …...
# ..                                                 ...
# 195  [両祖忌法要, 両祖忌法…, 両祖忌…要, 両祖忌…, 両祖…法要, 両祖…法…, 両祖…要...
# 196  [宗祖忌法要, 宗祖忌法…, 宗祖忌…要, 宗祖忌…, 宗祖…法要, 宗祖…法…, 宗祖…要...
# 197  [御会式法要, 御会式法…, 御会式…要, 御会式…, 御会…法要, 御会…法…, 御会…要...
# 198  [報恩講法要, 報恩講法…, 報恩講…要, 報恩講…, 報恩…法要, 報恩…法…, 報恩…要...
# 199  [追悼法要式, 追悼法要…, 追悼法…式, 追悼法…, 追悼…要式, 追悼…要…, 追悼…式...
#
# [200 rows x 5 columns]

# %%
## generate regular skippy n-grams
import re
for i, doc in enumerate(docs):
    print(f"Processing word {i} [use_Cython: {use_Cython}]: {doc}")
    word_segs = [ seg for seg in re.split(segmenter, doc) if len(seg) > 0 ]
    for j in range(1, max_n_for_ngram + 1):
        print(f"generating skippy {j}-grams ...")
        ngrams = gen_ngrams.gen_skippy_ngrams(word_segs, j, extended = skippy_means_extended, inclusive = ngram_is_inclusive, sep = sep_local, as_list = generated_as_list, check = False)
        if check:
            print(ngrams)
        ## update df
        df.loc[i, f'sk{j}g'] = ngrams
# Out:
# Processing word 0 [use_Cython: True]: 阿羅漢
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 1 [use_Cython: True]: 辟支仏
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 2 [use_Cython: True]: 転法輪
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 3 [use_Cython: True]: 十二因縁
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 4 [use_Cython: True]: 五蘊盛苦
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 5 [use_Cython: True]: 三法印
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 6 [use_Cython: True]: 四念処
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 7 [use_Cython: True]: 四神足
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 8 [use_Cython: True]: 五根五力
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 9 [use_Cython: True]: 七覚支
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 10 [use_Cython: True]: 三十七道品
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 11 [use_Cython: True]: 十善戒
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 12 [use_Cython: True]: 六神通
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 13 [use_Cython: True]: 四無量心
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 14 [use_Cython: True]: 慈悲喜捨
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 15 [use_Cython: True]: 八風不動
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 16 [use_Cython: True]: 不退転
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 17 [use_Cython: True]: 阿耨多羅三藐三菩提
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 18 [use_Cython: True]: 一切智
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 19 [use_Cython: True]: 無生法忍
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 20 [use_Cython: True]: 止観双修
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 21 [use_Cython: True]: 四禅定
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 22 [use_Cython: True]: 九次第定
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 23 [use_Cython: True]: 滅尽定
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 24 [use_Cython: True]: 無想定
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 25 [use_Cython: True]: 観呼吸
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 26 [use_Cython: True]: 観身不浄
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 27 [use_Cython: True]: 数息観
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 28 [use_Cython: True]: 白骨観
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 29 [use_Cython: True]: 不浄観
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 30 [use_Cython: True]: 慈心観
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 31 [use_Cython: True]: 因縁観
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 32 [use_Cython: True]: 念死観
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 33 [use_Cython: True]: 随念三宝
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 34 [use_Cython: True]: 経行禅
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 35 [use_Cython: True]: 立禅法
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 36 [use_Cython: True]: 食禅法
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 37 [use_Cython: True]: 作務禅
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 38 [use_Cython: True]: 公案禅
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 39 [use_Cython: True]: 只管打坐
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 40 [use_Cython: True]: 阿含経
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 41 [use_Cython: True]: 大般涅槃経
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 42 [use_Cython: True]: 大日経
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 43 [use_Cython: True]: 金剛頂経
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 44 [use_Cython: True]: 理趣経
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 45 [use_Cython: True]: 観音経
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 46 [use_Cython: True]: 地蔵経
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 47 [use_Cython: True]: 薬師経
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 48 [use_Cython: True]: 無量寿経
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 49 [use_Cython: True]: 観無量寿経
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 50 [use_Cython: True]: 倶舎論
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 51 [use_Cython: True]: 成実論
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 52 [use_Cython: True]: 大智度論
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 53 [use_Cython: True]: 中論頌
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 54 [use_Cython: True]: 唯識論
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 55 [use_Cython: True]: 起信論
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 56 [use_Cython: True]: 摩訶止観
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 57 [use_Cython: True]: 法界次第
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 58 [use_Cython: True]: 禅源諸詮集
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 59 [use_Cython: True]: 景徳伝灯録
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 60 [use_Cython: True]: 小乗仏教
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 61 [use_Cython: True]: 大乗仏教
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 62 [use_Cython: True]: 金剛乗
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 63 [use_Cython: True]: 秘密仏教
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 64 [use_Cython: True]: 南都六宗
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 65 [use_Cython: True]: 三論宗
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 66 [use_Cython: True]: 成実宗
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 67 [use_Cython: True]: 俱舎宗
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 68 [use_Cython: True]: 法相宗
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 69 [use_Cython: True]: 律宗派
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 70 [use_Cython: True]: 時宗派
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 71 [use_Cython: True]: 融通念仏宗
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 72 [use_Cython: True]: 一遍上人
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 73 [use_Cython: True]: 親鸞聖人
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 74 [use_Cython: True]: 法然上人
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 75 [use_Cython: True]: 道元禅師
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 76 [use_Cython: True]: 栄西禅師
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 77 [use_Cython: True]: 空海大師
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 78 [use_Cython: True]: 最澄大師
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 79 [use_Cython: True]: 鑑真和上
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 80 [use_Cython: True]: 開眼供養
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 81 [use_Cython: True]: 入仏供養
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 82 [use_Cython: True]: 落慶法要
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 83 [use_Cython: True]: 授戒会
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 84 [use_Cython: True]: 結縁灌頂
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 85 [use_Cython: True]: 伝法灌頂
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 86 [use_Cython: True]: 護摩供養
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 87 [use_Cython: True]: 千体仏供養
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 88 [use_Cython: True]: 水子供養
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 89 [use_Cython: True]: 先祖供養
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 90 [use_Cython: True]: 施餓鬼会
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 91 [use_Cython: True]: 大施食会
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 92 [use_Cython: True]: 盆踊り
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 93 [use_Cython: True]: 精霊流し
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 94 [use_Cython: True]: 迎え火
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 95 [use_Cython: True]: 送り火
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 96 [use_Cython: True]: 棚経参り
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 97 [use_Cython: True]: お数珠
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 98 [use_Cython: True]: 線香供養
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 99 [use_Cython: True]: 献花供養
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 100 [use_Cython: True]: 五重塔
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 101 [use_Cython: True]: 三重塔
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 102 [use_Cython: True]: 多宝塔
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 103 [use_Cython: True]: 仏舎利塔
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 104 [use_Cython: True]: 観音堂
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 105 [use_Cython: True]: 薬師堂
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 106 [use_Cython: True]: 阿弥陀堂
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 107 [use_Cython: True]: 大雄宝殿
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 108 [use_Cython: True]: 法堂建築
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 109 [use_Cython: True]: 禅堂建築
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 110 [use_Cython: True]: 客殿建築
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 111 [use_Cython: True]: 庫裏建築
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 112 [use_Cython: True]: 山門建築
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 113 [use_Cython: True]: 鐘楼建築
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 114 [use_Cython: True]: 経蔵建築
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 115 [use_Cython: True]: 宝蔵建築
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 116 [use_Cython: True]: 石庭造園
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 117 [use_Cython: True]: 枯山水
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 118 [use_Cython: True]: 借景技法
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 119 [use_Cython: True]: 禅庭設計
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 120 [use_Cython: True]: 千手観音
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 121 [use_Cython: True]: 十一面観音
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 122 [use_Cython: True]: 馬頭観音
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 123 [use_Cython: True]: 如意輪観音
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 124 [use_Cython: True]: 准胝観音
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 125 [use_Cython: True]: 不空羂索観音
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 126 [use_Cython: True]: 聖観音菩薩
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 127 [use_Cython: True]: 勢至菩薩
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 128 [use_Cython: True]: 文殊菩薩
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 129 [use_Cython: True]: 普賢菩薩
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 130 [use_Cython: True]: 弥勒菩薩
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 131 [use_Cython: True]: 薬王菩薩
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 132 [use_Cython: True]: 薬上菩薩
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 133 [use_Cython: True]: 虚空蔵菩薩
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 134 [use_Cython: True]: 大勢至菩薩
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 135 [use_Cython: True]: 金剛界曼荼羅
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 136 [use_Cython: True]: 胎蔵界曼荼羅
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 137 [use_Cython: True]: 両部曼荼羅
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 138 [use_Cython: True]: 八葉蓮華
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 139 [use_Cython: True]: 宝相華文様
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 140 [use_Cython: True]: 出家得度
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 141 [use_Cython: True]: 在家信者
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 142 [use_Cython: True]: 優婆塞
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 143 [use_Cython: True]: 優婆夷
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 144 [use_Cython: True]: 沙弥僧
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 145 [use_Cython: True]: 沙弥尼
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 146 [use_Cython: True]: 比丘僧
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 147 [use_Cython: True]: 比丘尼
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 148 [use_Cython: True]: 阿闍梨
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 149 [use_Cython: True]: 三蔵法師
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 150 [use_Cython: True]: 律師職位
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 151 [use_Cython: True]: 禅師職位
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 152 [use_Cython: True]: 大僧正
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 153 [use_Cython: True]: 僧正職位
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 154 [use_Cython: True]: 権僧正
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 155 [use_Cython: True]: 少僧都
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 156 [use_Cython: True]: 権少僧都
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 157 [use_Cython: True]: 法印大和尚
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 158 [use_Cython: True]: 伝燈大阿闍梨
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 159 [use_Cython: True]: 権大僧都
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 160 [use_Cython: True]: 三論教学
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 161 [use_Cython: True]: 法相教学
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 162 [use_Cython: True]: 華厳教学
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 163 [use_Cython: True]: 天台教学
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 164 [use_Cython: True]: 真言教学
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 165 [use_Cython: True]: 浄土教学
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 166 [use_Cython: True]: 禅宗教学
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 167 [use_Cython: True]: 日蓮教学
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 168 [use_Cython: True]: 唯識思想
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 169 [use_Cython: True]: 如来蔵思想
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 170 [use_Cython: True]: 本覚思想
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 171 [use_Cython: True]: 末法思想
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 172 [use_Cython: True]: 易行道
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 173 [use_Cython: True]: 難行道
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 174 [use_Cython: True]: 聖道門
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 175 [use_Cython: True]: 浄土門
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 176 [use_Cython: True]: 権教方便
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 177 [use_Cython: True]: 実教真実
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 178 [use_Cython: True]: 五時八教
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 179 [use_Cython: True]: 化法四教
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 180 [use_Cython: True]: 降誕会法要
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 181 [use_Cython: True]: 成道会法要
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 182 [use_Cython: True]: 涅槃会法要
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 183 [use_Cython: True]: 春彼岸法要
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 184 [use_Cython: True]: 秋彼岸法要
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 185 [use_Cython: True]: 盂蘭盆会
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 186 [use_Cython: True]: 十夜法要
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 187 [use_Cython: True]: 修正会法要
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 188 [use_Cython: True]: 節分会法要
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 189 [use_Cython: True]: 灌仏会法要
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 190 [use_Cython: True]: 花祭り行事
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 191 [use_Cython: True]: 除夜の鐘
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 192 [use_Cython: True]: 初詣参拝
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 193 [use_Cython: True]: 初護摩法要
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 194 [use_Cython: True]: 開山忌法要
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 195 [use_Cython: True]: 両祖忌法要
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 196 [use_Cython: True]: 宗祖忌法要
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 197 [use_Cython: True]: 御会式法要
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 198 [use_Cython: True]: 報恩講法要
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...
# Processing word 199 [use_Cython: True]: 追悼法要式
# generating skippy 1-grams ...
# generating skippy 2-grams ...
# generating skippy 3-grams ...
# generating skippy 4-grams ...
# generating skippy 5-grams ...

# %%
df[columns2]
# Out:
#                         sk1g  \
# 0              [阿…, …羅…, …漢]
# 1              [辟…, …支…, …仏]
# 2              [転…, …法…, …輪]
# 3         [十…, …二…, …因…, …縁]
# 4         [五…, …蘊…, …盛…, …苦]
# ..                       ...
# 195  [両…, …祖…, …忌…, …法…, …要]
# 196  [宗…, …祖…, …忌…, …法…, …要]
# 197  [御…, …会…, …式…, …法…, …要]
# 198  [報…, …恩…, …講…, …法…, …要]
# 199  [追…, …悼…, …法…, …要…, …式]
#
#                                                   sk2g  \
# 0                         [阿羅…, 阿…漢, 阿…, …羅漢, …羅…, …漢]
# 1                         [辟支…, 辟…仏, 辟…, …支仏, …支…, …仏]
# 2                         [転法…, 転…輪, 転…, …法輪, …法…, …輪]
# 3    [十二…, 十…因…, 十…縁, 十…, …二因…, …二…縁, …二…, …因縁, …因…...
# 4    [五蘊…, 五…盛…, 五…苦, 五…, …蘊盛…, …蘊…苦, …蘊…, …盛苦, …盛…...
# ..                                                 ...
# 195  [両祖…, 両…忌…, 両…法…, 両…要, 両…, …祖忌…, …祖…法…, …祖…要, ...
# 196  [宗祖…, 宗…忌…, 宗…法…, 宗…要, 宗…, …祖忌…, …祖…法…, …祖…要, ...
# 197  [御会…, 御…式…, 御…法…, 御…要, 御…, …会式…, …会…法…, …会…要, ...
# 198  [報恩…, 報…講…, 報…法…, 報…要, 報…, …恩講…, …恩…法…, …恩…要, ...
# 199  [追悼…, 追…法…, 追…要…, 追…式, 追…, …悼法…, …悼…要…, …悼…式, ...
#
#                                                   sk3g  \
# 0                    [阿羅漢, 阿羅…, 阿…漢, 阿…, …羅漢, …羅…, …漢]
# 1                    [辟支仏, 辟支…, 辟…仏, 辟…, …支仏, …支…, …仏]
# 2                    [転法輪, 転法…, 転…輪, 転…, …法輪, …法…, …輪]
# 3    [十二因…, 十二…縁, 十二…, 十…因縁, 十…因…, 十…縁, 十…, …二因縁, …...
# 4    [五蘊盛…, 五蘊…苦, 五蘊…, 五…盛苦, 五…盛…, 五…苦, 五…, …蘊盛苦, …...
# ..                                                 ...
# 195  [両祖忌…, 両祖…法…, 両祖…要, 両祖…, 両…忌法…, 両…忌…要, 両…忌…, 両...
# 196  [宗祖忌…, 宗祖…法…, 宗祖…要, 宗祖…, 宗…忌法…, 宗…忌…要, 宗…忌…, 宗...
# 197  [御会式…, 御会…法…, 御会…要, 御会…, 御…式法…, 御…式…要, 御…式…, 御...
# 198  [報恩講…, 報恩…法…, 報恩…要, 報恩…, 報…講法…, 報…講…要, 報…講…, 報...
# 199  [追悼法…, 追悼…要…, 追悼…式, 追悼…, 追…法要…, 追…法…式, 追…法…, 追...
#
#                                                   sk4g  \
# 0                    [阿羅漢, 阿羅…, 阿…漢, 阿…, …羅漢, …羅…, …漢]
# 1                    [辟支仏, 辟支…, 辟…仏, 辟…, …支仏, …支…, …仏]
# 2                    [転法輪, 転法…, 転…輪, 転…, …法輪, …法…, …輪]
# 3    [十二因縁, 十二因…, 十二…縁, 十二…, 十…因縁, 十…因…, 十…縁, 十…, …...
# 4    [五蘊盛苦, 五蘊盛…, 五蘊…苦, 五蘊…, 五…盛苦, 五…盛…, 五…苦, 五…, …...
# ..                                                 ...
# 195  [両祖忌法…, 両祖忌…要, 両祖忌…, 両祖…法要, 両祖…法…, 両祖…要, 両祖…, ...
# 196  [宗祖忌法…, 宗祖忌…要, 宗祖忌…, 宗祖…法要, 宗祖…法…, 宗祖…要, 宗祖…, ...
# 197  [御会式法…, 御会式…要, 御会式…, 御会…法要, 御会…法…, 御会…要, 御会…, ...
# 198  [報恩講法…, 報恩講…要, 報恩講…, 報恩…法要, 報恩…法…, 報恩…要, 報恩…, ...
# 199  [追悼法要…, 追悼法…式, 追悼法…, 追悼…要式, 追悼…要…, 追悼…式, 追悼…, ...
#
#                                                   sk5g
# 0                    [阿羅漢, 阿羅…, 阿…漢, 阿…, …羅漢, …羅…, …漢]
# 1                    [辟支仏, 辟支…, 辟…仏, 辟…, …支仏, …支…, …仏]
# 2                    [転法輪, 転法…, 転…輪, 転…, …法輪, …法…, …輪]
# 3    [十二因縁, 十二因…, 十二…縁, 十二…, 十…因縁, 十…因…, 十…縁, 十…, …...
# 4    [五蘊盛苦, 五蘊盛…, 五蘊…苦, 五蘊…, 五…盛苦, 五…盛…, 五…苦, 五…, …...
# ..                                                 ...
# 195  [両祖忌法要, 両祖忌法…, 両祖忌…要, 両祖忌…, 両祖…法要, 両祖…法…, 両祖…要...
# 196  [宗祖忌法要, 宗祖忌法…, 宗祖忌…要, 宗祖忌…, 宗祖…法要, 宗祖…法…, 宗祖…要...
# 197  [御会式法要, 御会式法…, 御会式…要, 御会式…, 御会…法要, 御会…法…, 御会…要...
# 198  [報恩講法要, 報恩講法…, 報恩講…要, 報恩講…, 報恩…法要, 報恩…法…, 報恩…要...
# 199  [追悼法要式, 追悼法要…, 追悼法…式, 追悼法…, 追悼…要式, 追悼…要…, 追悼…式...
#
# [200 rows x 5 columns]

# %%
## generate non-skippy n-grams
import re
for i, doc in enumerate(docs):
    ## update df for word
    df.loc[i,'doc'] = doc
    ##
    print(f"Processing word {i} [use_Cython: {use_Cython}]: {doc}")
    word_segs = [ x for x in re.split(segmenter, doc) if len(x) > 0 ]
    for j in range(1, max_n_for_ngram + 1):
        print(f"generating {j}-grams ...")
        ngrams = gen_ngrams.gen_ngrams(word_segs, j, inclusive = ngram_is_inclusive, sep = sep_local, as_list = generated_as_list, check = False)
        if check:
            print(ngrams)
        ## update df
        df.loc[i, f'{j}g'] = ngrams
# Out:
# Processing word 0 [use_Cython: True]: 阿羅漢
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 1 [use_Cython: True]: 辟支仏
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 2 [use_Cython: True]: 転法輪
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 3 [use_Cython: True]: 十二因縁
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 4 [use_Cython: True]: 五蘊盛苦
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 5 [use_Cython: True]: 三法印
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 6 [use_Cython: True]: 四念処
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 7 [use_Cython: True]: 四神足
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 8 [use_Cython: True]: 五根五力
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 9 [use_Cython: True]: 七覚支
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 10 [use_Cython: True]: 三十七道品
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 11 [use_Cython: True]: 十善戒
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 12 [use_Cython: True]: 六神通
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 13 [use_Cython: True]: 四無量心
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 14 [use_Cython: True]: 慈悲喜捨
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 15 [use_Cython: True]: 八風不動
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 16 [use_Cython: True]: 不退転
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 17 [use_Cython: True]: 阿耨多羅三藐三菩提
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 18 [use_Cython: True]: 一切智
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 19 [use_Cython: True]: 無生法忍
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 20 [use_Cython: True]: 止観双修
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 21 [use_Cython: True]: 四禅定
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 22 [use_Cython: True]: 九次第定
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 23 [use_Cython: True]: 滅尽定
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 24 [use_Cython: True]: 無想定
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 25 [use_Cython: True]: 観呼吸
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 26 [use_Cython: True]: 観身不浄
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 27 [use_Cython: True]: 数息観
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 28 [use_Cython: True]: 白骨観
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 29 [use_Cython: True]: 不浄観
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 30 [use_Cython: True]: 慈心観
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 31 [use_Cython: True]: 因縁観
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 32 [use_Cython: True]: 念死観
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 33 [use_Cython: True]: 随念三宝
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 34 [use_Cython: True]: 経行禅
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 35 [use_Cython: True]: 立禅法
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 36 [use_Cython: True]: 食禅法
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 37 [use_Cython: True]: 作務禅
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 38 [use_Cython: True]: 公案禅
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 39 [use_Cython: True]: 只管打坐
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 40 [use_Cython: True]: 阿含経
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 41 [use_Cython: True]: 大般涅槃経
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 42 [use_Cython: True]: 大日経
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 43 [use_Cython: True]: 金剛頂経
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 44 [use_Cython: True]: 理趣経
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 45 [use_Cython: True]: 観音経
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 46 [use_Cython: True]: 地蔵経
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 47 [use_Cython: True]: 薬師経
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 48 [use_Cython: True]: 無量寿経
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 49 [use_Cython: True]: 観無量寿経
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 50 [use_Cython: True]: 倶舎論
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 51 [use_Cython: True]: 成実論
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 52 [use_Cython: True]: 大智度論
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 53 [use_Cython: True]: 中論頌
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 54 [use_Cython: True]: 唯識論
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 55 [use_Cython: True]: 起信論
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 56 [use_Cython: True]: 摩訶止観
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 57 [use_Cython: True]: 法界次第
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 58 [use_Cython: True]: 禅源諸詮集
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 59 [use_Cython: True]: 景徳伝灯録
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 60 [use_Cython: True]: 小乗仏教
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 61 [use_Cython: True]: 大乗仏教
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 62 [use_Cython: True]: 金剛乗
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 63 [use_Cython: True]: 秘密仏教
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 64 [use_Cython: True]: 南都六宗
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 65 [use_Cython: True]: 三論宗
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 66 [use_Cython: True]: 成実宗
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 67 [use_Cython: True]: 俱舎宗
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 68 [use_Cython: True]: 法相宗
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 69 [use_Cython: True]: 律宗派
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 70 [use_Cython: True]: 時宗派
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 71 [use_Cython: True]: 融通念仏宗
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 72 [use_Cython: True]: 一遍上人
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 73 [use_Cython: True]: 親鸞聖人
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 74 [use_Cython: True]: 法然上人
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 75 [use_Cython: True]: 道元禅師
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 76 [use_Cython: True]: 栄西禅師
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 77 [use_Cython: True]: 空海大師
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 78 [use_Cython: True]: 最澄大師
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 79 [use_Cython: True]: 鑑真和上
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 80 [use_Cython: True]: 開眼供養
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 81 [use_Cython: True]: 入仏供養
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 82 [use_Cython: True]: 落慶法要
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 83 [use_Cython: True]: 授戒会
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 84 [use_Cython: True]: 結縁灌頂
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 85 [use_Cython: True]: 伝法灌頂
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 86 [use_Cython: True]: 護摩供養
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 87 [use_Cython: True]: 千体仏供養
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 88 [use_Cython: True]: 水子供養
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 89 [use_Cython: True]: 先祖供養
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 90 [use_Cython: True]: 施餓鬼会
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 91 [use_Cython: True]: 大施食会
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 92 [use_Cython: True]: 盆踊り
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 93 [use_Cython: True]: 精霊流し
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 94 [use_Cython: True]: 迎え火
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 95 [use_Cython: True]: 送り火
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 96 [use_Cython: True]: 棚経参り
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 97 [use_Cython: True]: お数珠
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 98 [use_Cython: True]: 線香供養
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 99 [use_Cython: True]: 献花供養
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 100 [use_Cython: True]: 五重塔
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 101 [use_Cython: True]: 三重塔
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 102 [use_Cython: True]: 多宝塔
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 103 [use_Cython: True]: 仏舎利塔
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 104 [use_Cython: True]: 観音堂
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 105 [use_Cython: True]: 薬師堂
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 106 [use_Cython: True]: 阿弥陀堂
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 107 [use_Cython: True]: 大雄宝殿
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 108 [use_Cython: True]: 法堂建築
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 109 [use_Cython: True]: 禅堂建築
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 110 [use_Cython: True]: 客殿建築
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 111 [use_Cython: True]: 庫裏建築
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 112 [use_Cython: True]: 山門建築
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 113 [use_Cython: True]: 鐘楼建築
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 114 [use_Cython: True]: 経蔵建築
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 115 [use_Cython: True]: 宝蔵建築
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 116 [use_Cython: True]: 石庭造園
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 117 [use_Cython: True]: 枯山水
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 118 [use_Cython: True]: 借景技法
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 119 [use_Cython: True]: 禅庭設計
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 120 [use_Cython: True]: 千手観音
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 121 [use_Cython: True]: 十一面観音
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 122 [use_Cython: True]: 馬頭観音
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 123 [use_Cython: True]: 如意輪観音
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 124 [use_Cython: True]: 准胝観音
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 125 [use_Cython: True]: 不空羂索観音
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 126 [use_Cython: True]: 聖観音菩薩
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 127 [use_Cython: True]: 勢至菩薩
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 128 [use_Cython: True]: 文殊菩薩
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 129 [use_Cython: True]: 普賢菩薩
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 130 [use_Cython: True]: 弥勒菩薩
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 131 [use_Cython: True]: 薬王菩薩
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 132 [use_Cython: True]: 薬上菩薩
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 133 [use_Cython: True]: 虚空蔵菩薩
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 134 [use_Cython: True]: 大勢至菩薩
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 135 [use_Cython: True]: 金剛界曼荼羅
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 136 [use_Cython: True]: 胎蔵界曼荼羅
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 137 [use_Cython: True]: 両部曼荼羅
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 138 [use_Cython: True]: 八葉蓮華
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 139 [use_Cython: True]: 宝相華文様
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 140 [use_Cython: True]: 出家得度
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 141 [use_Cython: True]: 在家信者
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 142 [use_Cython: True]: 優婆塞
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 143 [use_Cython: True]: 優婆夷
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 144 [use_Cython: True]: 沙弥僧
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 145 [use_Cython: True]: 沙弥尼
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 146 [use_Cython: True]: 比丘僧
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 147 [use_Cython: True]: 比丘尼
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 148 [use_Cython: True]: 阿闍梨
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 149 [use_Cython: True]: 三蔵法師
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 150 [use_Cython: True]: 律師職位
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 151 [use_Cython: True]: 禅師職位
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 152 [use_Cython: True]: 大僧正
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 153 [use_Cython: True]: 僧正職位
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 154 [use_Cython: True]: 権僧正
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 155 [use_Cython: True]: 少僧都
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 156 [use_Cython: True]: 権少僧都
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 157 [use_Cython: True]: 法印大和尚
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 158 [use_Cython: True]: 伝燈大阿闍梨
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 159 [use_Cython: True]: 権大僧都
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 160 [use_Cython: True]: 三論教学
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 161 [use_Cython: True]: 法相教学
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 162 [use_Cython: True]: 華厳教学
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 163 [use_Cython: True]: 天台教学
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 164 [use_Cython: True]: 真言教学
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 165 [use_Cython: True]: 浄土教学
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 166 [use_Cython: True]: 禅宗教学
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 167 [use_Cython: True]: 日蓮教学
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 168 [use_Cython: True]: 唯識思想
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 169 [use_Cython: True]: 如来蔵思想
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 170 [use_Cython: True]: 本覚思想
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 171 [use_Cython: True]: 末法思想
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 172 [use_Cython: True]: 易行道
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 173 [use_Cython: True]: 難行道
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 174 [use_Cython: True]: 聖道門
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 175 [use_Cython: True]: 浄土門
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 176 [use_Cython: True]: 権教方便
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 177 [use_Cython: True]: 実教真実
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 178 [use_Cython: True]: 五時八教
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 179 [use_Cython: True]: 化法四教
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 180 [use_Cython: True]: 降誕会法要
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 181 [use_Cython: True]: 成道会法要
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 182 [use_Cython: True]: 涅槃会法要
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 183 [use_Cython: True]: 春彼岸法要
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 184 [use_Cython: True]: 秋彼岸法要
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 185 [use_Cython: True]: 盂蘭盆会
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 186 [use_Cython: True]: 十夜法要
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 187 [use_Cython: True]: 修正会法要
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 188 [use_Cython: True]: 節分会法要
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 189 [use_Cython: True]: 灌仏会法要
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 190 [use_Cython: True]: 花祭り行事
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 191 [use_Cython: True]: 除夜の鐘
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 192 [use_Cython: True]: 初詣参拝
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 193 [use_Cython: True]: 初護摩法要
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 194 [use_Cython: True]: 開山忌法要
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 195 [use_Cython: True]: 両祖忌法要
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 196 [use_Cython: True]: 宗祖忌法要
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 197 [use_Cython: True]: 御会式法要
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 198 [use_Cython: True]: 報恩講法要
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...
# Processing word 199 [use_Cython: True]: 追悼法要式
# generating 1-grams ...
# generating 2-grams ...
# generating 3-grams ...
# generating 4-grams ...
# generating 5-grams ...

# %%
df[columns3]
# Out:
#                   1g                               2g  \
# 0          [阿, 羅, 漢]                [阿, 羅, 漢, 阿羅, 羅漢]
# 1          [辟, 支, 仏]                [辟, 支, 仏, 辟支, 支仏]
# 2          [転, 法, 輪]                [転, 法, 輪, 転法, 法輪]
# 3       [十, 二, 因, 縁]         [十, 二, 因, 縁, 十二, 二因, 因縁]
# 4       [五, 蘊, 盛, 苦]         [五, 蘊, 盛, 苦, 五蘊, 蘊盛, 盛苦]
# ..               ...                              ...
# 195  [両, 祖, 忌, 法, 要]  [両, 祖, 忌, 法, 要, 両祖, 祖忌, 忌法, 法要]
# 196  [宗, 祖, 忌, 法, 要]  [宗, 祖, 忌, 法, 要, 宗祖, 祖忌, 忌法, 法要]
# 197  [御, 会, 式, 法, 要]  [御, 会, 式, 法, 要, 御会, 会式, 式法, 法要]
# 198  [報, 恩, 講, 法, 要]  [報, 恩, 講, 法, 要, 報恩, 恩講, 講法, 法要]
# 199  [追, 悼, 法, 要, 式]  [追, 悼, 法, 要, 式, 追悼, 悼法, 法要, 要式]
#
#                                                  3g  \
# 0                            [阿, 羅, 漢, 阿羅, 羅漢, 阿羅漢]
# 1                            [辟, 支, 仏, 辟支, 支仏, 辟支仏]
# 2                            [転, 法, 輪, 転法, 法輪, 転法輪]
# 3                [十, 二, 因, 縁, 十二, 二因, 因縁, 十二因, 二因縁]
# 4                [五, 蘊, 盛, 苦, 五蘊, 蘊盛, 盛苦, 五蘊盛, 蘊盛苦]
# ..                                              ...
# 195  [両, 祖, 忌, 法, 要, 両祖, 祖忌, 忌法, 法要, 両祖忌, 祖忌法, 忌法要]
# 196  [宗, 祖, 忌, 法, 要, 宗祖, 祖忌, 忌法, 法要, 宗祖忌, 祖忌法, 忌法要]
# 197  [御, 会, 式, 法, 要, 御会, 会式, 式法, 法要, 御会式, 会式法, 式法要]
# 198  [報, 恩, 講, 法, 要, 報恩, 恩講, 講法, 法要, 報恩講, 恩講法, 講法要]
# 199  [追, 悼, 法, 要, 式, 追悼, 悼法, 法要, 要式, 追悼法, 悼法要, 法要式]
#
#                                                     4g  \
# 0                               [阿, 羅, 漢, 阿羅, 羅漢, 阿羅漢]
# 1                               [辟, 支, 仏, 辟支, 支仏, 辟支仏]
# 2                               [転, 法, 輪, 転法, 法輪, 転法輪]
# 3             [十, 二, 因, 縁, 十二, 二因, 因縁, 十二因, 二因縁, 十二因縁]
# 4             [五, 蘊, 盛, 苦, 五蘊, 蘊盛, 盛苦, 五蘊盛, 蘊盛苦, 五蘊盛苦]
# ..                                                 ...
# 195  [両, 祖, 忌, 法, 要, 両祖, 祖忌, 忌法, 法要, 両祖忌, 祖忌法, 忌法要,...
# 196  [宗, 祖, 忌, 法, 要, 宗祖, 祖忌, 忌法, 法要, 宗祖忌, 祖忌法, 忌法要,...
# 197  [御, 会, 式, 法, 要, 御会, 会式, 式法, 法要, 御会式, 会式法, 式法要,...
# 198  [報, 恩, 講, 法, 要, 報恩, 恩講, 講法, 法要, 報恩講, 恩講法, 講法要,...
# 199  [追, 悼, 法, 要, 式, 追悼, 悼法, 法要, 要式, 追悼法, 悼法要, 法要式,...
#
#                                                     5g
# 0                               [阿, 羅, 漢, 阿羅, 羅漢, 阿羅漢]
# 1                               [辟, 支, 仏, 辟支, 支仏, 辟支仏]
# 2                               [転, 法, 輪, 転法, 法輪, 転法輪]
# 3             [十, 二, 因, 縁, 十二, 二因, 因縁, 十二因, 二因縁, 十二因縁]
# 4             [五, 蘊, 盛, 苦, 五蘊, 蘊盛, 盛苦, 五蘊盛, 蘊盛苦, 五蘊盛苦]
# ..                                                 ...
# 195  [両, 祖, 忌, 法, 要, 両祖, 祖忌, 忌法, 法要, 両祖忌, 祖忌法, 忌法要,...
# 196  [宗, 祖, 忌, 法, 要, 宗祖, 祖忌, 忌法, 法要, 宗祖忌, 祖忌法, 忌法要,...
# 197  [御, 会, 式, 法, 要, 御会, 会式, 式法, 法要, 御会式, 会式法, 式法要,...
# 198  [報, 恩, 講, 法, 要, 報恩, 恩講, 講法, 法要, 報恩講, 恩講法, 講法要,...
# 199  [追, 悼, 法, 要, 式, 追悼, 悼法, 法要, 要式, 追悼法, 悼法要, 法要式,...
#
# [200 rows x 5 columns]

# %% [markdown]
# ## 結果の保存

# %%
if save_results:
    file_name = f"{save_dir}/{source_name}-reg-sk-xsk-df.csv"
    df.to_csv(file_name, header = True)

# %% [markdown]
# # end of file
